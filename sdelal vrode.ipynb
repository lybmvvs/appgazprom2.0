# %%
import pandas as pd
import statistics
import copy
import datetime

# %%
grp_dad = pd.read_excel('фраклист1.xlsx',header=[1], index_col=[1])
grp_dad
# Out:
#                                  Unnamed: 0       Дата    Подрядчик  \
# Номер скважины
# 974             Проблемы при построении ГРП 2018-07-28          МКМ
# 974             Проблемы при построении ГРП 2012-06-15          МКН
# 974                                     NaN 2007-01-06          МКН
# 827             Проблемы при построении ГРП 2019-05-13          МКМ
# 827             Проблемы при построении ГРП 2015-05-31  МекамиНефть
# ...                                     ...        ...          ...
# 101             Проблемы при построении ГРП 2015-04-21          ТВС
# 101             Проблемы при построении ГРП 2015-04-20          ТВС
# 101             Проблемы при построении ГРП 2006-02-06          МКН
# 1003            Проблемы при построении ГРП 2017-06-26          МКМ
# 1003            Проблемы при построении ГРП 2008-05-31          МКН
#
#                                                       Комментарии Страница  \
# Номер скважины
# 974             ГРП по плану 100т(+).Выполнена стадия Замещени...      -1_
# 974             По миниГРП : принято решение  уменьшить буфер ...      -1_
# 974             30.12-"стоп" на миниГРП. По результату Мини-ГР...      -1_
# 827             ГРП по плану 6т(+).  Выполнена стадия Замещени...      -1_
# 827                                                           327      -1_
# ...                                                           ...      ...
# 101                                                           327      -1_
# 101                                                           327      -1_
# 101             По результату Мини-ГРП увеличена подушка до 30...      -1_
# 1003            ГРП по плану (+),  После проведения и анализа ...      -1_
# 1003                          Увеличили подушку до 9м3 (план 7м3)      -1_
#
#                 Unnamed: 6   Пласт  Наклон  Азимут      k  ...  \
# Номер скважины                                             ...
# 974                    NaN  Б19-22    3.00   104.0   0.59  ...
# 974                    NaN      Ю1    4.25   102.0   4.90  ...
# 974                    NaN  Б19-22    2.00   217.0   0.50  ...
# 827                    NaN   А1(3)   12.00   317.0   2.00  ...
# 827                    NaN      Ю1   88.70   342.2   7.76  ...
# ...                    ...     ...     ...     ...    ...  ...
# 101                    NaN      Ю1   90.00   173.0   1.20  ...
# 101                    NaN      Ю1   91.00   169.0   1.20  ...
# 101                    NaN      А2    8.20   129.0  20.00  ...
# 1003                   NaN  Б19-22    2.00   330.0   1.00  ...
# 1003                   NaN   А1(3)    1.65   292.0  19.70  ...
#
#                                                 Проппант  Рпл Хорнер   Эфф  \
# Номер скважины
# 974                                  20/40 For+16/20 Bor        56.0  65.0
# 974                                                  NaN       220.0  70.0
# 974                                                  NaN       315.0  69.0
# 827                                            20/40 For        27.0  75.0
# 827                                 20/40 БКО +16/20 БКО         NaN  75.0
# ...                                                  ...         ...   ...
# 101                                20/40Carbo+16/20Carbo         NaN  80.0
# 101                                20/40Carbo+16/20Carbo         NaN  78.0
# 101                                                  NaN       152.0  40.0
# 1003            20/40 Bor+16/30 Nika+12/18 Nika 12/18 Fo        46.6  77.0
# 1003                                                 NaN       227.0  43.0
#
#                 Расход    Конц  Гель   М бр  V под  V без под  V гель
# Номер скважины
# 974                3.4     NaN   NaN  51.70   50.0      417.1     NaN
# 974                3.4  1200.0   NaN    NaN   16.0      129.4     NaN
# 974                NaN  1000.0   NaN    NaN  180.0      436.6     NaN
# 827                2.6  1000.0   NaN   8.41    6.0        NaN    23.0
# 827                3.4   900.0   NaN  70.00    9.0       74.0     NaN
# ...                ...     ...   ...    ...    ...        ...     ...
# 101                3.2   900.0   NaN  25.50   16.0       97.9     NaN
# 101                3.2   800.0   NaN  26.50   16.0      130.1     NaN
# 101                NaN   850.0   NaN    NaN   30.0      130.5     NaN
# 1003               3.6  1300.0   NaN  42.00  100.0      279.2     NaN
# 1003               NaN   800.0   NaN    NaN    9.0       69.8     NaN
#
# [562 rows x 35 columns]

# %%
grp_dad.reset_index(drop=True)
grp_dad.reset_index(inplace=True)
nnn = 1
zzz = grp_dad['Пласт'].value_counts()[:nnn].index.tolist()
plasttt = str(zzz[0])
grp_dad['удалю'] = grp_dad.apply(
            lambda x:
            'нет' if plasttt in str(x['Пласт'])
            else 'да', axis=1)
grp_dad = grp_dad.drop(grp_dad[grp_dad['удалю'] == 'да'].index).reset_index(drop=True)
grp_dad = grp_dad.drop(['удалю'], axis=1)
grp_dad
# Out:
#     Номер скважины                   Unnamed: 0       Дата    Подрядчик  \
# 0              974  Проблемы при построении ГРП 2012-06-15          МКН
# 1              827  Проблемы при построении ГРП 2015-05-31  МекамиНефть
# 2              827  Проблемы при построении ГРП 2015-05-30  МекамиНефть
# 3              827  Проблемы при построении ГРП 2015-05-30  МекамиНефть
# 4              827  Проблемы при построении ГРП 2015-05-30  МекамиНефть
# ..             ...                          ...        ...          ...
# 462           1028  Проблемы при построении ГРП 2019-04-02           КН
# 463           1028  Проблемы при построении ГРП 2019-03-31           КН
# 464            101  Проблемы при построении ГРП 2015-04-21          ТВС
# 465            101  Проблемы при построении ГРП 2015-04-21          ТВС
# 466            101  Проблемы при построении ГРП 2015-04-20          ТВС
#
#                                            Комментарии Страница  Unnamed: 6  \
# 0    По миниГРП : принято решение  уменьшить буфер ...      -1_         NaN
# 1                                                  327      -1_         NaN
# 2                                                  327      -1_         NaN
# 3                                                  327      -1_         NaN
# 4                                                  327      -1_         NaN
# ..                                                 ...      ...         ...
# 462  Оборудование:  НКТ, АМТ-  ООО "КАТКонефть" Сти...      -1_         NaN
# 463  Оборудование:  НКТ, АМТ-  ООО "КАТКонефть" Сти...      -1_         NaN
# 464                                                327      -1_         NaN
# 465                                                327      -1_         NaN
# 466                                                327      -1_         NaN
#
#     Пласт  Наклон  Азимут  ...                     Проппант  Рпл Хорнер   Эфф  \
# 0      Ю1    4.25   102.0  ...                          NaN       220.0  70.0
# 1      Ю1   88.70   342.2  ...         20/40 БКО +16/20 БКО         NaN  75.0
# 2      Ю1   88.70   342.2  ...         20/40 БКО +16/20 БКО         NaN  78.0
# 3      Ю1   87.90   326.2  ...         20/40 БКО +16/20 БКО         NaN  74.0
# 4      Ю1   88.40   325.9  ...         20/40 БКО +16/20 БКО         NaN  73.0
# ..    ...     ...     ...  ...                          ...         ...   ...
# 462    Ю1   24.00   299.6  ...          NIKA (Ptprop)+Fores         NaN  16.0
# 463    Ю1   84.69   299.6  ...  NIKA (Ptprop)+NIKA (Ptprop)        21.0  60.8
# 464    Ю1   90.00   176.0  ...        20/40Carbo+16/20Carbo         NaN  78.0
# 465    Ю1   90.00   173.0  ...        20/40Carbo+16/20Carbo         NaN  80.0
# 466    Ю1   91.00   169.0  ...        20/40Carbo+16/20Carbo         NaN  78.0
#
#      Расход    Конц  Гель  М бр  V под  V без под  V гель
# 0       3.4  1200.0   NaN   NaN   16.0      129.4     NaN
# 1       3.4   900.0   NaN  70.0    9.0       74.0     NaN
# 2       3.4   900.0   NaN  72.0    8.0       70.9     NaN
# 3       3.4   900.0   NaN  75.0    9.0       70.5     NaN
# 4       3.4   900.0   NaN  80.0    8.0       93.4     NaN
# ..      ...     ...   ...   ...    ...        ...     ...
# 462     2.0   800.0   NaN  93.0   15.0        NaN     NaN
# 463     3.4   800.0   NaN  55.0   19.0        NaN    75.9
# 464     3.2   900.0   NaN  25.0   22.0      121.2     NaN
# 465     3.2   900.0   NaN  25.5   16.0       97.9     NaN
# 466     3.2   800.0   NaN  26.5   16.0      130.1     NaN
#
# [467 rows x 36 columns]

# %%
grp_gtm = pd.read_excel('гтм1.xlsx',header=[1], index_col=[1])
grp_gtm
# Out:
#                Unnamed: 0 Скважина      Куст                 Тип  \
# Месторождение
# Ватинское      Добывающая     1003   КУСТ-24                 РИР
# Ватинское      Добывающая     1003   КУСТ-24                 ГРП
# Ватинское      Добывающая     1003   КУСТ-24                 РИР
# Ватинское      Добывающая     1003   КУСТ-24                 РИР
# Ватинское      Добывающая     1003   КУСТ-24                 РИР
# ...                   ...      ...       ...                 ...
# Ватинское      Добывающая      974  КУСТ-106               См_ПО
# Ватинское      Добывающая      974  КУСТ-106  Запуск без ремонта
# Ватинское      Добывающая      974  КУСТ-106  Запуск без ремонта
# Ватинское      Добывающая      974  КУСТ-106  Запуск без ремонта
# Ватинское      Добывающая      974  КУСТ-106               См_ПО
#
#               Объект разработки до ГТМ  Пласт Страница  gtmTypeFullName  Dэк  \
# Месторождение
# Ватинское                          NaN    NaN      -1_              NaN  NaN
# Ватинское                           Ю1    NaN      -1_              NaN  NaN
# Ватинское                          NaN    NaN      -1_              NaN  NaN
# Ватинское                          NaN    NaN      -1_              NaN  NaN
# Ватинское                          NaN    NaN      -1_              NaN  NaN
# ...                                ...    ...      ...              ...  ...
# Ватинское                       Б19-22    NaN      -1_              NaN  NaN
# Ватинское                       Б19-22    NaN      -1_              NaN  NaN
# Ватинское                       Б19-22    NaN      -1_              NaN  NaN
# Ватинское                       Б19-22    NaN      -1_              NaN  NaN
# Ватинское                       Б19-22    NaN      -1_              NaN  NaN
#
#               Краткое описание мероприятий  ...  Комментарий  План  Факт  \
# Месторождение                               ...
# Ватинское                              NaN  ...          NaN   NaN   NaN
# Ватинское             КР7-2 Проведение ГРП  ...          NaN   NaN   NaN
# Ватинское                              NaN  ...          NaN   NaN   NaN
# Ватинское                              NaN  ...          NaN   NaN   NaN
# Ватинское                              NaN  ...          NaN   NaN   NaN
# ...                                    ...  ...          ...   ...   ...
# Ватинское                  ТР5-1 Смена ЭЦН  ...          NaN   NaN   NaN
# Ватинское              Запуск в работу без  ...          NaN   NaN   NaN
# Ватинское              Запуск в работу без  ...          NaN   NaN   NaN
# Ватинское              Запуск в работу без  ...          NaN   NaN   NaN
# Ватинское                  ТР5-1 Смена ЭЦН  ...          NaN   NaN   NaN
#
#                Пл-ть нефти  Коб  В-ть жидк.  P нас  За текущий месяц  \
# Месторождение
# Ватинское              NaN  NaN         NaN    NaN               NaN
# Ватинское              NaN  NaN         NaN    NaN               NaN
# Ватинское              NaN  NaN         NaN    NaN               NaN
# Ватинское              NaN  NaN         NaN    NaN               NaN
# Ватинское              NaN  NaN         NaN    NaN               NaN
# ...                    ...  ...         ...    ...               ...
# Ватинское              NaN  NaN         NaN    NaN               NaN
# Ватинское              NaN  NaN         NaN    NaN               NaN
# Ватинское              NaN  NaN         NaN    NaN               NaN
# Ватинское              NaN  NaN         NaN    NaN               NaN
# Ватинское              NaN  NaN         NaN    NaN               NaN
#
#                С начала года  С начала мероприятия
# Месторождение
# Ватинское                NaN                   NaN
# Ватинское                NaN                   NaN
# Ватинское                NaN                   NaN
# Ватинское                NaN                   NaN
# Ватинское                NaN                   NaN
# ...                      ...                   ...
# Ватинское                NaN                   NaN
# Ватинское                NaN                   NaN
# Ватинское                NaN                   NaN
# Ватинское                NaN                   NaN
# Ватинское                NaN                   NaN
#
# [3939 rows x 70 columns]

# %%
grp_gtm.reset_index(drop=True)
grp_gtm.reset_index(inplace=True)
grp_gtm.tail(15)
# Out:
#      Месторождение  Unnamed: 0 Скважина      Куст                     Тип  \
# 3924     Ватинское  Добывающая      974  КУСТ-106  Переход или приобщение
# 3925     Ватинское  Добывающая      974  КУСТ-106                     КРС
# 3926     Ватинское  Добывающая      974  КУСТ-106                Доп.перф
# 3927     Ватинское  Добывающая      974  КУСТ-106  Переход или приобщение
# 3928     Ватинское  Добывающая      974  КУСТ-106                Доп.перф
# 3929     Ватинское  Добывающая      974  КУСТ-106                     ГРП
# 3930     Ватинское  Добывающая      974  КУСТ-106                   См_ПО
# 3931     Ватинское  Добывающая      974  КУСТ-106                   См_ПО
# 3932     Ватинское  Добывающая      974  КУСТ-106                   См_ПО
# 3933     Ватинское  Добывающая      974  КУСТ-106                     ОПЗ
# 3934     Ватинское  Добывающая      974  КУСТ-106                   См_ПО
# 3935     Ватинское  Добывающая      974  КУСТ-106      Запуск без ремонта
# 3936     Ватинское  Добывающая      974  КУСТ-106      Запуск без ремонта
# 3937     Ватинское  Добывающая      974  КУСТ-106      Запуск без ремонта
# 3938     Ватинское  Добывающая      974  КУСТ-106                   См_ПО
#
#      Объект разработки до ГТМ  Пласт Страница  gtmTypeFullName  Dэк  ...  \
# 3924                    А1(3)    NaN      -1_              NaN  NaN  ...
# 3925                      NaN    NaN      -1_              NaN  NaN  ...
# 3926                      NaN    NaN      -1_              NaN  NaN  ...
# 3927                       Б8    NaN      -1_              NaN  NaN  ...
# 3928                      NaN    NaN      -1_              NaN  NaN  ...
# 3929                   Б19-22    NaN      -1_              NaN  NaN  ...
# 3930                      NaN    NaN      -1_              NaN  NaN  ...
# 3931                      NaN    NaN      -1_              NaN  NaN  ...
# 3932                   Б19-22    NaN      -1_              NaN  NaN  ...
# 3933                   Б19-22    NaN      -1_              NaN  NaN  ...
# 3934                   Б19-22    NaN      -1_              NaN  NaN  ...
# 3935                   Б19-22    NaN      -1_              NaN  NaN  ...
# 3936                   Б19-22    NaN      -1_              NaN  NaN  ...
# 3937                   Б19-22    NaN      -1_              NaN  NaN  ...
# 3938                   Б19-22    NaN      -1_              NaN  NaN  ...
#
#      Комментарий  План  Факт  Пл-ть нефти  Коб  В-ть жидк.  P нас  \
# 3924         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3925         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3926         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3927         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3928         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3929         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3930         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3931         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3932         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3933         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3934         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3935         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3936         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3937         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3938         NaN   NaN   NaN          NaN  NaN         NaN    NaN
#
#       За текущий месяц  С начала года  С начала мероприятия
# 3924               NaN            NaN                   NaN
# 3925               NaN            NaN                   NaN
# 3926               NaN            NaN                   NaN
# 3927               NaN            NaN                   NaN
# 3928               NaN            NaN                   NaN
# 3929               NaN            NaN                   NaN
# 3930               NaN            NaN                   NaN
# 3931               NaN            NaN                   NaN
# 3932               NaN            NaN                   NaN
# 3933               NaN            NaN                   NaN
# 3934               NaN            NaN                   NaN
# 3935               NaN            NaN                   NaN
# 3936               NaN            NaN                   NaN
# 3937               NaN            NaN                   NaN
# 3938               NaN            NaN                   NaN
#
# [15 rows x 71 columns]

# %%
grp_gtm = grp_gtm[grp_gtm['Объект разработки до ГТМ'].notna()]
grp_gtm
# Out:
#      Месторождение  Unnamed: 0 Скважина      Куст                     Тип  \
# 1        Ватинское  Добывающая     1003   КУСТ-24                     ГРП
# 6        Ватинское  Добывающая     1003   КУСТ-24  Переход или приобщение
# 9        Ватинское  Добывающая     1003   КУСТ-24                     ГРП
# 22       Ватинское  Добывающая     1003   КУСТ-24                     ГРП
# 24       Ватинское  Добывающая     1003   КУСТ-24                   См_ПО
# ...            ...         ...      ...       ...                     ...
# 3934     Ватинское  Добывающая      974  КУСТ-106                   См_ПО
# 3935     Ватинское  Добывающая      974  КУСТ-106      Запуск без ремонта
# 3936     Ватинское  Добывающая      974  КУСТ-106      Запуск без ремонта
# 3937     Ватинское  Добывающая      974  КУСТ-106      Запуск без ремонта
# 3938     Ватинское  Добывающая      974  КУСТ-106                   См_ПО
#
#      Объект разработки до ГТМ  Пласт Страница  gtmTypeFullName  Dэк  ...  \
# 1                          Ю1    NaN      -1_              NaN  NaN  ...
# 6                          А2    NaN      -1_              NaN  NaN  ...
# 9                          А2    NaN      -1_              NaN  NaN  ...
# 22                     Б19-22    NaN      -1_              NaN  NaN  ...
# 24                     Б19-22    NaN      -1_              NaN  NaN  ...
# ...                       ...    ...      ...              ...  ...  ...
# 3934                   Б19-22    NaN      -1_              NaN  NaN  ...
# 3935                   Б19-22    NaN      -1_              NaN  NaN  ...
# 3936                   Б19-22    NaN      -1_              NaN  NaN  ...
# 3937                   Б19-22    NaN      -1_              NaN  NaN  ...
# 3938                   Б19-22    NaN      -1_              NaN  NaN  ...
#
#      Комментарий  План  Факт  Пл-ть нефти  Коб  В-ть жидк.  P нас  \
# 1            NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 6            NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 9            NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 22           NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 24           NaN   NaN   NaN          NaN  NaN         NaN    NaN
# ...          ...   ...   ...          ...  ...         ...    ...
# 3934         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3935         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3936         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3937         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3938         NaN   NaN   NaN          NaN  NaN         NaN    NaN
#
#       За текущий месяц  С начала года  С начала мероприятия
# 1                  NaN            NaN                   NaN
# 6                  NaN            NaN                   NaN
# 9                  NaN            NaN                   NaN
# 22                 NaN            NaN                   NaN
# 24                 NaN            NaN                   NaN
# ...                ...            ...                   ...
# 3934               NaN            NaN                   NaN
# 3935               NaN            NaN                   NaN
# 3936               NaN            NaN                   NaN
# 3937               NaN            NaN                   NaN
# 3938               NaN            NaN                   NaN
#
# [1501 rows x 71 columns]

# %%
nn = 1
zz = grp_gtm['Объект разработки до ГТМ'].value_counts()[:nn].index.tolist()
plastt = str(zz[0])
grp_gtm = grp_gtm.drop(grp_gtm[grp_gtm['Объект разработки до ГТМ'] != plastt].index).reset_index(drop=True)
grp_gtm
# Out:
#     Месторождение  Unnamed: 0 Скважина      Куст  Тип  \
# 0       Ватинское  Добывающая     1003   КУСТ-24  ГРП
# 1       Ватинское  Добывающая      101   КУСТ-15  ГРП
# 2       Ватинское  Добывающая      101   КУСТ-15  3БС
# 3       Ватинское  Добывающая     1028   КУСТ-31  ГРП
# 4       Ватинское  Добывающая     1028   КУСТ-31  3БС
# ..            ...         ...      ...       ...  ...
# 886     Ватинское  Добывающая      974  КУСТ-106  ГРП
# 887     Ватинское  Добывающая      974  КУСТ-106  ОПТ
# 888     Ватинское  Добывающая      974  КУСТ-106  ГРП
# 889     Ватинское  Добывающая      974  КУСТ-106  ГРП
# 890     Ватинское  Добывающая      974  КУСТ-106  ОПЗ
#
#     Объект разработки до ГТМ  Пласт Страница  gtmTypeFullName  Dэк  ...  \
# 0                         Ю1    NaN      -1_              NaN  NaN  ...
# 1                         Ю1    NaN      -1_              NaN  NaN  ...
# 2                         Ю1    NaN      -1_              NaN  NaN  ...
# 3                         Ю1    NaN      -1_              NaN  NaN  ...
# 4                         Ю1    NaN      -1_              NaN  NaN  ...
# ..                       ...    ...      ...              ...  ...  ...
# 886                       Ю1    NaN      -1_              NaN  NaN  ...
# 887                       Ю1    NaN      -1_              NaN  NaN  ...
# 888                       Ю1    NaN      -1_              NaN  NaN  ...
# 889                       Ю1    NaN      -1_              NaN  NaN  ...
# 890                       Ю1    NaN      -1_              NaN  NaN  ...
#
#     Комментарий  План  Факт  Пл-ть нефти  Коб  В-ть жидк.  P нас  \
# 0           NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 1           NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 2           NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3           NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 4           NaN   NaN   NaN          NaN  NaN         NaN    NaN
# ..          ...   ...   ...          ...  ...         ...    ...
# 886         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 887         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 888         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 889         NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 890         NaN   NaN   NaN          NaN  NaN         NaN    NaN
#
#      За текущий месяц  С начала года  С начала мероприятия
# 0                 NaN            NaN                   NaN
# 1                 NaN            NaN                   NaN
# 2                 NaN            NaN                   NaN
# 3                 NaN            NaN                   NaN
# 4                 NaN            NaN                   NaN
# ..                ...            ...                   ...
# 886               NaN            NaN                   NaN
# 887               NaN            NaN                   NaN
# 888               NaN            NaN                   NaN
# 889               NaN            NaN                   NaN
# 890               NaN            NaN                   NaN
#
# [891 rows x 71 columns]

# %%
coordinates = pd.read_excel('координаты скв1.xlsx')
coordinates
# Out:
#     № скважины  Координата X  Координата Y  \
# 0         1003        560719       6776574
# 1          101        555210       6775712
# 2        1022Л        561504       6778331
# 3         1028        554254       6783332
# 4         1060        556124       6786642
# ..         ...           ...           ...
# 171       5358        559266       6770043
# 172        974        561941       6771177
# 173       5319        558016       6761269
# 174       5314        557602       6761104
# 175       5316        557406       6760617
#
#      Координата забоя Х (по траектории)  Координата забоя Y (по траектории)
# 0                                560689                             6776622
# 1                                555163                             6775427
# 2                                561503                             6778330
# 3                                553976                             6783576
# 4                                555945                             6787230
# ..                                  ...                                 ...
# 171                              559902                             6769901
# 172                              561946                             6771174
# 173                              558021                             6761306
# 174                              557601                             6761101
# 175                              557407                             6760600
#
# [176 rows x 5 columns]

# %%
        coordinates['Length'] = coordinates.apply(
            lambda x: ((x['Координата забоя Х (по траектории)'] - x['Координата X']) ** (2) +
                       (x['Координата забоя Y (по траектории)'] - x['Координата Y']) ** (2)) ** (0.5)
            , axis=1)
        coordinates['№ скважины'] = coordinates.apply(
            lambda x:
            str(x['№ скважины']), axis=1)
        grp = copy.deepcopy(grp_dad)
        
        
        
        
        
        
        
        #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        grp_now_we_go= copy.deepcopy(grp_gtm)
        
        grp_now_we_go['Скважина'] = grp_now_we_go.apply(
            lambda x:
            str(x['Скважина']), axis=1)
        #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        
        
        
        
        
        
        
        
        
        #grp.reset_index(drop=True)
        #grp.reset_index(inplace=True)
        #grp = grp.drop(['Unnamed: 0', 'Подрядчик', 'Комментарии', 'Страница', 'Unnamed: 6', 'Азимут'], axis=1)
        #grp = grp.drop(
        #    ['V гель', 'V без под', 'V под', 'М бр', 'Гель', 'Конц', 'Расход', 'Эфф', 'Рпл Хорнер', 'Проппант', 'k',
        #     'Ноб', 'Нэф', 'Верх', 'Низ'], axis=1)
        #grp = grp.drop(['Xf', 'Hf', 'Wf', 'PIdsg', 'Скин-фактор', 'JD', 'FCD', 'М пр', 'Покр', 'План'], axis=1)
        grp['Номер скважины'] = grp.apply(
            lambda x:
            str(x['Номер скважины']), axis=1)
        # координаты скважин для нашего объекта
        my_wells = grp['Номер скважины'].tolist()
        my_wells_no_repeat = []
        for x in my_wells:
            if x not in my_wells_no_repeat:
                my_wells_no_repeat.append(x)
                
                
                
                
        #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!        
                # координаты скважин для нашего объекта, которых нет во фраклисте
        my_wells_gtm = grp_now_we_go['Скважина'].tolist()
        my_wells_no_repeat_gtm = []
        for x in my_wells_gtm:
            if x not in my_wells_no_repeat_gtm:
                my_wells_no_repeat_gtm.append(x)
        
        my_wells_only_gtm=[]
        for i in my_wells_no_repeat_gtm:
            if i not in my_wells_no_repeat:
                my_wells_only_gtm.append(i)
        my_wells_only_gtm
        #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
# ['1003',
#  '1119',
#  '1140',
#  '1142',
#  '1150',
#  '1205',
#  '1212',
#  '1240',
#  '1277',
#  '1278',
#  '1280',
#  '1285',
#  '1287',
#  '1299',
#  '1309Б',
#  '1317',
#  '1338',
#  '2715',
#  '32Р',
#  '3938',
#  '439',
#  '459',
#  '4768',
#  '5112',
#  '5216',
#  '5218',
#  '5219',
#  '5220',
#  '5233',
#  '5234',
#  '5247',
#  '5280',
#  '546',
#  '597']

# %%
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
wells_GTM = pd.DataFrame({"Номер скважины": my_wells_only_gtm
                   })
wells_GTM
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
#    Номер скважины
# 0            1003
# 1            1119
# 2            1140
# 3            1142
# 4            1150
# 5            1205
# 6            1212
# 7            1240
# 8            1277
# 9            1278
# 10           1280
# 11           1285
# 12           1287
# 13           1299
# 14          1309Б
# 15           1317
# 16           1338
# 17           2715
# 18            32Р
# 19           3938
# 20            439
# 21            459
# 22           4768
# 23           5112
# 24           5216
# 25           5218
# 26           5219
# 27           5220
# 28           5233
# 29           5234
# 30           5247
# 31           5280
# 32            546
# 33            597

# %%
coordinates_f = coordinates[
coordinates['№ скважины'].isin(my_wells_no_repeat)].reset_index(drop=True)
coordinates_f = coordinates_f.drop(['Координата X', 'Координата Y', 'Координата забоя Х (по траектории)',
                                        'Координата забоя Y (по траектории)'], axis=1)
new = coordinates_f['№ скважины'].tolist()
coordinates_f['Номер скважины'] = new
coordinates_f = coordinates_f.drop(['№ скважины'], axis=1)
final = grp.merge(coordinates_f, on='Номер скважины')
final.loc[final['Номер скважины'] == '5217']
# Out:
#    Номер скважины                   Unnamed: 0       Дата Подрядчик  \
# 39           5217  Проблемы при построении ГРП 2004-08-28       МКН
#
#                                           Комментарии Страница  Unnamed: 6  \
# 39  Пробка на миниГРП. Длительная закачка на высок...      -1_         NaN
#
#    Пласт  Наклон  Азимут  ...  Рпл Хорнер   Эфф  Расход    Конц  Гель  М бр  \
# 39    Ю1     NaN     NaN  ...         NaN  32.6     NaN  1100.0   NaN   NaN
#
#     V под  V без под  V гель     Length
# 39   75.0      215.0     NaN  27.784888
#
# [1 rows x 37 columns]

# %%
        coordinates_f = coordinates[
            coordinates['№ скважины'].isin(my_wells_no_repeat)].reset_index(drop=True)
        coordinates_f = coordinates_f.drop(['Координата X', 'Координата Y', 'Координата забоя Х (по траектории)',
                                        'Координата забоя Y (по траектории)'], axis=1)
        new = coordinates_f['№ скважины'].tolist()
        coordinates_f['Номер скважины'] = new
        coordinates_f = coordinates_f.drop(['№ скважины'], axis=1)
        final = grp.merge(coordinates_f, on='Номер скважины')
        final['Длиина ГС, м'] = final.apply(
            lambda x:
            x['Length'] if x['Наклон'] >= 70
            else 0, axis=1)
        final = final.drop(['Наклон', 'Length'], axis=1)
        final_number = final.groupby('Номер скважины').agg(
            {'Дата': lambda x:
            x.tolist()}
        )

# %%
final.loc[final['Номер скважины'] == '5217']
# Out:
#    Номер скважины                   Unnamed: 0       Дата Подрядчик  \
# 39           5217  Проблемы при построении ГРП 2004-08-28       МКН
#
#                                           Комментарии Страница  Unnamed: 6  \
# 39  Пробка на миниГРП. Длительная закачка на высок...      -1_         NaN
#
#    Пласт  Азимут    k  ...  Рпл Хорнер   Эфф  Расход    Конц  Гель  М бр  \
# 39    Ю1     NaN  1.5  ...         NaN  32.6     NaN  1100.0   NaN   NaN
#
#     V под  V без под  V гель  Длиина ГС, м
# 39   75.0      215.0     NaN           0.0
#
# [1 rows x 36 columns]

# %%
#!!!!!!!!!!!!!!!!!!!!!!!!!!
coordinates_gtm = coordinates[
            coordinates['№ скважины'].isin(my_wells_only_gtm)].reset_index(drop=True)
coordinates_gtm
#!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
#    № скважины  Координата X  Координата Y  Координата забоя Х (по траектории)  \
# 0        1003        560719       6776574                              560689
# 1        1119        555020       6788479                              555022
# 2        1140        555492       6789478                              555496
# 3        1142        555403       6788783                              555410
# 4        1150        556245       6787507                              556246
# 5        1205        559719       6775373                              559712
# 6        1212        560571       6778241                              560552
# 7        1240        560135       6775575                              560126
# 8        1277        561241       6771034                              561258
# 9        1278        561080       6772164                              561079
# 10       1280        560328       6769511                              560316
# 11       1285        560791       6769372                              560783
# 12       1287        560221       6768123                              560209
# 13       1299        560846       6767359                              560840
# 14      1309Б        562537       6779372                              562526
# 15       1317        554232       6786645                              554232
# 16       1338        557161       6778146                              556592
# 17       2715        554712       6772462                              555013
# 18        32Р        555380       6787261                              555589
# 19       3938        561618       6782150                              561608
# 20        439        556027       6788918                              556025
# 21        459        556462       6788583                              556463
# 22       4768        555397       6771545                              555414
# 23       5112        561844       6766106                              561816
# 24       5216        554573       6788603                              554584
# 25       5218        555542       6789873                              555542
# 26       5219        555346       6789189                              555331
# 27       5220        555654       6789059                              555643
# 28       5233        564819       6785986                              564806
# 29       5234        565290       6786157                              565266
# 30       5247        565647       6785964                              565636
# 31       5280        563980       6783374                              563972
# 32        546        564548       6776577                              564559
# 33        597        564280       6776010                              564291
#
#     Координата забоя Y (по траектории)      Length
# 0                              6776622   56.603887
# 1                              6788483    4.472136
# 2                              6789481    5.000000
# 3                              6788782    7.071068
# 4                              6787501    6.082763
# 5                              6775349   25.000000
# 6                              6778249   20.615528
# 7                              6775579    9.848858
# 8                              6771029   17.720045
# 9                              6772165    1.414214
# 10                             6769510   12.041595
# 11                             6769381   12.041595
# 12                             6768100   25.942244
# 13                             6767355    7.211103
# 14                             6779376   11.704700
# 15                             6786646    1.000000
# 16                             6778462  650.858664
# 17                             6773172  771.168594
# 18                             6787053  294.864376
# 19                             6782146   10.770330
# 20                             6788926    8.246211
# 21                             6788591    8.062258
# 22                             6771536   19.235384
# 23                             6766113   28.861739
# 24                             6788591   16.278821
# 25                             6789892   19.000000
# 26                             6789158   34.438351
# 27                             6789054   12.083046
# 28                             6785975   17.029386
# 29                             6786169   26.832816
# 30                             6785978   17.804494
# 31                             6783372    8.246211
# 32                             6776585   13.601471
# 33                             6776017   13.038405

# %%
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
coordinates_gtm = coordinates_gtm.drop(['Координата X', 'Координата Y', 'Координата забоя Х (по траектории)','Координата забоя Y (по траектории)'], axis=1)

# %%
        new_g = coordinates_gtm['№ скважины'].tolist()
        coordinates_gtm['Номер скважины'] = new_g
        coordinates_gtm = coordinates_gtm.drop(['№ скважины'], axis=1)

wells_GTM = wells_GTM.merge(coordinates_gtm, on='Номер скважины')
        wells_GTM['Длина ГС, м'] = wells_GTM.apply(
            lambda x:
            x['Length'] if x['Length'] >= 110
            else 0, axis=1)
        wells_GTM = wells_GTM.drop(['Length'], axis=1)
wells_GTM
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
#    Номер скважины  Длина ГС, м
# 0            1003     0.000000
# 1            1119     0.000000
# 2            1140     0.000000
# 3            1142     0.000000
# 4            1150     0.000000
# 5            1205     0.000000
# 6            1212     0.000000
# 7            1240     0.000000
# 8            1277     0.000000
# 9            1278     0.000000
# 10           1280     0.000000
# 11           1285     0.000000
# 12           1287     0.000000
# 13           1299     0.000000
# 14          1309Б     0.000000
# 15           1317     0.000000
# 16           1338   650.858664
# 17           2715   771.168594
# 18            32Р   294.864376
# 19           3938     0.000000
# 20            439     0.000000
# 21            459     0.000000
# 22           4768     0.000000
# 23           5112     0.000000
# 24           5216     0.000000
# 25           5218     0.000000
# 26           5219     0.000000
# 27           5220     0.000000
# 28           5233     0.000000
# 29           5234     0.000000
# 30           5247     0.000000
# 31           5280     0.000000
# 32            546     0.000000
# 33            597     0.000000

# %%
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
grp_ggtm = copy.deepcopy(grp_gtm)
grp_ggtm.reset_index(drop=True)
grp_ggtm.reset_index(inplace=True)
grp_ggtm['Скважина'] = grp_ggtm.apply(
            lambda x:
            str(x['Скважина']), axis=1)
grp_ggtm = grp_ggtm[grp_ggtm['Скважина'].isin(my_wells_only_gtm)].reset_index(drop=True)
        #grp_1 = grp_1.drop(['С начала мероприятия', 'С начала года', 'За текущий месяц', 'P нас', 'В-ть жидк.', 'Коб'],
        #                   axis=1)
        #grp_1 = grp_1.drop(['Пл-ть нефти', 'Факт', 'План', 'Комментарий', 'Dэк', 'Пласт', 'Страница'], axis=1)
        #grp_1 = grp_1.drop(['Unnamed: 11', 'Hэфф', 'Pпл.2', 'H дин.1', 'Pзаб.2', 'Состояние.1', 'Кпр'], axis=1)
        #grp_1 = grp_1.drop(['Скин-фактор.1', 'Интервалы перф..1', 'Насос.1', 'Напор.1', 'Производительность.1'], axis=1)
        #grp_1 = grp_1.drop(
        #    ['%.2', 'Qж.2', 'Qн.2', 'Hспуск.1', 'Кач.1', 'Част.1', 'Lхода.1', 'Метод.1', 'Скин-фактор', 'Pзаб.1',
        #     'Метод', 'Re'], axis=1)
        #grp_1 = grp_1.drop(['Pпл.1', '%.1', 'Qж.1', 'Qн.1', 'Окончание', 'Начало', 'Производительность', 'Насос'],
        #                   axis=1)
        #grp_1 = grp_1.drop(['Интервалы перф.', 'Hвд', 'Состояние', 'Pзаб', 'Pпл', 'H дин', 'Lхода', 'Напор'], axis=1)
        #grp_1 = grp_1.drop(['Месторождение', 'Unnamed: 0', 'Куст', 'Част', 'Кач', 'Hспуск', 'Qн', 'Qж', '%'], axis=1)
        #grp_1 = grp_1[grp_1['Скважина'].isin(my_wells_no_repeat)].reset_index(drop=True)
        # даты введения ГРП и ВНС на скважинах очень важно!!!!!!!
grp_ggtm
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
#      index Месторождение  Unnamed: 0 Скважина      Куст  \
# 0        0     Ватинское  Добывающая     1003   КУСТ-24
# 1       13     Ватинское  Добывающая     1119   КУСТ-55
# 2       14     Ватинское  Добывающая     1119   КУСТ-55
# 3       15     Ватинское  Добывающая     1119   КУСТ-55
# 4       20     Ватинское  Добывающая     1140  КУСТ-55Б
# ..     ...           ...         ...      ...       ...
# 156    859     Ватинское  Добывающая      546  КУСТ-111
# 157    860     Ватинское  Добывающая      546  КУСТ-111
# 158    861     Ватинское  Добывающая      546  КУСТ-111
# 159    862     Ватинское  Добывающая      597  КУСТ-111
# 160    863     Ватинское  Добывающая      597  КУСТ-111
#
#                                Тип Объект разработки до ГТМ  Пласт Страница  \
# 0                              ГРП                       Ю1    NaN      -1_
# 1                              ГРП                       Ю1    NaN      -1_
# 2    РИР негерметичности э/колонны                       Ю1    NaN      -1_
# 3           Переход или приобщение                       Ю1    NaN      -1_
# 4           Переход или приобщение                       Ю1    NaN      -1_
# ..                             ...                      ...    ...      ...
# 156                            ГРП                       Ю1    NaN      -1_
# 157                            ОПЗ                       Ю1    NaN      -1_
# 158                            ГРП                       Ю1    NaN      -1_
# 159                            ГРП                       Ю1    NaN      -1_
# 160                            ГРП                       Ю1    NaN      -1_
#
#      gtmTypeFullName  ...  Комментарий План  Факт  Пл-ть нефти  Коб  \
# 0                NaN  ...          NaN  NaN   NaN          NaN  NaN
# 1                NaN  ...          NaN  NaN   NaN          NaN  NaN
# 2                NaN  ...          NaN  NaN   NaN          NaN  NaN
# 3                NaN  ...          NaN  NaN   NaN          NaN  NaN
# 4                NaN  ...          NaN  NaN   NaN          NaN  NaN
# ..               ...  ...          ...  ...   ...          ...  ...
# 156              NaN  ...          NaN  NaN   NaN          NaN  NaN
# 157              NaN  ...          NaN  NaN   NaN          NaN  NaN
# 158              NaN  ...          NaN  NaN   NaN          NaN  NaN
# 159              NaN  ...          NaN  NaN   NaN          NaN  NaN
# 160              NaN  ...          NaN  NaN   NaN          NaN  NaN
#
#      В-ть жидк.  P нас  За текущий месяц  С начала года  С начала мероприятия
# 0           NaN    NaN               NaN            NaN                   NaN
# 1           NaN    NaN               NaN            NaN                   NaN
# 2           NaN    NaN               NaN            NaN                   NaN
# 3           NaN    NaN               NaN            NaN                   NaN
# 4           NaN    NaN               NaN            NaN                   NaN
# ..          ...    ...               ...            ...                   ...
# 156         NaN    NaN               NaN            NaN                   NaN
# 157         NaN    NaN               NaN            NaN                   NaN
# 158         NaN    NaN               NaN            NaN                   NaN
# 159         NaN    NaN               NaN            NaN                   NaN
# 160         NaN    NaN               NaN            NaN                   NaN
#
# [161 rows x 72 columns]

# %%
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
grp_gang = copy.deepcopy(grp_ggtm)
grp_gang['Дата ВНР после ГС \\ ГРП \\ЗБГС'] = grp_gang.apply(
            lambda x:
            x['ВНР.1'] if 'КР7-2' in str(x['Краткое описание мероприятий'])
            else x['Начало.1'] if 'Ввод добывающих сква' in str(x['Краткое описание мероприятий'])
            else 'нет', axis=1)
grp_gang['Тип ГТМ'] = grp_gang.apply(
            lambda x:
            'ГРП' if 'КР7-2' in str(x['Краткое описание мероприятий'])
            else 'ВНС' if 'Ввод добывающих сква' in str(x['Краткое описание мероприятий'])
            else 'нет', axis=1)

grp_gang.loc[grp_gang['Скважина'] == '3938']
# Out:
#      index Месторождение  Unnamed: 0 Скважина      Куст  Тип  \
# 102    643     Ватинское  Добывающая     3938  КУСТ-162  ГРП
#
#     Объект разработки до ГТМ  Пласт Страница  gtmTypeFullName  ...  Факт  \
# 102                       Ю1    NaN      -1_              NaN  ...   NaN
#
#     Пл-ть нефти  Коб  В-ть жидк.  P нас  За текущий месяц  С начала года  \
# 102         NaN  NaN         NaN    NaN               NaN            NaN
#
#      С начала мероприятия  Дата ВНР после ГС \ ГРП \ЗБГС  Тип ГТМ
# 102                   NaN            1996-11-07 00:00:00      ГРП
#
# [1 rows x 74 columns]

# %%
grp_gang = grp_gang.drop(grp_gang[grp_gang['Дата ВНР после ГС \\ ГРП \\ЗБГС'] == 'нет'].index)
grp_gang = grp_gang.groupby(by=['Скважина', 'Дата ВНР после ГС \ ГРП \ЗБГС']).agg(
            {'Тип ГТМ': lambda x:
            x.tolist()[0]}
        )
grp_gang.reset_index(inplace=True)
grp_gang.loc[grp_gang['Скважина'] == '3938']
# Out:
#    Скважина Дата ВНР после ГС \ ГРП \ЗБГС Тип ГТМ
# 26     3938                    1996-11-07     ГРП

# %%
vvvvv = grp_gang['Скважина'].tolist()

grp_gang['Номер скважины'] = vvvvv
grp_gang = grp_gang.drop(['Скважина'], axis=1)
grp_gang
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
#    Дата ВНР после ГС \ ГРП \ЗБГС Тип ГТМ Номер скважины
# 0                     1995-09-01     ГРП           1003
# 1                     1995-10-01     ГРП           1119
# 2                     1994-10-01     ГРП           1150
# 3                     1998-06-19     ГРП           1150
# 4                     1996-03-04     ГРП           1205
# 5                     2000-04-21     ГРП           1205
# 6                     1994-09-01     ГРП           1212
# 7                     1997-07-31     ГРП           1240
# 8                     1999-12-10     ГРП           1240
# 9                     2002-12-18     ГРП           1240
# 10                    1995-09-01     ГРП           1277
# 11                    1995-04-01     ГРП           1278
# 12                    1993-07-01     ГРП           1280
# 13                    1993-04-01     ГРП           1285
# 14                    1998-04-28     ГРП           1285
# 15                    1993-05-01     ГРП           1287
# 16                    2005-02-14     ГРП           1287
# 17                    2001-10-01     ВНС           1299
# 18                    2001-10-10     ГРП           1299
# 19                    1994-01-01     ГРП          1309Б
# 20                    2002-11-13     ГРП          1309Б
# 21                    1994-03-01     ГРП           1317
# 22                    2014-04-17     ВНС           1338
# 23                    2017-11-09     ВНС           2715
# 24                    2017-11-24     ГРП           2715
# 25                    2018-03-30     ГРП            32Р
# 26                    1996-11-07     ГРП           3938
# 27                    1994-12-26     ГРП            439
# 28                    1999-11-29     ГРП            459
# 29                    2012-09-26     ГРП            459
# 30                    1996-03-22     ГРП           4768
# 31                    2003-08-01     ВНС           5112
# 32                    2009-02-01     ГРП           5112
# 33                    1994-06-01     ГРП           5216
# 34                    1997-05-19     ГРП           5218
# 35                    1999-12-08     ГРП           5220
# 36                    1999-07-05     ГРП           5233
# 37                    2004-10-21     ГРП           5233
# 38                    2019-04-14     ГРП           5233
# 39                    1998-05-13     ВНС           5234
# 40                    1998-10-03     ВНС           5247
# 41                    1999-03-30     ГРП           5247
# 42                    1999-11-19     ГРП           5280
# 43                    1995-03-01     ГРП            546
# 44                    2002-09-03     ГРП            546
# 45                    2006-06-07     ГРП            546
# 46                    1995-06-01     ГРП            597
# 47                    2004-12-24     ГРП            597

# %%
#!!!!!!!!!!!!!!!!!!!!!!!!
grp_gang['Полудлина трещины, м'] = grp_gang.apply(
            lambda x:
            100, axis=1)
grp_gang['Ширина трещины, мм'] = grp_gang.apply(
            lambda x:
            4, axis=1)
grp_gang['Проницаемость проппанта, Д'] = grp_gang.apply(
            lambda x:
            100, axis=1)
grp_gang['Полудлина трещины, м'] = grp_gang.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Полудлина трещины, м']
            , axis=1)
grp_gang['Ширина трещины, мм'] = grp_gang.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Ширина трещины, мм']
            , axis=1)
grp_gang['Проницаемость проппанта, Д'] = grp_gang.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Проницаемость проппанта, Д']
            , axis=1)
        # ДОБАВИТЬ В ВНС
grp_gang['Число стадий ГРП'] = grp_gang.apply(
            lambda x:
            1, axis=1)
grp_gang['Число стадий ГРП'] = grp_gang.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Число стадий ГРП']
            , axis=1)
wells_GTM = wells_GTM.merge(grp_gang, on='Номер скважины')
wells_GTM['ГС/ННС'] = wells_GTM.apply(
            lambda x:
            'ННС' if x['Длина ГС, м'] == 0
            else 'ГС', axis=1)
# редактируем его в зависимости от наличия грп
wells_GTM['ГС/ННС'] = wells_GTM.apply(
            lambda x:
            str(x['ГС/ННС']) + '+ГРП' if str(x['Тип ГТМ']) == 'ГРП'
            else x['ГС/ННС'], axis=1)
new_400 = wells_GTM['Номер скважины'].tolist()
wells_GTM['Скважина №'] = new_400
wells_GTM = wells_GTM.drop(['Номер скважины'], axis=1)
wells_GTM['Пласт'] = wells_GTM.apply(
            lambda x:
            plastt, axis=1)
wells_GTM = wells_GTM.reindex(
            columns=['Скважина №', 'Длина ГС, м', 'Число стадий ГРП', 'Полудлина трещины, м', 'Ширина трещины, мм',
                     'Проницаемость проппанта, Д', 'Дата ВНР после ГС \ ГРП \ЗБГС', 'ГС/ННС', 'Тип ГТМ', 'Пласт'])
wells_GTM
    #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1003     0.000000                 1                   100
# 1        1119     0.000000                 1                   100
# 2        1150     0.000000                 1                   100
# 3        1150     0.000000                 1                   100
# 4        1205     0.000000                 1                   100
# 5        1205     0.000000                 1                   100
# 6        1212     0.000000                 1                   100
# 7        1240     0.000000                 1                   100
# 8        1240     0.000000                 1                   100
# 9        1240     0.000000                 1                   100
# 10       1277     0.000000                 1                   100
# 11       1278     0.000000                 1                   100
# 12       1280     0.000000                 1                   100
# 13       1285     0.000000                 1                   100
# 14       1285     0.000000                 1                   100
# 15       1287     0.000000                 1                   100
# 16       1287     0.000000                 1                   100
# 17       1299     0.000000                 0                     0
# 18       1299     0.000000                 1                   100
# 19      1309Б     0.000000                 1                   100
# 20      1309Б     0.000000                 1                   100
# 21       1317     0.000000                 1                   100
# 22       1338   650.858664                 0                     0
# 23       2715   771.168594                 0                     0
# 24       2715   771.168594                 1                   100
# 25        32Р   294.864376                 1                   100
# 26       3938     0.000000                 1                   100
# 27        439     0.000000                 1                   100
# 28        459     0.000000                 1                   100
# 29        459     0.000000                 1                   100
# 30       4768     0.000000                 1                   100
# 31       5112     0.000000                 0                     0
# 32       5112     0.000000                 1                   100
# 33       5216     0.000000                 1                   100
# 34       5218     0.000000                 1                   100
# 35       5220     0.000000                 1                   100
# 36       5233     0.000000                 1                   100
# 37       5233     0.000000                 1                   100
# 38       5233     0.000000                 1                   100
# 39       5234     0.000000                 0                     0
# 40       5247     0.000000                 0                     0
# 41       5247     0.000000                 1                   100
# 42       5280     0.000000                 1                   100
# 43        546     0.000000                 1                   100
# 44        546     0.000000                 1                   100
# 45        546     0.000000                 1                   100
# 46        597     0.000000                 1                   100
# 47        597     0.000000                 1                   100
#
#     Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                    4                         100
# 1                    4                         100
# 2                    4                         100
# 3                    4                         100
# 4                    4                         100
# 5                    4                         100
# 6                    4                         100
# 7                    4                         100
# 8                    4                         100
# 9                    4                         100
# 10                   4                         100
# 11                   4                         100
# 12                   4                         100
# 13                   4                         100
# 14                   4                         100
# 15                   4                         100
# 16                   4                         100
# 17                   0                           0
# 18                   4                         100
# 19                   4                         100
# 20                   4                         100
# 21                   4                         100
# 22                   0                           0
# 23                   0                           0
# 24                   4                         100
# 25                   4                         100
# 26                   4                         100
# 27                   4                         100
# 28                   4                         100
# 29                   4                         100
# 30                   4                         100
# 31                   0                           0
# 32                   4                         100
# 33                   4                         100
# 34                   4                         100
# 35                   4                         100
# 36                   4                         100
# 37                   4                         100
# 38                   4                         100
# 39                   0                           0
# 40                   0                           0
# 41                   4                         100
# 42                   4                         100
# 43                   4                         100
# 44                   4                         100
# 45                   4                         100
# 46                   4                         100
# 47                   4                         100
#
#    Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт
# 0                     1995-09-01  ННС+ГРП     ГРП    Ю1
# 1                     1995-10-01  ННС+ГРП     ГРП    Ю1
# 2                     1994-10-01  ННС+ГРП     ГРП    Ю1
# 3                     1998-06-19  ННС+ГРП     ГРП    Ю1
# 4                     1996-03-04  ННС+ГРП     ГРП    Ю1
# 5                     2000-04-21  ННС+ГРП     ГРП    Ю1
# 6                     1994-09-01  ННС+ГРП     ГРП    Ю1
# 7                     1997-07-31  ННС+ГРП     ГРП    Ю1
# 8                     1999-12-10  ННС+ГРП     ГРП    Ю1
# 9                     2002-12-18  ННС+ГРП     ГРП    Ю1
# 10                    1995-09-01  ННС+ГРП     ГРП    Ю1
# 11                    1995-04-01  ННС+ГРП     ГРП    Ю1
# 12                    1993-07-01  ННС+ГРП     ГРП    Ю1
# 13                    1993-04-01  ННС+ГРП     ГРП    Ю1
# 14                    1998-04-28  ННС+ГРП     ГРП    Ю1
# 15                    1993-05-01  ННС+ГРП     ГРП    Ю1
# 16                    2005-02-14  ННС+ГРП     ГРП    Ю1
# 17                    2001-10-01      ННС     ВНС    Ю1
# 18                    2001-10-10  ННС+ГРП     ГРП    Ю1
# 19                    1994-01-01  ННС+ГРП     ГРП    Ю1
# 20                    2002-11-13  ННС+ГРП     ГРП    Ю1
# 21                    1994-03-01  ННС+ГРП     ГРП    Ю1
# 22                    2014-04-17       ГС     ВНС    Ю1
# 23                    2017-11-09       ГС     ВНС    Ю1
# 24                    2017-11-24   ГС+ГРП     ГРП    Ю1
# 25                    2018-03-30   ГС+ГРП     ГРП    Ю1
# 26                    1996-11-07  ННС+ГРП     ГРП    Ю1
# 27                    1994-12-26  ННС+ГРП     ГРП    Ю1
# 28                    1999-11-29  ННС+ГРП     ГРП    Ю1
# 29                    2012-09-26  ННС+ГРП     ГРП    Ю1
# 30                    1996-03-22  ННС+ГРП     ГРП    Ю1
# 31                    2003-08-01      ННС     ВНС    Ю1
# 32                    2009-02-01  ННС+ГРП     ГРП    Ю1
# 33                    1994-06-01  ННС+ГРП     ГРП    Ю1
# 34                    1997-05-19  ННС+ГРП     ГРП    Ю1
# 35                    1999-12-08  ННС+ГРП     ГРП    Ю1
# 36                    1999-07-05  ННС+ГРП     ГРП    Ю1
# 37                    2004-10-21  ННС+ГРП     ГРП    Ю1
# 38                    2019-04-14  ННС+ГРП     ГРП    Ю1
# 39                    1998-05-13      ННС     ВНС    Ю1
# 40                    1998-10-03      ННС     ВНС    Ю1
# 41                    1999-03-30  ННС+ГРП     ГРП    Ю1
# 42                    1999-11-19  ННС+ГРП     ГРП    Ю1
# 43                    1995-03-01  ННС+ГРП     ГРП    Ю1
# 44                    2002-09-03  ННС+ГРП     ГРП    Ю1
# 45                    2006-06-07  ННС+ГРП     ГРП    Ю1
# 46                    1995-06-01  ННС+ГРП     ГРП    Ю1
# 47                    2004-12-24  ННС+ГРП     ГРП    Ю1

# %%
grp_1 = copy.deepcopy(grp_gtm)
grp_1.reset_index(drop=True)
grp_1.reset_index(inplace=True)
grp_1['Скважина'] = grp_1.apply(
lambda x:
str(x['Скважина']), axis=1)
grp_1 = grp_1[grp_1['Скважина'].isin(my_wells_no_repeat)].reset_index(drop=True)
        #grp_1 = grp_1.drop(['С начала мероприятия', 'С начала года', 'За текущий месяц', 'P нас', 'В-ть жидк.', 'Коб'],
        #                   axis=1)
        #grp_1 = grp_1.drop(['Пл-ть нефти', 'Факт', 'План', 'Комментарий', 'Dэк', 'Пласт', 'Страница'], axis=1)
        #grp_1 = grp_1.drop(['Unnamed: 11', 'Hэфф', 'Pпл.2', 'H дин.1', 'Pзаб.2', 'Состояние.1', 'Кпр'], axis=1)
        #grp_1 = grp_1.drop(['Скин-фактор.1', 'Интервалы перф..1', 'Насос.1', 'Напор.1', 'Производительность.1'], axis=1)
        #grp_1 = grp_1.drop(
        #    ['%.2', 'Qж.2', 'Qн.2', 'Hспуск.1', 'Кач.1', 'Част.1', 'Lхода.1', 'Метод.1', 'Скин-фактор', 'Pзаб.1',
        #     'Метод', 'Re'], axis=1)
        #grp_1 = grp_1.drop(['Pпл.1', '%.1', 'Qж.1', 'Qн.1', 'Окончание', 'Начало', 'Производительность', 'Насос'],
        #                   axis=1)
        #grp_1 = grp_1.drop(['Интервалы перф.', 'Hвд', 'Состояние', 'Pзаб', 'Pпл', 'H дин', 'Lхода', 'Напор'], axis=1)
        #grp_1 = grp_1.drop(['Месторождение', 'Unnamed: 0', 'Куст', 'Част', 'Кач', 'Hспуск', 'Qн', 'Qж', '%'], axis=1)
        #grp_1 = grp_1[grp_1['Скважина'].isin(my_wells_no_repeat)].reset_index(drop=True)
        # даты введения ГРП и ВНС на скважинах очень важно!!!!!!!
grp_3 = copy.deepcopy(grp_1)
grp_3['Дата ВНР после ГС \\ ГРП \\ЗБГС'] = grp_3.apply(
lambda x:
x['ВНР.1'] if 'КР7-2' in str(x['Краткое описание мероприятий'])
else x['Начало.1'] if 'Ввод добывающих сква' in str(x['Краткое описание мероприятий'])
else 'нет', axis=1)
grp_3['Тип ГТМ'] = grp_3.apply(
lambda x:
'ГРП' if 'КР7-2' in str(x['Краткое описание мероприятий'])
else 'ВНС' if 'Ввод добывающих сква' in str(x['Краткое описание мероприятий'])
else 'нет', axis=1)
grp_3 = grp_3.drop(grp_3[grp_3['Дата ВНР после ГС \\ ГРП \\ЗБГС'] == 'нет'].index)
grp_3 = grp_3.groupby(by=['Скважина', 'Дата ВНР после ГС \ ГРП \ЗБГС']).agg(
{'Тип ГТМ': lambda x:
x.tolist()[0]}
)
grp_3.reset_index(inplace=True)
vvv = grp_3['Скважина'].tolist()

grp_3['Номер скважины'] = vvv
grp_3 = grp_3.drop(['Скважина'], axis=1)
grp_3.loc[grp_3['Номер скважины'] == '5217']
# Out:
#     Дата ВНР после ГС \ ГРП \ЗБГС Тип ГТМ Номер скважины
# 256                    2001-11-01     ВНС           5217
# 257                    2004-09-03     ГРП           5217

# %%
grp_2 = copy.deepcopy(grp_1)
grp_2['ГРП'] = grp_2.apply(
lambda x:
'грп' if 'КР7-2' in str(x['Краткое описание мероприятий'])
else 'вдс' if 'Ввод добывающих сква' in str(x['Краткое описание мероприятий'])
else 'нет', axis=1)
grp_2 = grp_2.drop(grp_2[grp_2['ГРП'] == 'нет'].index)
grp_2 = grp_2.groupby('Скважина').agg(
{'ГРП': lambda x:
x.tolist()}
)
grp_2.reset_index(inplace=True)
        #for i in grp_2['ГРП']:
        #    if 'вдс' in i:
        #        i.remove('вдс')
new_1 = grp_2['Скважина'].tolist()
grp_2['Номер скважины'] = new_1
grp_2 = grp_2.drop(['Скважина'], axis=1)

# %%
        #WARNINGS???????????????????????????
        final = final.merge(grp_3, on='Номер скважины', how='right')
        #final = final.merge(grp_2, on='Номер скважины')
        #final['Число стадий ГРП'] = final.apply(
        #    lambda x:
        #    len(x['ГРП']) if len(x['ГРП']) > 0
        #    else 0, axis=1)
        final['Число стадий ГРП'] = final.apply(
            lambda x:
            3, axis=1)
        #final = final.drop(['ГРП'], axis=1)
        #WARNINGS??????????????????????
        final.loc[final['Номер скважины'] == '5217']
# Out:
#      Номер скважины                   Unnamed: 0       Дата Подрядчик  \
# 1076           5217  Проблемы при построении ГРП 2004-08-28       МКН
# 1077           5217  Проблемы при построении ГРП 2004-08-28       МКН
#
#                                             Комментарии Страница  Unnamed: 6  \
# 1076  Пробка на миниГРП. Длительная закачка на высок...      -1_         NaN
# 1077  Пробка на миниГРП. Длительная закачка на высок...      -1_         NaN
#
#      Пласт  Азимут    k  ...    Конц  Гель  М бр  V под  V без под  V гель  \
# 1076    Ю1     NaN  1.5  ...  1100.0   NaN   NaN   75.0      215.0     NaN
# 1077    Ю1     NaN  1.5  ...  1100.0   NaN   NaN   75.0      215.0     NaN
#
#       Длиина ГС, м  Дата ВНР после ГС \ ГРП \ЗБГС  Тип ГТМ  Число стадий ГРП
# 1076           0.0                     2001-11-01      ВНС                 3
# 1077           0.0                     2004-09-03      ГРП                 3
#
# [2 rows x 39 columns]

# %%
       # число стадий грп по фраклисту
final = final.drop(['Дата'], axis=1)
final_re = final.groupby(by=['Номер скважины']).agg(
            {'Число стадий ГРП': lambda x:
            statistics.mean(x)}
        )
final_re.reset_index(inplace=True)
final_re.loc[final_re['Номер скважины'] == '5217']
# Out:
#    Номер скважины  Число стадий ГРП
# 98           5217                 3

# %%
final_go = final.groupby(by=['Номер скважины']).agg(
            {'Длиина ГС, м': lambda x:
            max(x)}
        )
final_go.reset_index(inplace=True)
final_re = final_re.merge(final_go, on='Номер скважины')
final_re.loc[final_re['Номер скважины'] == '5217']
# Out:
#    Номер скважины  Число стадий ГРП  Длиина ГС, м
# 98           5217                 3           0.0

# %%
final_re['Число стадий ГРП'] = final_re.apply(
            lambda x:
            1 if x['Длиина ГС, м'] == 0 and x['Число стадий ГРП'] >= 1
            else x['Число стадий ГРП'], axis=1)
final_re1 = copy.deepcopy(final_re)

final_re1 = final_re1.drop(final_re1[final_re1['Длиина ГС, м'] == 0].index).reset_index(drop=True)
spisok = final_re1['Номер скважины'].tolist()
        # берем число строк из фраклиста для скважины
final = final.groupby('Номер скважины').agg(
            {'Число стадий ГРП': lambda x:
            x.tolist()}
        )

final['Количество'] = final.apply(
            lambda x:
            len(x['Число стадий ГРП'])
            , axis=1)
final.reset_index(inplace=True)
final = final[final['Номер скважины'].isin(spisok)].reset_index(drop=True)
final = final.drop(['Число стадий ГРП'], axis=1)
final_re2 = final_re.merge(final, on='Номер скважины',how='left')
final_re2.loc[final_re2['Номер скважины'] == '5217']
# Out:
#    Номер скважины  Число стадий ГРП  Длиина ГС, м  Количество
# 98           5217                 1           0.0         NaN

# %%
final_re2 = final_re2.drop(['Число стадий ГРП'], axis=1)
cv = final_re2['Количество'].tolist()
final_re2['Число стадий ГРП'] = cv
final_re2 = final_re2.drop(['Количество'], axis=1)
final_re = final_re[~final_re['Номер скважины'].isin(spisok)].reset_index(drop=True)
new_file = pd.concat([final_re, final_re2])
grp = grp.groupby('Номер скважины').agg(
            {'Пласт': lambda x:
            x.tolist()[0]}
        )
grp.reset_index(inplace=True)
new_file = new_file.merge(grp, on='Номер скважины')
new_file['Полудлина трещины, м'] = new_file.apply(
            lambda x:
            100, axis=1)
new_file['Ширина трещины, мм'] = new_file.apply(
            lambda x:
            4, axis=1)
new_file['Проницаемость проппанта, Д'] = new_file.apply(
            lambda x:
            100, axis=1)
        # объединение грп и нью файла по скважинам
sotired = grp_3.merge(new_file, on='Номер скважины')
        # добавляем последнй столбец
sotired['ГС/ННС'] = sotired.apply(
            lambda x:
            'ННС' if x['Длиина ГС, м'] == 0
            else 'ГС', axis=1)
        # редактируем его в зависимости от наличия грп
sotired['ГС/ННС'] = sotired.apply(
            lambda x:
            str(x['ГС/ННС']) + '+ГРП' if str(x['Тип ГТМ']) == 'ГРП'
            else x['ГС/ННС'], axis=1)
        # перемещаем столбцы в нужном порядке
r = sotired.pop('Дата ВНР после ГС \ ГРП \ЗБГС')
sotired1 = pd.concat([sotired, r], 1)
        # перемещаем столбцы в нужном порядке
q = sotired1.pop('ГС/ННС')
sotired2 = pd.concat([sotired1, q], 1)
        # перемещаем столбцы в нужном порядке
z = sotired2.pop('Тип ГТМ')
sotired3 = pd.concat([sotired2, z], 1)
        # перемещаем столбцы в нужном порядке
d = sotired3.pop('Пласт')
sotired4 = pd.concat([sotired3, d], 1)
i = sotired4['Номер скважины'].tolist()
sotired4['Скважина №'] = i
sotired4 = sotired4.drop(['Номер скважины'], axis=1)
sotired_final = sotired4.reindex(
columns=['Скважина №', 'Длиина ГС, м', 'Число стадий ГРП', 'Полудлина трещины, м', 'Ширина трещины, мм',
                     'Проницаемость проппанта, Д', 'Дата ВНР после ГС \ ГРП \ЗБГС', 'ГС/ННС', 'Тип ГТМ', 'Пласт'])
sotired_final['Число стадий ГРП'] = sotired.apply(
            lambda x:
            0 if str(x['Тип ГТМ']) == 'ВНС'
            else x['Число стадий ГРП'], axis=1)
n = 1
z = sotired_final['Пласт'].value_counts()[:n].index.tolist()
plast = str(z[0])
sotired_final = sotired_final.drop(sotired_final[sotired_final['Пласт'] != plast].index).reset_index(drop=True)
zzz = sotired_final['Длиина ГС, м'].tolist()
sotired_final['Длина ГС, м'] = zzz

sotired_final = sotired_final.drop(['Длиина ГС, м'], axis=1)
sotired_final = sotired_final.reindex(
            columns=['Скважина №', 'Длина ГС, м', 'Число стадий ГРП', 'Полудлина трещины, м', 'Ширина трещины, мм',
                     'Проницаемость проппанта, Д', 'Дата ВНР после ГС \ ГРП \ЗБГС', 'ГС/ННС', 'Тип ГТМ', 'Пласт'])
        #корректное число стадий для грп разных периодов из ФРАКЛИСТА
sotired_final['Дата ВНР после ГС \ ГРП \ЗБГС'] = sotired_final.apply(
            lambda x:
            str(x['Дата ВНР после ГС \ ГРП \ЗБГС']), axis=1)
sotired_final['месяц с грп'] = sotired_final.apply(
            lambda x:
            x['Дата ВНР после ГС \ ГРП \ЗБГС'][:4],
            axis=1
        )
grp_number = copy.deepcopy(grp_dad)
#grp_number.reset_index(drop=True)
#grp_number.reset_index(inplace=True)

        # grp=grp.drop(['Unnamed: 0','Подрядчик','Комментарии','Страница','Unnamed: 6','Азимут'],axis=1)
        # grp=grp.drop(['V гель','V без под','V под','М бр','Гель','Конц','Расход','Эфф','Рпл Хорнер','Проппант','k','Ноб','Нэф','Верх','Низ'],axis=1)
        # grp=grp.drop(['Xf','Hf','Wf','PIdsg','Скин-фактор','JD','FCD','М пр','Покр','План'],axis=1)
grp_number['Номер скважины'] = grp_number.apply(
            lambda x:
            str(x['Номер скважины']), axis=1)
grp_number['Дата'] = grp_number.apply(
            lambda x:
            str(x['Дата']), axis=1)
grp_number['месяц с грп'] = grp_number.apply(
            lambda x:
            x['Дата'][:4],
            axis=1
        )
grp_number_group = grp_number.groupby(by=['Номер скважины', 'месяц с грп']).agg(
            {'Наклон': lambda x:
            x.tolist()}
        )
grp_number_group.reset_index(inplace=True)
grp_number_group['число стадий'] = grp_number_group.apply(
            lambda x:
            len(x['Наклон']), axis=1)
grp_number_group = grp_number_group.drop('Наклон', axis=1)
blabla = grp_number_group['Номер скважины'].tolist()

grp_number_group['Скважина №'] = blabla
grp_number_group = grp_number_group.drop(['Номер скважины'], axis=1)
sotired_final = sotired_final.merge(grp_number_group, on=['месяц с грп', 'Скважина №'],how='left')
milan = sotired_final['число стадий'].tolist()
sotired_final = sotired_final.drop(['Число стадий ГРП'], axis=1)
sotired_final['Число стадий ГРП'] = milan
sotired_final = sotired_final.drop(['число стадий'], axis=1)
sotired_final['Дата ВНР после ГС \ ГРП \ЗБГС']=pd.to_datetime(sotired_final['Дата ВНР после ГС \ ГРП \ЗБГС'])
sotired_final = sotired_final.reindex(
            columns=['Скважина №', 'Длина ГС, м', 'Число стадий ГРП', 'Полудлина трещины, м', 'Ширина трещины, мм',
                     'Проницаемость проппанта, Д', 'Дата ВНР после ГС \ ГРП \ЗБГС', 'ГС/ННС', 'Тип ГТМ', 'Пласт',
                     'месяц с грп'])
sotired_final = pd.concat([sotired_final, wells_GTM])
# Out:
# C:\Users\USER\miniconda3\lib\site-packages\ipykernel_launcher.py:36: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
# C:\Users\USER\miniconda3\lib\site-packages\ipykernel_launcher.py:39: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
# C:\Users\USER\miniconda3\lib\site-packages\ipykernel_launcher.py:42: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
# C:\Users\USER\miniconda3\lib\site-packages\ipykernel_launcher.py:45: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only

# %%
        
        
        
        
        
        
        
        
        
        
        
        
        


        # ставим нули для ВНС
sotired_final['Полудлина трещины, м'] = sotired_final.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Полудлина трещины, м']
            , axis=1)
sotired_final['Ширина трещины, мм'] = sotired_final.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Ширина трещины, мм']
            , axis=1)
sotired_final['Проницаемость проппанта, Д'] = sotired_final.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Проницаемость проппанта, Д']
            , axis=1)
        # ДОБАВИТЬ В ВНС
sotired_final['Число стадий ГРП'] = sotired_final.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Число стадий ГРП']
            , axis=1)
sotired_final
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0         101   288.849442               3.0                   100
# 1        1028   369.891876               6.0                   100
# 2        1060   614.642172               0.0                     0
# 3        1060   614.642172               7.0                   100
# 4        1138     0.000000               NaN                   100
# ..        ...          ...               ...                   ...
# 43        546     0.000000               1.0                   100
# 44        546     0.000000               1.0                   100
# 45        546     0.000000               1.0                   100
# 46        597     0.000000               1.0                   100
# 47        597     0.000000               1.0                   100
#
#     Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                    4                         100
# 1                    4                         100
# 2                    0                           0
# 3                    4                         100
# 4                    4                         100
# ..                 ...                         ...
# 43                   4                         100
# 44                   4                         100
# 45                   4                         100
# 46                   4                         100
# 47                   4                         100
#
#    Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп
# 0                     2015-04-26   ГС+ГРП     ГРП    Ю1        2015
# 1                     2019-04-05   ГС+ГРП     ГРП    Ю1        2019
# 2                     2017-05-08       ГС     ВНС    Ю1        2017
# 3                     2017-05-17   ГС+ГРП     ГРП    Ю1        2017
# 4                     2001-12-30  ННС+ГРП     ГРП    Ю1        2001
# ..                           ...      ...     ...   ...         ...
# 43                    1995-03-01  ННС+ГРП     ГРП    Ю1         NaN
# 44                    2002-09-03  ННС+ГРП     ГРП    Ю1         NaN
# 45                    2006-06-07  ННС+ГРП     ГРП    Ю1         NaN
# 46                    1995-06-01  ННС+ГРП     ГРП    Ю1         NaN
# 47                    2004-12-24  ННС+ГРП     ГРП    Ю1         NaN
#
# [461 rows x 11 columns]

# %%
sotired_final.loc[sotired_final['Скважина №'] == '5217']
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 371       5217          0.0               0.0                     0
# 372       5217          0.0               0.0                     0
# 373       5217          0.0               1.0                   100
# 374       5217          0.0               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 371                   0                           0
# 372                   0                           0
# 373                   4                         100
# 374                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп
# 371                    2001-11-01      ННС     ВНС    Ю1        2001
# 372                    2001-11-01      ННС     ВНС    Ю1        2001
# 373                    2004-09-03  ННС+ГРП     ГРП    Ю1        2004
# 374                    2004-09-03  ННС+ГРП     ГРП    Ю1        2004

# %%
sotired_final.reset_index(drop=True)
sotired_final.reset_index(inplace=True)
sotired_final
# Out:
#      index Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        0        101   288.849442               3.0                   100
# 1        1       1028   369.891876               6.0                   100
# 2        2       1060   614.642172               0.0                     0
# 3        3       1060   614.642172               7.0                   100
# 4        4       1138     0.000000               NaN                   100
# ..     ...        ...          ...               ...                   ...
# 456     43        546     0.000000               1.0                   100
# 457     44        546     0.000000               1.0                   100
# 458     45        546     0.000000               1.0                   100
# 459     46        597     0.000000               1.0                   100
# 460     47        597     0.000000               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     4                         100
# 1                     4                         100
# 2                     0                           0
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 456                   4                         100
# 457                   4                         100
# 458                   4                         100
# 459                   4                         100
# 460                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп
# 0                      2015-04-26   ГС+ГРП     ГРП    Ю1        2015
# 1                      2019-04-05   ГС+ГРП     ГРП    Ю1        2019
# 2                      2017-05-08       ГС     ВНС    Ю1        2017
# 3                      2017-05-17   ГС+ГРП     ГРП    Ю1        2017
# 4                      2001-12-30  ННС+ГРП     ГРП    Ю1        2001
# ..                            ...      ...     ...   ...         ...
# 456                    1995-03-01  ННС+ГРП     ГРП    Ю1         NaN
# 457                    2002-09-03  ННС+ГРП     ГРП    Ю1         NaN
# 458                    2006-06-07  ННС+ГРП     ГРП    Ю1         NaN
# 459                    1995-06-01  ННС+ГРП     ГРП    Ю1         NaN
# 460                    2004-12-24  ННС+ГРП     ГРП    Ю1         NaN
#
# [461 rows x 12 columns]

# %%
#sotired_final = sotired_final.drop(['level_0'], axis=1)
sotired_final = sotired_final.drop(['index'], axis=1)

# %%
sotired_final["is_duplicate"]= sotired_final.duplicated()
sotired_final.loc[sotired_final['Скважина №'] == '5217']
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 371       5217          0.0               0.0                     0
# 372       5217          0.0               0.0                     0
# 373       5217          0.0               1.0                   100
# 374       5217          0.0               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 371                   0                           0
# 372                   0                           0
# 373                   4                         100
# 374                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 371                    2001-11-01      ННС     ВНС    Ю1        2001
# 372                    2001-11-01      ННС     ВНС    Ю1        2001
# 373                    2004-09-03  ННС+ГРП     ГРП    Ю1        2004
# 374                    2004-09-03  ННС+ГРП     ГРП    Ю1        2004
#
#      is_duplicate
# 371         False
# 372          True
# 373         False
# 374          True

# %%
sotired_final = sotired_final.drop(sotired_final[sotired_final['is_duplicate'] == True].index)
sotired_final.loc[sotired_final['Скважина №'] == '5217']
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 371       5217          0.0               0.0                     0
# 373       5217          0.0               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 371                   0                           0
# 373                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 371                    2001-11-01      ННС     ВНС    Ю1        2001
# 373                    2004-09-03  ННС+ГРП     ГРП    Ю1        2004
#
#      is_duplicate
# 371         False
# 373         False

# %%
sotired_final
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0          101   288.849442               3.0                   100
# 1         1028   369.891876               6.0                   100
# 2         1060   614.642172               0.0                     0
# 3         1060   614.642172               7.0                   100
# 4         1138     0.000000               NaN                   100
# ..         ...          ...               ...                   ...
# 456        546     0.000000               1.0                   100
# 457        546     0.000000               1.0                   100
# 458        546     0.000000               1.0                   100
# 459        597     0.000000               1.0                   100
# 460        597     0.000000               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     4                         100
# 1                     4                         100
# 2                     0                           0
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 456                   4                         100
# 457                   4                         100
# 458                   4                         100
# 459                   4                         100
# 460                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2015-04-26   ГС+ГРП     ГРП    Ю1        2015
# 1                      2019-04-05   ГС+ГРП     ГРП    Ю1        2019
# 2                      2017-05-08       ГС     ВНС    Ю1        2017
# 3                      2017-05-17   ГС+ГРП     ГРП    Ю1        2017
# 4                      2001-12-30  ННС+ГРП     ГРП    Ю1        2001
# ..                            ...      ...     ...   ...         ...
# 456                    1995-03-01  ННС+ГРП     ГРП    Ю1         NaN
# 457                    2002-09-03  ННС+ГРП     ГРП    Ю1         NaN
# 458                    2006-06-07  ННС+ГРП     ГРП    Ю1         NaN
# 459                    1995-06-01  ННС+ГРП     ГРП    Ю1         NaN
# 460                    2004-12-24  ННС+ГРП     ГРП    Ю1         NaN
#
#      is_duplicate
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 456         False
# 457         False
# 458         False
# 459         False
# 460         False
#
# [316 rows x 12 columns]

# %%
sotired_final.reset_index(inplace=True)
sotired_final = sotired_final.drop(['index'], axis=1)
sotired_final['level_0'] = sotired_final.index
sotired_final
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0          101   288.849442               3.0                   100
# 1         1028   369.891876               6.0                   100
# 2         1060   614.642172               0.0                     0
# 3         1060   614.642172               7.0                   100
# 4         1138     0.000000               NaN                   100
# ..         ...          ...               ...                   ...
# 311        546     0.000000               1.0                   100
# 312        546     0.000000               1.0                   100
# 313        546     0.000000               1.0                   100
# 314        597     0.000000               1.0                   100
# 315        597     0.000000               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     4                         100
# 1                     4                         100
# 2                     0                           0
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 311                   4                         100
# 312                   4                         100
# 313                   4                         100
# 314                   4                         100
# 315                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2015-04-26   ГС+ГРП     ГРП    Ю1        2015
# 1                      2019-04-05   ГС+ГРП     ГРП    Ю1        2019
# 2                      2017-05-08       ГС     ВНС    Ю1        2017
# 3                      2017-05-17   ГС+ГРП     ГРП    Ю1        2017
# 4                      2001-12-30  ННС+ГРП     ГРП    Ю1        2001
# ..                            ...      ...     ...   ...         ...
# 311                    1995-03-01  ННС+ГРП     ГРП    Ю1         NaN
# 312                    2002-09-03  ННС+ГРП     ГРП    Ю1         NaN
# 313                    2006-06-07  ННС+ГРП     ГРП    Ю1         NaN
# 314                    1995-06-01  ННС+ГРП     ГРП    Ю1         NaN
# 315                    2004-12-24  ННС+ГРП     ГРП    Ю1         NaN
#
#      is_duplicate  level_0
# 0           False        0
# 1           False        1
# 2           False        2
# 3           False        3
# 4           False        4
# ..            ...      ...
# 311         False      311
# 312         False      312
# 313         False      313
# 314         False      314
# 315         False      315
#
# [316 rows x 13 columns]

# %%
#удаляем если в одном месяце
dele = copy.deepcopy(sotired_final)
dele['чек'] = dele.apply(
            lambda x:
            x['Скважина №'].partition('_')[0] if '_' in str(x['Скважина №'])
            else x['Скважина №'], axis=1)
dele['месяц'] =dele.apply(
            lambda x:
            str(x['Дата ВНР после ГС \ ГРП \ЗБГС'])[:7],
            axis=1
        )
dele = dele.groupby(by=['чек','месяц']).agg(
            {'level_0': lambda x:
            x.tolist()}
        )
dele['скока_их'] = dele.apply(
            lambda x: len(x['level_0'])
            , axis=1)
dele = dele.drop(dele[dele['скока_их'] < 2].index).reset_index(drop=True)
to_stay=[]
all_wells=[]
for i in dele['level_0']:    
    all_wells+=i
for i in dele['level_0']:    
    to_stay.append(i[-1])

to_stay
# Out:
# [3,
#  67,
#  73,
#  286,
#  90,
#  92,
#  94,
#  96,
#  99,
#  102,
#  104,
#  107,
#  111,
#  114,
#  117,
#  119,
#  121,
#  123,
#  125,
#  127,
#  129,
#  131,
#  133,
#  135,
#  137,
#  141,
#  143,
#  145,
#  149,
#  151,
#  153,
#  156,
#  158,
#  160,
#  163,
#  166,
#  292,
#  173,
#  176,
#  180,
#  182,
#  194,
#  215,
#  217,
#  219,
#  222,
#  224,
#  227,
#  229,
#  232,
#  234,
#  248,
#  254,
#  256,
#  258,
#  261,
#  264]

# %%
all_wells
# Out:
# [2,
#  3,
#  66,
#  67,
#  72,
#  73,
#  285,
#  286,
#  89,
#  90,
#  91,
#  92,
#  93,
#  94,
#  95,
#  96,
#  98,
#  99,
#  101,
#  102,
#  103,
#  104,
#  106,
#  107,
#  110,
#  111,
#  113,
#  114,
#  116,
#  117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  123,
#  124,
#  125,
#  126,
#  127,
#  128,
#  129,
#  130,
#  131,
#  132,
#  133,
#  134,
#  135,
#  136,
#  137,
#  140,
#  141,
#  142,
#  143,
#  144,
#  145,
#  148,
#  149,
#  150,
#  151,
#  152,
#  153,
#  154,
#  155,
#  156,
#  157,
#  158,
#  159,
#  160,
#  162,
#  163,
#  165,
#  166,
#  291,
#  292,
#  172,
#  173,
#  175,
#  176,
#  179,
#  180,
#  181,
#  182,
#  193,
#  194,
#  214,
#  215,
#  216,
#  217,
#  218,
#  219,
#  221,
#  222,
#  223,
#  224,
#  226,
#  227,
#  228,
#  229,
#  231,
#  232,
#  233,
#  234,
#  247,
#  248,
#  253,
#  254,
#  255,
#  256,
#  257,
#  258,
#  260,
#  261,
#  263,
#  264]

# %%
array_3 = list(all_wells)
for x in to_stay:
    try:
        array_3.remove(x)
    except ValueError:
        pass
array_3
# Out:
# [2,
#  66,
#  72,
#  285,
#  89,
#  91,
#  93,
#  95,
#  98,
#  101,
#  103,
#  106,
#  110,
#  113,
#  116,
#  118,
#  120,
#  122,
#  124,
#  126,
#  128,
#  130,
#  132,
#  134,
#  136,
#  140,
#  142,
#  144,
#  148,
#  150,
#  152,
#  154,
#  155,
#  157,
#  159,
#  162,
#  165,
#  291,
#  172,
#  175,
#  179,
#  181,
#  193,
#  214,
#  216,
#  218,
#  221,
#  223,
#  226,
#  228,
#  231,
#  233,
#  247,
#  253,
#  255,
#  257,
#  260,
#  263]

# %%
sotired_final = sotired_final[~sotired_final['level_0'].isin(array_3)].reset_index(drop=True)
sotired_final
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0          101   288.849442               3.0                   100
# 1         1028   369.891876               6.0                   100
# 2         1060   614.642172               7.0                   100
# 3         1138     0.000000               NaN                   100
# 4         1138     0.000000               1.0                   100
# ..         ...          ...               ...                   ...
# 253        546     0.000000               1.0                   100
# 254        546     0.000000               1.0                   100
# 255        546     0.000000               1.0                   100
# 256        597     0.000000               1.0                   100
# 257        597     0.000000               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     4                         100
# 1                     4                         100
# 2                     4                         100
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 253                   4                         100
# 254                   4                         100
# 255                   4                         100
# 256                   4                         100
# 257                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2015-04-26   ГС+ГРП     ГРП    Ю1        2015
# 1                      2019-04-05   ГС+ГРП     ГРП    Ю1        2019
# 2                      2017-05-17   ГС+ГРП     ГРП    Ю1        2017
# 3                      2001-12-30  ННС+ГРП     ГРП    Ю1        2001
# 4                      2006-05-02  ННС+ГРП     ГРП    Ю1        2006
# ..                            ...      ...     ...   ...         ...
# 253                    1995-03-01  ННС+ГРП     ГРП    Ю1         NaN
# 254                    2002-09-03  ННС+ГРП     ГРП    Ю1         NaN
# 255                    2006-06-07  ННС+ГРП     ГРП    Ю1         NaN
# 256                    1995-06-01  ННС+ГРП     ГРП    Ю1         NaN
# 257                    2004-12-24  ННС+ГРП     ГРП    Ю1         NaN
#
#      is_duplicate  level_0
# 0           False        0
# 1           False        1
# 2           False        3
# 3           False        4
# 4           False        5
# ..            ...      ...
# 253         False      311
# 254         False      312
# 255         False      313
# 256         False      314
# 257         False      315
#
# [258 rows x 13 columns]

# %%
sotired_final = sotired_final.drop(['level_0'], axis=1)
sotired_final
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0          101   288.849442               3.0                   100
# 1         1028   369.891876               6.0                   100
# 2         1060   614.642172               7.0                   100
# 3         1138     0.000000               NaN                   100
# 4         1138     0.000000               1.0                   100
# ..         ...          ...               ...                   ...
# 253        546     0.000000               1.0                   100
# 254        546     0.000000               1.0                   100
# 255        546     0.000000               1.0                   100
# 256        597     0.000000               1.0                   100
# 257        597     0.000000               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     4                         100
# 1                     4                         100
# 2                     4                         100
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 253                   4                         100
# 254                   4                         100
# 255                   4                         100
# 256                   4                         100
# 257                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2015-04-26   ГС+ГРП     ГРП    Ю1        2015
# 1                      2019-04-05   ГС+ГРП     ГРП    Ю1        2019
# 2                      2017-05-17   ГС+ГРП     ГРП    Ю1        2017
# 3                      2001-12-30  ННС+ГРП     ГРП    Ю1        2001
# 4                      2006-05-02  ННС+ГРП     ГРП    Ю1        2006
# ..                            ...      ...     ...   ...         ...
# 253                    1995-03-01  ННС+ГРП     ГРП    Ю1         NaN
# 254                    2002-09-03  ННС+ГРП     ГРП    Ю1         NaN
# 255                    2006-06-07  ННС+ГРП     ГРП    Ю1         NaN
# 256                    1995-06-01  ННС+ГРП     ГРП    Ю1         NaN
# 257                    2004-12-24  ННС+ГРП     ГРП    Ю1         NaN
#
#      is_duplicate
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 253         False
# 254         False
# 255         False
# 256         False
# 257         False
#
# [258 rows x 12 columns]

# %%
sotired_final.loc[sotired_final['Скважина №'] == '1183']
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 17       1183   363.207929               NaN                   100
#
#     Ширина трещины, мм  Проницаемость проппанта, Д  \
# 17                   4                         100
#
#    Дата ВНР после ГС \ ГРП \ЗБГС  ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 17                    1993-06-01  ГС+ГРП     ГРП    Ю1        1993
#
#     is_duplicate
# 17         False

# %%
        # проверяем ЗБС
grp_4 = copy.deepcopy(grp_gtm)

grp_4['Скважина'] = grp_4.apply(
            lambda x:
            str(x['Скважина']), axis=1)
grp_4 = grp_4[grp_4['Скважина'].isin(my_wells_no_repeat+my_wells_only_gtm)].reset_index(drop=True)
#grp_4
grp_zbs = grp_4.drop(grp_4[grp_4['Тип'] != '3БС'].index).reset_index(drop=True)
#grp_zbs = grp_4.loc[grp_4['Тип'] == 'ЗБС']
grp_zbs = grp_zbs.groupby('Скважина').agg(
            {'Начало.1': lambda x:
            x.tolist()[1] if len(x.tolist())>1
            else x.tolist()[0]}
        )
grp_zbs
# Out:
#            Начало.1
# Скважина
# 101      2015-02-21
# 1028     2019-04-24
# 1180     2018-11-09
# 1182     2017-06-01
# 1183     2017-09-25
# 1185     2018-03-10
# 1189     2013-07-03
# 1218     2019-04-03
# 1302     2013-11-19
# 1308     2014-02-26
# 1319     2009-07-21
# 1978     2018-02-14
# 2220     2019-04-08
# 235      2019-05-08
# 32Р      2018-02-10
# 3567     2019-09-08
# 407      2019-05-26
# 4346     2016-08-01
# 4732     2013-08-07
# 5202     2017-08-28
# 821      2017-04-18

# %%
grp_zbs.reset_index(drop=True)
grp_zbs.reset_index(inplace=True)
#grp_zbs

vv = grp_zbs['Скважина'].tolist()

grp_zbs['Скважина №'] = vv
grp_zbs = grp_zbs.drop(['Скважина'], axis=1)
sotired_final_zbs = sotired_final.merge(grp_zbs, on='Скважина №')
#sotired_final_zbs
abba = sotired_final_zbs['Скважина №'].tolist()
#abba

sotired_final_zbs['Длина ГС, м'] = sotired_final_zbs.apply(
            lambda x:
            0 if x['Дата ВНР после ГС \ ГРП \ЗБГС'] < x['Начало.1'] else x['Длина ГС, м'],
            axis=1
        )
sotired_final_zbs['Число стадий ГРП'] = sotired_final_zbs.apply(
            lambda x:
            1 if x['Дата ВНР после ГС \ ГРП \ЗБГС'] < x['Начало.1'] else x['Число стадий ГРП'],
            axis=1
        )
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            str(x['Скважина №'])
            + ('_Л' if x['Длина ГС, м'] == 0 else ''),
            axis=1
        )
sotired_final_zbs = sotired_final_zbs.drop(['Начало.1'], axis=1)
sotired_final = sotired_final[~sotired_final['Скважина №'].isin(abba)].reset_index(drop=True)
sotired_final = pd.concat([sotired_final, sotired_final_zbs])
sotired_final.reset_index(drop=True)
sotired_final.reset_index(inplace=True)
sotired_final
# Out:
#      index Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        0       1060   614.642172               7.0                   100
# 1        1       1138     0.000000               NaN                   100
# 2        2       1138     0.000000               1.0                   100
# 3        3       1157     0.000000               NaN                   100
# 4        4       1157     0.000000               1.0                   100
# ..     ...        ...          ...               ...                   ...
# 253     41     5202_Л     0.000000               1.0                   100
# 254     42     5202_Л     0.000000               1.0                   100
# 255     43       5202   307.247457               4.0                   100
# 256     44       5202   307.247457               1.0                   100
# 257     45        32Р   294.864376               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     4                         100
# 1                     4                         100
# 2                     4                         100
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 253                   4                         100
# 254                   4                         100
# 255                   4                         100
# 256                   4                         100
# 257                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2017-05-17   ГС+ГРП     ГРП    Ю1        2017
# 1                      2001-12-30  ННС+ГРП     ГРП    Ю1        2001
# 2                      2006-05-02  ННС+ГРП     ГРП    Ю1        2006
# 3                      1994-01-01  ННС+ГРП     ГРП    Ю1        1994
# 4                      2004-03-05  ННС+ГРП     ГРП    Ю1        2004
# ..                            ...      ...     ...   ...         ...
# 253                    1993-05-01   ГС+ГРП     ГРП    Ю1        1993
# 254                    2005-10-02   ГС+ГРП     ГРП    Ю1        2005
# 255                    2017-09-26   ГС+ГРП     ГРП    Ю1        2017
# 256                    2018-07-19   ГС+ГРП     ГРП    Ю1        2018
# 257                    2018-03-30   ГС+ГРП     ГРП    Ю1         NaN
#
#      is_duplicate
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 253         False
# 254         False
# 255         False
# 256         False
# 257         False
#
# [258 rows x 13 columns]

# %%
sotired_final.loc[sotired_final['Скважина №'] == '1180_Л']
# Out:
#      index Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 214      2     1180_Л          0.0               1.0                   100
# 215      3     1180_Л          0.0               1.0                   100
# 216      4     1180_Л          0.0               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 214                   4                         100
# 215                   4                         100
# 216                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС  ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 214                    1993-11-01  ГС+ГРП     ГРП    Ю1        1993
# 215                    1998-10-01  ГС+ГРП     ГРП    Ю1        1998
# 216                    2006-06-05  ГС+ГРП     ГРП    Ю1        2006
#
#      is_duplicate
# 214         False
# 215         False
# 216         False

# %%
#приставка ФРАК там где надо
sotired_final.reset_index(drop=True)
sotired_final.reset_index(inplace=True)
sotired_final
# Out:
#      level_0  index Скважина №  Длина ГС, м  Число стадий ГРП  \
# 0          0      0       1060   614.642172               7.0
# 1          1      1       1138     0.000000               NaN
# 2          2      2       1138     0.000000               1.0
# 3          3      3       1157     0.000000               NaN
# 4          4      4       1157     0.000000               1.0
# ..       ...    ...        ...          ...               ...
# 253      253     41     5202_Л     0.000000               1.0
# 254      254     42     5202_Л     0.000000               1.0
# 255      255     43       5202   307.247457               4.0
# 256      256     44       5202   307.247457               1.0
# 257      257     45        32Р   294.864376               1.0
#
#      Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     100                   4                         100
# 1                     100                   4                         100
# 2                     100                   4                         100
# 3                     100                   4                         100
# 4                     100                   4                         100
# ..                    ...                 ...                         ...
# 253                   100                   4                         100
# 254                   100                   4                         100
# 255                   100                   4                         100
# 256                   100                   4                         100
# 257                   100                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2017-05-17   ГС+ГРП     ГРП    Ю1        2017
# 1                      2001-12-30  ННС+ГРП     ГРП    Ю1        2001
# 2                      2006-05-02  ННС+ГРП     ГРП    Ю1        2006
# 3                      1994-01-01  ННС+ГРП     ГРП    Ю1        1994
# 4                      2004-03-05  ННС+ГРП     ГРП    Ю1        2004
# ..                            ...      ...     ...   ...         ...
# 253                    1993-05-01   ГС+ГРП     ГРП    Ю1        1993
# 254                    2005-10-02   ГС+ГРП     ГРП    Ю1        2005
# 255                    2017-09-26   ГС+ГРП     ГРП    Ю1        2017
# 256                    2018-07-19   ГС+ГРП     ГРП    Ю1        2018
# 257                    2018-03-30   ГС+ГРП     ГРП    Ю1         NaN
#
#      is_duplicate
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 253         False
# 254         False
# 255         False
# 256         False
# 257         False
#
# [258 rows x 14 columns]

# %%
step = sotired_final.drop(
            sotired_final[(sotired_final['ГС/ННС'] == 'ГС') | (sotired_final['ГС/ННС'] == 'ННС')].index)
step['для_фрак'] = step.apply(
            lambda x:
            x['Скважина №'].partition('_')[0] if '_' in str(x['Скважина №'])
            else x['Скважина №'], axis=1)
step
# Out:
#      level_0  index Скважина №  Длина ГС, м  Число стадий ГРП  \
# 0          0      0       1060   614.642172               7.0
# 1          1      1       1138     0.000000               NaN
# 2          2      2       1138     0.000000               1.0
# 3          3      3       1157     0.000000               NaN
# 4          4      4       1157     0.000000               1.0
# ..       ...    ...        ...          ...               ...
# 253      253     41     5202_Л     0.000000               1.0
# 254      254     42     5202_Л     0.000000               1.0
# 255      255     43       5202   307.247457               4.0
# 256      256     44       5202   307.247457               1.0
# 257      257     45        32Р   294.864376               1.0
#
#      Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     100                   4                         100
# 1                     100                   4                         100
# 2                     100                   4                         100
# 3                     100                   4                         100
# 4                     100                   4                         100
# ..                    ...                 ...                         ...
# 253                   100                   4                         100
# 254                   100                   4                         100
# 255                   100                   4                         100
# 256                   100                   4                         100
# 257                   100                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2017-05-17   ГС+ГРП     ГРП    Ю1        2017
# 1                      2001-12-30  ННС+ГРП     ГРП    Ю1        2001
# 2                      2006-05-02  ННС+ГРП     ГРП    Ю1        2006
# 3                      1994-01-01  ННС+ГРП     ГРП    Ю1        1994
# 4                      2004-03-05  ННС+ГРП     ГРП    Ю1        2004
# ..                            ...      ...     ...   ...         ...
# 253                    1993-05-01   ГС+ГРП     ГРП    Ю1        1993
# 254                    2005-10-02   ГС+ГРП     ГРП    Ю1        2005
# 255                    2017-09-26   ГС+ГРП     ГРП    Ю1        2017
# 256                    2018-07-19   ГС+ГРП     ГРП    Ю1        2018
# 257                    2018-03-30   ГС+ГРП     ГРП    Ю1         NaN
#
#      is_duplicate для_фрак
# 0           False     1060
# 1           False     1138
# 2           False     1138
# 3           False     1157
# 4           False     1157
# ..            ...      ...
# 253         False     5202
# 254         False     5202
# 255         False     5202
# 256         False     5202
# 257         False      32Р
#
# [245 rows x 15 columns]

# %%
step.loc[step['для_фрак'] == '5202']
# Out:
#      level_0  index Скважина №  Длина ГС, м  Число стадий ГРП  \
# 253      253     41     5202_Л     0.000000               1.0
# 254      254     42     5202_Л     0.000000               1.0
# 255      255     43       5202   307.247457               4.0
# 256      256     44       5202   307.247457               1.0
#
#      Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 253                   100                   4                         100
# 254                   100                   4                         100
# 255                   100                   4                         100
# 256                   100                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС  ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 253                    1993-05-01  ГС+ГРП     ГРП    Ю1        1993
# 254                    2005-10-02  ГС+ГРП     ГРП    Ю1        2005
# 255                    2017-09-26  ГС+ГРП     ГРП    Ю1        2017
# 256                    2018-07-19  ГС+ГРП     ГРП    Ю1        2018
#
#      is_duplicate для_фрак
# 253         False     5202
# 254         False     5202
# 255         False     5202
# 256         False     5202

# %%
step = step.groupby(by=['для_фрак']).agg(
            {'level_0': lambda x:
            x.tolist()}
        )
step.reset_index(inplace=True)
step.rename(columns={'для_фрак': 'список'}, inplace=True)

step['Length'] = step.apply(
            lambda x: len(x['level_0'])
            , axis=1)
step
# Out:
#     список          level_0  Length
# 0     1003            [167]       1
# 1      101            [212]       1
# 2     1028            [213]       1
# 3     1060              [0]       1
# 4     1119            [168]       1
# ..     ...              ...     ...
# 130    546  [207, 208, 209]       3
# 131    597       [210, 211]       2
# 132    824            [161]       1
# 133    827            [163]       1
# 134    974  [164, 165, 166]       3
#
# [135 rows x 3 columns]

# %%
step.loc[step['список'] == '5202']
# Out:
#     список               level_0  Length
# 113   5202  [253, 254, 255, 256]       4

# %%
step = step.drop(step[step['Length'] < 1].index)
gang1 = []
gang2 = []
gang3 = []
gang4 = []
gang5 = []
gang6 = []
gang7 = []
gang8 = []
gang9 = []
gang10 = []

for i in step['level_0']:
    if len(i) >= 1:
        gang1.append(i[0])
    if len(i) >= 2:
        gang2.append(i[1])
    if len(i) >= 3:
        gang3.append(i[2])
    if len(i) >= 4:
        gang4.append(i[3])
    if len(i) >= 5:
        gang5.append(i[4])
    if len(i) >= 6:
        gang6.append(i[5])
    if len(i) >= 7:
        gang7.append(i[6])
    if len(i) >= 8:
        gang8.append(i[7])
    if len(i) >= 9:
        gang9.append(i[8])
    if len(i) >= 10:
        gang10.append(i[9])
    else:
        pass
gang1
# Out:
# [167,
#  212,
#  213,
#  0,
#  168,
#  1,
#  169,
#  3,
#  6,
#  214,
#  218,
#  219,
#  220,
#  224,
#  10,
#  15,
#  17,
#  171,
#  20,
#  173,
#  22,
#  229,
#  24,
#  174,
#  26,
#  28,
#  31,
#  35,
#  36,
#  177,
#  178,
#  39,
#  179,
#  41,
#  180,
#  182,
#  43,
#  45,
#  48,
#  49,
#  184,
#  233,
#  235,
#  185,
#  187,
#  239,
#  54,
#  56,
#  58,
#  59,
#  60,
#  61,
#  63,
#  66,
#  68,
#  71,
#  72,
#  73,
#  75,
#  76,
#  77,
#  78,
#  79,
#  80,
#  81,
#  82,
#  83,
#  84,
#  240,
#  85,
#  86,
#  87,
#  90,
#  91,
#  92,
#  94,
#  243,
#  95,
#  96,
#  244,
#  99,
#  189,
#  257,
#  103,
#  105,
#  108,
#  109,
#  245,
#  110,
#  117,
#  119,
#  121,
#  123,
#  127,
#  129,
#  190,
#  248,
#  249,
#  191,
#  192,
#  251,
#  194,
#  132,
#  133,
#  134,
#  136,
#  137,
#  196,
#  139,
#  140,
#  142,
#  143,
#  146,
#  253,
#  197,
#  148,
#  198,
#  199,
#  149,
#  200,
#  151,
#  152,
#  205,
#  153,
#  206,
#  155,
#  156,
#  157,
#  158,
#  159,
#  207,
#  210,
#  161,
#  163,
#  164]

# %%
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ГРП' if x['level_0'] in gang1
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_1' if x['level_0'] in gang2
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_2' if x['level_0'] in gang3
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_3' if x['level_0'] in gang4
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_4' if x['level_0'] in gang5
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_5' if x['level_0'] in gang6
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_6' if x['level_0'] in gang7
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_7' if x['level_0'] in gang8
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_8' if x['level_0'] in gang9
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_9' if x['level_0'] in gang10
            else x['Скважина №'], axis=1)
sotired_final = sotired_final.drop(['level_0'], axis=1)
#sotired_final = sotired_final.drop(['месяц с грп'], axis=1)
sotired_final
# Out:
#      index     Скважина №  Длина ГС, м  Число стадий ГРП  \
# 0        0       1060_ГРП   614.642172               7.0
# 1        1       1138_ГРП     0.000000               NaN
# 2        2    1138_ФРАК_1     0.000000               1.0
# 3        3       1157_ГРП     0.000000               NaN
# 4        4    1157_ФРАК_1     0.000000               1.0
# ..     ...            ...          ...               ...
# 253     41     5202_Л_ГРП     0.000000               1.0
# 254     42  5202_Л_ФРАК_1     0.000000               1.0
# 255     43    5202_ФРАК_2   307.247457               4.0
# 256     44    5202_ФРАК_3   307.247457               1.0
# 257     45        32Р_ГРП   294.864376               1.0
#
#      Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     100                   4                         100
# 1                     100                   4                         100
# 2                     100                   4                         100
# 3                     100                   4                         100
# 4                     100                   4                         100
# ..                    ...                 ...                         ...
# 253                   100                   4                         100
# 254                   100                   4                         100
# 255                   100                   4                         100
# 256                   100                   4                         100
# 257                   100                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2017-05-17   ГС+ГРП     ГРП    Ю1        2017
# 1                      2001-12-30  ННС+ГРП     ГРП    Ю1        2001
# 2                      2006-05-02  ННС+ГРП     ГРП    Ю1        2006
# 3                      1994-01-01  ННС+ГРП     ГРП    Ю1        1994
# 4                      2004-03-05  ННС+ГРП     ГРП    Ю1        2004
# ..                            ...      ...     ...   ...         ...
# 253                    1993-05-01   ГС+ГРП     ГРП    Ю1        1993
# 254                    2005-10-02   ГС+ГРП     ГРП    Ю1        2005
# 255                    2017-09-26   ГС+ГРП     ГРП    Ю1        2017
# 256                    2018-07-19   ГС+ГРП     ГРП    Ю1        2018
# 257                    2018-03-30   ГС+ГРП     ГРП    Ю1         NaN
#
#      is_duplicate
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 253         False
# 254         False
# 255         False
# 256         False
# 257         False
#
# [258 rows x 13 columns]

# %%
sotired_final
# Out:
#      level_0     Скважина №  Длина ГС, м  Число стадий ГРП  \
# 0          0       1060_ГРП   614.642172               7.0
# 1          1       1138_ГРП     0.000000               1.0
# 2          2    1138_ФРАК_1     0.000000               1.0
# 3          3       1157_ГРП     0.000000               1.0
# 4          4    1157_ФРАК_1     0.000000               1.0
# ..       ...            ...          ...               ...
# 253      253     5202_Л_ГРП     0.000000               1.0
# 254      254  5202_Л_ФРАК_1     0.000000               1.0
# 255      255    5202_ФРАК_2   307.247457               4.0
# 256      256    5202_ФРАК_3   307.247457               1.0
# 257      257        32Р_ГРП   294.864376               1.0
#
#      Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     100                   4                         100
# 1                     100                   4                         100
# 2                     100                   4                         100
# 3                     100                   4                         100
# 4                     100                   4                         100
# ..                    ...                 ...                         ...
# 253                   100                   4                         100
# 254                   100                   4                         100
# 255                   100                   4                         100
# 256                   100                   4                         100
# 257                   100                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт
# 0                      2017-05-17   ГС+ГРП     ГРП    Ю1
# 1                      2001-12-30  ННС+ГРП     ГРП    Ю1
# 2                      2006-05-02  ННС+ГРП     ГРП    Ю1
# 3                      1994-01-01  ННС+ГРП     ГРП    Ю1
# 4                      2004-03-05  ННС+ГРП     ГРП    Ю1
# ..                            ...      ...     ...   ...
# 253                    1993-05-01   ГС+ГРП     ГРП    Ю1
# 254                    2005-10-02   ГС+ГРП     ГРП    Ю1
# 255                    2017-09-26   ГС+ГРП     ГРП    Ю1
# 256                    2018-07-19   ГС+ГРП     ГРП    Ю1
# 257                    2018-03-30   ГС+ГРП     ГРП    Ю1
#
# [258 rows x 11 columns]

# %%
# #удаляем если в одном месяце
# dele = copy.deepcopy(sotired_final)
# dele['чек'] = dele.apply(
#             lambda x:
#             x['Скважина №'].partition('_')[0] if '_' in str(x['Скважина №'])
#             else x['Скважина №'], axis=1)
# dele['месяц'] =dele.apply(
#             lambda x:
#             str(x['Дата ВНР после ГС \ ГРП \ЗБГС'])[:7],
#             axis=1
#         )
# dele = dele.groupby(by=['чек','месяц']).agg(
#             {'level_0': lambda x:
#             x.tolist()}
#         )
# dele['скока_их'] = dele.apply(
#             lambda x: len(x['level_0'])
#             , axis=1)
# dele = dele.drop(dele[dele['скока_их'] < 2].index).reset_index(drop=True)
# to_stay=[]


# for i in dele['level_0']:    
#     to_stay.append(i[-1])
# to_stay

# %%
# dele = copy.deepcopy(sotired_final)
# dele['чек'] = dele.apply(
#             lambda x:
#             x['Скважина №'].partition('_')[0] if '_' in str(x['Скважина №'])
#             else x['Скважина №'], axis=1)
# dele['месяц'] =dele.apply(
#             lambda x:
#             str(x['Дата ВНР после ГС \ ГРП \ЗБГС'])[:7],
#             axis=1
#         )

# dele

# %%
# dele = dele.groupby(by=['чек','месяц']).agg(
#             {'level_0': lambda x:
#             x.tolist()}
#         )
# dele['скока_их'] = dele.apply(
#             lambda x: len(x['level_0'])
#             , axis=1)
# dele = dele.drop(dele[dele['скока_их'] < 2].index).reset_index(drop=True)
# dele

# %%
# to_stay=[]


# for i in dele['level_0']:    
#     to_stay.append(i[-1])
# to_stay

# %%
sotired_final.to_excel('sdelal.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-58-b54ac68ecf65> in <module>
# ----> 1 sotired_final.to_excel('sdelal.xlsx')
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2289             freeze_panes=freeze_panes,
#    2290             engine=engine,
# -> 2291             storage_options=storage_options,
#    2292         )
#    2293
#
# ~\miniconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     833             # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
#     834             writer = ExcelWriter(  # type: ignore[abstract]
# --> 835                 writer, engine=engine, storage_options=storage_options
#     836             )
#     837             need_save = True
#
# ~\miniconda3\lib\site-packages\pandas\io\excel\_openpyxl.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      55             storage_options=storage_options,
#      56             if_sheet_exists=if_sheet_exists,
# ---> 57             engine_kwargs=engine_kwargs,
#      58         )
#      59
#
# ~\miniconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     924         if not isinstance(path, ExcelWriter):
#     925             self.handles = get_handle(
# --> 926                 path, mode, storage_options=storage_options, is_text=False
#     927             )
#     928         self.sheets: dict[str, Any] = {}
#
# ~\miniconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# PermissionError: [Errno 13] Permission denied: 'sdelal.xlsx'
