# %%
import pandas as pd
import statistics
import copy
import datetime

# %%
grp_dad = pd.read_excel('фраклист ЗУБ Ю2.xlsx',header=[1], index_col=[1])
grp_dad
# Out:
# C:\Users\USER\miniconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                  Unnamed: 0       Дата Подрядчик  \
# Номер скважины
# 99              Проблемы при построении ГРП 2017-09-05       МКМ
# 99              Проблемы при построении ГРП 2014-09-16       МКН
# 99              Проблемы при построении ГРП 2012-11-24       МКН
# 98              Проблемы при построении ГРП 2013-02-26       МКН
# 98              Проблемы при построении ГРП 2013-02-03       МКН
# ...                                     ...        ...       ...
# 104             Проблемы при построении ГРП 2020-03-20        КН
# 104             Проблемы при построении ГРП 2020-03-19        КН
# 104             Проблемы при построении ГРП 2020-03-19        КН
# 104             Проблемы при построении ГРП 2020-03-18        КН
# 100             Проблемы при построении ГРП 2017-01-27       МКМ
#
#                                                       Комментарии Страница  \
# Номер скважины
# 99              ГРП по плану (+), 40 т. Выполнена стадия запол...      -1_
# 99                                                            289      -1_
# 99              По результатам миниГРП, принято решение провес...      -1_
# 98              После анализа данных, полученных при проведени...      -1_
# 98              После анализа данных, полученных при проведени...      -1_
# ...                                                           ...      ...
# 104             Оборудование:  НКТ, АМТ-  ООО "КАТКонефть". Ст...      -1_
# 104             Оборудование:  НКТ, АМТ-  ООО "КАТКонефть" . С...      -1_
# 104             Оборудование:  НКТ, АМТ-  ООО "КАТКонефть"  Ст...      -1_
# 104             Оборудование:  НКТ, АМТ-  ООО "КАТКонефть"  Ст...      -1_
# 100             Отмена. "1.Кварц.Песок 100 Mash -2 тонны предо...      -1_
#
#                 Unnamed: 6 Пласт  Наклон  Азимут     k  ...  \
# Номер скважины                                          ...
# 99                     NaN   Б10   73.00  152.00  13.8  ...
# 99                     NaN   Б10   10.50   86.00   4.9  ...
# 99                     NaN   Б10   10.50   86.00   8.0  ...
# 98                     NaN   Б10    9.58  333.00   8.0  ...
# 98                     NaN   Б10    9.58  333.00  12.0  ...
# ...                    ...   ...     ...     ...   ...  ...
# 104                    NaN   Б10   88.15  210.19  12.0  ...
# 104                    NaN   Б10   88.15  210.19  12.0  ...
# 104                    NaN   Б10   88.15  210.19  12.0  ...
# 104                    NaN   Б10   88.15  210.19  12.0  ...
# 100                    NaN   Б10   93.00   85.00   8.0  ...
#
#                                          Проппант  Рпл Хорнер   Эфф  Расход  \
# Номер скважины
# 99                   20/40 Nik+16/30 Nik16/20 Nik        31.0  48.0     3.2
# 99                                    20/40+16/20         NaN  74.0     3.6
# 99                                            NaN       265.0  56.0     3.2
# 98                                            NaN       260.0  82.0     3.8
# 98                                            NaN       262.0  75.0     3.6
# ...                                           ...         ...   ...     ...
# 104             NIKA (Ptprop)+NIKA (Ptprop)+0+0+0        46.0  64.0     3.2
# 104             NIKA (Ptprop)+NIKA (Ptprop)+0+0+0        41.0  57.0     3.2
# 104             NIKA (Ptprop)+NIKA (Ptprop)+0+0+0        49.0  48.0     3.2
# 104             NIKA (Ptprop)+NIKA (Ptprop)+0+0+0        21.0  51.0     3.2
# 100                                      100 Mash         NaN   NaN     NaN
#
#                   Конц  Гель        М бр  V под  V без под  V гель
# Номер скважины
# 99               800.0   NaN   39.000000   35.0      156.5     NaN
# 99               900.0   NaN  122.200000   95.0      270.2     NaN
# 99              1100.0   NaN         NaN   14.0      135.1     NaN
# 98              1000.0   NaN         NaN   18.0      133.7     NaN
# 98                 NaN   NaN         NaN   22.0       97.5     NaN
# ...                ...   ...         ...    ...        ...     ...
# 104              800.0   NaN  465.403690    NaN        NaN    65.0
# 104              800.0   NaN  472.075611    NaN        NaN    66.0
# 104              800.0   NaN  543.249600    NaN        NaN    82.0
# 104              800.0   NaN  600.049801    NaN        NaN    80.0
# 100                NaN   NaN   18.000000    NaN       61.0     NaN
#
# [972 rows x 35 columns]

# %%
grp_dad.reset_index(drop=True)
grp_dad.reset_index(inplace=True)
nnn = 1
zzz = grp_dad['Пласт'].value_counts()[:nnn].index.tolist()
plasttt = str(zzz[0])
grp_dad['удалю'] = grp_dad.apply(
            lambda x:
            'нет' if plasttt in str(x['Пласт'])
            else 'да', axis=1)
grp_dad = grp_dad.drop(grp_dad[grp_dad['удалю'] == 'да'].index).reset_index(drop=True)
grp_dad = grp_dad.drop(['удалю'], axis=1)
grp_dad
# Out:
#     Номер скважины                   Unnamed: 0       Дата Подрядчик  \
# 0               99  Проблемы при построении ГРП 2017-09-05       МКМ
# 1               99  Проблемы при построении ГРП 2014-09-16       МКН
# 2               99  Проблемы при построении ГРП 2012-11-24       МКН
# 3               98  Проблемы при построении ГРП 2013-02-26       МКН
# 4               98  Проблемы при построении ГРП 2013-02-03       МКН
# ..             ...                          ...        ...       ...
# 785            104  Проблемы при построении ГРП 2020-03-20        КН
# 786            104  Проблемы при построении ГРП 2020-03-19        КН
# 787            104  Проблемы при построении ГРП 2020-03-19        КН
# 788            104  Проблемы при построении ГРП 2020-03-18        КН
# 789            100  Проблемы при построении ГРП 2017-01-27       МКМ
#
#                                            Комментарии Страница  Unnamed: 6  \
# 0    ГРП по плану (+), 40 т. Выполнена стадия запол...      -1_         NaN
# 1                                                  289      -1_         NaN
# 2    По результатам миниГРП, принято решение провес...      -1_         NaN
# 3    После анализа данных, полученных при проведени...      -1_         NaN
# 4    После анализа данных, полученных при проведени...      -1_         NaN
# ..                                                 ...      ...         ...
# 785  Оборудование:  НКТ, АМТ-  ООО "КАТКонефть". Ст...      -1_         NaN
# 786  Оборудование:  НКТ, АМТ-  ООО "КАТКонефть" . С...      -1_         NaN
# 787  Оборудование:  НКТ, АМТ-  ООО "КАТКонефть"  Ст...      -1_         NaN
# 788  Оборудование:  НКТ, АМТ-  ООО "КАТКонефть"  Ст...      -1_         NaN
# 789  Отмена. "1.Кварц.Песок 100 Mash -2 тонны предо...      -1_         NaN
#
#     Пласт  Наклон  Азимут  ...                           Проппант  Рпл Хорнер  \
# 0     Б10   73.00  152.00  ...       20/40 Nik+16/30 Nik16/20 Nik        31.0
# 1     Б10   10.50   86.00  ...                        20/40+16/20         NaN
# 2     Б10   10.50   86.00  ...                                NaN       265.0
# 3     Б10    9.58  333.00  ...                                NaN       260.0
# 4     Б10    9.58  333.00  ...                                NaN       262.0
# ..    ...     ...     ...  ...                                ...         ...
# 785   Б10   88.15  210.19  ...  NIKA (Ptprop)+NIKA (Ptprop)+0+0+0        46.0
# 786   Б10   88.15  210.19  ...  NIKA (Ptprop)+NIKA (Ptprop)+0+0+0        41.0
# 787   Б10   88.15  210.19  ...  NIKA (Ptprop)+NIKA (Ptprop)+0+0+0        49.0
# 788   Б10   88.15  210.19  ...  NIKA (Ptprop)+NIKA (Ptprop)+0+0+0        21.0
# 789   Б10   93.00   85.00  ...                           100 Mash         NaN
#
#       Эфф  Расход    Конц  Гель        М бр  V под  V без под  V гель
# 0    48.0     3.2   800.0   NaN   39.000000   35.0      156.5     NaN
# 1    74.0     3.6   900.0   NaN  122.200000   95.0      270.2     NaN
# 2    56.0     3.2  1100.0   NaN         NaN   14.0      135.1     NaN
# 3    82.0     3.8  1000.0   NaN         NaN   18.0      133.7     NaN
# 4    75.0     3.6     NaN   NaN         NaN   22.0       97.5     NaN
# ..    ...     ...     ...   ...         ...    ...        ...     ...
# 785  64.0     3.2   800.0   NaN  465.403690    NaN        NaN    65.0
# 786  57.0     3.2   800.0   NaN  472.075611    NaN        NaN    66.0
# 787  48.0     3.2   800.0   NaN  543.249600    NaN        NaN    82.0
# 788  51.0     3.2   800.0   NaN  600.049801    NaN        NaN    80.0
# 789   NaN     NaN     NaN   NaN   18.000000    NaN       61.0     NaN
#
# [790 rows x 36 columns]

# %%
grp_gtm = pd.read_excel('гтм ЗУБ Ю2.xlsx',header=[1], index_col=[1])
grp_gtm
# Out:
# C:\Users\USER\miniconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                       Unnamed: 0 Скважина     Куст       Тип  \
# Месторождение
# Западно-Усть-Балыкск  Добывающая     1040  КУСТ-14       ГРП
# Западно-Усть-Балыкск  Добывающая     1040  КУСТ-14       ВНС
# Западно-Усть-Балыкск  Добывающая     1040  КУСТ-14       ОПЗ
# Западно-Усть-Балыкск  Добывающая     1040  КУСТ-14       ГРП
# Западно-Усть-Балыкск  Добывающая     1040  КУСТ-14     См_ПО
# ...                          ...      ...      ...       ...
# Западно-Усть-Балыкск  Добывающая       9В   КУСТ-7  Доп.перф
# Западно-Усть-Балыкск  Добывающая       9В   КУСТ-7       ВНС
# Западно-Усть-Балыкск  Добывающая       9В   КУСТ-7     См_ПО
# Западно-Усть-Балыкск  Добывающая       9В   КУСТ-7     См_ПО
# Западно-Усть-Балыкск  Добывающая       9В   КУСТ-7     См_ПО
#
#                      Объект разработки до ГТМ  Объект разработки после ГТМ  \
# Месторождение
# Западно-Усть-Балыкск                       Ю2                          NaN
# Западно-Усть-Балыкск                       Ю2                          NaN
# Западно-Усть-Балыкск                       Ю2                          NaN
# Западно-Усть-Балыкск                       Ю2                          NaN
# Западно-Усть-Балыкск                       Ю2                          NaN
# ...                                       ...                          ...
# Западно-Усть-Балыкск                      NaN                          NaN
# Западно-Усть-Балыкск                      NaN                          NaN
# Западно-Усть-Балыкск                      NaN                          NaN
# Западно-Усть-Балыкск                      NaN                          NaN
# Западно-Усть-Балыкск                      NaN                          NaN
#
#                      Страница  Dэк  \
# Месторождение
# Западно-Усть-Балыкск      -1_  NaN
# Западно-Усть-Балыкск      -1_  NaN
# Западно-Усть-Балыкск      -1_  NaN
# Западно-Усть-Балыкск      -1_  NaN
# Западно-Усть-Балыкск      -1_  NaN
# ...                       ...  ...
# Западно-Усть-Балыкск      -1_  NaN
# Западно-Усть-Балыкск      -1_  NaN
# Западно-Усть-Балыкск      -1_  NaN
# Западно-Усть-Балыкск      -1_  NaN
# Западно-Усть-Балыкск      -1_  NaN
#
#                                            Краткое описание мероприятий  \
# Месторождение
# Западно-Усть-Балыкск                              КР7-2 Проведение МГРП
# Западно-Усть-Балыкск                 Ввод добывающих скважин из бурения
# Западно-Усть-Балыкск                      КР7-34 Интенсификация притока
# Западно-Усть-Балыкск                               КР7-2 Проведение ГРП
# Западно-Усть-Балыкск                    ТР5-8 Подъем УЭЦН спуск воронки
# ...                                                                 ...
# Западно-Усть-Балыкск                                                NaN
# Западно-Усть-Балыкск               Ввод водозаборных скважин из бурения
# Западно-Усть-Балыкск                                    ТР5-1 Смена ЭЦН
# Западно-Усть-Балыкск  ТР3-2 Изменение глубины подвески, смена типора...
# Западно-Усть-Балыкск     ТР9-3 Смена ЭЦН (ремонт водозаборных скважин )
#
#                       Unnamed: 10  ...  Напор.1  Производительность.1  \
# Месторождение                      ...
# Западно-Усть-Балыкск          NaN  ...      NaN                   NaN
# Западно-Усть-Балыкск          NaN  ...      NaN                   NaN
# Западно-Усть-Балыкск          NaN  ...      NaN                   NaN
# Западно-Усть-Балыкск          NaN  ...      NaN                   NaN
# Западно-Усть-Балыкск          NaN  ...      NaN                   NaN
# ...                           ...  ...      ...                   ...
# Западно-Усть-Балыкск          NaN  ...      NaN                   NaN
# Западно-Усть-Балыкск          NaN  ...      NaN                   NaN
# Западно-Усть-Балыкск          NaN  ...      NaN                   NaN
# Западно-Усть-Балыкск          NaN  ...      NaN                   NaN
# Западно-Усть-Балыкск          NaN  ...      NaN                   NaN
#
#                       Комментарий  План  Факт  Пл-ть нефти  Коб  В-ть жидк.  \
# Месторождение
# Западно-Усть-Балыкск          NaN   NaN   NaN          NaN  NaN         NaN
# Западно-Усть-Балыкск          NaN   NaN   NaN          NaN  NaN         NaN
# Западно-Усть-Балыкск          NaN   NaN   NaN          NaN  NaN         NaN
# Западно-Усть-Балыкск          NaN   NaN   NaN          NaN  NaN         NaN
# Западно-Усть-Балыкск          NaN   NaN   NaN          NaN  NaN         NaN
# ...                           ...   ...   ...          ...  ...         ...
# Западно-Усть-Балыкск          NaN   NaN   NaN          NaN  NaN         NaN
# Западно-Усть-Балыкск          NaN   NaN   NaN          NaN  NaN         NaN
# Западно-Усть-Балыкск          NaN   NaN   NaN          NaN  NaN         NaN
# Западно-Усть-Балыкск          NaN   NaN   NaN          NaN  NaN         NaN
# Западно-Усть-Балыкск          NaN   NaN   NaN          NaN  NaN         NaN
#
#                       P нас  Unnamed: 65
# Месторождение
# Западно-Усть-Балыкск    NaN          NaN
# Западно-Усть-Балыкск    NaN          NaN
# Западно-Усть-Балыкск    NaN          NaN
# Западно-Усть-Балыкск    NaN          NaN
# Западно-Усть-Балыкск    NaN          NaN
# ...                     ...          ...
# Западно-Усть-Балыкск    NaN          NaN
# Западно-Усть-Балыкск    NaN          NaN
# Западно-Усть-Балыкск    NaN          NaN
# Западно-Усть-Балыкск    NaN          NaN
# Западно-Усть-Балыкск    NaN          NaN
#
# [3600 rows x 65 columns]

# %%
grp_gtm.reset_index(drop=True)
grp_gtm.reset_index(inplace=True)
grp_gtm.tail(15)
# Out:
#              Месторождение  Unnamed: 0 Скважина    Куст       Тип  \
# 3585  Западно-Усть-Балыкск  Добывающая       99  КУСТ-5     См_ПО
# 3586  Западно-Усть-Балыкск  Добывающая       99  КУСТ-5       КРС
# 3587  Западно-Усть-Балыкск  Добывающая       99  КУСТ-5     См_ПО
# 3588  Западно-Усть-Балыкск  Добывающая       99  КУСТ-5     См_ПО
# 3589  Западно-Усть-Балыкск  Добывающая       99  КУСТ-5  Доп.перф
# 3590  Западно-Усть-Балыкск  Добывающая       99  КУСТ-5  Доп.перф
# 3591  Западно-Усть-Балыкск  Добывающая       99  КУСТ-5     См_ПО
# 3592  Западно-Усть-Балыкск  Добывающая       99  КУСТ-5     См_ПО
# 3593  Западно-Усть-Балыкск  Добывающая      99Л  КУСТ-5       РИР
# 3594  Западно-Усть-Балыкск  Добывающая      99Л  КУСТ-5       РИР
# 3595  Западно-Усть-Балыкск  Добывающая       9В  КУСТ-7  Доп.перф
# 3596  Западно-Усть-Балыкск  Добывающая       9В  КУСТ-7       ВНС
# 3597  Западно-Усть-Балыкск  Добывающая       9В  КУСТ-7     См_ПО
# 3598  Западно-Усть-Балыкск  Добывающая       9В  КУСТ-7     См_ПО
# 3599  Западно-Усть-Балыкск  Добывающая       9В  КУСТ-7     См_ПО
#
#      Объект разработки до ГТМ  Объект разработки после ГТМ Страница  Dэк  \
# 3585                      NaN                          NaN      -1_  NaN
# 3586                      NaN                          NaN      -1_  NaN
# 3587                      NaN                          NaN      -1_  NaN
# 3588                      NaN                          NaN      -1_  NaN
# 3589                      NaN                          NaN      -1_  NaN
# 3590                      NaN                          NaN      -1_  NaN
# 3591                      NaN                          NaN      -1_  NaN
# 3592                      NaN                          NaN      -1_  NaN
# 3593                      NaN                          NaN      -1_  NaN
# 3594                      NaN                          NaN      -1_  NaN
# 3595                      NaN                          NaN      -1_  NaN
# 3596                      NaN                          NaN      -1_  NaN
# 3597                      NaN                          NaN      -1_  NaN
# 3598                      NaN                          NaN      -1_  NaN
# 3599                      NaN                          NaN      -1_  NaN
#
#                            Краткое описание мероприятий  ...  Напор.1  \
# 3585                                    ТР5-1 Смена ЭЦН  ...      NaN
# 3586                             КР13 Прочие виды работ  ...      NaN
# 3587                                    ТР5-1 Смена ЭЦН  ...      NaN
# 3588                                    ТР5-1 Смена ЭЦН  ...      NaN
# 3589                                                NaN  ...      NaN
# 3590                                                NaN  ...      NaN
# 3591                                    ТР5-1 Смена ЭЦН  ...      NaN
# 3592                                    ТР5-1 Смена ЭЦН  ...      NaN
# 3593                                                NaN  ...      NaN
# 3594                                                NaN  ...      NaN
# 3595                                                NaN  ...      NaN
# 3596               Ввод водозаборных скважин из бурения  ...      NaN
# 3597                                    ТР5-1 Смена ЭЦН  ...      NaN
# 3598  ТР3-2 Изменение глубины подвески, смена типора...  ...      NaN
# 3599     ТР9-3 Смена ЭЦН (ремонт водозаборных скважин )  ...      NaN
#
#       Производительность.1  Комментарий  План  Факт  Пл-ть нефти  Коб  \
# 3585                   NaN          NaN   NaN   NaN          NaN  NaN
# 3586                   NaN          NaN   NaN   NaN          NaN  NaN
# 3587                   NaN          NaN   NaN   NaN          NaN  NaN
# 3588                   NaN          NaN   NaN   NaN          NaN  NaN
# 3589                   NaN          NaN   NaN   NaN          NaN  NaN
# 3590                   NaN          NaN   NaN   NaN          NaN  NaN
# 3591                   NaN          NaN   NaN   NaN          NaN  NaN
# 3592                   NaN          NaN   NaN   NaN          NaN  NaN
# 3593                   NaN          NaN   NaN   NaN          NaN  NaN
# 3594                   NaN          NaN   NaN   NaN          NaN  NaN
# 3595                   NaN          NaN   NaN   NaN          NaN  NaN
# 3596                   NaN          NaN   NaN   NaN          NaN  NaN
# 3597                   NaN          NaN   NaN   NaN          NaN  NaN
# 3598                   NaN          NaN   NaN   NaN          NaN  NaN
# 3599                   NaN          NaN   NaN   NaN          NaN  NaN
#
#       В-ть жидк.  P нас  Unnamed: 65
# 3585         NaN    NaN          NaN
# 3586         NaN    NaN          NaN
# 3587         NaN    NaN          NaN
# 3588         NaN    NaN          NaN
# 3589         NaN    NaN          NaN
# 3590         NaN    NaN          NaN
# 3591         NaN    NaN          NaN
# 3592         NaN    NaN          NaN
# 3593         NaN    NaN          NaN
# 3594         NaN    NaN          NaN
# 3595         NaN    NaN          NaN
# 3596         NaN    NaN          NaN
# 3597         NaN    NaN          NaN
# 3598         NaN    NaN          NaN
# 3599         NaN    NaN          NaN
#
# [15 rows x 66 columns]

# %%
grp_gtm = grp_gtm[grp_gtm['Объект разработки до ГТМ'].notna()]
grp_gtm
# Out:
#              Месторождение  Unnamed: 0 Скважина     Куст                 Тип  \
# 0     Западно-Усть-Балыкск  Добывающая     1040  КУСТ-14                 ГРП
# 1     Западно-Усть-Балыкск  Добывающая     1040  КУСТ-14                 ВНС
# 2     Западно-Усть-Балыкск  Добывающая     1040  КУСТ-14                 ОПЗ
# 3     Западно-Усть-Балыкск  Добывающая     1040  КУСТ-14                 ГРП
# 4     Западно-Усть-Балыкск  Добывающая     1040  КУСТ-14               См_ПО
# ...                    ...         ...      ...      ...                 ...
# 2098  Западно-Усть-Балыкск  Добывающая       99   КУСТ-5                 ГРП
# 2099  Западно-Усть-Балыкск  Добывающая       99   КУСТ-5                 3БС
# 2100  Западно-Усть-Балыкск  Добывающая       99   КУСТ-5               См_ПО
# 2101  Западно-Усть-Балыкск  Добывающая       99   КУСТ-5               См_ПО
# 2102  Западно-Усть-Балыкск  Добывающая       99   КУСТ-5  Запуск без ремонта
#
#      Объект разработки до ГТМ  Объект разработки после ГТМ Страница  Dэк  \
# 0                          Ю2                          NaN      -1_  NaN
# 1                          Ю2                          NaN      -1_  NaN
# 2                          Ю2                          NaN      -1_  NaN
# 3                          Ю2                          NaN      -1_  NaN
# 4                          Ю2                          NaN      -1_  NaN
# ...                       ...                          ...      ...  ...
# 2098                      Б10                          NaN      -1_  NaN
# 2099                      Б10                          NaN      -1_  NaN
# 2100                      Б10                          NaN      -1_  NaN
# 2101                      Б10                          NaN      -1_  NaN
# 2102                      Б10                          NaN      -1_  NaN
#
#                            Краткое описание мероприятий  ...  Напор.1  \
# 0                                 КР7-2 Проведение МГРП  ...      NaN
# 1                    Ввод добывающих скважин из бурения  ...      NaN
# 2                         КР7-34 Интенсификация притока  ...      NaN
# 3                                  КР7-2 Проведение ГРП  ...      NaN
# 4                       ТР5-8 Подъем УЭЦН спуск воронки  ...      NaN
# ...                                                 ...  ...      ...
# 2098                               КР7-2 Проведение ГРП  ...      NaN
# 2099  КР6-3 Зарезка нового или продолжение ствола с ...  ...      NaN
# 2100                                    ТР5-1 Смена ЭЦН  ...      NaN
# 2101                                    ТР5-1 Смена ЭЦН  ...      NaN
# 2102                        Запуск в работу без ремонта  ...      NaN
#
#       Производительность.1  Комментарий  План  Факт  Пл-ть нефти  Коб  \
# 0                      NaN          NaN   NaN   NaN          NaN  NaN
# 1                      NaN          NaN   NaN   NaN          NaN  NaN
# 2                      NaN          NaN   NaN   NaN          NaN  NaN
# 3                      NaN          NaN   NaN   NaN          NaN  NaN
# 4                      NaN          NaN   NaN   NaN          NaN  NaN
# ...                    ...          ...   ...   ...          ...  ...
# 2098                   NaN          NaN   NaN   NaN          NaN  NaN
# 2099                   NaN          NaN   NaN   NaN          NaN  NaN
# 2100                   NaN          NaN   NaN   NaN          NaN  NaN
# 2101                   NaN          NaN   NaN   NaN          NaN  NaN
# 2102                   NaN          NaN   NaN   NaN          NaN  NaN
#
#       В-ть жидк.  P нас  Unnamed: 65
# 0            NaN    NaN          NaN
# 1            NaN    NaN          NaN
# 2            NaN    NaN          NaN
# 3            NaN    NaN          NaN
# 4            NaN    NaN          NaN
# ...          ...    ...          ...
# 2098         NaN    NaN          NaN
# 2099         NaN    NaN          NaN
# 2100         NaN    NaN          NaN
# 2101         NaN    NaN          NaN
# 2102         NaN    NaN          NaN
#
# [2103 rows x 66 columns]

# %%
nn = 1
zz = grp_gtm['Объект разработки до ГТМ'].value_counts()[:nn].index.tolist()
plastt = str(zz[0])
grp_gtm = grp_gtm.drop(grp_gtm[grp_gtm['Объект разработки до ГТМ'] != plastt].index).reset_index(drop=True)
grp_gtm
# Out:
#              Месторождение  Unnamed: 0 Скважина    Куст                 Тип  \
# 0     Западно-Усть-Балыкск  Добывающая      100  КУСТ-5                 ВНС
# 1     Западно-Усть-Балыкск  Добывающая      100  КУСТ-5                 ГРП
# 2     Западно-Усть-Балыкск  Добывающая      100  КУСТ-5               См_ПО
# 3     Западно-Усть-Балыкск  Добывающая      100  КУСТ-5               См_ПО
# 4     Западно-Усть-Балыкск  Добывающая      100  КУСТ-5               См_ПО
# ...                    ...         ...      ...     ...                 ...
# 1740  Западно-Усть-Балыкск  Добывающая       99  КУСТ-5                 ГРП
# 1741  Западно-Усть-Балыкск  Добывающая       99  КУСТ-5                 3БС
# 1742  Западно-Усть-Балыкск  Добывающая       99  КУСТ-5               См_ПО
# 1743  Западно-Усть-Балыкск  Добывающая       99  КУСТ-5               См_ПО
# 1744  Западно-Усть-Балыкск  Добывающая       99  КУСТ-5  Запуск без ремонта
#
#      Объект разработки до ГТМ  Объект разработки после ГТМ Страница  Dэк  \
# 0                         Б10                          NaN      -1_  NaN
# 1                         Б10                          NaN      -1_  NaN
# 2                         Б10                          NaN      -1_  NaN
# 3                         Б10                          NaN      -1_  NaN
# 4                         Б10                          NaN      -1_  NaN
# ...                       ...                          ...      ...  ...
# 1740                      Б10                          NaN      -1_  NaN
# 1741                      Б10                          NaN      -1_  NaN
# 1742                      Б10                          NaN      -1_  NaN
# 1743                      Б10                          NaN      -1_  NaN
# 1744                      Б10                          NaN      -1_  NaN
#
#                            Краткое описание мероприятий  ...  Напор.1  \
# 0                    Ввод добывающих скважин из бурения  ...      NaN
# 1                                  КР7-2 Проведение ГРП  ...      NaN
# 2                                       ТР5-1 Смена ЭЦН  ...      NaN
# 3                                       ТР5-1 Смена ЭЦН  ...      NaN
# 4                                       ТР5-1 Смена ЭЦН  ...      NaN
# ...                                                 ...  ...      ...
# 1740                               КР7-2 Проведение ГРП  ...      NaN
# 1741  КР6-3 Зарезка нового или продолжение ствола с ...  ...      NaN
# 1742                                    ТР5-1 Смена ЭЦН  ...      NaN
# 1743                                    ТР5-1 Смена ЭЦН  ...      NaN
# 1744                        Запуск в работу без ремонта  ...      NaN
#
#       Производительность.1  Комментарий  План  Факт  Пл-ть нефти  Коб  \
# 0                      NaN          NaN   NaN   NaN          NaN  NaN
# 1                      NaN          NaN   NaN   NaN          NaN  NaN
# 2                      NaN          NaN   NaN   NaN          NaN  NaN
# 3                      NaN          NaN   NaN   NaN          NaN  NaN
# 4                      NaN          NaN   NaN   NaN          NaN  NaN
# ...                    ...          ...   ...   ...          ...  ...
# 1740                   NaN          NaN   NaN   NaN          NaN  NaN
# 1741                   NaN          NaN   NaN   NaN          NaN  NaN
# 1742                   NaN          NaN   NaN   NaN          NaN  NaN
# 1743                   NaN          NaN   NaN   NaN          NaN  NaN
# 1744                   NaN          NaN   NaN   NaN          NaN  NaN
#
#       В-ть жидк.  P нас  Unnamed: 65
# 0            NaN    NaN          NaN
# 1            NaN    NaN          NaN
# 2            NaN    NaN          NaN
# 3            NaN    NaN          NaN
# 4            NaN    NaN          NaN
# ...          ...    ...          ...
# 1740         NaN    NaN          NaN
# 1741         NaN    NaN          NaN
# 1742         NaN    NaN          NaN
# 1743         NaN    NaN          NaN
# 1744         NaN    NaN          NaN
#
# [1745 rows x 66 columns]

# %%
coordinates = pd.read_excel('координаты скв ЗУБ Ю2.xlsx')
coordinates
# Out:
#     № скважины  Координата X  Координата Y  \
# 0           10        352881       6776189
# 1          100        352800       6770462
# 2        100-2        352817       6770397
# 3          104        352219       6775800
# 4         1040        356070       6762382
# ..         ...           ...           ...
# 443       96ПЛ        353746       6771195
# 444         98        353294       6770937
# 445         99        354073       6769852
# 446        99Л        353911       6770005
# 447         9В        355282       6766533
#
#      Координата забоя Х (по траектории)  Координата забоя Y (по траектории)
# 0                              353011.0                           6775891.0
# 1                              352657.0                           6770998.0
# 2                              352897.0                           6771122.0
# 3                              351745.0                           6775530.0
# 4                              355833.0                           6762802.0
# ..                                  ...                                 ...
# 443                            353787.0                           6771287.0
# 444                            353290.0                           6770979.0
# 445                            354137.0                           6769713.0
# 446                            353956.0                           6769993.0
# 447                            355019.0                           6766684.0
#
# [448 rows x 5 columns]

# %%
        coordinates['Length'] = coordinates.apply(
            lambda x: ((x['Координата забоя Х (по траектории)'] - x['Координата X']) ** (2) +
                       (x['Координата забоя Y (по траектории)'] - x['Координата Y']) ** (2)) ** (0.5)
            , axis=1)
        coordinates['№ скважины'] = coordinates.apply(
            lambda x:
            str(x['№ скважины']), axis=1)
        grp = copy.deepcopy(grp_dad)
        
        
        
        
        
        
        
        #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        grp_now_we_go= copy.deepcopy(grp_gtm)
        
        grp_now_we_go['Скважина'] = grp_now_we_go.apply(
            lambda x:
            str(x['Скважина']), axis=1)
        #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        
        
        
        
        
        
        
        
        
        #grp.reset_index(drop=True)
        #grp.reset_index(inplace=True)
        #grp = grp.drop(['Unnamed: 0', 'Подрядчик', 'Комментарии', 'Страница', 'Unnamed: 6', 'Азимут'], axis=1)
        #grp = grp.drop(
        #    ['V гель', 'V без под', 'V под', 'М бр', 'Гель', 'Конц', 'Расход', 'Эфф', 'Рпл Хорнер', 'Проппант', 'k',
        #     'Ноб', 'Нэф', 'Верх', 'Низ'], axis=1)
        #grp = grp.drop(['Xf', 'Hf', 'Wf', 'PIdsg', 'Скин-фактор', 'JD', 'FCD', 'М пр', 'Покр', 'План'], axis=1)
        grp['Номер скважины'] = grp.apply(
            lambda x:
            str(x['Номер скважины']), axis=1)
        # координаты скважин для нашего объекта
        my_wells = grp['Номер скважины'].tolist()
        my_wells_no_repeat = []
        for x in my_wells:
            if x not in my_wells_no_repeat:
                my_wells_no_repeat.append(x)
                
                
                
                
        #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!        
                # координаты скважин для нашего объекта, которых нет во фраклисте
        my_wells_gtm = grp_now_we_go['Скважина'].tolist()
        my_wells_no_repeat_gtm = []
        for x in my_wells_gtm:
            if x not in my_wells_no_repeat_gtm:
                my_wells_no_repeat_gtm.append(x)
        
        my_wells_only_gtm=[]
        for i in my_wells_no_repeat_gtm:
            if i not in my_wells_no_repeat:
                my_wells_only_gtm.append(i)
        my_wells_only_gtm
        #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
# ['1044',
#  '1050',
#  '1053',
#  '110',
#  '111',
#  '113',
#  '114',
#  '115',
#  '1194Р',
#  '141',
#  '144',
#  '15',
#  '16',
#  '161',
#  '17',
#  '171',
#  '18',
#  '19',
#  '210',
#  '211',
#  '246',
#  '25',
#  '29',
#  '307',
#  '32',
#  '35',
#  '38',
#  '39',
#  '41',
#  '76',
#  '83',
#  '88',
#  '905',
#  '93',
#  '94']

# %%
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
wells_GTM = pd.DataFrame({"Номер скважины": my_wells_only_gtm
                   })
wells_GTM
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
#    Номер скважины
# 0            1044
# 1            1050
# 2            1053
# 3             110
# 4             111
# 5             113
# 6             114
# 7             115
# 8           1194Р
# 9             141
# 10            144
# 11             15
# 12             16
# 13            161
# 14             17
# 15            171
# 16             18
# 17             19
# 18            210
# 19            211
# 20            246
# 21             25
# 22             29
# 23            307
# 24             32
# 25             35
# 26             38
# 27             39
# 28             41
# 29             76
# 30             83
# 31             88
# 32            905
# 33             93
# 34             94

# %%
coordinates_f = coordinates[
coordinates['№ скважины'].isin(my_wells_no_repeat)].reset_index(drop=True)
coordinates_f = coordinates_f.drop(['Координата X', 'Координата Y', 'Координата забоя Х (по траектории)',
                                        'Координата забоя Y (по траектории)'], axis=1)
new = coordinates_f['№ скважины'].tolist()
coordinates_f['Номер скважины'] = new
coordinates_f = coordinates_f.drop(['№ скважины'], axis=1)
final = grp.merge(coordinates_f, on='Номер скважины')
final.loc[final['Номер скважины'] == '5217']
# Out:
# Empty DataFrame
# Columns: [Номер скважины, Unnamed: 0, Дата, Подрядчик, Комментарии, Страница, Unnamed: 6, Пласт, Наклон, Азимут, k, Ноб, Нэф, Рпл, Верх, Низ, Xf, Hf, Wf, PIdsg, Скин-фактор, JD, FCD, М пр, Покр, План, Проппант, Рпл Хорнер, Эфф, Расход, Конц, Гель, М бр, V под, V без под, V гель, Length]
# Index: []
#
# [0 rows x 37 columns]

# %%
        coordinates_f = coordinates[
            coordinates['№ скважины'].isin(my_wells_no_repeat)].reset_index(drop=True)
        coordinates_f = coordinates_f.drop(['Координата X', 'Координата Y', 'Координата забоя Х (по траектории)',
                                        'Координата забоя Y (по траектории)'], axis=1)
        new = coordinates_f['№ скважины'].tolist()
        coordinates_f['Номер скважины'] = new
        coordinates_f = coordinates_f.drop(['№ скважины'], axis=1)
        final = grp.merge(coordinates_f, on='Номер скважины')
        final['Длиина ГС, м'] = final.apply(
            lambda x:
            x['Length'] if x['Наклон'] >= 70
            else 0, axis=1)
        final = final.drop(['Наклон', 'Length'], axis=1)
        final_number = final.groupby('Номер скважины').agg(
            {'Дата': lambda x:
            x.tolist()}
        )

# %%
final.loc[final['Номер скважины'] == '5217']
# Out:
# Empty DataFrame
# Columns: [Номер скважины, Unnamed: 0, Дата, Подрядчик, Комментарии, Страница, Unnamed: 6, Пласт, Азимут, k, Ноб, Нэф, Рпл, Верх, Низ, Xf, Hf, Wf, PIdsg, Скин-фактор, JD, FCD, М пр, Покр, План, Проппант, Рпл Хорнер, Эфф, Расход, Конц, Гель, М бр, V под, V без под, V гель, Длиина ГС, м]
# Index: []
#
# [0 rows x 36 columns]

# %%
#!!!!!!!!!!!!!!!!!!!!!!!!!!
coordinates_gtm = coordinates[
            coordinates['№ скважины'].isin(my_wells_only_gtm)].reset_index(drop=True)
coordinates_gtm
#!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
#    № скважины  Координата X  Координата Y  Координата забоя Х (по траектории)  \
# 0        1044        355879       6760292                            355561.0
# 1        1050        354845       6760530                            355294.0
# 2        1053        354280       6760340                            354279.0
# 3         110        352610       6771646                            352594.0
# 4         111        353356       6772107                            353431.0
# 5         113        352828       6772122                            353037.0
# 6         114        353940       6773091                            354006.0
# 7         115        352667       6773402                            352427.0
# 8       1194Р        353327       6775565                            352734.0
# 9         141        350644       6776294                            350534.0
# 10        144        354558       6766134                            354428.0
# 11         15        354988       6768258                            354994.0
# 12         16        354446       6767972                            354590.0
# 13        161        353971       6766349                            353904.0
# 14         17        354608       6768882                            354778.0
# 15        171        354561       6767035                            354388.0
# 16         18        353684       6769087                            353734.0
# 17         19        354102       6768826                            354063.0
# 18        210        353832       6762952                            353874.0
# 19        211        355773       6760625                            355799.0
# 20        246        352942       6782109                            353079.0
# 21         25        353912       6762355                            353916.0
# 22         29        353782       6763946                            353832.0
# 23        307        356100       6766138                            356294.0
# 24         32        354453       6762096                            354951.0
# 25         35        353487       6762615                            353347.0
# 26         38        356061       6762603                            356174.0
# 27         39        354317       6763084                            354315.0
# 28         41        354717       6761311                            355294.0
# 29         76        351839       6779277                            351931.0
# 30         83        352492       6777831                            352757.0
# 31         88        353594       6770243                            353546.0
# 32        905        354133       6785110                            354119.0
# 33         93        353033       6769374                            353289.0
# 34         94        352797       6769850                            352797.0
#
#     Координата забоя Y (по траектории)      Length
# 0                            6760065.0  390.708331
# 1                            6760125.0  604.670158
# 2                            6760336.0    4.123106
# 3                            6771492.0  154.828938
# 4                            6772017.0  117.153745
# 5                            6771625.0  539.156749
# 6                            6773097.0   66.272166
# 7                            6773582.0  300.000000
# 8                            6775583.0  593.273124
# 9                            6776398.0  151.380316
# 10                           6766113.0  131.685231
# 11                           6768265.0    9.219544
# 12                           6767467.0  525.129508
# 13                           6766321.0   72.615425
# 14                           6769256.0  410.823563
# 15                           6766631.0  439.482650
# 16                           6769014.0   88.481637
# 17                           6768901.0   84.534017
# 18                           6763530.0  579.523943
# 19                           6760420.0  206.642203
# 20                           6782383.0  306.341313
# 21                           6762350.0    6.403124
# 22                           6764648.0  703.778374
# 23                           6765680.0  497.393205
# 24                           6761752.0  605.260275
# 25                           6763224.0  624.884789
# 26                           6762645.0  120.552893
# 27                           6763163.0   79.025312
# 28                           6761013.0  649.409732
# 29                           6779307.0   96.767763
# 30                           6777668.0  311.117341
# 31                           6770203.0   62.481997
# 32                           6785145.0   37.696154
# 33                           6768760.0  665.230787
# 34                           6769847.0    3.000000

# %%
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
coordinates_gtm = coordinates_gtm.drop(['Координата X', 'Координата Y', 'Координата забоя Х (по траектории)','Координата забоя Y (по траектории)'], axis=1)

# %%
        new_g = coordinates_gtm['№ скважины'].tolist()
        coordinates_gtm['Номер скважины'] = new_g
        coordinates_gtm = coordinates_gtm.drop(['№ скважины'], axis=1)

wells_GTM = wells_GTM.merge(coordinates_gtm, on='Номер скважины')
        wells_GTM['Длина ГС, м'] = wells_GTM.apply(
            lambda x:
            x['Length'] if x['Length'] >= 110
            else 0, axis=1)
        wells_GTM = wells_GTM.drop(['Length'], axis=1)
wells_GTM
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
#    Номер скважины  Длина ГС, м
# 0            1044   390.708331
# 1            1050   604.670158
# 2            1053     0.000000
# 3             110   154.828938
# 4             111   117.153745
# 5             113   539.156749
# 6             114     0.000000
# 7             115   300.000000
# 8           1194Р   593.273124
# 9             141   151.380316
# 10            144   131.685231
# 11             15     0.000000
# 12             16   525.129508
# 13            161     0.000000
# 14             17   410.823563
# 15            171   439.482650
# 16             18     0.000000
# 17             19     0.000000
# 18            210   579.523943
# 19            211   206.642203
# 20            246   306.341313
# 21             25     0.000000
# 22             29   703.778374
# 23            307   497.393205
# 24             32   605.260275
# 25             35   624.884789
# 26             38   120.552893
# 27             39     0.000000
# 28             41   649.409732
# 29             76     0.000000
# 30             83   311.117341
# 31             88     0.000000
# 32            905     0.000000
# 33             93   665.230787
# 34             94     0.000000

# %%
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
grp_ggtm = copy.deepcopy(grp_gtm)
grp_ggtm.reset_index(drop=True)
grp_ggtm.reset_index(inplace=True)
grp_ggtm['Скважина'] = grp_ggtm.apply(
            lambda x:
            str(x['Скважина']), axis=1)
grp_ggtm = grp_ggtm[grp_ggtm['Скважина'].isin(my_wells_only_gtm)].reset_index(drop=True)
        #grp_1 = grp_1.drop(['С начала мероприятия', 'С начала года', 'За текущий месяц', 'P нас', 'В-ть жидк.', 'Коб'],
        #                   axis=1)
        #grp_1 = grp_1.drop(['Пл-ть нефти', 'Факт', 'План', 'Комментарий', 'Dэк', 'Пласт', 'Страница'], axis=1)
        #grp_1 = grp_1.drop(['Unnamed: 11', 'Hэфф', 'Pпл.2', 'H дин.1', 'Pзаб.2', 'Состояние.1', 'Кпр'], axis=1)
        #grp_1 = grp_1.drop(['Скин-фактор.1', 'Интервалы перф..1', 'Насос.1', 'Напор.1', 'Производительность.1'], axis=1)
        #grp_1 = grp_1.drop(
        #    ['%.2', 'Qж.2', 'Qн.2', 'Hспуск.1', 'Кач.1', 'Част.1', 'Lхода.1', 'Метод.1', 'Скин-фактор', 'Pзаб.1',
        #     'Метод', 'Re'], axis=1)
        #grp_1 = grp_1.drop(['Pпл.1', '%.1', 'Qж.1', 'Qн.1', 'Окончание', 'Начало', 'Производительность', 'Насос'],
        #                   axis=1)
        #grp_1 = grp_1.drop(['Интервалы перф.', 'Hвд', 'Состояние', 'Pзаб', 'Pпл', 'H дин', 'Lхода', 'Напор'], axis=1)
        #grp_1 = grp_1.drop(['Месторождение', 'Unnamed: 0', 'Куст', 'Част', 'Кач', 'Hспуск', 'Qн', 'Qж', '%'], axis=1)
        #grp_1 = grp_1[grp_1['Скважина'].isin(my_wells_no_repeat)].reset_index(drop=True)
        # даты введения ГРП и ВНС на скважинах очень важно!!!!!!!
grp_ggtm
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
#      index         Месторождение  Unnamed: 0 Скважина     Куст  \
# 0       14  Западно-Усть-Балыкск  Добывающая     1044  КУСТ-14
# 1       15  Западно-Усть-Балыкск  Добывающая     1044  КУСТ-14
# 2       16  Западно-Усть-Балыкск  Добывающая     1044  КУСТ-14
# 3       17  Западно-Усть-Балыкск  Добывающая     1044  КУСТ-14
# 4       18  Западно-Усть-Балыкск  Добывающая     1044  КУСТ-14
# ..     ...                   ...         ...      ...      ...
# 296   1713  Западно-Усть-Балыкск  Добывающая       94   КУСТ-5
# 297   1714  Западно-Усть-Балыкск  Добывающая       94   КУСТ-5
# 298   1715  Западно-Усть-Балыкск  Добывающая       94   КУСТ-5
# 299   1716  Западно-Усть-Балыкск  Добывающая       94   КУСТ-5
# 300   1717  Западно-Усть-Балыкск  Добывающая       94   КУСТ-5
#
#                     Тип Объект разработки до ГТМ  Объект разработки после ГТМ  \
# 0                   ВНС                      Б10                          NaN
# 1                   3БС                      Б10                          NaN
# 2                   ЛАР                      Б10                          NaN
# 3                 См_ПО                      Б10                          NaN
# 4    Запуск без ремонта                      Б10                          NaN
# ..                  ...                      ...                          ...
# 296  Запуск без ремонта                      Б10                          NaN
# 297  Запуск без ремонта                      Б10                          NaN
# 298                 ППР                      Б10                          NaN
# 299                 ОПЗ                      Б10                          NaN
# 300  Запуск без ремонта                      Б10                          NaN
#
#     Страница  Dэк  ... Напор.1  Производительность.1  Комментарий  План  Факт  \
# 0        -1_  NaN  ...     NaN                   NaN          NaN   NaN   NaN
# 1        -1_  NaN  ...     NaN                   NaN          NaN   NaN   NaN
# 2        -1_  NaN  ...     NaN                   NaN          NaN   NaN   NaN
# 3        -1_  NaN  ...     NaN                   NaN          NaN   NaN   NaN
# 4        -1_  NaN  ...     NaN                   NaN          NaN   NaN   NaN
# ..       ...  ...  ...     ...                   ...          ...   ...   ...
# 296      -1_  NaN  ...     NaN                   NaN          NaN   NaN   NaN
# 297      -1_  NaN  ...     NaN                   NaN          NaN   NaN   NaN
# 298      -1_  NaN  ...     NaN                   NaN          NaN   NaN   NaN
# 299      -1_  NaN  ...     NaN                   NaN          NaN   NaN   NaN
# 300      -1_  NaN  ...     NaN                   NaN          NaN   NaN   NaN
#
#      Пл-ть нефти  Коб  В-ть жидк.  P нас  Unnamed: 65
# 0            NaN  NaN         NaN    NaN          NaN
# 1            NaN  NaN         NaN    NaN          NaN
# 2            NaN  NaN         NaN    NaN          NaN
# 3            NaN  NaN         NaN    NaN          NaN
# 4            NaN  NaN         NaN    NaN          NaN
# ..           ...  ...         ...    ...          ...
# 296          NaN  NaN         NaN    NaN          NaN
# 297          NaN  NaN         NaN    NaN          NaN
# 298          NaN  NaN         NaN    NaN          NaN
# 299          NaN  NaN         NaN    NaN          NaN
# 300          NaN  NaN         NaN    NaN          NaN
#
# [301 rows x 67 columns]

# %%
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
grp_gang = copy.deepcopy(grp_ggtm)
grp_gang['Дата ВНР после ГС \\ ГРП \\ЗБГС'] = grp_gang.apply(
            lambda x:
            x['ВНР.1'] if 'КР7-2' in str(x['Краткое описание мероприятий'])
            else x['ВНР.1'] if 'Ввод добывающих сква' in str(x['Краткое описание мероприятий'])
            else 'нет', axis=1)
grp_gang['Тип ГТМ'] = grp_gang.apply(
            lambda x:
            'ГРП' if 'КР7-2' in str(x['Краткое описание мероприятий'])
            else 'ВНС' if 'Ввод добывающих сква' in str(x['Краткое описание мероприятий'])
            else 'нет', axis=1)

grp_gang.loc[grp_gang['Скважина'] == '3938']
# Out:
# Empty DataFrame
# Columns: [index, Месторождение, Unnamed: 0, Скважина, Куст, Тип, Объект разработки до ГТМ, Объект разработки после ГТМ, Страница, Dэк, Краткое описание мероприятий, Unnamed: 10, Hэфф, Re, Метод, Насос, Производительность, Напор, Lхода, Част, Кач, Hспуск, Qн, Qж, %, H дин, Рпл, Pзаб, Состояние, Hвд, Начало, Окончание, ВНР, Начало.1, Окончание.1, ВНР.1, Qн.1, Qж.1, %.1, Рпл.1, Pзаб.1, Скин-фактор, Метод.1, Lхода.1, Част.1, Кач.1, Hспуск.1, Qн.2, Qж.2, %.2, H дин.1, Рпл.2, Pзаб.2, Состояние.1, Кпр, Скин-фактор.1, Насос.1, Напор.1, Производительность.1, Комментарий, План, Факт, Пл-ть нефти, Коб, В-ть жидк., P нас, Unnamed: 65, Дата ВНР после ГС \ ГРП \ЗБГС, Тип ГТМ]
# Index: []
#
# [0 rows x 69 columns]

# %%
grp_gang
# Out:
#      index         Месторождение  Unnamed: 0 Скважина     Куст  \
# 0       14  Западно-Усть-Балыкск  Добывающая     1044  КУСТ-14
# 1       15  Западно-Усть-Балыкск  Добывающая     1044  КУСТ-14
# 2       16  Западно-Усть-Балыкск  Добывающая     1044  КУСТ-14
# 3       17  Западно-Усть-Балыкск  Добывающая     1044  КУСТ-14
# 4       18  Западно-Усть-Балыкск  Добывающая     1044  КУСТ-14
# ..     ...                   ...         ...      ...      ...
# 296   1713  Западно-Усть-Балыкск  Добывающая       94   КУСТ-5
# 297   1714  Западно-Усть-Балыкск  Добывающая       94   КУСТ-5
# 298   1715  Западно-Усть-Балыкск  Добывающая       94   КУСТ-5
# 299   1716  Западно-Усть-Балыкск  Добывающая       94   КУСТ-5
# 300   1717  Западно-Усть-Балыкск  Добывающая       94   КУСТ-5
#
#                     Тип Объект разработки до ГТМ  Объект разработки после ГТМ  \
# 0                   ВНС                      Б10                          NaN
# 1                   3БС                      Б10                          NaN
# 2                   ЛАР                      Б10                          NaN
# 3                 См_ПО                      Б10                          NaN
# 4    Запуск без ремонта                      Б10                          NaN
# ..                  ...                      ...                          ...
# 296  Запуск без ремонта                      Б10                          NaN
# 297  Запуск без ремонта                      Б10                          NaN
# 298                 ППР                      Б10                          NaN
# 299                 ОПЗ                      Б10                          NaN
# 300  Запуск без ремонта                      Б10                          NaN
#
#     Страница  Dэк  ... Комментарий  План  Факт  Пл-ть нефти  Коб  В-ть жидк.  \
# 0        -1_  NaN  ...         NaN   NaN   NaN          NaN  NaN         NaN
# 1        -1_  NaN  ...         NaN   NaN   NaN          NaN  NaN         NaN
# 2        -1_  NaN  ...         NaN   NaN   NaN          NaN  NaN         NaN
# 3        -1_  NaN  ...         NaN   NaN   NaN          NaN  NaN         NaN
# 4        -1_  NaN  ...         NaN   NaN   NaN          NaN  NaN         NaN
# ..       ...  ...  ...         ...   ...   ...          ...  ...         ...
# 296      -1_  NaN  ...         NaN   NaN   NaN          NaN  NaN         NaN
# 297      -1_  NaN  ...         NaN   NaN   NaN          NaN  NaN         NaN
# 298      -1_  NaN  ...         NaN   NaN   NaN          NaN  NaN         NaN
# 299      -1_  NaN  ...         NaN   NaN   NaN          NaN  NaN         NaN
# 300      -1_  NaN  ...         NaN   NaN   NaN          NaN  NaN         NaN
#
#      P нас  Unnamed: 65  Дата ВНР после ГС \ ГРП \ЗБГС  Тип ГТМ
# 0      NaN          NaN            2014-11-18 00:00:00      ВНС
# 1      NaN          NaN                            нет      нет
# 2      NaN          NaN                            нет      нет
# 3      NaN          NaN                            нет      нет
# 4      NaN          NaN                            нет      нет
# ..     ...          ...                            ...      ...
# 296    NaN          NaN                            нет      нет
# 297    NaN          NaN                            нет      нет
# 298    NaN          NaN                            нет      нет
# 299    NaN          NaN                            нет      нет
# 300    NaN          NaN                            нет      нет
#
# [301 rows x 69 columns]

# %%
grp_gang = grp_gang.drop(grp_gang[grp_gang['Дата ВНР после ГС \\ ГРП \\ЗБГС'] == 'нет'].index)
grp_gang = grp_gang.groupby(by=['Скважина', 'Дата ВНР после ГС \ ГРП \ЗБГС']).agg(
            {'Тип ГТМ': lambda x:
            x.tolist()[0]}
        )
grp_gang.reset_index(inplace=True)
grp_gang.loc[grp_gang['Скважина'] == '3938']
# Out:
# Empty DataFrame
# Columns: [Скважина, Дата ВНР после ГС \ ГРП \ЗБГС, Тип ГТМ]
# Index: []

# %%
grp_gang
# Out:
#    Скважина Дата ВНР после ГС \ ГРП \ЗБГС Тип ГТМ
# 0      1044                    2014-11-18     ВНС
# 1      1050                    2015-05-24     ВНС
# 2       111                    2012-11-16     ВНС
# 3       111                    2013-01-04     ГРП
# 4       113                    2012-12-22     ВНС
# 5       114                    2012-12-29     ВНС
# 6       115                    2012-08-11     ГРП
# 7       115                    2019-05-22     ГРП
# 8     1194Р                    2005-01-15     ГРП
# 9     1194Р                    2005-03-01     ВНС
# 10    1194Р                    2018-04-19     ГРП
# 11      141                    2013-01-29     ГРП
# 12      141                    2017-02-05     ГРП
# 13       15                    2011-06-16     ВНС
# 14       16                    2011-11-05     ВНС
# 15      161                    2012-08-11     ГРП
# 16       17                    2011-09-15     ГРП
# 17       17                    2017-11-10     ГРП
# 18      171                    2012-06-10     ВНС
# 19       18                    2012-09-17     ВНС
# 20       18                    2012-12-25     ГРП
# 21       19                    2011-08-28     ВНС
# 22      210                    2012-06-10     ВНС
# 23      211                    2012-07-30     ВНС
# 24      211                    2013-08-28     ГРП
# 25      246                    2016-11-03     ГРП
# 26       25                    2011-12-23     ВНС
# 27       29                    2012-10-09     ВНС
# 28      307                    2018-04-16     ГРП
# 29      307                    2021-11-27     ГРП
# 30       32                    2012-04-19     ВНС
# 31       35                    2013-02-12     ВНС
# 32       38                    2012-03-17     ГРП
# 33       39                    2012-06-30     ВНС
# 34       41                    2012-07-07     ВНС
# 35       76                    2013-08-26     ГРП
# 36       83                    2013-03-18     ГРП
# 37       88                    2013-06-11     ГРП
# 38       88                    2014-10-16     ГРП
# 39      905                    2016-10-02     ВНС
# 40       93                    2012-09-09     ВНС

# %%
grp_vnski_double = grp_gang.drop(grp_gang[grp_gang['Тип ГТМ'] != 'ВНС'].index).reset_index(drop=True)
grp_vnski_double
# Out:
#    Скважина Дата ВНР после ГС \ ГРП \ЗБГС Тип ГТМ
# 0      1044                    2014-11-18     ВНС
# 1      1050                    2015-05-24     ВНС
# 2       111                    2012-11-16     ВНС
# 3       113                    2012-12-22     ВНС
# 4       114                    2012-12-29     ВНС
# 5     1194Р                    2005-03-01     ВНС
# 6        15                    2011-06-16     ВНС
# 7        16                    2011-11-05     ВНС
# 8       171                    2012-06-10     ВНС
# 9        18                    2012-09-17     ВНС
# 10       19                    2011-08-28     ВНС
# 11      210                    2012-06-10     ВНС
# 12      211                    2012-07-30     ВНС
# 13       25                    2011-12-23     ВНС
# 14       29                    2012-10-09     ВНС
# 15       32                    2012-04-19     ВНС
# 16       35                    2013-02-12     ВНС
# 17       39                    2012-06-30     ВНС
# 18       41                    2012-07-07     ВНС
# 19      905                    2016-10-02     ВНС
# 20       93                    2012-09-09     ВНС

# %%
vvvvv = grp_gang['Скважина'].tolist()

grp_gang['Номер скважины'] = vvvvv
grp_gang = grp_gang.drop(['Скважина'], axis=1)
grp_gang
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
#    Дата ВНР после ГС \ ГРП \ЗБГС Тип ГТМ Номер скважины
# 0                     2014-11-18     ВНС           1044
# 1                     2015-05-24     ВНС           1050
# 2                     2012-11-16     ВНС            111
# 3                     2013-01-04     ГРП            111
# 4                     2012-12-22     ВНС            113
# 5                     2012-12-29     ВНС            114
# 6                     2012-08-11     ГРП            115
# 7                     2019-05-22     ГРП            115
# 8                     2005-01-15     ГРП          1194Р
# 9                     2005-03-01     ВНС          1194Р
# 10                    2018-04-19     ГРП          1194Р
# 11                    2013-01-29     ГРП            141
# 12                    2017-02-05     ГРП            141
# 13                    2011-06-16     ВНС             15
# 14                    2011-11-05     ВНС             16
# 15                    2012-08-11     ГРП            161
# 16                    2011-09-15     ГРП             17
# 17                    2017-11-10     ГРП             17
# 18                    2012-06-10     ВНС            171
# 19                    2012-09-17     ВНС             18
# 20                    2012-12-25     ГРП             18
# 21                    2011-08-28     ВНС             19
# 22                    2012-06-10     ВНС            210
# 23                    2012-07-30     ВНС            211
# 24                    2013-08-28     ГРП            211
# 25                    2016-11-03     ГРП            246
# 26                    2011-12-23     ВНС             25
# 27                    2012-10-09     ВНС             29
# 28                    2018-04-16     ГРП            307
# 29                    2021-11-27     ГРП            307
# 30                    2012-04-19     ВНС             32
# 31                    2013-02-12     ВНС             35
# 32                    2012-03-17     ГРП             38
# 33                    2012-06-30     ВНС             39
# 34                    2012-07-07     ВНС             41
# 35                    2013-08-26     ГРП             76
# 36                    2013-03-18     ГРП             83
# 37                    2013-06-11     ГРП             88
# 38                    2014-10-16     ГРП             88
# 39                    2016-10-02     ВНС            905
# 40                    2012-09-09     ВНС             93

# %%
#!!!!!!!!!!!!!!!!!!!!!!!!
grp_gang['Полудлина трещины, м'] = grp_gang.apply(
            lambda x:
            100, axis=1)
grp_gang['Ширина трещины, мм'] = grp_gang.apply(
            lambda x:
            4, axis=1)
grp_gang['Проницаемость проппанта, Д'] = grp_gang.apply(
            lambda x:
            100, axis=1)
grp_gang['Полудлина трещины, м'] = grp_gang.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Полудлина трещины, м']
            , axis=1)
grp_gang['Ширина трещины, мм'] = grp_gang.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Ширина трещины, мм']
            , axis=1)
grp_gang['Проницаемость проппанта, Д'] = grp_gang.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Проницаемость проппанта, Д']
            , axis=1)
        # ДОБАВИТЬ В ВНС
grp_gang['Число стадий ГРП'] = grp_gang.apply(
            lambda x:
            1, axis=1)
grp_gang['Число стадий ГРП'] = grp_gang.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Число стадий ГРП']
            , axis=1)
wells_GTM = wells_GTM.merge(grp_gang, on='Номер скважины')
wells_GTM['ГС/ННС'] = wells_GTM.apply(
            lambda x:
            'ННС' if x['Длина ГС, м'] == 0
            else 'ГС', axis=1)
# редактируем его в зависимости от наличия грп
wells_GTM['ГС/ННС'] = wells_GTM.apply(
            lambda x:
            str(x['ГС/ННС']) + '+ГРП' if str(x['Тип ГТМ']) == 'ГРП'
            else x['ГС/ННС'], axis=1)
new_400 = wells_GTM['Номер скважины'].tolist()
wells_GTM['Скважина №'] = new_400
wells_GTM = wells_GTM.drop(['Номер скважины'], axis=1)
wells_GTM['Пласт'] = wells_GTM.apply(
            lambda x:
            plastt, axis=1)
wells_GTM = wells_GTM.reindex(
            columns=['Скважина №', 'Длина ГС, м', 'Число стадий ГРП', 'Полудлина трещины, м', 'Ширина трещины, мм',
                     'Проницаемость проппанта, Д', 'Дата ВНР после ГС \ ГРП \ЗБГС', 'ГС/ННС', 'Тип ГТМ', 'Пласт'])
wells_GTM
    #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1044   390.708331                 0                     0
# 1        1050   604.670158                 0                     0
# 2         111   117.153745                 0                     0
# 3         111   117.153745                 1                   100
# 4         113   539.156749                 0                     0
# 5         114     0.000000                 0                     0
# 6         115   300.000000                 1                   100
# 7         115   300.000000                 1                   100
# 8       1194Р   593.273124                 1                   100
# 9       1194Р   593.273124                 0                     0
# 10      1194Р   593.273124                 1                   100
# 11        141   151.380316                 1                   100
# 12        141   151.380316                 1                   100
# 13         15     0.000000                 0                     0
# 14         16   525.129508                 0                     0
# 15        161     0.000000                 1                   100
# 16         17   410.823563                 1                   100
# 17         17   410.823563                 1                   100
# 18        171   439.482650                 0                     0
# 19         18     0.000000                 0                     0
# 20         18     0.000000                 1                   100
# 21         19     0.000000                 0                     0
# 22        210   579.523943                 0                     0
# 23        211   206.642203                 0                     0
# 24        211   206.642203                 1                   100
# 25        246   306.341313                 1                   100
# 26         25     0.000000                 0                     0
# 27         29   703.778374                 0                     0
# 28        307   497.393205                 1                   100
# 29        307   497.393205                 1                   100
# 30         32   605.260275                 0                     0
# 31         35   624.884789                 0                     0
# 32         38   120.552893                 1                   100
# 33         39     0.000000                 0                     0
# 34         41   649.409732                 0                     0
# 35         76     0.000000                 1                   100
# 36         83   311.117341                 1                   100
# 37         88     0.000000                 1                   100
# 38         88     0.000000                 1                   100
# 39        905     0.000000                 0                     0
# 40         93   665.230787                 0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                    0                           0
# 1                    0                           0
# 2                    0                           0
# 3                    4                         100
# 4                    0                           0
# 5                    0                           0
# 6                    4                         100
# 7                    4                         100
# 8                    4                         100
# 9                    0                           0
# 10                   4                         100
# 11                   4                         100
# 12                   4                         100
# 13                   0                           0
# 14                   0                           0
# 15                   4                         100
# 16                   4                         100
# 17                   4                         100
# 18                   0                           0
# 19                   0                           0
# 20                   4                         100
# 21                   0                           0
# 22                   0                           0
# 23                   0                           0
# 24                   4                         100
# 25                   4                         100
# 26                   0                           0
# 27                   0                           0
# 28                   4                         100
# 29                   4                         100
# 30                   0                           0
# 31                   0                           0
# 32                   4                         100
# 33                   0                           0
# 34                   0                           0
# 35                   4                         100
# 36                   4                         100
# 37                   4                         100
# 38                   4                         100
# 39                   0                           0
# 40                   0                           0
#
#    Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт
# 0                     2014-11-18       ГС     ВНС   Б10
# 1                     2015-05-24       ГС     ВНС   Б10
# 2                     2012-11-16       ГС     ВНС   Б10
# 3                     2013-01-04   ГС+ГРП     ГРП   Б10
# 4                     2012-12-22       ГС     ВНС   Б10
# 5                     2012-12-29      ННС     ВНС   Б10
# 6                     2012-08-11   ГС+ГРП     ГРП   Б10
# 7                     2019-05-22   ГС+ГРП     ГРП   Б10
# 8                     2005-01-15   ГС+ГРП     ГРП   Б10
# 9                     2005-03-01       ГС     ВНС   Б10
# 10                    2018-04-19   ГС+ГРП     ГРП   Б10
# 11                    2013-01-29   ГС+ГРП     ГРП   Б10
# 12                    2017-02-05   ГС+ГРП     ГРП   Б10
# 13                    2011-06-16      ННС     ВНС   Б10
# 14                    2011-11-05       ГС     ВНС   Б10
# 15                    2012-08-11  ННС+ГРП     ГРП   Б10
# 16                    2011-09-15   ГС+ГРП     ГРП   Б10
# 17                    2017-11-10   ГС+ГРП     ГРП   Б10
# 18                    2012-06-10       ГС     ВНС   Б10
# 19                    2012-09-17      ННС     ВНС   Б10
# 20                    2012-12-25  ННС+ГРП     ГРП   Б10
# 21                    2011-08-28      ННС     ВНС   Б10
# 22                    2012-06-10       ГС     ВНС   Б10
# 23                    2012-07-30       ГС     ВНС   Б10
# 24                    2013-08-28   ГС+ГРП     ГРП   Б10
# 25                    2016-11-03   ГС+ГРП     ГРП   Б10
# 26                    2011-12-23      ННС     ВНС   Б10
# 27                    2012-10-09       ГС     ВНС   Б10
# 28                    2018-04-16   ГС+ГРП     ГРП   Б10
# 29                    2021-11-27   ГС+ГРП     ГРП   Б10
# 30                    2012-04-19       ГС     ВНС   Б10
# 31                    2013-02-12       ГС     ВНС   Б10
# 32                    2012-03-17   ГС+ГРП     ГРП   Б10
# 33                    2012-06-30      ННС     ВНС   Б10
# 34                    2012-07-07       ГС     ВНС   Б10
# 35                    2013-08-26  ННС+ГРП     ГРП   Б10
# 36                    2013-03-18   ГС+ГРП     ГРП   Б10
# 37                    2013-06-11  ННС+ГРП     ГРП   Б10
# 38                    2014-10-16  ННС+ГРП     ГРП   Б10
# 39                    2016-10-02      ННС     ВНС   Б10
# 40                    2012-09-09       ГС     ВНС   Б10

# %%
grp_1 = copy.deepcopy(grp_gtm)
grp_1.reset_index(drop=True)
grp_1.reset_index(inplace=True)
grp_1['Скважина'] = grp_1.apply(
lambda x:
str(x['Скважина']), axis=1)
grp_1 = grp_1[grp_1['Скважина'].isin(my_wells_no_repeat)].reset_index(drop=True)
        #grp_1 = grp_1.drop(['С начала мероприятия', 'С начала года', 'За текущий месяц', 'P нас', 'В-ть жидк.', 'Коб'],
        #                   axis=1)
        #grp_1 = grp_1.drop(['Пл-ть нефти', 'Факт', 'План', 'Комментарий', 'Dэк', 'Пласт', 'Страница'], axis=1)
        #grp_1 = grp_1.drop(['Unnamed: 11', 'Hэфф', 'Pпл.2', 'H дин.1', 'Pзаб.2', 'Состояние.1', 'Кпр'], axis=1)
        #grp_1 = grp_1.drop(['Скин-фактор.1', 'Интервалы перф..1', 'Насос.1', 'Напор.1', 'Производительность.1'], axis=1)
        #grp_1 = grp_1.drop(
        #    ['%.2', 'Qж.2', 'Qн.2', 'Hспуск.1', 'Кач.1', 'Част.1', 'Lхода.1', 'Метод.1', 'Скин-фактор', 'Pзаб.1',
        #     'Метод', 'Re'], axis=1)
        #grp_1 = grp_1.drop(['Pпл.1', '%.1', 'Qж.1', 'Qн.1', 'Окончание', 'Начало', 'Производительность', 'Насос'],
        #                   axis=1)
        #grp_1 = grp_1.drop(['Интервалы перф.', 'Hвд', 'Состояние', 'Pзаб', 'Pпл', 'H дин', 'Lхода', 'Напор'], axis=1)
        #grp_1 = grp_1.drop(['Месторождение', 'Unnamed: 0', 'Куст', 'Част', 'Кач', 'Hспуск', 'Qн', 'Qж', '%'], axis=1)
        #grp_1 = grp_1[grp_1['Скважина'].isin(my_wells_no_repeat)].reset_index(drop=True)
        # даты введения ГРП и ВНС на скважинах очень важно!!!!!!!
grp_3 = copy.deepcopy(grp_1)
grp_3['Дата ВНР после ГС \\ ГРП \\ЗБГС'] = grp_3.apply(
lambda x:
x['ВНР.1'] if 'КР7-2' in str(x['Краткое описание мероприятий'])
else x['ВНР.1'] if 'Ввод добывающих сква' in str(x['Краткое описание мероприятий'])
else 'нет', axis=1)
grp_3['Тип ГТМ'] = grp_3.apply(
lambda x:
'ГРП' if 'КР7-2' in str(x['Краткое описание мероприятий'])
else 'ВНС' if 'Ввод добывающих сква' in str(x['Краткое описание мероприятий'])
else 'нет', axis=1)
grp_3 = grp_3.drop(grp_3[grp_3['Дата ВНР после ГС \\ ГРП \\ЗБГС'] == 'нет'].index)
grp_3 = grp_3.groupby(by=['Скважина', 'Дата ВНР после ГС \ ГРП \ЗБГС']).agg(
{'Тип ГТМ': lambda x:
x.tolist()[0]}
)
grp_3.reset_index(inplace=True)
vvv = grp_3['Скважина'].tolist()

grp_3['Номер скважины'] = vvv
grp_3 = grp_3.drop(['Скважина'], axis=1)
grp_3.loc[grp_3['Номер скважины'] == '5217']
# Out:
# Empty DataFrame
# Columns: [Дата ВНР после ГС \ ГРП \ЗБГС, Тип ГТМ, Номер скважины]
# Index: []

# %%
grp_2 = copy.deepcopy(grp_1)
grp_2['ГРП'] = grp_2.apply(
lambda x:
'грп' if 'КР7-2' in str(x['Краткое описание мероприятий'])
else 'вдс' if 'Ввод добывающих сква' in str(x['Краткое описание мероприятий'])
else 'нет', axis=1)
grp_2 = grp_2.drop(grp_2[grp_2['ГРП'] == 'нет'].index)
grp_2 = grp_2.groupby('Скважина').agg(
{'ГРП': lambda x:
x.tolist()}
)
grp_2.reset_index(inplace=True)
        #for i in grp_2['ГРП']:
        #    if 'вдс' in i:
        #        i.remove('вдс')
new_1 = grp_2['Скважина'].tolist()
grp_2['Номер скважины'] = new_1
grp_2 = grp_2.drop(['Скважина'], axis=1)

# %%
        #WARNINGS???????????????????????????
        final = final.merge(grp_3, on='Номер скважины', how='right')
        #final = final.merge(grp_2, on='Номер скважины')
        #final['Число стадий ГРП'] = final.apply(
        #    lambda x:
        #    len(x['ГРП']) if len(x['ГРП']) > 0
        #    else 0, axis=1)
        final['Число стадий ГРП'] = final.apply(
            lambda x:
            3, axis=1)
        #final = final.drop(['ГРП'], axis=1)
        #WARNINGS??????????????????????
        final.loc[final['Номер скважины'] == '5217']
# Out:
# Empty DataFrame
# Columns: [Номер скважины, Unnamed: 0, Дата, Подрядчик, Комментарии, Страница, Unnamed: 6, Пласт, Азимут, k, Ноб, Нэф, Рпл, Верх, Низ, Xf, Hf, Wf, PIdsg, Скин-фактор, JD, FCD, М пр, Покр, План, Проппант, Рпл Хорнер, Эфф, Расход, Конц, Гель, М бр, V под, V без под, V гель, Длиина ГС, м, Дата ВНР после ГС \ ГРП \ЗБГС, Тип ГТМ, Число стадий ГРП]
# Index: []
#
# [0 rows x 39 columns]

# %%
       # число стадий грп по фраклисту
final = final.drop(['Дата'], axis=1)
final_re = final.groupby(by=['Номер скважины']).agg(
            {'Число стадий ГРП': lambda x:
            statistics.mean(x)}
        )
final_re.reset_index(inplace=True)
final_re.loc[final_re['Номер скважины'] == '5217']
# Out:
# Empty DataFrame
# Columns: [Номер скважины, Число стадий ГРП]
# Index: []

# %%
final_go = final.groupby(by=['Номер скважины']).agg(
            {'Длиина ГС, м': lambda x:
            max(x)}
        )
final_go.reset_index(inplace=True)
final_re = final_re.merge(final_go, on='Номер скважины')
final_re.loc[final_re['Номер скважины'] == '5217']
# Out:
# Empty DataFrame
# Columns: [Номер скважины, Число стадий ГРП, Длиина ГС, м]
# Index: []

# %%
final_re['Число стадий ГРП'] = final_re.apply(
            lambda x:
            1 if x['Длиина ГС, м'] == 0 and x['Число стадий ГРП'] >= 1
            else x['Число стадий ГРП'], axis=1)
final_re1 = copy.deepcopy(final_re)

final_re1 = final_re1.drop(final_re1[final_re1['Длиина ГС, м'] == 0].index).reset_index(drop=True)
spisok = final_re1['Номер скважины'].tolist()
        # берем число строк из фраклиста для скважины
final = final.groupby('Номер скважины').agg(
            {'Число стадий ГРП': lambda x:
            x.tolist()}
        )

final['Количество'] = final.apply(
            lambda x:
            len(x['Число стадий ГРП'])
            , axis=1)
final.reset_index(inplace=True)
final = final[final['Номер скважины'].isin(spisok)].reset_index(drop=True)
final = final.drop(['Число стадий ГРП'], axis=1)
final_re2 = final_re.merge(final, on='Номер скважины',how='left')
final_re2.loc[final_re2['Номер скважины'] == '5217']
# Out:
# Empty DataFrame
# Columns: [Номер скважины, Число стадий ГРП, Длиина ГС, м, Количество]
# Index: []

# %%
final_re2 = final_re2.drop(['Число стадий ГРП'], axis=1)
cv = final_re2['Количество'].tolist()
final_re2['Число стадий ГРП'] = cv
final_re2 = final_re2.drop(['Количество'], axis=1)
final_re = final_re[~final_re['Номер скважины'].isin(spisok)].reset_index(drop=True)
new_file = pd.concat([final_re, final_re2])
grp = grp.groupby('Номер скважины').agg(
            {'Пласт': lambda x:
            x.tolist()[0]}
        )
grp.reset_index(inplace=True)
new_file = new_file.merge(grp, on='Номер скважины')
new_file['Полудлина трещины, м'] = new_file.apply(
            lambda x:
            100, axis=1)
new_file['Ширина трещины, мм'] = new_file.apply(
            lambda x:
            4, axis=1)
new_file['Проницаемость проппанта, Д'] = new_file.apply(
            lambda x:
            100, axis=1)
        # объединение грп и нью файла по скважинам
sotired = grp_3.merge(new_file, on='Номер скважины')
        # добавляем последнй столбец
sotired['ГС/ННС'] = sotired.apply(
            lambda x:
            'ННС' if x['Длиина ГС, м'] == 0
            else 'ГС', axis=1)
        # редактируем его в зависимости от наличия грп
sotired['ГС/ННС'] = sotired.apply(
            lambda x:
            str(x['ГС/ННС']) + '+ГРП' if str(x['Тип ГТМ']) == 'ГРП'
            else x['ГС/ННС'], axis=1)
        # перемещаем столбцы в нужном порядке
r = sotired.pop('Дата ВНР после ГС \ ГРП \ЗБГС')
sotired1 = pd.concat([sotired, r], 1)
        # перемещаем столбцы в нужном порядке
q = sotired1.pop('ГС/ННС')
sotired2 = pd.concat([sotired1, q], 1)
        # перемещаем столбцы в нужном порядке
z = sotired2.pop('Тип ГТМ')
sotired3 = pd.concat([sotired2, z], 1)
        # перемещаем столбцы в нужном порядке
d = sotired3.pop('Пласт')
sotired4 = pd.concat([sotired3, d], 1)
i = sotired4['Номер скважины'].tolist()
sotired4['Скважина №'] = i
sotired4 = sotired4.drop(['Номер скважины'], axis=1)
sotired_final = sotired4.reindex(
columns=['Скважина №', 'Длиина ГС, м', 'Число стадий ГРП', 'Полудлина трещины, м', 'Ширина трещины, мм',
                     'Проницаемость проппанта, Д', 'Дата ВНР после ГС \ ГРП \ЗБГС', 'ГС/ННС', 'Тип ГТМ', 'Пласт'])
sotired_final['Число стадий ГРП'] = sotired.apply(
            lambda x:
            0 if str(x['Тип ГТМ']) == 'ВНС'
            else x['Число стадий ГРП'], axis=1)
n = 1
z = sotired_final['Пласт'].value_counts()[:n].index.tolist()
plast = str(z[0])
sotired_final = sotired_final.drop(sotired_final[sotired_final['Пласт'] != plast].index).reset_index(drop=True)
zzz = sotired_final['Длиина ГС, м'].tolist()
sotired_final['Длина ГС, м'] = zzz

sotired_final = sotired_final.drop(['Длиина ГС, м'], axis=1)
sotired_final = sotired_final.reindex(
            columns=['Скважина №', 'Длина ГС, м', 'Число стадий ГРП', 'Полудлина трещины, м', 'Ширина трещины, мм',
                     'Проницаемость проппанта, Д', 'Дата ВНР после ГС \ ГРП \ЗБГС', 'ГС/ННС', 'Тип ГТМ', 'Пласт'])
        #корректное число стадий для грп разных периодов из ФРАКЛИСТА
sotired_final['Дата ВНР после ГС \ ГРП \ЗБГС'] = sotired_final.apply(
            lambda x:
            str(x['Дата ВНР после ГС \ ГРП \ЗБГС']), axis=1)
sotired_final['месяц с грп'] = sotired_final.apply(
            lambda x:
            x['Дата ВНР после ГС \ ГРП \ЗБГС'][:4],
            axis=1
        )
grp_number = copy.deepcopy(grp_dad)
#grp_number.reset_index(drop=True)
#grp_number.reset_index(inplace=True)

        # grp=grp.drop(['Unnamed: 0','Подрядчик','Комментарии','Страница','Unnamed: 6','Азимут'],axis=1)
        # grp=grp.drop(['V гель','V без под','V под','М бр','Гель','Конц','Расход','Эфф','Рпл Хорнер','Проппант','k','Ноб','Нэф','Верх','Низ'],axis=1)
        # grp=grp.drop(['Xf','Hf','Wf','PIdsg','Скин-фактор','JD','FCD','М пр','Покр','План'],axis=1)
grp_number['Номер скважины'] = grp_number.apply(
            lambda x:
            str(x['Номер скважины']), axis=1)
grp_number['Дата'] = grp_number.apply(
            lambda x:
            str(x['Дата']), axis=1)
grp_number['месяц с грп'] = grp_number.apply(
            lambda x:
            x['Дата'][:4],
            axis=1
        )
grp_number_group = grp_number.groupby(by=['Номер скважины', 'месяц с грп']).agg(
            {'Наклон': lambda x:
            x.tolist()}
        )
grp_number_group.reset_index(inplace=True)
grp_number_group['число стадий'] = grp_number_group.apply(
            lambda x:
            len(x['Наклон']), axis=1)
grp_number_group = grp_number_group.drop('Наклон', axis=1)
blabla = grp_number_group['Номер скважины'].tolist()

grp_number_group['Скважина №'] = blabla
grp_number_group = grp_number_group.drop(['Номер скважины'], axis=1)
sotired_final = sotired_final.merge(grp_number_group, on=['месяц с грп', 'Скважина №'],how='left')
milan = sotired_final['число стадий'].tolist()
sotired_final = sotired_final.drop(['Число стадий ГРП'], axis=1)
sotired_final['Число стадий ГРП'] = milan
sotired_final = sotired_final.drop(['число стадий'], axis=1)
sotired_final['Дата ВНР после ГС \ ГРП \ЗБГС']=pd.to_datetime(sotired_final['Дата ВНР после ГС \ ГРП \ЗБГС'])
sotired_final = sotired_final.reindex(
            columns=['Скважина №', 'Длина ГС, м', 'Число стадий ГРП', 'Полудлина трещины, м', 'Ширина трещины, мм',
                     'Проницаемость проппанта, Д', 'Дата ВНР после ГС \ ГРП \ЗБГС', 'ГС/ННС', 'Тип ГТМ', 'Пласт',
                     'месяц с грп'])
sotired_final = pd.concat([sotired_final, wells_GTM])
# Out:
# C:\Users\USER\miniconda3\lib\site-packages\ipykernel_launcher.py:36: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
# C:\Users\USER\miniconda3\lib\site-packages\ipykernel_launcher.py:39: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
# C:\Users\USER\miniconda3\lib\site-packages\ipykernel_launcher.py:42: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
# C:\Users\USER\miniconda3\lib\site-packages\ipykernel_launcher.py:45: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only

# %%
        
        
        
        
        
        
        
        
        
        
        
        
        


        # ставим нули для ВНС
sotired_final['Полудлина трещины, м'] = sotired_final.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Полудлина трещины, м']
            , axis=1)
sotired_final['Ширина трещины, мм'] = sotired_final.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Ширина трещины, мм']
            , axis=1)
sotired_final['Проницаемость проппанта, Д'] = sotired_final.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Проницаемость проппанта, Д']
            , axis=1)
        # ДОБАВИТЬ В ВНС
sotired_final['Число стадий ГРП'] = sotired_final.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Число стадий ГРП']
            , axis=1)
sotired_final
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0         100   554.747690               0.0                     0
# 1         100   554.747690               1.0                   100
# 2         104   545.505270               NaN                   100
# 3         104   545.505270               5.0                   100
# 4         105   512.609988               4.0                   100
# ..        ...          ...               ...                   ...
# 36         83   311.117341               1.0                   100
# 37         88     0.000000               1.0                   100
# 38         88     0.000000               1.0                   100
# 39        905     0.000000               0.0                     0
# 40         93   665.230787               0.0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                    0                           0
# 1                    4                         100
# 2                    4                         100
# 3                    4                         100
# 4                    4                         100
# ..                 ...                         ...
# 36                   4                         100
# 37                   4                         100
# 38                   4                         100
# 39                   0                           0
# 40                   0                           0
#
#    Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп
# 0                     2013-01-22       ГС     ВНС   Б10        2013
# 1                     2017-02-20   ГС+ГРП     ГРП   Б10        2017
# 2                     2013-07-22   ГС+ГРП     ГРП   Б10        2013
# 3                     2020-03-20   ГС+ГРП     ГРП   Б10        2020
# 4                     2013-04-27   ГС+ГРП     ГРП   Б10        2013
# ..                           ...      ...     ...   ...         ...
# 36                    2013-03-18   ГС+ГРП     ГРП   Б10         NaN
# 37                    2013-06-11  ННС+ГРП     ГРП   Б10         NaN
# 38                    2014-10-16  ННС+ГРП     ГРП   Б10         NaN
# 39                    2016-10-02      ННС     ВНС   Б10         NaN
# 40                    2012-09-09       ГС     ВНС   Б10         NaN
#
# [456 rows x 11 columns]

# %%
sotired_final.loc[sotired_final['Скважина №'] == '5217']
# Out:
# Empty DataFrame
# Columns: [Скважина №, Длина ГС, м, Число стадий ГРП, Полудлина трещины, м, Ширина трещины, мм, Проницаемость проппанта, Д, Дата ВНР после ГС \ ГРП \ЗБГС, ГС/ННС, Тип ГТМ, Пласт, месяц с грп]
# Index: []

# %%
sotired_final.reset_index(drop=True)
sotired_final.reset_index(inplace=True)
sotired_final
# Out:
#      index Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        0        100   554.747690               0.0                     0
# 1        1        100   554.747690               1.0                   100
# 2        2        104   545.505270               NaN                   100
# 3        3        104   545.505270               5.0                   100
# 4        4        105   512.609988               4.0                   100
# ..     ...        ...          ...               ...                   ...
# 451     36         83   311.117341               1.0                   100
# 452     37         88     0.000000               1.0                   100
# 453     38         88     0.000000               1.0                   100
# 454     39        905     0.000000               0.0                     0
# 455     40         93   665.230787               0.0                     0
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     0                           0
# 1                     4                         100
# 2                     4                         100
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 451                   4                         100
# 452                   4                         100
# 453                   4                         100
# 454                   0                           0
# 455                   0                           0
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп
# 0                      2013-01-22       ГС     ВНС   Б10        2013
# 1                      2017-02-20   ГС+ГРП     ГРП   Б10        2017
# 2                      2013-07-22   ГС+ГРП     ГРП   Б10        2013
# 3                      2020-03-20   ГС+ГРП     ГРП   Б10        2020
# 4                      2013-04-27   ГС+ГРП     ГРП   Б10        2013
# ..                            ...      ...     ...   ...         ...
# 451                    2013-03-18   ГС+ГРП     ГРП   Б10         NaN
# 452                    2013-06-11  ННС+ГРП     ГРП   Б10         NaN
# 453                    2014-10-16  ННС+ГРП     ГРП   Б10         NaN
# 454                    2016-10-02      ННС     ВНС   Б10         NaN
# 455                    2012-09-09       ГС     ВНС   Б10         NaN
#
# [456 rows x 12 columns]

# %%
#sotired_final = sotired_final.drop(['level_0'], axis=1)
sotired_final = sotired_final.drop(['index'], axis=1)

# %%
sotired_final["is_duplicate"]= sotired_final.duplicated()
sotired_final.loc[sotired_final['Скважина №'] == '5217']
# Out:
# Empty DataFrame
# Columns: [Скважина №, Длина ГС, м, Число стадий ГРП, Полудлина трещины, м, Ширина трещины, мм, Проницаемость проппанта, Д, Дата ВНР после ГС \ ГРП \ЗБГС, ГС/ННС, Тип ГТМ, Пласт, месяц с грп, is_duplicate]
# Index: []

# %%
sotired_final = sotired_final.drop(sotired_final[sotired_final['is_duplicate'] == True].index)
sotired_final.loc[sotired_final['Скважина №'] == '5217']
# Out:
# Empty DataFrame
# Columns: [Скважина №, Длина ГС, м, Число стадий ГРП, Полудлина трещины, м, Ширина трещины, мм, Проницаемость проппанта, Д, Дата ВНР после ГС \ ГРП \ЗБГС, ГС/ННС, Тип ГТМ, Пласт, месяц с грп, is_duplicate]
# Index: []

# %%
sotired_final
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0          100   554.747690               0.0                     0
# 1          100   554.747690               1.0                   100
# 2          104   545.505270               NaN                   100
# 3          104   545.505270               5.0                   100
# 4          105   512.609988               4.0                   100
# ..         ...          ...               ...                   ...
# 451         83   311.117341               1.0                   100
# 452         88     0.000000               1.0                   100
# 453         88     0.000000               1.0                   100
# 454        905     0.000000               0.0                     0
# 455         93   665.230787               0.0                     0
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     0                           0
# 1                     4                         100
# 2                     4                         100
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 451                   4                         100
# 452                   4                         100
# 453                   4                         100
# 454                   0                           0
# 455                   0                           0
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2013-01-22       ГС     ВНС   Б10        2013
# 1                      2017-02-20   ГС+ГРП     ГРП   Б10        2017
# 2                      2013-07-22   ГС+ГРП     ГРП   Б10        2013
# 3                      2020-03-20   ГС+ГРП     ГРП   Б10        2020
# 4                      2013-04-27   ГС+ГРП     ГРП   Б10        2013
# ..                            ...      ...     ...   ...         ...
# 451                    2013-03-18   ГС+ГРП     ГРП   Б10         NaN
# 452                    2013-06-11  ННС+ГРП     ГРП   Б10         NaN
# 453                    2014-10-16  ННС+ГРП     ГРП   Б10         NaN
# 454                    2016-10-02      ННС     ВНС   Б10         NaN
# 455                    2012-09-09       ГС     ВНС   Б10         NaN
#
#      is_duplicate
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 451         False
# 452         False
# 453         False
# 454         False
# 455         False
#
# [333 rows x 12 columns]

# %%
sotired_final.reset_index(inplace=True)
sotired_final = sotired_final.drop(['index'], axis=1)
sotired_final['level_0'] = sotired_final.index
sotired_final
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0          100   554.747690               0.0                     0
# 1          100   554.747690               1.0                   100
# 2          104   545.505270               NaN                   100
# 3          104   545.505270               5.0                   100
# 4          105   512.609988               4.0                   100
# ..         ...          ...               ...                   ...
# 328         83   311.117341               1.0                   100
# 329         88     0.000000               1.0                   100
# 330         88     0.000000               1.0                   100
# 331        905     0.000000               0.0                     0
# 332         93   665.230787               0.0                     0
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     0                           0
# 1                     4                         100
# 2                     4                         100
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 328                   4                         100
# 329                   4                         100
# 330                   4                         100
# 331                   0                           0
# 332                   0                           0
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2013-01-22       ГС     ВНС   Б10        2013
# 1                      2017-02-20   ГС+ГРП     ГРП   Б10        2017
# 2                      2013-07-22   ГС+ГРП     ГРП   Б10        2013
# 3                      2020-03-20   ГС+ГРП     ГРП   Б10        2020
# 4                      2013-04-27   ГС+ГРП     ГРП   Б10        2013
# ..                            ...      ...     ...   ...         ...
# 328                    2013-03-18   ГС+ГРП     ГРП   Б10         NaN
# 329                    2013-06-11  ННС+ГРП     ГРП   Б10         NaN
# 330                    2014-10-16  ННС+ГРП     ГРП   Б10         NaN
# 331                    2016-10-02      ННС     ВНС   Б10         NaN
# 332                    2012-09-09       ГС     ВНС   Б10         NaN
#
#      is_duplicate  level_0
# 0           False        0
# 1           False        1
# 2           False        2
# 3           False        3
# 4           False        4
# ..            ...      ...
# 328         False      328
# 329         False      329
# 330         False      330
# 331         False      331
# 332         False      332
#
# [333 rows x 13 columns]

# %%
#удаляем если в одном месяце
dele = copy.deepcopy(sotired_final)
dele['чек'] = dele.apply(
            lambda x:
            x['Скважина №'].partition('_')[0] if '_' in str(x['Скважина №'])
            else x['Скважина №'], axis=1)
dele['месяц'] =dele.apply(
            lambda x:
            str(x['Дата ВНР после ГС \ ГРП \ЗБГС'])[:7],
            axis=1
        )
dele = dele.groupby(by=['чек','месяц']).agg(
            {'level_0': lambda x:
            x.tolist()}
        )
dele['скока_их'] = dele.apply(
            lambda x: len(x['level_0'])
            , axis=1)
dele = dele.drop(dele[dele['скока_их'] < 2].index).reset_index(drop=True)
to_stay=[]
all_wells=[]
for i in dele['level_0']:    
    all_wells+=i
for i in dele['level_0']:    
    to_stay.append(i[-1])

to_stay
# Out:
# [33, 68, 106, 212, 220]

# %%
all_wells
# Out:
# [32, 33, 67, 68, 105, 106, 211, 212, 219, 220]

# %%
array_3 = list(all_wells)
for x in to_stay:
    try:
        array_3.remove(x)
    except ValueError:
        pass
array_3
# Out:
# [32, 67, 105, 211, 219]

# %%
sotired_final = sotired_final[~sotired_final['level_0'].isin(array_3)].reset_index(drop=True)
sotired_final
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0          100   554.747690               0.0                     0
# 1          100   554.747690               1.0                   100
# 2          104   545.505270               NaN                   100
# 3          104   545.505270               5.0                   100
# 4          105   512.609988               4.0                   100
# ..         ...          ...               ...                   ...
# 323         83   311.117341               1.0                   100
# 324         88     0.000000               1.0                   100
# 325         88     0.000000               1.0                   100
# 326        905     0.000000               0.0                     0
# 327         93   665.230787               0.0                     0
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     0                           0
# 1                     4                         100
# 2                     4                         100
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 323                   4                         100
# 324                   4                         100
# 325                   4                         100
# 326                   0                           0
# 327                   0                           0
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2013-01-22       ГС     ВНС   Б10        2013
# 1                      2017-02-20   ГС+ГРП     ГРП   Б10        2017
# 2                      2013-07-22   ГС+ГРП     ГРП   Б10        2013
# 3                      2020-03-20   ГС+ГРП     ГРП   Б10        2020
# 4                      2013-04-27   ГС+ГРП     ГРП   Б10        2013
# ..                            ...      ...     ...   ...         ...
# 323                    2013-03-18   ГС+ГРП     ГРП   Б10         NaN
# 324                    2013-06-11  ННС+ГРП     ГРП   Б10         NaN
# 325                    2014-10-16  ННС+ГРП     ГРП   Б10         NaN
# 326                    2016-10-02      ННС     ВНС   Б10         NaN
# 327                    2012-09-09       ГС     ВНС   Б10         NaN
#
#      is_duplicate  level_0
# 0           False        0
# 1           False        1
# 2           False        2
# 3           False        3
# 4           False        4
# ..            ...      ...
# 323         False      328
# 324         False      329
# 325         False      330
# 326         False      331
# 327         False      332
#
# [328 rows x 13 columns]

# %%
sotired_final = sotired_final.drop(['level_0'], axis=1)
sotired_final
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0          100   554.747690               0.0                     0
# 1          100   554.747690               1.0                   100
# 2          104   545.505270               NaN                   100
# 3          104   545.505270               5.0                   100
# 4          105   512.609988               4.0                   100
# ..         ...          ...               ...                   ...
# 323         83   311.117341               1.0                   100
# 324         88     0.000000               1.0                   100
# 325         88     0.000000               1.0                   100
# 326        905     0.000000               0.0                     0
# 327         93   665.230787               0.0                     0
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     0                           0
# 1                     4                         100
# 2                     4                         100
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 323                   4                         100
# 324                   4                         100
# 325                   4                         100
# 326                   0                           0
# 327                   0                           0
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2013-01-22       ГС     ВНС   Б10        2013
# 1                      2017-02-20   ГС+ГРП     ГРП   Б10        2017
# 2                      2013-07-22   ГС+ГРП     ГРП   Б10        2013
# 3                      2020-03-20   ГС+ГРП     ГРП   Б10        2020
# 4                      2013-04-27   ГС+ГРП     ГРП   Б10        2013
# ..                            ...      ...     ...   ...         ...
# 323                    2013-03-18   ГС+ГРП     ГРП   Б10         NaN
# 324                    2013-06-11  ННС+ГРП     ГРП   Б10         NaN
# 325                    2014-10-16  ННС+ГРП     ГРП   Б10         NaN
# 326                    2016-10-02      ННС     ВНС   Б10         NaN
# 327                    2012-09-09       ГС     ВНС   Б10         NaN
#
#      is_duplicate
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 323         False
# 324         False
# 325         False
# 326         False
# 327         False
#
# [328 rows x 12 columns]

# %%
sotired_final.loc[sotired_final['Скважина №'] == '1183']
# Out:
# Empty DataFrame
# Columns: [Скважина №, Длина ГС, м, Число стадий ГРП, Полудлина трещины, м, Ширина трещины, мм, Проницаемость проппанта, Д, Дата ВНР после ГС \ ГРП \ЗБГС, ГС/ННС, Тип ГТМ, Пласт, месяц с грп, is_duplicate]
# Index: []

# %%
        # проверяем ЗБС
grp_4 = copy.deepcopy(grp_gtm)

grp_4['Скважина'] = grp_4.apply(
            lambda x:
            str(x['Скважина']), axis=1)
grp_4 = grp_4[grp_4['Скважина'].isin(my_wells_no_repeat+my_wells_only_gtm)].reset_index(drop=True)
#grp_4
grp_zbs = grp_4.drop(grp_4[grp_4['Тип'] != '3БС'].index).reset_index(drop=True)
#grp_zbs = grp_4.loc[grp_4['Тип'] == 'ЗБС']
grp_zbs = grp_zbs.groupby('Скважина').agg(
            {'Начало.1': lambda x:
            x.tolist()[1] if len(x.tolist())>1
            else x.tolist()[0]}
        )
grp_zbs
# Out:
#            Начало.1
# Скважина
# 104      2020-02-26
# 1044     2018-07-31
# 1052     2020-05-25
# 1063     2019-03-18
# 115      2019-05-08
# 1194Р    2018-04-16
# 120      2018-10-15
# 122      2021-10-12
# 123      2021-04-11
# 13       2018-08-07
# 134      2020-07-15
# 138      2020-06-07
# 139      2017-09-15
# 14       2018-06-05
# 141      2020-10-06
# 142      2021-02-08
# 145      2021-02-02
# 151      2019-02-05
# 156      2020-07-27
# 158      2016-07-25
# 160      2020-03-11
# 161      2020-12-14
# 162      2018-04-17
# 165      2018-11-09
# 17       2017-09-08
# 173      2014-12-15
# 177      2015-05-01
# 2002П    2018-11-02
# 207      2021-07-02
# 211      2021-03-23
# 242      2019-04-13
# 246      2019-12-16
# 303      2017-10-11
# 307      2018-02-07
# 37       2020-08-02
# 40       2021-06-04
# 48       2014-02-04
# 83       2021-09-26
# 911      2020-01-31
# 913      2020-11-09
# 917      2020-10-12
# 918      2019-11-06
# 92       2018-06-26
# 923      2017-10-29
# 99       2017-08-14

# %%
grp_zbs.reset_index(drop=True)
grp_zbs.reset_index(inplace=True)
#grp_zbs

vv = grp_zbs['Скважина'].tolist()

grp_zbs['Скважина №'] = vv
grp_zbs = grp_zbs.drop(['Скважина'], axis=1)
sotired_final_zbs = sotired_final.merge(grp_zbs, on='Скважина №')
#sotired_final_zbs
abba = sotired_final_zbs['Скважина №'].tolist()
#abba

sotired_final_zbs['Длина ГС, м'] = sotired_final_zbs.apply(
            lambda x:
            0 if x['Дата ВНР после ГС \ ГРП \ЗБГС'] < x['Начало.1'] else x['Длина ГС, м'],
            axis=1
        )
sotired_final_zbs['Число стадий ГРП'] = sotired_final_zbs.apply(
            lambda x:
            1 if x['Дата ВНР после ГС \ ГРП \ЗБГС'] < x['Начало.1'] else x['Число стадий ГРП'],
            axis=1
        )
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            str(x['Скважина №'])
            + ('_Л' if x['Длина ГС, м'] == 0 else ''),
            axis=1
        )
sotired_final_zbs = sotired_final_zbs.drop(['Начало.1'], axis=1)
sotired_final = sotired_final[~sotired_final['Скважина №'].isin(abba)].reset_index(drop=True)
sotired_final = pd.concat([sotired_final, sotired_final_zbs])
sotired_final.reset_index(drop=True)
sotired_final.reset_index(inplace=True)
sotired_final
# Out:
#      index Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        0        100   554.747690               0.0                     0
# 1        1        100   554.747690               1.0                   100
# 2        2        105   512.609988               4.0                   100
# 3        3       1051     0.000000               1.0                   100
# 4        4        106     0.000000               1.0                   100
# ..     ...        ...          ...               ...                   ...
# 323    101      211_Л     0.000000               1.0                   100
# 324    102      246_Л     0.000000               1.0                   100
# 325    103        307   497.393205               1.0                   100
# 326    104        307   497.393205               1.0                   100
# 327    105       83_Л     0.000000               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     0                           0
# 1                     4                         100
# 2                     4                         100
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 323                   4                         100
# 324                   4                         100
# 325                   4                         100
# 326                   4                         100
# 327                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2013-01-22       ГС     ВНС   Б10        2013
# 1                      2017-02-20   ГС+ГРП     ГРП   Б10        2017
# 2                      2013-04-27   ГС+ГРП     ГРП   Б10        2013
# 3                      2015-05-26  ННС+ГРП     ГРП   Б10        2015
# 4                      2013-04-12  ННС+ГРП     ГРП   Б10        2013
# ..                            ...      ...     ...   ...         ...
# 323                    2013-08-28   ГС+ГРП     ГРП   Б10         NaN
# 324                    2016-11-03   ГС+ГРП     ГРП   Б10         NaN
# 325                    2018-04-16   ГС+ГРП     ГРП   Б10         NaN
# 326                    2021-11-27   ГС+ГРП     ГРП   Б10         NaN
# 327                    2013-03-18   ГС+ГРП     ГРП   Б10         NaN
#
#      is_duplicate
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 323         False
# 324         False
# 325         False
# 326         False
# 327         False
#
# [328 rows x 13 columns]

# %%
sotired_final.loc[sotired_final['Скважина №'] == '1180_Л']
# Out:
# Empty DataFrame
# Columns: [index, Скважина №, Длина ГС, м, Число стадий ГРП, Полудлина трещины, м, Ширина трещины, мм, Проницаемость проппанта, Д, Дата ВНР после ГС \ ГРП \ЗБГС, ГС/ННС, Тип ГТМ, Пласт, месяц с грп, is_duplicate]
# Index: []

# %%
#приставка ФРАК там где надо
sotired_final.reset_index(drop=True)
sotired_final.reset_index(inplace=True)
sotired_final
# Out:
#      level_0  index Скважина №  Длина ГС, м  Число стадий ГРП  \
# 0          0      0        100   554.747690               0.0
# 1          1      1        100   554.747690               1.0
# 2          2      2        105   512.609988               4.0
# 3          3      3       1051     0.000000               1.0
# 4          4      4        106     0.000000               1.0
# ..       ...    ...        ...          ...               ...
# 323      323    101      211_Л     0.000000               1.0
# 324      324    102      246_Л     0.000000               1.0
# 325      325    103        307   497.393205               1.0
# 326      326    104        307   497.393205               1.0
# 327      327    105       83_Л     0.000000               1.0
#
#      Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                       0                   0                           0
# 1                     100                   4                         100
# 2                     100                   4                         100
# 3                     100                   4                         100
# 4                     100                   4                         100
# ..                    ...                 ...                         ...
# 323                   100                   4                         100
# 324                   100                   4                         100
# 325                   100                   4                         100
# 326                   100                   4                         100
# 327                   100                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2013-01-22       ГС     ВНС   Б10        2013
# 1                      2017-02-20   ГС+ГРП     ГРП   Б10        2017
# 2                      2013-04-27   ГС+ГРП     ГРП   Б10        2013
# 3                      2015-05-26  ННС+ГРП     ГРП   Б10        2015
# 4                      2013-04-12  ННС+ГРП     ГРП   Б10        2013
# ..                            ...      ...     ...   ...         ...
# 323                    2013-08-28   ГС+ГРП     ГРП   Б10         NaN
# 324                    2016-11-03   ГС+ГРП     ГРП   Б10         NaN
# 325                    2018-04-16   ГС+ГРП     ГРП   Б10         NaN
# 326                    2021-11-27   ГС+ГРП     ГРП   Б10         NaN
# 327                    2013-03-18   ГС+ГРП     ГРП   Б10         NaN
#
#      is_duplicate
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 323         False
# 324         False
# 325         False
# 326         False
# 327         False
#
# [328 rows x 14 columns]

# %%
step = sotired_final.drop(
            sotired_final[(sotired_final['ГС/ННС'] == 'ГС') | (sotired_final['ГС/ННС'] == 'ННС')].index)
step['для_фрак'] = step.apply(
            lambda x:
            x['Скважина №'].partition('_')[0] if '_' in str(x['Скважина №'])
            else x['Скважина №'], axis=1)
step
# Out:
#      level_0  index Скважина №  Длина ГС, м  Число стадий ГРП  \
# 1          1      1        100   554.747690               1.0
# 2          2      2        105   512.609988               4.0
# 3          3      3       1051     0.000000               1.0
# 4          4      4        106     0.000000               1.0
# 5          5      5       1061   599.368000               5.0
# ..       ...    ...        ...          ...               ...
# 323      323    101      211_Л     0.000000               1.0
# 324      324    102      246_Л     0.000000               1.0
# 325      325    103        307   497.393205               1.0
# 326      326    104        307   497.393205               1.0
# 327      327    105       83_Л     0.000000               1.0
#
#      Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 1                     100                   4                         100
# 2                     100                   4                         100
# 3                     100                   4                         100
# 4                     100                   4                         100
# 5                     100                   4                         100
# ..                    ...                 ...                         ...
# 323                   100                   4                         100
# 324                   100                   4                         100
# 325                   100                   4                         100
# 326                   100                   4                         100
# 327                   100                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 1                      2017-02-20   ГС+ГРП     ГРП   Б10        2017
# 2                      2013-04-27   ГС+ГРП     ГРП   Б10        2013
# 3                      2015-05-26  ННС+ГРП     ГРП   Б10        2015
# 4                      2013-04-12  ННС+ГРП     ГРП   Б10        2013
# 5                      2014-09-20   ГС+ГРП     ГРП   Б10        2014
# ..                            ...      ...     ...   ...         ...
# 323                    2013-08-28   ГС+ГРП     ГРП   Б10         NaN
# 324                    2016-11-03   ГС+ГРП     ГРП   Б10         NaN
# 325                    2018-04-16   ГС+ГРП     ГРП   Б10         NaN
# 326                    2021-11-27   ГС+ГРП     ГРП   Б10         NaN
# 327                    2013-03-18   ГС+ГРП     ГРП   Б10         NaN
#
#      is_duplicate для_фрак
# 1           False      100
# 2           False      105
# 3           False     1051
# 4           False      106
# 5           False     1061
# ..            ...      ...
# 323         False      211
# 324         False      246
# 325         False      307
# 326         False      307
# 327         False       83
#
# [272 rows x 15 columns]

# %%
step.loc[step['для_фрак'] == '5202']
# Out:
# Empty DataFrame
# Columns: [level_0, index, Скважина №, Длина ГС, м, Число стадий ГРП, Полудлина трещины, м, Ширина трещины, мм, Проницаемость проппанта, Д, Дата ВНР после ГС \ ГРП \ЗБГС, ГС/ННС, Тип ГТМ, Пласт, месяц с грп, is_duplicate, для_фрак]
# Index: []

# %%
step = step.groupby(by=['для_фрак']).agg(
            {'level_0': lambda x:
            x.tolist()}
        )
step.reset_index(inplace=True)
step.rename(columns={'для_фрак': 'список'}, inplace=True)

step['Length'] = step.apply(
            lambda x: len(x['level_0'])
            , axis=1)
step
# Out:
#     список          level_0  Length
# 0      100              [1]       1
# 1      104       [222, 223]       2
# 2      105              [2]       1
# 3     1051              [3]       1
# 4     1052       [224, 225]       2
# ..     ...              ...     ...
# 179    921            [195]       1
# 180    923       [306, 307]       2
# 181     96            [196]       1
# 182     98            [197]       1
# 183     99  [308, 309, 310]       3
#
# [184 rows x 3 columns]

# %%
step.loc[step['список'] == '5202']
# Out:
# Empty DataFrame
# Columns: [список, level_0, Length]
# Index: []

# %%
step = step.drop(step[step['Length'] < 1].index)
gang1 = []
gang2 = []
gang3 = []
gang4 = []
gang5 = []
gang6 = []
gang7 = []
gang8 = []
gang9 = []
gang10 = []

for i in step['level_0']:
    if len(i) >= 1:
        gang1.append(i[0])
    if len(i) >= 2:
        gang2.append(i[1])
    if len(i) >= 3:
        gang3.append(i[2])
    if len(i) >= 4:
        gang4.append(i[3])
    if len(i) >= 5:
        gang5.append(i[4])
    if len(i) >= 6:
        gang6.append(i[5])
    if len(i) >= 7:
        gang7.append(i[6])
    if len(i) >= 8:
        gang8.append(i[7])
    if len(i) >= 9:
        gang9.append(i[8])
    if len(i) >= 10:
        gang10.append(i[9])
    else:
        pass
gang1
# Out:
# [1,
#  222,
#  2,
#  3,
#  224,
#  4,
#  5,
#  6,
#  226,
#  8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  15,
#  200,
#  16,
#  312,
#  17,
#  19,
#  20,
#  21,
#  25,
#  26,
#  314,
#  27,
#  230,
#  28,
#  233,
#  235,
#  29,
#  30,
#  31,
#  34,
#  36,
#  37,
#  237,
#  38,
#  39,
#  40,
#  42,
#  240,
#  44,
#  45,
#  47,
#  242,
#  246,
#  249,
#  50,
#  317,
#  251,
#  51,
#  252,
#  52,
#  53,
#  55,
#  58,
#  255,
#  61,
#  63,
#  64,
#  257,
#  65,
#  259,
#  67,
#  262,
#  319,
#  264,
#  68,
#  266,
#  320,
#  69,
#  70,
#  269,
#  71,
#  273,
#  72,
#  74,
#  207,
#  76,
#  78,
#  79,
#  80,
#  81,
#  82,
#  84,
#  86,
#  87,
#  89,
#  91,
#  275,
#  92,
#  278,
#  93,
#  94,
#  323,
#  96,
#  98,
#  99,
#  100,
#  101,
#  280,
#  102,
#  103,
#  104,
#  324,
#  105,
#  106,
#  107,
#  108,
#  110,
#  113,
#  114,
#  117,
#  118,
#  120,
#  122,
#  123,
#  125,
#  127,
#  130,
#  132,
#  135,
#  137,
#  138,
#  283,
#  325,
#  139,
#  285,
#  214,
#  290,
#  141,
#  145,
#  148,
#  151,
#  152,
#  154,
#  156,
#  157,
#  160,
#  161,
#  162,
#  163,
#  164,
#  217,
#  165,
#  167,
#  168,
#  169,
#  170,
#  172,
#  327,
#  173,
#  174,
#  175,
#  218,
#  176,
#  177,
#  178,
#  179,
#  180,
#  181,
#  182,
#  183,
#  184,
#  185,
#  186,
#  296,
#  187,
#  298,
#  190,
#  191,
#  192,
#  300,
#  301,
#  193,
#  304,
#  194,
#  195,
#  306,
#  196,
#  197,
#  308]

# %%
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ГРП' if x['level_0'] in gang1
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_1' if x['level_0'] in gang2
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_2' if x['level_0'] in gang3
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_3' if x['level_0'] in gang4
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_4' if x['level_0'] in gang5
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_5' if x['level_0'] in gang6
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_6' if x['level_0'] in gang7
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_7' if x['level_0'] in gang8
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_8' if x['level_0'] in gang9
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_9' if x['level_0'] in gang10
            else x['Скважина №'], axis=1)
sotired_final = sotired_final.drop(['level_0'], axis=1)
#sotired_final = sotired_final.drop(['месяц с грп'], axis=1)
sotired_final
# Out:
#      index  Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        0         100   554.747690               0.0                     0
# 1        1     100_ГРП   554.747690               1.0                   100
# 2        2     105_ГРП   512.609988               4.0                   100
# 3        3    1051_ГРП     0.000000               1.0                   100
# 4        4     106_ГРП     0.000000               1.0                   100
# ..     ...         ...          ...               ...                   ...
# 323    101   211_Л_ГРП     0.000000               1.0                   100
# 324    102   246_Л_ГРП     0.000000               1.0                   100
# 325    103     307_ГРП   497.393205               1.0                   100
# 326    104  307_ФРАК_1   497.393205               1.0                   100
# 327    105    83_Л_ГРП     0.000000               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     0                           0
# 1                     4                         100
# 2                     4                         100
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 323                   4                         100
# 324                   4                         100
# 325                   4                         100
# 326                   4                         100
# 327                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2013-01-22       ГС     ВНС   Б10        2013
# 1                      2017-02-20   ГС+ГРП     ГРП   Б10        2017
# 2                      2013-04-27   ГС+ГРП     ГРП   Б10        2013
# 3                      2015-05-26  ННС+ГРП     ГРП   Б10        2015
# 4                      2013-04-12  ННС+ГРП     ГРП   Б10        2013
# ..                            ...      ...     ...   ...         ...
# 323                    2013-08-28   ГС+ГРП     ГРП   Б10         NaN
# 324                    2016-11-03   ГС+ГРП     ГРП   Б10         NaN
# 325                    2018-04-16   ГС+ГРП     ГРП   Б10         NaN
# 326                    2021-11-27   ГС+ГРП     ГРП   Б10         NaN
# 327                    2013-03-18   ГС+ГРП     ГРП   Б10         NaN
#
#      is_duplicate
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 323         False
# 324         False
# 325         False
# 326         False
# 327         False
#
# [328 rows x 13 columns]

# %%
sotired_final
# Out:
#      index  Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        0         100   554.747690               0.0                     0
# 1        1     100_ГРП   554.747690               1.0                   100
# 2        2     105_ГРП   512.609988               4.0                   100
# 3        3    1051_ГРП     0.000000               1.0                   100
# 4        4     106_ГРП     0.000000               1.0                   100
# ..     ...         ...          ...               ...                   ...
# 323    101   211_Л_ГРП     0.000000               1.0                   100
# 324    102   246_Л_ГРП     0.000000               1.0                   100
# 325    103     307_ГРП   497.393205               1.0                   100
# 326    104  307_ФРАК_1   497.393205               1.0                   100
# 327    105    83_Л_ГРП     0.000000               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     0                           0
# 1                     4                         100
# 2                     4                         100
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 323                   4                         100
# 324                   4                         100
# 325                   4                         100
# 326                   4                         100
# 327                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ Пласт месяц с грп  \
# 0                      2013-01-22       ГС     ВНС   Б10        2013
# 1                      2017-02-20   ГС+ГРП     ГРП   Б10        2017
# 2                      2013-04-27   ГС+ГРП     ГРП   Б10        2013
# 3                      2015-05-26  ННС+ГРП     ГРП   Б10        2015
# 4                      2013-04-12  ННС+ГРП     ГРП   Б10        2013
# ..                            ...      ...     ...   ...         ...
# 323                    2013-08-28   ГС+ГРП     ГРП   Б10         NaN
# 324                    2016-11-03   ГС+ГРП     ГРП   Б10         NaN
# 325                    2018-04-16   ГС+ГРП     ГРП   Б10         NaN
# 326                    2021-11-27   ГС+ГРП     ГРП   Б10         NaN
# 327                    2013-03-18   ГС+ГРП     ГРП   Б10         NaN
#
#      is_duplicate
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 323         False
# 324         False
# 325         False
# 326         False
# 327         False
#
# [328 rows x 13 columns]

# %%
# #удаляем если в одном месяце
# dele = copy.deepcopy(sotired_final)
# dele['чек'] = dele.apply(
#             lambda x:
#             x['Скважина №'].partition('_')[0] if '_' in str(x['Скважина №'])
#             else x['Скважина №'], axis=1)
# dele['месяц'] =dele.apply(
#             lambda x:
#             str(x['Дата ВНР после ГС \ ГРП \ЗБГС'])[:7],
#             axis=1
#         )
# dele = dele.groupby(by=['чек','месяц']).agg(
#             {'level_0': lambda x:
#             x.tolist()}
#         )
# dele['скока_их'] = dele.apply(
#             lambda x: len(x['level_0'])
#             , axis=1)
# dele = dele.drop(dele[dele['скока_их'] < 2].index).reset_index(drop=True)
# to_stay=[]


# for i in dele['level_0']:    
#     to_stay.append(i[-1])
# to_stay

# %%
# dele = copy.deepcopy(sotired_final)
# dele['чек'] = dele.apply(
#             lambda x:
#             x['Скважина №'].partition('_')[0] if '_' in str(x['Скважина №'])
#             else x['Скважина №'], axis=1)
# dele['месяц'] =dele.apply(
#             lambda x:
#             str(x['Дата ВНР после ГС \ ГРП \ЗБГС'])[:7],
#             axis=1
#         )

# dele

# %%
# dele = dele.groupby(by=['чек','месяц']).agg(
#             {'level_0': lambda x:
#             x.tolist()}
#         )
# dele['скока_их'] = dele.apply(
#             lambda x: len(x['level_0'])
#             , axis=1)
# dele = dele.drop(dele[dele['скока_их'] < 2].index).reset_index(drop=True)
# dele

# %%
# to_stay=[]


# for i in dele['level_0']:    
#     to_stay.append(i[-1])
# to_stay

# %%
sotired_final.to_excel('sdelal.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-61-b54ac68ecf65> in <module>
# ----> 1 sotired_final.to_excel('sdelal.xlsx')
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2289             freeze_panes=freeze_panes,
#    2290             engine=engine,
# -> 2291             storage_options=storage_options,
#    2292         )
#    2293
#
# ~\miniconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     833             # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
#     834             writer = ExcelWriter(  # type: ignore[abstract]
# --> 835                 writer, engine=engine, storage_options=storage_options
#     836             )
#     837             need_save = True
#
# ~\miniconda3\lib\site-packages\pandas\io\excel\_openpyxl.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      55             storage_options=storage_options,
#      56             if_sheet_exists=if_sheet_exists,
# ---> 57             engine_kwargs=engine_kwargs,
#      58         )
#      59
#
# ~\miniconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     924         if not isinstance(path, ExcelWriter):
#     925             self.handles = get_handle(
# --> 926                 path, mode, storage_options=storage_options, is_text=False
#     927             )
#     928         self.sheets: dict[str, Any] = {}
#
# ~\miniconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# PermissionError: [Errno 13] Permission denied: 'sdelal.xlsx'
