# %%
import pandas as pd
import statistics
import copy

# %%
coordinates = pd.read_excel('координаты скв1.xlsx')
coordinates.head()
# Out:
#   № скважины  Координата X  Координата Y  Координата забоя Х (по траектории)  \
# 0        103        482574       6770110                            482539.0
# 1      103ПА        483938       6771248                            483951.0
# 2       1084        478410       6770651                            478410.0
# 3       1085        478791       6771402                            478594.0
# 4       1086        478995       6772092                            479215.0
#
#    Координата забоя Y (по траектории)
# 0                           6770073.0
# 1                           6771257.0
# 2                           6770626.0
# 3                           6770936.0
# 4                           6771562.0

# %%
#вычисление длины ствола гс скважины
coordinates['Length'] = coordinates.apply(
    lambda x:((x['Координата забоя Х (по траектории)']-x['Координата X'])**(2)+
              (x['Координата забоя Y (по траектории)']-x['Координата Y'])**(2)) **(0.5)
    , axis=1)
coordinates['№ скважины'] = coordinates.apply(
    lambda x: 
    str(x['№ скважины']), axis=1)
coordinates
coordinates.head()
# Out:
#   № скважины  Координата X  Координата Y  Координата забоя Х (по траектории)  \
# 0        103        482574       6770110                            482539.0
# 1      103ПА        483938       6771248                            483951.0
# 2       1084        478410       6770651                            478410.0
# 3       1085        478791       6771402                            478594.0
# 4       1086        478995       6772092                            479215.0
#
#    Координата забоя Y (по траектории)      Length
# 0                           6770073.0   50.931326
# 1                           6771257.0   15.811388
# 2                           6770626.0   25.000000
# 3                           6770936.0  505.929837
# 4                           6771562.0  573.846669

# %%
grp=pd.read_excel('фраклист1.xlsx',header=[1], index_col=[1])
grp.reset_index(drop=True)
grp.reset_index(inplace=True)

grp=grp.drop(['Unnamed: 0','Подрядчик','Комментарии','Страница','Unnamed: 6','Азимут'],axis=1)
grp=grp.drop(['V гель','V без под','V под','М бр','Гель','Конц','Расход','Эфф','Рпл Хорнер','Проппант','k','Ноб','Нэф','Верх','Низ'],axis=1)
grp=grp.drop(['Xf','Hf','Wf','PIdsg','Скин-фактор','JD','FCD','М пр','Покр','План'],axis=1)
grp['Номер скважины'] = grp.apply(
    lambda x: 
    str(x['Номер скважины']), axis=1)
grp
# Out:
# C:\Users\USER\miniconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    Номер скважины       Дата  Пласт  Наклон    Pпл
# 0             931 2006-07-12  Ю1(1)    2.12  197.0
# 1             931 2004-10-05  Ю1(1)     NaN  236.0
# 2             913 2015-03-22     Б7   26.00  238.0
# 3             911 2015-05-26     Б7   26.00  240.0
# 4             903 2015-05-11   Б6-7    1.00  235.0
# ..            ...        ...    ...     ...    ...
# 86            277 2003-12-29  Ю1(1)     NaN    NaN
# 87            252 2004-08-30  Ю1(1)     NaN  201.0
# 88            149 2005-03-31  Ю1(1)     NaN  252.0
# 89           1338 2020-09-08  Ю1(1)   13.00  215.0
# 90           1330 2020-01-11  Ю1(1)   40.00  226.0
#
# [91 rows x 5 columns]

# %%
#координаты скважин для нашего объекта 
my_wells=grp['Номер скважины'].tolist()
my_wells_no_repeat = [] 
for x in my_wells:
    if x not in my_wells_no_repeat:
        my_wells_no_repeat.append(x)
my_wells_no_repeat
# Out:
# ['931',
#  '913',
#  '911',
#  '903',
#  '902',
#  '900',
#  '899',
#  '890',
#  '889',
#  '878',
#  '864',
#  '861',
#  '842',
#  '830',
#  '819',
#  '810',
#  '659',
#  '65',
#  '632',
#  '631',
#  '63',
#  '614',
#  '61',
#  '60',
#  '564',
#  '539',
#  '535',
#  '525',
#  '524Б',
#  '508',
#  '503',
#  '497',
#  '491',
#  '487',
#  '486',
#  '480',
#  '462',
#  '439',
#  '431',
#  '418',
#  '409',
#  '383',
#  '340',
#  '300',
#  '277',
#  '252',
#  '149',
#  '1338',
#  '1330']

# %%
coordinates=coordinates[
    coordinates['№ скважины'].isin(my_wells_no_repeat)].reset_index(drop=True)
coordinates
# Out:
#    № скважины  Координата X  Координата Y  Координата забоя Х (по траектории)  \
# 0        1330        469292       6783355                            469228.0
# 1        1338        470707       6781886                            470707.0
# 2         149        480902       6783350                            480901.0
# 3         252        485428       6783674                            485440.0
# 4         277        475705       6783605                            475702.0
# 5         300        484295       6782975                            484280.0
# 6         340        486005       6781744                            486007.0
# 7         383        486626       6780555                            486854.0
# 8         409        486733       6780067                            487058.0
# 9         418        475898       6783244                            475897.0
# 10        431        487234       6779774                            487237.0
# 11        439        473976       6783438                            473977.0
# 12        462        471891       6783911                            471878.0
# 13        480        486846       6779074                            487105.0
# 14        486        470454       6783713                            470149.0
# 15        487        471617       6783455                            471615.0
# 16        491        474922       6782390                            474961.0
# 17        497        479935       6780679                            479927.0
# 18        503        471123       6783301                            471127.0
# 19        508        475328       6781957                            475325.0
# 20       524Б        475124       6781519                            475122.0
# 21        525        475908       6781293                            475908.0
# 22        535        472204       6782316                            472208.0
# 23        539        475507       6781228                            475507.0
# 24        564        474806       6780573                            474803.0
# 25         60        486781       6775496                            486801.0
# 26         61        487289       6777075                            487393.0
# 27        614        484811       6779120                            484833.0
# 28         63        486461       6775746                            486205.0
# 29        631        485828       6778117                            485826.0
# 30        632        486687       6778092                            486751.0
# 31         65        487134       6777703                            487286.0
# 32        659        485851       6776026                            485934.0
# 33        810        486311       6781273                            486321.0
# 34        819        476656       6783796                            476655.0
# 35        830        485866       6780705                            485868.0
# 36        842        476178       6782931                            476170.0
# 37        861        471241       6783759                            471240.0
# 38        864        473867       6783019                            473868.0
# 39        878        485349       6779214                            485348.0
# 40        889        474802       6781924                            474790.0
# 41        890        475588       6781620                            475588.0
# 42        899        472469       6781909                            472478.0
# 43        900        473369       6781558                            473369.0
# 44        902        474992       6780952                            474401.0
# 45        903        475822       6780835                            475823.0
# 46        911        474439       6780471                            474410.0
# 47        913        476051       6779920                            476056.0
# 48        931        485725       6777613                            485725.0
#
#     Координата забоя Y (по траектории)      Length
# 0                            6783395.0   75.471849
# 1                            6781876.0   10.000000
# 2                            6783354.0    4.123106
# 3                            6783690.0   20.000000
# 4                            6783607.0    3.605551
# 5                            6783009.0   37.161808
# 6                            6781749.0    5.385165
# 7                            6780454.0  249.369204
# 8                            6780219.0  358.788238
# 9                            6783252.0    8.062258
# 10                           6779776.0    3.605551
# 11                           6783439.0    1.414214
# 12                           6783894.0   21.400935
# 13                           6778978.0  276.219116
# 14                           6783689.0  305.942805
# 15                           6783448.0    7.280110
# 16                           6782367.0   45.276926
# 17                           6780675.0    8.944272
# 18                           6783295.0    7.211103
# 19                           6781972.0   15.297059
# 20                           6781522.0    3.605551
# 21                           6781299.0    6.000000
# 22                           6782318.0    4.472136
# 23                           6781226.0    2.000000
# 24                           6780571.0    3.605551
# 25                           6775467.0   35.227830
# 26                           6777206.0  167.263266
# 27                           6779119.0   22.022716
# 28                           6775281.0  530.811643
# 29                           6778119.0    2.828427
# 30                           6778380.0  295.025423
# 31                           6778393.0  706.543700
# 32                           6775707.0  329.620994
# 33                           6781292.0   21.470911
# 34                           6783797.0    1.414214
# 35                           6780707.0    2.828427
# 36                           6782950.0   20.615528
# 37                           6783759.0    1.000000
# 38                           6783018.0    1.414214
# 39                           6779211.0    3.162278
# 40                           6781940.0   20.000000
# 41                           6781620.0    0.000000
# 42                           6781903.0   10.816654
# 43                           6781571.0   13.000000
# 44                           6780875.0  595.994966
# 45                           6780835.0    1.000000
# 46                           6780457.0   32.202484
# 47                           6779914.0    7.810250
# 48                           6777615.0    2.000000

# %%
coordinates=coordinates.drop(['Координата X','Координата Y','Координата забоя Х (по траектории)','Координата забоя Y (по траектории)'],axis=1)
new=coordinates['№ скважины'].tolist()
coordinates['Номер скважины']=new
coordinates=coordinates.drop(['№ скважины'],axis=1)

coordinates
# Out:
#         Length Номер скважины
# 0    75.471849           1330
# 1    10.000000           1338
# 2     4.123106            149
# 3    20.000000            252
# 4     3.605551            277
# 5    37.161808            300
# 6     5.385165            340
# 7   249.369204            383
# 8   358.788238            409
# 9     8.062258            418
# 10    3.605551            431
# 11    1.414214            439
# 12   21.400935            462
# 13  276.219116            480
# 14  305.942805            486
# 15    7.280110            487
# 16   45.276926            491
# 17    8.944272            497
# 18    7.211103            503
# 19   15.297059            508
# 20    3.605551           524Б
# 21    6.000000            525
# 22    4.472136            535
# 23    2.000000            539
# 24    3.605551            564
# 25   35.227830             60
# 26  167.263266             61
# 27   22.022716            614
# 28  530.811643             63
# 29    2.828427            631
# 30  295.025423            632
# 31  706.543700             65
# 32  329.620994            659
# 33   21.470911            810
# 34    1.414214            819
# 35    2.828427            830
# 36   20.615528            842
# 37    1.000000            861
# 38    1.414214            864
# 39    3.162278            878
# 40   20.000000            889
# 41    0.000000            890
# 42   10.816654            899
# 43   13.000000            900
# 44  595.994966            902
# 45    1.000000            903
# 46   32.202484            911
# 47    7.810250            913
# 48    2.000000            931

# %%
final = grp.merge(coordinates, on='Номер скважины')
final['Длиина ГС, м'] = final.apply(
    lambda x: 
    x['Length'] if x['Наклон']>=70
    else 0, axis=1)
final
# Out:
#    Номер скважины       Дата  Пласт  Наклон    Pпл     Length  Длиина ГС, м
# 0             931 2006-07-12  Ю1(1)    2.12  197.0   2.000000           0.0
# 1             931 2004-10-05  Ю1(1)     NaN  236.0   2.000000           0.0
# 2             913 2015-03-22     Б7   26.00  238.0   7.810250           0.0
# 3             911 2015-05-26     Б7   26.00  240.0  32.202484           0.0
# 4             903 2015-05-11   Б6-7    1.00  235.0   1.000000           0.0
# ..            ...        ...    ...     ...    ...        ...           ...
# 86            277 2003-12-29  Ю1(1)     NaN    NaN   3.605551           0.0
# 87            252 2004-08-30  Ю1(1)     NaN  201.0  20.000000           0.0
# 88            149 2005-03-31  Ю1(1)     NaN  252.0   4.123106           0.0
# 89           1338 2020-09-08  Ю1(1)   13.00  215.0  10.000000           0.0
# 90           1330 2020-01-11  Ю1(1)   40.00  226.0  75.471849           0.0
#
# [91 rows x 7 columns]

# %%
final=final.drop(['Наклон','Length'],axis=1)
final_number = final.groupby('Номер скважины').agg(
    {'Дата': lambda x: 
     x.tolist()}
)

final
# Out:
#    Номер скважины       Дата  Пласт    Pпл  Длиина ГС, м
# 0             931 2006-07-12  Ю1(1)  197.0           0.0
# 1             931 2004-10-05  Ю1(1)  236.0           0.0
# 2             913 2015-03-22     Б7  238.0           0.0
# 3             911 2015-05-26     Б7  240.0           0.0
# 4             903 2015-05-11   Б6-7  235.0           0.0
# ..            ...        ...    ...    ...           ...
# 86            277 2003-12-29  Ю1(1)    NaN           0.0
# 87            252 2004-08-30  Ю1(1)  201.0           0.0
# 88            149 2005-03-31  Ю1(1)  252.0           0.0
# 89           1338 2020-09-08  Ю1(1)  215.0           0.0
# 90           1330 2020-01-11  Ю1(1)  226.0           0.0
#
# [91 rows x 5 columns]

# %%
#обработка и чтение гтм
grp_1=pd.read_excel('гтм.xlsx',header=[1], index_col=[1])
grp_1.reset_index(drop=True)
grp_1.reset_index(inplace=True)
grp_1
# Out:
# C:\Users\USER\miniconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#       Месторождение  Unnamed: 0 Скважина      Куст  \
# 0     Покамасовское  Добывающая     1084  КУСТ-132
# 1     Покамасовское  Добывающая     1084  КУСТ-132
# 2     Покамасовское  Добывающая     1084  КУСТ-132
# 3     Покамасовское  Добывающая     1084  КУСТ-132
# 4     Покамасовское  Добывающая     1084  КУСТ-132
# ...             ...         ...      ...       ...
# 4132  Покамасовское  Добывающая      935   КУСТ-51
# 4133  Покамасовское  Добывающая      935   КУСТ-51
# 4134  Покамасовское  Добывающая       9В   КУСТ-21
# 4135  Покамасовское  Добывающая       9В   КУСТ-21
# 4136  Покамасовское  Добывающая       9Р       NaN
#
#                                     Тип Объект разработки до ГТМ  Пласт  \
# 0                                   ВНС                    Ю1(1)    NaN
# 1                    Запуск без ремонта                    Ю1(1)    NaN
# 2                                 См_ПО                    Ю1(1)    NaN
# 3     Перевод скважин с фонтана на УЭЦН                    Ю1(1)    NaN
# 4                                 См_ПО                    Ю1(1)    NaN
# ...                                 ...                      ...    ...
# 4132                              См_ПО                      NaN    NaN
# 4133                 Запуск без ремонта                    Ю1(1)    NaN
# 4134                                РИР                      NaN    NaN
# 4135                                РИР                      NaN    NaN
# 4136                           Доп.перф                      NaN    NaN
#
#      Страница                    gtmTypeFullName  Dэк  ... Комментарий  План  \
# 0         -1_                 Ввод новых скважин  NaN  ...         NaN   NaN
# 1         -1_                 Запуск без ремонта  NaN  ...         NaN   NaN
# 2         -1_                       Смена насоса  NaN  ...         NaN   NaN
# 3         -1_  Перевод скважин с фонтана на УЭЦН  NaN  ...         NaN   NaN
# 4         -1_                       Смена насоса  NaN  ...         NaN   NaN
# ...       ...                                ...  ...  ...         ...   ...
# 4132      -1_                       Смена насоса  NaN  ...         NaN   NaN
# 4133      -1_                 Запуск без ремонта  NaN  ...         NaN   NaN
# 4134      -1_       Ремонтно-изоляционные работы  NaN  ...         NaN   NaN
# 4135      -1_       Ремонтно-изоляционные работы  NaN  ...         NaN   NaN
# 4136      -1_          Дополнительная перфорация  NaN  ...         NaN   NaN
#
#       Факт  Пл-ть нефти  Коб  В-ть жидк.  P нас  За текущий месяц  \
# 0      NaN          NaN  NaN         NaN    NaN               NaN
# 1      NaN          NaN  NaN         NaN    NaN               NaN
# 2      NaN          NaN  NaN         NaN    NaN               NaN
# 3      NaN          NaN  NaN         NaN    NaN               NaN
# 4      NaN          NaN  NaN         NaN    NaN               NaN
# ...    ...          ...  ...         ...    ...               ...
# 4132   NaN          NaN  NaN         NaN    NaN               NaN
# 4133   NaN          NaN  NaN         NaN    NaN               NaN
# 4134   NaN          NaN  NaN         NaN    NaN               NaN
# 4135   NaN          NaN  NaN         NaN    NaN               NaN
# 4136   NaN          NaN  NaN         NaN    NaN               NaN
#
#       С начала года  С начала мероприятия
# 0               NaN                   NaN
# 1               NaN                   NaN
# 2               NaN                   NaN
# 3               NaN                   NaN
# 4               NaN                   NaN
# ...             ...                   ...
# 4132            NaN                   NaN
# 4133            NaN                   NaN
# 4134            NaN                   NaN
# 4135            NaN                   NaN
# 4136            NaN                   NaN
#
# [4137 rows x 71 columns]

# %%
grp_1['Скважина'] = grp_1.apply(
    lambda x: 
    str(x['Скважина']), axis=1)
grp_1=grp_1[grp_1['Скважина'].isin(my_wells_no_repeat)].reset_index(drop=True)
grp_1=grp_1.drop(['С начала мероприятия','С начала года','За текущий месяц','P нас','В-ть жидк.','Коб'],axis=1)
grp_1=grp_1.drop(['Пл-ть нефти','Факт','План','Комментарий','Dэк','Пласт','Страница'],axis=1)
grp_1=grp_1.drop(['Unnamed: 11','Hэфф','Pпл.2','H дин.1','Pзаб.2','Состояние.1','Кпр'],axis=1)
grp_1=grp_1.drop(['Скин-фактор.1','Интервалы перф..1','Насос.1','Напор.1','Производительность.1'],axis=1)
grp_1=grp_1.drop(['%.2','Qж.2','Qн.2','Hспуск.1','Кач.1','Част.1','Lхода.1','Метод.1','Скин-фактор','Pзаб.1','Метод','Re'],axis=1)
grp_1=grp_1.drop(['Pпл.1','%.1','Qж.1','Qн.1','Окончание','Начало','Производительность','Насос'],axis=1)
grp_1=grp_1.drop(['Интервалы перф.','Hвд','Состояние','Pзаб','Pпл','H дин','Lхода','Напор'],axis=1)
grp_1=grp_1.drop(['Месторождение','Unnamed: 0','Куст','Част','Кач','Hспуск','Qн','Qж','%'],axis=1)
grp_1
#['931', '913', '911', '903', '902', '900', '899', '890', '889', '878', '864', '861', '842', '830', '819', '810', '659', '65', '632', '631', '63', '614', '61', '60', '564', '539', '535', '525', '524Б', '508', '503', '497', '491', '487', '486', '480', '462', '439', '431', '418', '409', '383', '340', '300', '277', '252', '149', '1338', '1330']
# Out:
#     Скважина                     Тип Объект разработки до ГТМ  \
# 0       1330                     ВНС                    Ю1(1)
# 1       1330  Переход или приобщение                    Ю1(1)
# 2       1330                     ГРП                    Ю1(1)
# 3       1330                     ОПЗ                    Ю1(1)
# 4       1330  Переход или приобщение                    Ю1(1)
# ..       ...                     ...                      ...
# 928      931                   См_ПО                      NaN
# 929      931      Запуск без ремонта                    Ю1(1)
# 930      931      Запуск без ремонта                    Ю1(1)
# 931      931      Запуск без ремонта                    Ю1(1)
# 932      931                   См_ПО                    Ю1(1)
#
#                              gtmTypeFullName Краткое описание мероприятий  \
# 0                         Ввод новых скважин         Ввод добывающих сква
# 1    Переход на другой объект или приобщение         КР4 Переход на други
# 2               Гидравлический разрыв пласта         КР7-2 Проведение ГРП
# 3        Обработка призабойной зоны скважины         КР7-34 Интенсификаци
# 4    Переход на другой объект или приобщение         КР4 Переход на други
# ..                                       ...                          ...
# 928                             Смена насоса              ТР4-1 Смена ШГН
# 929                       Запуск без ремонта          Запуск в работу без
# 930                       Запуск без ремонта          Запуск в работу без
# 931                       Запуск без ремонта          Запуск в работу без
# 932                             Смена насоса         ТР5-8 Подъем УЭЦН сп
#
#      ВНР   Начало.1 Окончание.1      ВНР.1
# 0    NaN 2019-09-14  2019-09-24 2019-09-24
# 1    NaN 2019-10-11  2019-10-22 2019-10-22
# 2    NaN 2020-01-01  2020-01-20 2020-01-20
# 3    NaN 2020-02-03  2020-02-19 2020-02-19
# 4    NaN 2020-02-03  2020-02-19 2020-02-19
# ..   ...        ...         ...        ...
# 928  NaN 2013-04-08  2013-04-11 2013-04-11
# 929  NaN 2019-12-30  2019-12-31 2019-12-31
# 930  NaN 2020-02-20  2020-02-20 2020-02-20
# 931  NaN 2020-03-13  2020-03-13 2020-03-13
# 932  NaN 2020-08-23  2020-08-25 2020-08-25
#
# [933 rows x 9 columns]

# %%
grp_1=grp_1[grp_1['Скважина'].isin(my_wells_no_repeat)].reset_index(drop=True)
grp_1
# Out:
#     Скважина                     Тип Объект разработки до ГТМ  \
# 0       1330                     ВНС                    Ю1(1)
# 1       1330  Переход или приобщение                    Ю1(1)
# 2       1330                     ГРП                    Ю1(1)
# 3       1330                     ОПЗ                    Ю1(1)
# 4       1330  Переход или приобщение                    Ю1(1)
# ..       ...                     ...                      ...
# 928      931                   См_ПО                      NaN
# 929      931      Запуск без ремонта                    Ю1(1)
# 930      931      Запуск без ремонта                    Ю1(1)
# 931      931      Запуск без ремонта                    Ю1(1)
# 932      931                   См_ПО                    Ю1(1)
#
#                              gtmTypeFullName Краткое описание мероприятий  \
# 0                         Ввод новых скважин         Ввод добывающих сква
# 1    Переход на другой объект или приобщение         КР4 Переход на други
# 2               Гидравлический разрыв пласта         КР7-2 Проведение ГРП
# 3        Обработка призабойной зоны скважины         КР7-34 Интенсификаци
# 4    Переход на другой объект или приобщение         КР4 Переход на други
# ..                                       ...                          ...
# 928                             Смена насоса              ТР4-1 Смена ШГН
# 929                       Запуск без ремонта          Запуск в работу без
# 930                       Запуск без ремонта          Запуск в работу без
# 931                       Запуск без ремонта          Запуск в работу без
# 932                             Смена насоса         ТР5-8 Подъем УЭЦН сп
#
#      ВНР   Начало.1 Окончание.1      ВНР.1
# 0    NaN 2019-09-14  2019-09-24 2019-09-24
# 1    NaN 2019-10-11  2019-10-22 2019-10-22
# 2    NaN 2020-01-01  2020-01-20 2020-01-20
# 3    NaN 2020-02-03  2020-02-19 2020-02-19
# 4    NaN 2020-02-03  2020-02-19 2020-02-19
# ..   ...        ...         ...        ...
# 928  NaN 2013-04-08  2013-04-11 2013-04-11
# 929  NaN 2019-12-30  2019-12-31 2019-12-31
# 930  NaN 2020-02-20  2020-02-20 2020-02-20
# 931  NaN 2020-03-13  2020-03-13 2020-03-13
# 932  NaN 2020-08-23  2020-08-25 2020-08-25
#
# [933 rows x 9 columns]

# %%
#даты введения ГРП и ВНС на скважинах очень важно!!!!!!!
grp_3 = copy.deepcopy(grp_1)
grp_3=grp_1
grp_3['Дата ВНР после ГС \\ ГРП \\ЗБГС'] = grp_3.apply(
    lambda x: 
    x['Начало.1'] if 'КР7-2' in str(x['Краткое описание мероприятий'])
    else x['Начало.1'] if 'Ввод добывающих сква' in str(x['Краткое описание мероприятий'])
    else 'нет', axis=1)
grp_3['Тип ГТМ'] = grp_3.apply(
    lambda x: 
    'ГРП' if 'КР7-2' in str(x['Краткое описание мероприятий'])
    else 'ВНС' if 'Ввод добывающих сква' in str(x['Краткое описание мероприятий'])
    else 'нет', axis=1)
grp_3 = grp_3.drop(grp_1[grp_1['Дата ВНР после ГС \\ ГРП \\ЗБГС'] == 'нет'].index)
grp_3 = grp_3.groupby(by=['Скважина','Дата ВНР после ГС \ ГРП \ЗБГС']).agg(
    {'Тип ГТМ': lambda x: 
     x.tolist()[0]}
)
grp_3.reset_index(inplace=True)
vvv=grp_3['Скважина'].tolist()

grp_3['Номер скважины']=vvv
grp_3=grp_3.drop(['Скважина'],axis=1)
grp_3
# Out:
#     Дата ВНР после ГС \ ГРП \ЗБГС Тип ГТМ Номер скважины
# 0                      2019-09-14     ВНС           1330
# 1                      2020-01-01     ГРП           1330
# 2                      2020-09-08     ГРП           1338
# 3                      2020-09-13     ВНС           1338
# 4                      2005-03-31     ГРП            149
# ..                            ...     ...            ...
# 97                     2015-04-07     ГРП            913
# 98                     2001-06-05     ВНС            931
# 99                     2001-06-07     ГРП            931
# 100                    2004-10-05     ГРП            931
# 101                    2006-07-12     ГРП            931
#
# [102 rows x 3 columns]

# %%
grp_2 = copy.deepcopy(grp_1)
grp_2['ГРП'] = grp_2.apply(
    lambda x: 
    'грп' if 'КР7-2' in str(x['Краткое описание мероприятий'])
    else 'вдс' if 'Ввод добывающих сква' in str(x['Краткое описание мероприятий'])
    else 'нет', axis=1)
grp_2 = grp_2.drop(grp_2[grp_2['ГРП'] == 'нет'].index)
grp_2
# Out:
#     Скважина  Тип Объект разработки до ГТМ               gtmTypeFullName  \
# 0       1330  ВНС                    Ю1(1)            Ввод новых скважин
# 2       1330  ГРП                    Ю1(1)  Гидравлический разрыв пласта
# 8       1338  ГРП                    Ю1(1)  Гидравлический разрыв пласта
# 9       1338  ВНС                    Ю1(1)            Ввод новых скважин
# 11       149  ГРП                    Ю1(1)  Гидравлический разрыв пласта
# ..       ...  ...                      ...                           ...
# 886      913  ГРП                    Ю1(1)  Гидравлический разрыв пласта
# 893      931  ГРП                    Ю1(1)  Гидравлический разрыв пласта
# 894      931  ВНС                    Ю1(1)            Ввод новых скважин
# 902      931  ГРП                    Ю1(1)  Гидравлический разрыв пласта
# 910      931  ГРП                    Ю1(1)  Гидравлический разрыв пласта
#
#     Краткое описание мероприятий  ВНР   Начало.1 Окончание.1      ВНР.1  \
# 0           Ввод добывающих сква  NaN 2019-09-14  2019-09-24 2019-09-24
# 2           КР7-2 Проведение ГРП  NaN 2020-01-01  2020-01-20 2020-01-20
# 8           КР7-2 Проведение ГРП  NaN 2020-09-08  2020-09-08 2020-09-08
# 9           Ввод добывающих сква  NaN 2020-09-13  2020-09-13 2020-09-13
# 11          КР7-2 Проведение ГРП  NaN 2005-03-31  2005-03-31 2005-03-31
# ..                           ...  ...        ...         ...        ...
# 886         КР7-2 Проведение ГРП  NaN 2015-04-07  2015-04-07 2015-04-07
# 893         КР7-2 Проведение ГРП  NaN 2001-06-07  2001-06-07 2001-06-07
# 894         Ввод добывающих сква  NaN 2001-06-05  2001-06-27 2001-06-27
# 902         КР7-2 Проведение ГРП  NaN 2004-10-05  2004-10-05 2004-10-05
# 910         КР7-2 Проведение ГРП  NaN 2006-07-12  2006-07-12 2006-07-12
#
#     Дата ВНР после ГС \ ГРП \ЗБГС Тип ГТМ  ГРП
# 0             2019-09-14 00:00:00     ВНС  вдс
# 2             2020-01-01 00:00:00     ГРП  грп
# 8             2020-09-08 00:00:00     ГРП  грп
# 9             2020-09-13 00:00:00     ВНС  вдс
# 11            2005-03-31 00:00:00     ГРП  грп
# ..                            ...     ...  ...
# 886           2015-04-07 00:00:00     ГРП  грп
# 893           2001-06-07 00:00:00     ГРП  грп
# 894           2001-06-05 00:00:00     ВНС  вдс
# 902           2004-10-05 00:00:00     ГРП  грп
# 910           2006-07-12 00:00:00     ГРП  грп
#
# [107 rows x 12 columns]

# %%
grp_2 = grp_2.groupby('Скважина').agg(
    {'ГРП': lambda x: 
     x.tolist()}
)
grp_2.reset_index(inplace=True)
grp_2
# Out:
#    Скважина                                            ГРП
# 0      1330                                     [вдс, грп]
# 1      1338                                     [грп, вдс]
# 2       149                                          [грп]
# 3       252                                     [грп, грп]
# 4       277                                     [вдс, грп]
# 5       300                                     [грп, грп]
# 6       340                                [грп, грп, грп]
# 7       383                           [грп, грп, грп, грп]
# 8       409                                [вдс, грп, грп]
# 9       418                                     [вдс, грп]
# 10      431                                     [вдс, грп]
# 11      439                                          [грп]
# 12      462                                     [вдс, грп]
# 13      480                           [грп, вдс, грп, грп]
# 14      486                                [вдс, грп, грп]
# 15      487                                     [вдс, грп]
# 16      491                                     [грп, грп]
# 17      497                                          [грп]
# 18      503                                     [вдс, грп]
# 19      508                      [грп, грп, грп, грп, грп]
# 20      525                                          [грп]
# 21      535                                     [вдс, грп]
# 22      539                                          [грп]
# 23      564                                          [грп]
# 24       60                                          [грп]
# 25       61                                          [грп]
# 26      614                           [грп, грп, грп, грп]
# 27       63                                     [грп, вдс]
# 28      631                                [вдс, грп, грп]
# 29      632  [грп, вдс, грп, грп, грп, грп, грп, грп, грп]
# 30       65                                     [грп, вдс]
# 31      659                           [вдс, грп, грп, грп]
# 32      810                                [грп, грп, грп]
# 33      819                                     [вдс, грп]
# 34      830                                          [грп]
# 35      842                                     [вдс, грп]
# 36      861                                     [вдс, грп]
# 37      864                                     [грп, грп]
# 38      878                           [грп, вдс, грп, грп]
# 39      889                                          [грп]
# 40      890                                          [грп]
# 41      899                                     [грп, вдс]
# 42      900                                          [грп]
# 43      903                                     [грп, грп]
# 44      911                                          [грп]
# 45      913                                          [грп]
# 46      931                           [грп, вдс, грп, грп]

# %%
for i in grp_2['ГРП']:
    if 'вдс' in i:
        i.remove('вдс')
grp_2
# Out:
#    Скважина                                       ГРП
# 0      1330                                     [грп]
# 1      1338                                     [грп]
# 2       149                                     [грп]
# 3       252                                [грп, грп]
# 4       277                                     [грп]
# 5       300                                [грп, грп]
# 6       340                           [грп, грп, грп]
# 7       383                      [грп, грп, грп, грп]
# 8       409                                [грп, грп]
# 9       418                                     [грп]
# 10      431                                     [грп]
# 11      439                                     [грп]
# 12      462                                     [грп]
# 13      480                           [грп, грп, грп]
# 14      486                                [грп, грп]
# 15      487                                     [грп]
# 16      491                                [грп, грп]
# 17      497                                     [грп]
# 18      503                                     [грп]
# 19      508                 [грп, грп, грп, грп, грп]
# 20      525                                     [грп]
# 21      535                                     [грп]
# 22      539                                     [грп]
# 23      564                                     [грп]
# 24       60                                     [грп]
# 25       61                                     [грп]
# 26      614                      [грп, грп, грп, грп]
# 27       63                                     [грп]
# 28      631                                [грп, грп]
# 29      632  [грп, грп, грп, грп, грп, грп, грп, грп]
# 30       65                                     [грп]
# 31      659                           [грп, грп, грп]
# 32      810                           [грп, грп, грп]
# 33      819                                     [грп]
# 34      830                                     [грп]
# 35      842                                     [грп]
# 36      861                                     [грп]
# 37      864                                [грп, грп]
# 38      878                           [грп, грп, грп]
# 39      889                                     [грп]
# 40      890                                     [грп]
# 41      899                                     [грп]
# 42      900                                     [грп]
# 43      903                                [грп, грп]
# 44      911                                     [грп]
# 45      913                                     [грп]
# 46      931                           [грп, грп, грп]

# %%
new_1=grp_2['Скважина'].tolist()
grp_2['Номер скважины']=new_1
grp_2=grp_2.drop(['Скважина'],axis=1)
final = final.merge(grp_2, on='Номер скважины')
final
# Out:
#    Номер скважины       Дата  Пласт    Pпл  Длиина ГС, м              ГРП
# 0             931 2006-07-12  Ю1(1)  197.0           0.0  [грп, грп, грп]
# 1             931 2004-10-05  Ю1(1)  236.0           0.0  [грп, грп, грп]
# 2             913 2015-03-22     Б7  238.0           0.0            [грп]
# 3             911 2015-05-26     Б7  240.0           0.0            [грп]
# 4             903 2015-05-11   Б6-7  235.0           0.0       [грп, грп]
# ..            ...        ...    ...    ...           ...              ...
# 84            277 2003-12-29  Ю1(1)    NaN           0.0            [грп]
# 85            252 2004-08-30  Ю1(1)  201.0           0.0       [грп, грп]
# 86            149 2005-03-31  Ю1(1)  252.0           0.0            [грп]
# 87           1338 2020-09-08  Ю1(1)  215.0           0.0            [грп]
# 88           1330 2020-01-11  Ю1(1)  226.0           0.0            [грп]
#
# [89 rows x 6 columns]

# %%
final['Число стадий ГРП'] = final.apply(
    lambda x: 
    len(x['ГРП']) if len(x['ГРП'])>0
    else 0, axis=1)
final=final.drop(['ГРП'],axis=1)
#число стадий грп по фраклисту
final=final.drop(['Дата'],axis=1)
final_re = final.groupby(by=['Номер скважины']).agg(
    {'Число стадий ГРП': lambda x: 
     statistics.mean(x)}
)
final_re.reset_index(inplace=True)
final_re
# Out:
#    Номер скважины  Число стадий ГРП
# 0            1330                 1
# 1            1338                 1
# 2             149                 1
# 3             252                 2
# 4             277                 1
# 5             300                 2
# 6             340                 3
# 7             383                 4
# 8             409                 2
# 9             418                 1
# 10            431                 1
# 11            439                 1
# 12            462                 1
# 13            480                 3
# 14            486                 2
# 15            487                 1
# 16            491                 2
# 17            497                 1
# 18            503                 1
# 19            508                 5
# 20            525                 1
# 21            535                 1
# 22            539                 1
# 23            564                 1
# 24             60                 1
# 25             61                 1
# 26            614                 4
# 27             63                 1
# 28            631                 2
# 29            632                 8
# 30             65                 1
# 31            659                 3
# 32            810                 3
# 33            819                 1
# 34            830                 1
# 35            842                 1
# 36            861                 1
# 37            864                 2
# 38            878                 3
# 39            889                 1
# 40            890                 1
# 41            899                 1
# 42            900                 1
# 43            903                 2
# 44            911                 1
# 45            913                 1
# 46            931                 3

# %%
final_go = final.groupby(by=['Номер скважины']).agg(
    {'Длиина ГС, м': lambda x: 
     statistics.mean(x)}
)
final_go.reset_index(inplace=True)
final_go
# Out:
#    Номер скважины  Длиина ГС, м
# 0            1330      0.000000
# 1            1338      0.000000
# 2             149      0.000000
# 3             252      0.000000
# 4             277      0.000000
# 5             300      0.000000
# 6             340      0.000000
# 7             383    249.369204
# 8             409    358.788238
# 9             418      0.000000
# 10            431      0.000000
# 11            439      0.000000
# 12            462      0.000000
# 13            480    220.975293
# 14            486    244.754244
# 15            487      0.000000
# 16            491      0.000000
# 17            497      0.000000
# 18            503      0.000000
# 19            508      0.000000
# 20            525      0.000000
# 21            535      0.000000
# 22            539      0.000000
# 23            564      0.000000
# 24             60      0.000000
# 25             61      0.000000
# 26            614      0.000000
# 27             63    530.811643
# 28            631      0.000000
# 29            632    252.878934
# 30             65    706.543700
# 31            659    263.696796
# 32            810      0.000000
# 33            819      0.000000
# 34            830      0.000000
# 35            842      0.000000
# 36            861      0.000000
# 37            864      0.000000
# 38            878      0.000000
# 39            889      0.000000
# 40            890      0.000000
# 41            899      0.000000
# 42            900      0.000000
# 43            903      0.000000
# 44            911      0.000000
# 45            913      0.000000
# 46            931      0.000000

# %%
final_re = final_re.merge(final_go, on='Номер скважины')
final_re
# Out:
#    Номер скважины  Число стадий ГРП  Длиина ГС, м
# 0            1330                 1      0.000000
# 1            1338                 1      0.000000
# 2             149                 1      0.000000
# 3             252                 2      0.000000
# 4             277                 1      0.000000
# 5             300                 2      0.000000
# 6             340                 3      0.000000
# 7             383                 4    249.369204
# 8             409                 2    358.788238
# 9             418                 1      0.000000
# 10            431                 1      0.000000
# 11            439                 1      0.000000
# 12            462                 1      0.000000
# 13            480                 3    220.975293
# 14            486                 2    244.754244
# 15            487                 1      0.000000
# 16            491                 2      0.000000
# 17            497                 1      0.000000
# 18            503                 1      0.000000
# 19            508                 5      0.000000
# 20            525                 1      0.000000
# 21            535                 1      0.000000
# 22            539                 1      0.000000
# 23            564                 1      0.000000
# 24             60                 1      0.000000
# 25             61                 1      0.000000
# 26            614                 4      0.000000
# 27             63                 1    530.811643
# 28            631                 2      0.000000
# 29            632                 8    252.878934
# 30             65                 1    706.543700
# 31            659                 3    263.696796
# 32            810                 3      0.000000
# 33            819                 1      0.000000
# 34            830                 1      0.000000
# 35            842                 1      0.000000
# 36            861                 1      0.000000
# 37            864                 2      0.000000
# 38            878                 3      0.000000
# 39            889                 1      0.000000
# 40            890                 1      0.000000
# 41            899                 1      0.000000
# 42            900                 1      0.000000
# 43            903                 2      0.000000
# 44            911                 1      0.000000
# 45            913                 1      0.000000
# 46            931                 3      0.000000

# %%
final_re['Число стадий ГРП'] = final_re.apply(
    lambda x: 
    1 if x['Длиина ГС, м']==0 and x['Число стадий ГРП']>=1 
    else x['Число стадий ГРП'], axis=1)
final_re
# Out:
#    Номер скважины  Число стадий ГРП  Длиина ГС, м
# 0            1330                 1      0.000000
# 1            1338                 1      0.000000
# 2             149                 1      0.000000
# 3             252                 1      0.000000
# 4             277                 1      0.000000
# 5             300                 1      0.000000
# 6             340                 1      0.000000
# 7             383                 4    249.369204
# 8             409                 2    358.788238
# 9             418                 1      0.000000
# 10            431                 1      0.000000
# 11            439                 1      0.000000
# 12            462                 1      0.000000
# 13            480                 3    220.975293
# 14            486                 2    244.754244
# 15            487                 1      0.000000
# 16            491                 1      0.000000
# 17            497                 1      0.000000
# 18            503                 1      0.000000
# 19            508                 1      0.000000
# 20            525                 1      0.000000
# 21            535                 1      0.000000
# 22            539                 1      0.000000
# 23            564                 1      0.000000
# 24             60                 1      0.000000
# 25             61                 1      0.000000
# 26            614                 1      0.000000
# 27             63                 1    530.811643
# 28            631                 1      0.000000
# 29            632                 8    252.878934
# 30             65                 1    706.543700
# 31            659                 3    263.696796
# 32            810                 1      0.000000
# 33            819                 1      0.000000
# 34            830                 1      0.000000
# 35            842                 1      0.000000
# 36            861                 1      0.000000
# 37            864                 1      0.000000
# 38            878                 1      0.000000
# 39            889                 1      0.000000
# 40            890                 1      0.000000
# 41            899                 1      0.000000
# 42            900                 1      0.000000
# 43            903                 1      0.000000
# 44            911                 1      0.000000
# 45            913                 1      0.000000
# 46            931                 1      0.000000

# %%
final_re1=final_re
final_re1 = final_re1.drop(final_re1[final_re1['Длиина ГС, м'] == 0].index).reset_index(drop=True)
spisok=final_re1['Номер скважины'].tolist()
final_re1
# Out:
#   Номер скважины  Число стадий ГРП  Длиина ГС, м
# 0            383                 4    249.369204
# 1            409                 2    358.788238
# 2            480                 3    220.975293
# 3            486                 2    244.754244
# 4             63                 1    530.811643
# 5            632                 8    252.878934
# 6             65                 1    706.543700
# 7            659                 3    263.696796

# %%
#берем число строк из фраклиста для скважины
final = final.groupby('Номер скважины').agg(
    {'Число стадий ГРП': lambda x: 
     x.tolist()}
)

final['Количество'] = final.apply(
    lambda x: 
    len(x['Число стадий ГРП']) 
    ,axis=1)
final.reset_index(inplace=True)
final=final[final['Номер скважины'].isin(spisok)].reset_index(drop=True)
final=final.drop(['Число стадий ГРП'],axis=1)
final
# Out:
#   Номер скважины  Количество
# 0            383           3
# 1            409           4
# 2            480           5
# 3            486           5
# 4             63           9
# 5            632           7
# 6             65           8
# 7            659           5

# %%
final_re2 = final_re.merge(final, on='Номер скважины')
final_re2=final_re2.drop(['Число стадий ГРП'],axis=1)
cv=final_re2['Количество'].tolist()
final_re2['Число стадий ГРП']=cv
final_re2=final_re2.drop(['Количество'],axis=1)
final_re2
# Out:
#   Номер скважины  Длиина ГС, м  Число стадий ГРП
# 0            383    249.369204                 3
# 1            409    358.788238                 4
# 2            480    220.975293                 5
# 3            486    244.754244                 5
# 4             63    530.811643                 9
# 5            632    252.878934                 7
# 6             65    706.543700                 8
# 7            659    263.696796                 5

# %%
final_re=final_re[~final_re['Номер скважины'].isin(spisok)].reset_index(drop=True)
final_re
# Out:
#    Номер скважины  Число стадий ГРП  Длиина ГС, м
# 0            1330                 1           0.0
# 1            1338                 1           0.0
# 2             149                 1           0.0
# 3             252                 1           0.0
# 4             277                 1           0.0
# 5             300                 1           0.0
# 6             340                 1           0.0
# 7             418                 1           0.0
# 8             431                 1           0.0
# 9             439                 1           0.0
# 10            462                 1           0.0
# 11            487                 1           0.0
# 12            491                 1           0.0
# 13            497                 1           0.0
# 14            503                 1           0.0
# 15            508                 1           0.0
# 16            525                 1           0.0
# 17            535                 1           0.0
# 18            539                 1           0.0
# 19            564                 1           0.0
# 20             60                 1           0.0
# 21             61                 1           0.0
# 22            614                 1           0.0
# 23            631                 1           0.0
# 24            810                 1           0.0
# 25            819                 1           0.0
# 26            830                 1           0.0
# 27            842                 1           0.0
# 28            861                 1           0.0
# 29            864                 1           0.0
# 30            878                 1           0.0
# 31            889                 1           0.0
# 32            890                 1           0.0
# 33            899                 1           0.0
# 34            900                 1           0.0
# 35            903                 1           0.0
# 36            911                 1           0.0
# 37            913                 1           0.0
# 38            931                 1           0.0

# %%
new_file=pd.concat([final_re,final_re2])
new_file
# Out:
#    Номер скважины  Число стадий ГРП  Длиина ГС, м
# 0            1330                 1      0.000000
# 1            1338                 1      0.000000
# 2             149                 1      0.000000
# 3             252                 1      0.000000
# 4             277                 1      0.000000
# 5             300                 1      0.000000
# 6             340                 1      0.000000
# 7             418                 1      0.000000
# 8             431                 1      0.000000
# 9             439                 1      0.000000
# 10            462                 1      0.000000
# 11            487                 1      0.000000
# 12            491                 1      0.000000
# 13            497                 1      0.000000
# 14            503                 1      0.000000
# 15            508                 1      0.000000
# 16            525                 1      0.000000
# 17            535                 1      0.000000
# 18            539                 1      0.000000
# 19            564                 1      0.000000
# 20             60                 1      0.000000
# 21             61                 1      0.000000
# 22            614                 1      0.000000
# 23            631                 1      0.000000
# 24            810                 1      0.000000
# 25            819                 1      0.000000
# 26            830                 1      0.000000
# 27            842                 1      0.000000
# 28            861                 1      0.000000
# 29            864                 1      0.000000
# 30            878                 1      0.000000
# 31            889                 1      0.000000
# 32            890                 1      0.000000
# 33            899                 1      0.000000
# 34            900                 1      0.000000
# 35            903                 1      0.000000
# 36            911                 1      0.000000
# 37            913                 1      0.000000
# 38            931                 1      0.000000
# 0             383                 3    249.369204
# 1             409                 4    358.788238
# 2             480                 5    220.975293
# 3             486                 5    244.754244
# 4              63                 9    530.811643
# 5             632                 7    252.878934
# 6              65                 8    706.543700
# 7             659                 5    263.696796

# %%
grp = grp.groupby('Номер скважины').agg(
    {'Пласт': lambda x: 
     x.tolist()[0]}
)
grp.reset_index(inplace=True)
grp
# Out:
#    Номер скважины  Пласт
# 0            1330  Ю1(1)
# 1            1338  Ю1(1)
# 2             149  Ю1(1)
# 3             252  Ю1(1)
# 4             277  Ю1(1)
# 5             300  Ю1(1)
# 6             340  Ю1(1)
# 7             383  Ю1(1)
# 8             409  Ю1(1)
# 9             418  Ю1(1)
# 10            431  Ю1(1)
# 11            439  Ю1(1)
# 12            462  Ю1(1)
# 13            480  Ю1(1)
# 14            486  Ю1(1)
# 15            487  Ю1(1)
# 16            491  Ю1(1)
# 17            497  Ю1(1)
# 18            503  Ю1(1)
# 19            508     Б7
# 20           524Б  Ю1(1)
# 21            525   Б6-7
# 22            535  Ю1(1)
# 23            539     Б7
# 24            564     Б7
# 25             60  Ю1(1)
# 26             61  Ю1(1)
# 27            614  Ю1(1)
# 28             63  Ю1(1)
# 29            631  Ю1(1)
# 30            632  Ю1(1)
# 31             65  Ю1(1)
# 32            659  Ю1(1)
# 33            810  Ю1(1)
# 34            819  Ю1(1)
# 35            830  Ю1(1)
# 36            842     Б7
# 37            861  Ю1(1)
# 38            864  Ю1(1)
# 39            878  Ю1(1)
# 40            889     Б7
# 41            890     Б7
# 42            899  Ю1(1)
# 43            900  Ю1(1)
# 44            902     Б7
# 45            903   Б6-7
# 46            911     Б7
# 47            913     Б7
# 48            931  Ю1(1)

# %%
new_file = new_file.merge(grp, on='Номер скважины')
new_file
# Out:
#    Номер скважины  Число стадий ГРП  Длиина ГС, м  Пласт
# 0            1330                 1      0.000000  Ю1(1)
# 1            1338                 1      0.000000  Ю1(1)
# 2             149                 1      0.000000  Ю1(1)
# 3             252                 1      0.000000  Ю1(1)
# 4             277                 1      0.000000  Ю1(1)
# 5             300                 1      0.000000  Ю1(1)
# 6             340                 1      0.000000  Ю1(1)
# 7             418                 1      0.000000  Ю1(1)
# 8             431                 1      0.000000  Ю1(1)
# 9             439                 1      0.000000  Ю1(1)
# 10            462                 1      0.000000  Ю1(1)
# 11            487                 1      0.000000  Ю1(1)
# 12            491                 1      0.000000  Ю1(1)
# 13            497                 1      0.000000  Ю1(1)
# 14            503                 1      0.000000  Ю1(1)
# 15            508                 1      0.000000     Б7
# 16            525                 1      0.000000   Б6-7
# 17            535                 1      0.000000  Ю1(1)
# 18            539                 1      0.000000     Б7
# 19            564                 1      0.000000     Б7
# 20             60                 1      0.000000  Ю1(1)
# 21             61                 1      0.000000  Ю1(1)
# 22            614                 1      0.000000  Ю1(1)
# 23            631                 1      0.000000  Ю1(1)
# 24            810                 1      0.000000  Ю1(1)
# 25            819                 1      0.000000  Ю1(1)
# 26            830                 1      0.000000  Ю1(1)
# 27            842                 1      0.000000     Б7
# 28            861                 1      0.000000  Ю1(1)
# 29            864                 1      0.000000  Ю1(1)
# 30            878                 1      0.000000  Ю1(1)
# 31            889                 1      0.000000     Б7
# 32            890                 1      0.000000     Б7
# 33            899                 1      0.000000  Ю1(1)
# 34            900                 1      0.000000  Ю1(1)
# 35            903                 1      0.000000   Б6-7
# 36            911                 1      0.000000     Б7
# 37            913                 1      0.000000     Б7
# 38            931                 1      0.000000  Ю1(1)
# 39            383                 3    249.369204  Ю1(1)
# 40            409                 4    358.788238  Ю1(1)
# 41            480                 5    220.975293  Ю1(1)
# 42            486                 5    244.754244  Ю1(1)
# 43             63                 9    530.811643  Ю1(1)
# 44            632                 7    252.878934  Ю1(1)
# 45             65                 8    706.543700  Ю1(1)
# 46            659                 5    263.696796  Ю1(1)

# %%
new_file['Полудлина трещины, м'] = new_file.apply(
    lambda x: 
    100, axis=1)
new_file['Ширина трещины, мм'] = new_file.apply(
    lambda x: 
    4, axis=1)
new_file['Проницаемость проппанта, Д'] = new_file.apply(
    lambda x: 
    100, axis=1)
new_file
# Out:
#    Номер скважины  Число стадий ГРП  Длиина ГС, м  Пласт  \
# 0            1330                 1      0.000000  Ю1(1)
# 1            1338                 1      0.000000  Ю1(1)
# 2             149                 1      0.000000  Ю1(1)
# 3             252                 1      0.000000  Ю1(1)
# 4             277                 1      0.000000  Ю1(1)
# 5             300                 1      0.000000  Ю1(1)
# 6             340                 1      0.000000  Ю1(1)
# 7             418                 1      0.000000  Ю1(1)
# 8             431                 1      0.000000  Ю1(1)
# 9             439                 1      0.000000  Ю1(1)
# 10            462                 1      0.000000  Ю1(1)
# 11            487                 1      0.000000  Ю1(1)
# 12            491                 1      0.000000  Ю1(1)
# 13            497                 1      0.000000  Ю1(1)
# 14            503                 1      0.000000  Ю1(1)
# 15            508                 1      0.000000     Б7
# 16            525                 1      0.000000   Б6-7
# 17            535                 1      0.000000  Ю1(1)
# 18            539                 1      0.000000     Б7
# 19            564                 1      0.000000     Б7
# 20             60                 1      0.000000  Ю1(1)
# 21             61                 1      0.000000  Ю1(1)
# 22            614                 1      0.000000  Ю1(1)
# 23            631                 1      0.000000  Ю1(1)
# 24            810                 1      0.000000  Ю1(1)
# 25            819                 1      0.000000  Ю1(1)
# 26            830                 1      0.000000  Ю1(1)
# 27            842                 1      0.000000     Б7
# 28            861                 1      0.000000  Ю1(1)
# 29            864                 1      0.000000  Ю1(1)
# 30            878                 1      0.000000  Ю1(1)
# 31            889                 1      0.000000     Б7
# 32            890                 1      0.000000     Б7
# 33            899                 1      0.000000  Ю1(1)
# 34            900                 1      0.000000  Ю1(1)
# 35            903                 1      0.000000   Б6-7
# 36            911                 1      0.000000     Б7
# 37            913                 1      0.000000     Б7
# 38            931                 1      0.000000  Ю1(1)
# 39            383                 3    249.369204  Ю1(1)
# 40            409                 4    358.788238  Ю1(1)
# 41            480                 5    220.975293  Ю1(1)
# 42            486                 5    244.754244  Ю1(1)
# 43             63                 9    530.811643  Ю1(1)
# 44            632                 7    252.878934  Ю1(1)
# 45             65                 8    706.543700  Ю1(1)
# 46            659                 5    263.696796  Ю1(1)
#
#     Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д
# 0                    100                   4                         100
# 1                    100                   4                         100
# 2                    100                   4                         100
# 3                    100                   4                         100
# 4                    100                   4                         100
# 5                    100                   4                         100
# 6                    100                   4                         100
# 7                    100                   4                         100
# 8                    100                   4                         100
# 9                    100                   4                         100
# 10                   100                   4                         100
# 11                   100                   4                         100
# 12                   100                   4                         100
# 13                   100                   4                         100
# 14                   100                   4                         100
# 15                   100                   4                         100
# 16                   100                   4                         100
# 17                   100                   4                         100
# 18                   100                   4                         100
# 19                   100                   4                         100
# 20                   100                   4                         100
# 21                   100                   4                         100
# 22                   100                   4                         100
# 23                   100                   4                         100
# 24                   100                   4                         100
# 25                   100                   4                         100
# 26                   100                   4                         100
# 27                   100                   4                         100
# 28                   100                   4                         100
# 29                   100                   4                         100
# 30                   100                   4                         100
# 31                   100                   4                         100
# 32                   100                   4                         100
# 33                   100                   4                         100
# 34                   100                   4                         100
# 35                   100                   4                         100
# 36                   100                   4                         100
# 37                   100                   4                         100
# 38                   100                   4                         100
# 39                   100                   4                         100
# 40                   100                   4                         100
# 41                   100                   4                         100
# 42                   100                   4                         100
# 43                   100                   4                         100
# 44                   100                   4                         100
# 45                   100                   4                         100
# 46                   100                   4                         100

# %%
#объединение грп и нью файла по скважинам
sotired = grp_3.merge(new_file, on='Номер скважины')
sotired
# Out:
#     Дата ВНР после ГС \ ГРП \ЗБГС Тип ГТМ Номер скважины  Число стадий ГРП  \
# 0                      2019-09-14     ВНС           1330                 1
# 1                      2020-01-01     ГРП           1330                 1
# 2                      2020-09-08     ГРП           1338                 1
# 3                      2020-09-13     ВНС           1338                 1
# 4                      2005-03-31     ГРП            149                 1
# ..                            ...     ...            ...               ...
# 97                     2015-04-07     ГРП            913                 1
# 98                     2001-06-05     ВНС            931                 1
# 99                     2001-06-07     ГРП            931                 1
# 100                    2004-10-05     ГРП            931                 1
# 101                    2006-07-12     ГРП            931                 1
#
#      Длиина ГС, м  Пласт  Полудлина трещины, м  Ширина трещины, мм  \
# 0             0.0  Ю1(1)                   100                   4
# 1             0.0  Ю1(1)                   100                   4
# 2             0.0  Ю1(1)                   100                   4
# 3             0.0  Ю1(1)                   100                   4
# 4             0.0  Ю1(1)                   100                   4
# ..            ...    ...                   ...                 ...
# 97            0.0     Б7                   100                   4
# 98            0.0  Ю1(1)                   100                   4
# 99            0.0  Ю1(1)                   100                   4
# 100           0.0  Ю1(1)                   100                   4
# 101           0.0  Ю1(1)                   100                   4
#
#      Проницаемость проппанта, Д
# 0                           100
# 1                           100
# 2                           100
# 3                           100
# 4                           100
# ..                          ...
# 97                          100
# 98                          100
# 99                          100
# 100                         100
# 101                         100
#
# [102 rows x 9 columns]

# %%
#добавляем последнй столбец
sotired['ГС/ННС'] = sotired.apply(
    lambda x: 
    'ННС' if x['Длиина ГС, м']==0
    else 'ГС', axis=1)
sotired
# Out:
#     Дата ВНР после ГС \ ГРП \ЗБГС Тип ГТМ Номер скважины  Число стадий ГРП  \
# 0                      2019-09-14     ВНС           1330                 1
# 1                      2020-01-01     ГРП           1330                 1
# 2                      2020-09-08     ГРП           1338                 1
# 3                      2020-09-13     ВНС           1338                 1
# 4                      2005-03-31     ГРП            149                 1
# ..                            ...     ...            ...               ...
# 97                     2015-04-07     ГРП            913                 1
# 98                     2001-06-05     ВНС            931                 1
# 99                     2001-06-07     ГРП            931                 1
# 100                    2004-10-05     ГРП            931                 1
# 101                    2006-07-12     ГРП            931                 1
#
#      Длиина ГС, м  Пласт  Полудлина трещины, м  Ширина трещины, мм  \
# 0             0.0  Ю1(1)                   100                   4
# 1             0.0  Ю1(1)                   100                   4
# 2             0.0  Ю1(1)                   100                   4
# 3             0.0  Ю1(1)                   100                   4
# 4             0.0  Ю1(1)                   100                   4
# ..            ...    ...                   ...                 ...
# 97            0.0     Б7                   100                   4
# 98            0.0  Ю1(1)                   100                   4
# 99            0.0  Ю1(1)                   100                   4
# 100           0.0  Ю1(1)                   100                   4
# 101           0.0  Ю1(1)                   100                   4
#
#      Проницаемость проппанта, Д ГС/ННС
# 0                           100    ННС
# 1                           100    ННС
# 2                           100    ННС
# 3                           100    ННС
# 4                           100    ННС
# ..                          ...    ...
# 97                          100    ННС
# 98                          100    ННС
# 99                          100    ННС
# 100                         100    ННС
# 101                         100    ННС
#
# [102 rows x 10 columns]

# %%
#редактируем его в зависимости от наличия грп
sotired['ГС/ННС'] = sotired.apply(
    lambda x: 
    str(x['ГС/ННС'])+'+ГРП' if str(x['Тип ГТМ'])=='ГРП'
    else x['ГС/ННС'], axis=1)
sotired
# Out:
#     Дата ВНР после ГС \ ГРП \ЗБГС Тип ГТМ Номер скважины  Число стадий ГРП  \
# 0                      2019-09-14     ВНС           1330                 1
# 1                      2020-01-01     ГРП           1330                 1
# 2                      2020-09-08     ГРП           1338                 1
# 3                      2020-09-13     ВНС           1338                 1
# 4                      2005-03-31     ГРП            149                 1
# ..                            ...     ...            ...               ...
# 97                     2015-04-07     ГРП            913                 1
# 98                     2001-06-05     ВНС            931                 1
# 99                     2001-06-07     ГРП            931                 1
# 100                    2004-10-05     ГРП            931                 1
# 101                    2006-07-12     ГРП            931                 1
#
#      Длиина ГС, м  Пласт  Полудлина трещины, м  Ширина трещины, мм  \
# 0             0.0  Ю1(1)                   100                   4
# 1             0.0  Ю1(1)                   100                   4
# 2             0.0  Ю1(1)                   100                   4
# 3             0.0  Ю1(1)                   100                   4
# 4             0.0  Ю1(1)                   100                   4
# ..            ...    ...                   ...                 ...
# 97            0.0     Б7                   100                   4
# 98            0.0  Ю1(1)                   100                   4
# 99            0.0  Ю1(1)                   100                   4
# 100           0.0  Ю1(1)                   100                   4
# 101           0.0  Ю1(1)                   100                   4
#
#      Проницаемость проппанта, Д   ГС/ННС
# 0                           100      ННС
# 1                           100  ННС+ГРП
# 2                           100  ННС+ГРП
# 3                           100      ННС
# 4                           100  ННС+ГРП
# ..                          ...      ...
# 97                          100  ННС+ГРП
# 98                          100      ННС
# 99                          100  ННС+ГРП
# 100                         100  ННС+ГРП
# 101                         100  ННС+ГРП
#
# [102 rows x 10 columns]

# %%
#перемещаем столбцы в нужном порядке
r = sotired.pop('Дата ВНР после ГС \ ГРП \ЗБГС')
sotired1 = pd.concat([sotired, r], 1)
#перемещаем столбцы в нужном порядке
q = sotired1.pop('ГС/ННС')
sotired2 = pd.concat([sotired1, q], 1)
#перемещаем столбцы в нужном порядке
z = sotired2.pop('Тип ГТМ')
sotired3 = pd.concat([sotired2, z], 1)
#перемещаем столбцы в нужном порядке
d = sotired3.pop('Пласт')
sotired4 = pd.concat([sotired3, d], 1)
i=sotired4['Номер скважины'].tolist()
sotired4['Скважина №']=i
sotired4=sotired4.drop(['Номер скважины'],axis=1)
sotired_final = sotired4.reindex(columns=['Скважина №', 'Длиина ГС, м', 'Число стадий ГРП','Полудлина трещины, м','Ширина трещины, мм','Проницаемость проппанта, Д','Дата ВНР после ГС \ ГРП \ЗБГС','ГС/ННС','Тип ГТМ','Пласт'])
sotired_final
# Out:
# C:\Users\USER\miniconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\USER\miniconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#
# C:\Users\USER\miniconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   if __name__ == '__main__':
# C:\Users\USER\miniconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   if sys.path[0] == '':
#     Скважина №  Длиина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0         1330           0.0                 1                   100
# 1         1330           0.0                 1                   100
# 2         1338           0.0                 1                   100
# 3         1338           0.0                 1                   100
# 4          149           0.0                 1                   100
# ..         ...           ...               ...                   ...
# 97         913           0.0                 1                   100
# 98         931           0.0                 1                   100
# 99         931           0.0                 1                   100
# 100        931           0.0                 1                   100
# 101        931           0.0                 1                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     4                         100
# 1                     4                         100
# 2                     4                         100
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 97                    4                         100
# 98                    4                         100
# 99                    4                         100
# 100                   4                         100
# 101                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ  Пласт
# 0                      2019-09-14      ННС     ВНС  Ю1(1)
# 1                      2020-01-01  ННС+ГРП     ГРП  Ю1(1)
# 2                      2020-09-08  ННС+ГРП     ГРП  Ю1(1)
# 3                      2020-09-13      ННС     ВНС  Ю1(1)
# 4                      2005-03-31  ННС+ГРП     ГРП  Ю1(1)
# ..                            ...      ...     ...    ...
# 97                     2015-04-07  ННС+ГРП     ГРП     Б7
# 98                     2001-06-05      ННС     ВНС  Ю1(1)
# 99                     2001-06-07  ННС+ГРП     ГРП  Ю1(1)
# 100                    2004-10-05  ННС+ГРП     ГРП  Ю1(1)
# 101                    2006-07-12  ННС+ГРП     ГРП  Ю1(1)
#
# [102 rows x 10 columns]

# %%
sotired_final['Число стадий ГРП'] = sotired.apply(
    lambda x: 
    0 if str(x['Тип ГТМ'])=='ВНС'
    else x['Число стадий ГРП'], axis=1)
sotired_final
# Out:
#     Скважина №  Длиина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0         1330           0.0                 0                   100
# 1         1330           0.0                 1                   100
# 2         1338           0.0                 1                   100
# 3         1338           0.0                 0                   100
# 4          149           0.0                 1                   100
# ..         ...           ...               ...                   ...
# 97         913           0.0                 1                   100
# 98         931           0.0                 0                   100
# 99         931           0.0                 1                   100
# 100        931           0.0                 1                   100
# 101        931           0.0                 1                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     4                         100
# 1                     4                         100
# 2                     4                         100
# 3                     4                         100
# 4                     4                         100
# ..                  ...                         ...
# 97                    4                         100
# 98                    4                         100
# 99                    4                         100
# 100                   4                         100
# 101                   4                         100
#
#     Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ  Пласт
# 0                      2019-09-14      ННС     ВНС  Ю1(1)
# 1                      2020-01-01  ННС+ГРП     ГРП  Ю1(1)
# 2                      2020-09-08  ННС+ГРП     ГРП  Ю1(1)
# 3                      2020-09-13      ННС     ВНС  Ю1(1)
# 4                      2005-03-31  ННС+ГРП     ГРП  Ю1(1)
# ..                            ...      ...     ...    ...
# 97                     2015-04-07  ННС+ГРП     ГРП     Б7
# 98                     2001-06-05      ННС     ВНС  Ю1(1)
# 99                     2001-06-07  ННС+ГРП     ГРП  Ю1(1)
# 100                    2004-10-05  ННС+ГРП     ГРП  Ю1(1)
# 101                    2006-07-12  ННС+ГРП     ГРП  Ю1(1)
#
# [102 rows x 10 columns]

# %%
n=1
z=sotired_final['Пласт'].value_counts()[:n].index.tolist()
plast=str(z[0])
sotired_final = sotired_final.drop(sotired_final[sotired_final['Пласт'] != plast].index).reset_index(drop=True)
zzz = sotired_final['Длиина ГС, м'].tolist()
sotired_final['Длина ГС, м'] = zzz

sotired_final = sotired_final.drop(['Длиина ГС, м'], axis=1)
sotired_final = sotired_final.reindex(
columns=['Скважина №', 'Длина ГС, м', 'Число стадий ГРП', 'Полудлина трещины, м', 'Ширина трещины, мм',
                     'Проницаемость проппанта, Д', 'Дата ВНР после ГС \ ГРП \ЗБГС', 'ГС/ННС', 'Тип ГТМ', 'Пласт'])
sotired_final
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1330          0.0                 0                   100
# 1        1330          0.0                 1                   100
# 2        1338          0.0                 1                   100
# 3        1338          0.0                 0                   100
# 4         149          0.0                 1                   100
# ..        ...          ...               ...                   ...
# 83        900          0.0                 1                   100
# 84        931          0.0                 0                   100
# 85        931          0.0                 1                   100
# 86        931          0.0                 1                   100
# 87        931          0.0                 1                   100
#
#     Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                    4                         100
# 1                    4                         100
# 2                    4                         100
# 3                    4                         100
# 4                    4                         100
# ..                 ...                         ...
# 83                   4                         100
# 84                   4                         100
# 85                   4                         100
# 86                   4                         100
# 87                   4                         100
#
#    Дата ВНР после ГС \ ГРП \ЗБГС   ГС/ННС Тип ГТМ  Пласт
# 0                     2019-09-14      ННС     ВНС  Ю1(1)
# 1                     2020-01-01  ННС+ГРП     ГРП  Ю1(1)
# 2                     2020-09-08  ННС+ГРП     ГРП  Ю1(1)
# 3                     2020-09-13      ННС     ВНС  Ю1(1)
# 4                     2005-03-31  ННС+ГРП     ГРП  Ю1(1)
# ..                           ...      ...     ...    ...
# 83                    2004-02-01  ННС+ГРП     ГРП  Ю1(1)
# 84                    2001-06-05      ННС     ВНС  Ю1(1)
# 85                    2001-06-07  ННС+ГРП     ГРП  Ю1(1)
# 86                    2004-10-05  ННС+ГРП     ГРП  Ю1(1)
# 87                    2006-07-12  ННС+ГРП     ГРП  Ю1(1)
#
# [88 rows x 10 columns]
