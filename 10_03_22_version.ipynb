# %%
import sys
import copy
import pandas as pd
import statistics
import datetime

# %%
grp_dad = pd.read_excel('one.xlsx',header=[1], index_col=[1])
print(grp_dad.head(20),grp_dad.shape)
# Out:
# C:\Users\USER\miniconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                  Unnamed: 0       Дата Подрядчик  \
# Номер скважины
# 99              Проблемы при построении ГРП 2019-10-20        КН
# 980             Проблемы при построении ГРП 2015-10-22        КН
# 980             Проблемы при построении ГРП 2015-10-21        КН
# 980             Проблемы при построении ГРП 2015-10-21        КН
# 980             Проблемы при построении ГРП 2015-10-20        КН
# 980             Проблемы при построении ГРП 2015-10-20        КН
# 980             Проблемы при построении ГРП 2015-10-11        КН
# 980             Проблемы при построении ГРП 2015-10-11        КН
# 98              Проблемы при построении ГРП 2019-07-31        КН
# 98              Проблемы при построении ГРП 2019-07-30        КН
# 98              Проблемы при построении ГРП 2019-07-30        КН
# 98              Проблемы при построении ГРП 2019-07-29        КН
# 98              Проблемы при построении ГРП 2019-07-29        КН
# 98              Проблемы при построении ГРП 2019-07-28        КН
# 98              Проблемы при построении ГРП 2019-07-28        КН
# 98              Проблемы при построении ГРП 2019-07-27        КН
# 98              Проблемы при построении ГРП 2019-07-27        КН
# 978             Проблемы при построении ГРП 2015-10-31        КН
# 977             Проблемы при построении ГРП 2015-08-29        КН
# 977             Проблемы при построении ГРП 2015-08-29        КН
#
#                                                       Комментарии Страница  \
# Номер скважины
# 99              Оборудование:  НКТ, ПРО, АМТ-  ООО "КАТКонефть...      -1_
# 980             Замещение проводилось 21.10.2015 г. По результ...      -1_
# 980             Замещение проводилось 21.10.2015 г. По результ...      -1_
# 980             По результатам замещения была проведена повтор...      -1_
# 980             Замещение проводилось 19.10.2015 г. По результ...      -1_
# 980             замещение проводилось 19.10.2015 г. По результ...      -1_
# 980             На стадии замещения при активации муфты ГРП №1...      -1_
# 980             По результату замещения принято решение о сокр...      -1_
# 98              Оборудование:  НКТ, АМТ-  ООО "КАТКонефть"  Ст...      -1_
# 98              Оборудование:  НКТ, АМТ-  ООО "КАТКонефть"  Ст...      -1_
# 98              Оборудование:  НКТ, АМТ-  ООО "КАТКонефть"  Ст...      -1_
# 98              Оборудование:  НКТ, АМТ-  ООО "КАТКонефть"  Ст...      -1_
# 98              Оборудование:  НКТ, АМТ-  ООО "КАТКонефть"  Ст...      -1_
# 98              Оборудование:  НКТ, АМТ-  ООО "КАТКонефть"  Ст...      -1_
# 98              Оборудование:  НКТ, АМТ-  ООО "КАТКонефть"  Ст...      -1_
# 98              Оборудование:  НКТ, АМТ-  ООО "КАТКонефть"  Ст...      -1_
# 98              Оборудование:  НКТ, АМТ-  ООО "КАТКонефть"  Ст...      -1_
# 978             Мини ГРП проводился 31.10.2015 г. По результат...      -1_
# 977             По результатам замещения были внесены изменени...      -1_
# 977             По результату Мини ГРП были внесены изменения ...      -1_
#
#                 Unnamed: 6 Пласт  Наклон  Азимут     k  ...  \
# Номер скважины                                          ...
# 99                     NaN    Ю3   17.00   245.0  24.6  ...
# 980                    NaN    Ю2   87.70   184.0  15.0  ...
# 980                    NaN    Ю2   90.90   184.0  15.0  ...
# 980                    NaN    Ю2   90.30   184.0  15.0  ...
# 980                    NaN    Ю2   89.90   183.0  15.0  ...
# 980                    NaN    Ю2   90.90   184.0  15.0  ...
# 980                    NaN    Ю2   90.90   184.0  15.0  ...
# 980                    NaN    Ю2   92.50   183.0  15.0  ...
# 98                     NaN    Ю2   76.83   312.0   7.7  ...
# 98                     NaN    Ю2   91.14   311.1   7.7  ...
# 98                     NaN    Ю2   93.64   310.9   7.7  ...
# 98                     NaN    Ю2   89.71   304.4   7.7  ...
# 98                     NaN    Ю2   87.69   302.4   7.7  ...
# 98                     NaN    Ю2   87.69   302.4   7.7  ...
# 98                     NaN    Ю2   88.70   300.3   7.7  ...
# 98                     NaN    Ю2   87.82    93.5   7.7  ...
# 98                     NaN    Ю2   90.14   298.9   7.7  ...
# 978                    NaN    Ю2    8.90   191.0  11.3  ...
# 977                    NaN    Ю2   88.40   160.0  23.3  ...
# 977                    NaN    Ю2   90.50   163.0  23.3  ...
#
#                                                 Проппант  Рпл Хорнер   Эфф  \
# Номер скважины
# 99                             NIKA (Ptprop)+Fores+Fores        48.0  71.0
# 980             Welltech 20/40+Welltech 16/20+Welltech 1         NaN  59.0
# 980             Welltech 20/40+Welltech 16/20+Welltech 1         NaN  80.0
# 980             Welltech 20/40+Welltech 16/20+Welltech 1         NaN  56.0
# 980             Welltech 20/40+Welltech 16/20+Welltech 1         NaN  85.0
# 980             Welltech 20/40+Welltech 16/20+Welltech 1         NaN  66.0
# 980             Welltech 20/40+Welltech 16/20+Welltech 1         NaN   NaN
# 980             Welltech 20/40+Welltech 16/20+Welltech 1         NaN  75.0
# 98                                    ForeProp+PT Prop+0        41.0  50.0
# 98                            ForeProp+PT Prop+PT Prop+0        33.0  52.0
# 98                                            ForeProp+0        32.0  37.0
# 98                                    ForeProp+PT Prop+0        32.0  43.0
# 98                                    ForeProp+PT Prop+0        35.0  48.0
# 98                                    ForeProp+PT Prop+0        32.0  51.0
# 98                                     ForeProp+PTProp+0        35.0  39.0
# 98                                   ForeProp+ForeProp+0        53.0  53.0
# 98                                   ForeProp+ForeProp+0        23.0  33.0
# 978              Bor 20/40+Welltech 16/20+Welltech 12/18         NaN  52.0
# 977              Bor 20/40+Welltech 16/20+Welltech 12/18         NaN  85.0
# 977              Bor 20/40+Welltech 16/20+Welltech 12/18         NaN  59.0
#
#                 Расход    Конц  Гель   М бр  V под   V без под  V гель
# Номер скважины
# 99                 3.2   900.0   NaN   41.1    9.0         NaN    53.0
# 980                3.6   900.0   NaN  190.0   75.0  272.700000     NaN
# 980                3.6   900.0   NaN  182.0   65.0  260.400000     NaN
# 980                3.6   900.0   NaN  192.0   70.0  331.200000     NaN
# 980                3.6   900.0   NaN  183.0   65.0  262.000000     NaN
# 980                3.6   900.0   NaN  180.0   65.0  252.800000     NaN
# 980                NaN   800.0   NaN   15.0    NaN   30.042131     NaN
# 980                3.6   800.0   NaN  145.0   40.0  215.751469     NaN
# 98                 3.4   800.0   NaN  140.4    NaN   45.000000   151.0
# 98                 3.4   800.0   NaN  143.1    NaN   45.000000   151.0
# 98                 3.4   800.0   NaN  152.8    NaN   45.000000   151.0
# 98                 3.4   800.0   NaN  149.5    NaN   45.000000   151.0
# 98                 3.4   800.0   NaN  149.8    NaN   45.000000   151.0
# 98                 3.4   800.0   NaN  149.5    NaN   45.000000   151.0
# 98                 3.4   800.0   NaN  226.7    NaN   45.000000   120.0
# 98                 3.4   800.0   NaN  163.6    NaN   42.000000   144.0
# 98                 3.4   800.0   NaN  161.1    NaN   45.000000   151.0
# 978                3.4  1200.0   NaN  121.5   50.0  188.699945     NaN
# 977                3.6  1000.0   NaN  208.0   95.0  334.404409     NaN
# 977                3.4   900.0   NaN  165.0   63.0  267.207626     NaN
#
# [20 rows x 35 columns] (2944, 35)

# %%
grp_gtm = pd.read_excel('two.xlsx',header=[1], index_col=[1])
print(grp_gtm.head(10),grp_gtm.shape)
# Out:
# C:\Users\USER\miniconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                    Unnamed: 0 Скважина Куст  \
# Месторождение
# Тайлаковское       Добывающая        1  NaN
# Тайлаковское       Добывающая        1  NaN
# Тайлаковское   Нагнетательная        1  NaN
# Тайлаковское       Добывающая        1  NaN
# Тайлаковское       Добывающая        1  NaN
# Тайлаковское       Добывающая        1  NaN
# Тайлаковское       Добывающая        1  NaN
# Тайлаковское       Добывающая        1  NaN
# Тайлаковское       Добывающая        1  NaN
# Тайлаковское       Добывающая        1  NaN
#
#                                                          Тип  \
# Месторождение
# Тайлаковское                                 ВНС из др. фонд
# Тайлаковское                                             ГРП
# Тайлаковское                                   Перевод в ППД
# Тайлаковское   Выравнивание профиля притока или приёмистости
# Тайлаковское                                 Проведение ГДИС
# Тайлаковское   Выравнивание профиля притока или приёмистости
# Тайлаковское                              Запуск без ремонта
# Тайлаковское                              Запуск без ремонта
# Тайлаковское                              Запуск без ремонта
# Тайлаковское                          Промывка гибкой трубой
#
#               Объект разработки до ГТМ  Объект разработки после ГТМ Страница  \
# Месторождение
# Тайлаковское                        Ю3                          NaN      -1_
# Тайлаковское                        Ю3                          NaN      -1_
# Тайлаковское                        Ю3                          NaN      -1_
# Тайлаковское                        Ю3                          NaN      -1_
# Тайлаковское                        Ю3                          NaN      -1_
# Тайлаковское                        Ю3                          NaN      -1_
# Тайлаковское                        Ю3                          NaN      -1_
# Тайлаковское                        Ю3                          NaN      -1_
# Тайлаковское                        Ю3                          NaN      -1_
# Тайлаковское                        Ю3                          NaN      -1_
#
#                Dэк                       Краткое описание мероприятий  \
# Месторождение
# Тайлаковское   NaN                 КР9-5 Перевод скважин в добывающие
# Тайлаковское   NaN                               КР7-2 Проведение ГРП
# Тайлаковское   NaN  КР9-6 Перевод под нагнетание из других категор...
# Тайлаковское   NaN                                     Проведение ВПП
# Тайлаковское   NaN                     Гидродинамические исследования
# Тайлаковское   NaN                                     Проведение ВПП
# Тайлаковское   NaN                        Запуск в работу без ремонта
# Тайлаковское   NaN                        Запуск в работу без ремонта
# Тайлаковское   NaN                        Запуск в работу без ремонта
# Тайлаковское   NaN                             Промывка гибкой трубой
#
#                Unnamed: 10  ...  Напор.1  Производительность.1  Комментарий  \
# Месторождение               ...
# Тайлаковское           NaN  ...      NaN                   NaN          NaN
# Тайлаковское           NaN  ...      NaN                   NaN          NaN
# Тайлаковское           NaN  ...      NaN                   NaN          NaN
# Тайлаковское           NaN  ...      NaN                   NaN          NaN
# Тайлаковское           NaN  ...      NaN                   NaN          NaN
# Тайлаковское           NaN  ...      NaN                   NaN          NaN
# Тайлаковское           NaN  ...      NaN                   NaN          NaN
# Тайлаковское           NaN  ...      NaN                   NaN          NaN
# Тайлаковское           NaN  ...      NaN                   NaN          NaN
# Тайлаковское           NaN  ...      NaN                   NaN          NaN
#
#                План  Факт  Пл-ть нефти  Коб  В-ть жидк.  P нас  Unnamed: 65
# Месторождение
# Тайлаковское    NaN   NaN          NaN  NaN         NaN    NaN          NaN
# Тайлаковское    NaN   NaN          NaN  NaN         NaN    NaN          NaN
# Тайлаковское    NaN   NaN          NaN  NaN         NaN    NaN          NaN
# Тайлаковское    NaN   NaN          NaN  NaN         NaN    NaN          NaN
# Тайлаковское    NaN   NaN          NaN  NaN         NaN    NaN          NaN
# Тайлаковское    NaN   NaN          NaN  NaN         NaN    NaN          NaN
# Тайлаковское    NaN   NaN          NaN  NaN         NaN    NaN          NaN
# Тайлаковское    NaN   NaN          NaN  NaN         NaN    NaN          NaN
# Тайлаковское    NaN   NaN          NaN  NaN         NaN    NaN          NaN
# Тайлаковское    NaN   NaN          NaN  NaN         NaN    NaN          NaN
#
# [10 rows x 65 columns] (17163, 65)

# %%
coordinates = pd.read_excel('three.xlsx')
print(coordinates.head(10),coordinates.shape)
# Out:
#   № скважины  Координата X  Координата Y  Координата забоя Х (по траектории)  \
# 0          1        430902       6562954                              430903
# 1         10        437823       6547130                              437826
# 2        100        434596       6559294                              434070
# 3       1000        435618       6555935                              435597
# 4       1004        455990       6565368                              456033
# 5       1005        455105       6565028                              455102
# 6       1006        456303       6565179                              456326
# 7       1007        455815       6565717                              455823
# 8      100ПЛ        434353       6559493                              434352
# 9        101        434378       6559105                              433680
#
#    Координата забоя Y (по траектории)
# 0                             6562958
# 1                             6547128
# 2                             6559895
# 3                             6555955
# 4                             6565408
# 5                             6565045
# 6                             6565200
# 7                             6565751
# 8                             6559493
# 9                             6559690   (1560, 5)

# %%
grp_dad.reset_index(drop=True)
grp_dad.reset_index(inplace=True)

# %%
#вставка 22.02.22
grp_dad['Номер скважины'] = grp_dad.apply(
            lambda x:
            str(x['Номер скважины']), axis=1)
grp_gtm['Скважина'] = grp_gtm.apply(
            lambda x:
            str(x['Скважина']), axis=1)

        #вставка 22.02.22

# %%
plasttt = 'Ю3'
grp_dad['удалю'] = grp_dad.apply(
            lambda x:
            'нет' if plasttt in str(x['Пласт'])
            else 'да', axis=1)
grp_dad = grp_dad.drop(grp_dad[grp_dad['удалю'] == 'да'].index).reset_index(drop=True)
grp_dad = grp_dad.drop(['удалю'], axis=1)
grp_gtm.reset_index(drop=True)
grp_gtm.reset_index(inplace=True)
grp_gtm = grp_gtm[grp_gtm['Объект разработки до ГТМ'].notna()]
grp_dad.head(10)
# Out:
#   Номер скважины                   Unnamed: 0       Дата Подрядчик  \
# 0             99  Проблемы при построении ГРП 2019-10-20        КН
# 1             96  Проблемы при построении ГРП 2019-06-20       SLB
# 2            949  Проблемы при построении ГРП 2021-09-15        КН
# 3            949  Проблемы при построении ГРП 2021-09-15        КН
# 4            949  Проблемы при построении ГРП 2021-09-15        КН
# 5            949  Проблемы при построении ГРП 2021-09-15        КН
# 6            949  Проблемы при построении ГРП 2021-09-14        КН
# 7            924  Проблемы при построении ГРП 2012-09-09       МКН
# 8            923                          NaN 2011-01-12       ШЛБ
# 9            911  Проблемы при построении ГРП 2015-03-11        КН
#
#                                          Комментарии Страница  Unnamed: 6  \
# 0  Оборудование:  НКТ, ПРО, АМТ-  ООО "КАТКонефть...      -1_         NaN
# 1  По согласованию с представителями Заказчика пр...      -1_         NaN
# 2  Оборудование:  НКТ, АМТ- ООО "КАТКонефть"  Сти...      -1_         NaN
# 3  Оборудование:  НКТ, АМТ- ООО "КАТКонефть"  Сти...      -1_         NaN
# 4  Оборудование:  НКТ, АМТ- ООО "КАТКонефть"  Сти...      -1_         NaN
# 5  Оборудование:  НКТ, АМТ- ООО "КАТКонефть"  Сти...      -1_         NaN
# 6  Оборудование:  НКТ, АМТ- ООО "КАТКонефть"  Сти...      -1_         NaN
# 7  По  миниГРП:   увеличили стадию "подушка" до 5...      -1_         NaN
# 8                                                NaN      -1_         NaN
# 9  Мини ГРП проводился 12.03.2015 г. По результат...      -1_         NaN
#
#   Пласт  Наклон  Азимут  ...                                  Проппант  \
# 0    Ю3    17.0   245.0  ...                 NIKA (Ptprop)+Fores+Fores
# 1    Ю3     7.0   152.0  ...                НИК20/40+НИК16/20+НИК12/18
# 2    Ю3    93.7   305.1  ...                       Fores+Nika+Nika+0+0
# 3    Ю3    93.7   305.1  ...                       Fores+Nika+Nika+0+0
# 4    Ю3    93.7   305.1  ...                       Fores+Nika+Nika+0+0
# 5    Ю3    93.7   305.1  ...                          Fores+Nika+0+0+0
# 6    Ю3    93.7   305.1  ...                       Nika+Fores+Nika+0+0
# 7    Ю3    15.1     9.0  ...                         16/20+12/18+12/18
# 8    Ю3    20.0     NaN  ...      16/20Fore \n12/18Fore \n12/18ForeRCP
# 9    Ю3    89.4     1.0  ...  Bor 20/40+Welltech-Bor 16/20+Welltech-Bo
#
#    Рпл Хорнер   Эфф  Расход    Конц  Гель       М бр  V под  V без под  V гель
# 0        48.0  71.0     3.2   900.0   NaN   41.10000    9.0        NaN    53.0
# 1        45.0  63.0     3.6   800.0   NaN  241.37000   32.0        NaN   165.0
# 2        60.0  37.0     3.6  1000.0   NaN   45.95220    NaN        NaN    71.5
# 3        62.0  31.5     3.6  1000.0   NaN   40.47128    NaN        NaN    54.8
# 4        58.0  36.0     3.6  1000.0   NaN   41.01312    NaN        NaN    53.8
# 5        42.5  48.7     3.4  1000.0   NaN   39.30424    NaN        NaN    50.8
# 6        44.5  56.6     3.4   800.0   NaN   70.37668    NaN        NaN    59.6
# 7       256.0  45.0     3.5  1200.0   NaN        NaN   52.0      210.9     NaN
# 8       228.0  38.2     2.6  1024.0   NaN        NaN   60.0      216.3     NaN
# 9         NaN  28.0     3.8   900.0   NaN  232.00000  100.0      392.4     NaN
#
# [10 rows x 36 columns]

# %%
grp_gtm = grp_gtm.drop(grp_gtm[grp_gtm['Объект разработки до ГТМ'] != plasttt].index).reset_index(drop=True)
grp_gtm.head(10)
# Out:
#   Месторождение      Unnamed: 0 Скважина Куст  \
# 0  Тайлаковское      Добывающая        1  NaN
# 1  Тайлаковское      Добывающая        1  NaN
# 2  Тайлаковское  Нагнетательная        1  NaN
# 3  Тайлаковское      Добывающая        1  NaN
# 4  Тайлаковское      Добывающая        1  NaN
# 5  Тайлаковское      Добывающая        1  NaN
# 6  Тайлаковское      Добывающая        1  NaN
# 7  Тайлаковское      Добывающая        1  NaN
# 8  Тайлаковское      Добывающая        1  NaN
# 9  Тайлаковское      Добывающая        1  NaN
#
#                                              Тип Объект разработки до ГТМ  \
# 0                                ВНС из др. фонд                       Ю3
# 1                                            ГРП                       Ю3
# 2                                  Перевод в ППД                       Ю3
# 3  Выравнивание профиля притока или приёмистости                       Ю3
# 4                                Проведение ГДИС                       Ю3
# 5  Выравнивание профиля притока или приёмистости                       Ю3
# 6                             Запуск без ремонта                       Ю3
# 7                             Запуск без ремонта                       Ю3
# 8                             Запуск без ремонта                       Ю3
# 9                         Промывка гибкой трубой                       Ю3
#
#    Объект разработки после ГТМ Страница  Dэк  \
# 0                          NaN      -1_  NaN
# 1                          NaN      -1_  NaN
# 2                          NaN      -1_  NaN
# 3                          NaN      -1_  NaN
# 4                          NaN      -1_  NaN
# 5                          NaN      -1_  NaN
# 6                          NaN      -1_  NaN
# 7                          NaN      -1_  NaN
# 8                          NaN      -1_  NaN
# 9                          NaN      -1_  NaN
#
#                         Краткое описание мероприятий  ...  Напор.1  \
# 0                 КР9-5 Перевод скважин в добывающие  ...      NaN
# 1                               КР7-2 Проведение ГРП  ...      NaN
# 2  КР9-6 Перевод под нагнетание из других категор...  ...      NaN
# 3                                     Проведение ВПП  ...      NaN
# 4                     Гидродинамические исследования  ...      NaN
# 5                                     Проведение ВПП  ...      NaN
# 6                        Запуск в работу без ремонта  ...      NaN
# 7                        Запуск в работу без ремонта  ...      NaN
# 8                        Запуск в работу без ремонта  ...      NaN
# 9                             Промывка гибкой трубой  ...      NaN
#
#    Производительность.1  Комментарий  План  Факт  Пл-ть нефти  Коб  \
# 0                   NaN          NaN   NaN   NaN          NaN  NaN
# 1                   NaN          NaN   NaN   NaN          NaN  NaN
# 2                   NaN          NaN   NaN   NaN          NaN  NaN
# 3                   NaN          NaN   NaN   NaN          NaN  NaN
# 4                   NaN          NaN   NaN   NaN          NaN  NaN
# 5                   NaN          NaN   NaN   NaN          NaN  NaN
# 6                   NaN          NaN   NaN   NaN          NaN  NaN
# 7                   NaN          NaN   NaN   NaN          NaN  NaN
# 8                   NaN          NaN   NaN   NaN          NaN  NaN
# 9                   NaN          NaN   NaN   NaN          NaN  NaN
#
#    В-ть жидк.  P нас  Unnamed: 65
# 0         NaN    NaN          NaN
# 1         NaN    NaN          NaN
# 2         NaN    NaN          NaN
# 3         NaN    NaN          NaN
# 4         NaN    NaN          NaN
# 5         NaN    NaN          NaN
# 6         NaN    NaN          NaN
# 7         NaN    NaN          NaN
# 8         NaN    NaN          NaN
# 9         NaN    NaN          NaN
#
# [10 rows x 66 columns]

# %%
coordinates['Length'] = coordinates.apply(
            lambda x: ((x['Координата забоя Х (по траектории)'] - x['Координата X']) ** (2) +
                       (x['Координата забоя Y (по траектории)'] - x['Координата Y']) ** (2)) ** (0.5)
            , axis=1)
coordinates['№ скважины'] = coordinates.apply(
            lambda x:
            str(x['№ скважины']), axis=1)
grp = copy.deepcopy(grp_dad)
coordinates.head(10)
# Out:
#   № скважины  Координата X  Координата Y  Координата забоя Х (по траектории)  \
# 0          1        430902       6562954                              430903
# 1         10        437823       6547130                              437826
# 2        100        434596       6559294                              434070
# 3       1000        435618       6555935                              435597
# 4       1004        455990       6565368                              456033
# 5       1005        455105       6565028                              455102
# 6       1006        456303       6565179                              456326
# 7       1007        455815       6565717                              455823
# 8      100ПЛ        434353       6559493                              434352
# 9        101        434378       6559105                              433680
#
#    Координата забоя Y (по траектории)      Length
# 0                             6562958    4.123106
# 1                             6547128    3.605551
# 2                             6559895  798.672023
# 3                             6555955   29.000000
# 4                             6565408   58.728187
# 5                             6565045   17.262677
# 6                             6565200   31.144823
# 7                             6565751   34.928498
# 8                             6559493    1.000000
# 9                             6559690  910.729927

# %%
grp_now_we_go = copy.deepcopy(grp_gtm)
grp_now_we_go['Скважина'] = grp_now_we_go.apply(
            lambda x:
            str(x['Скважина']), axis=1)
grp_now_we_go.head(10)
# Out:
#   Месторождение      Unnamed: 0 Скважина Куст  \
# 0  Тайлаковское      Добывающая        1  NaN
# 1  Тайлаковское      Добывающая        1  NaN
# 2  Тайлаковское  Нагнетательная        1  NaN
# 3  Тайлаковское      Добывающая        1  NaN
# 4  Тайлаковское      Добывающая        1  NaN
# 5  Тайлаковское      Добывающая        1  NaN
# 6  Тайлаковское      Добывающая        1  NaN
# 7  Тайлаковское      Добывающая        1  NaN
# 8  Тайлаковское      Добывающая        1  NaN
# 9  Тайлаковское      Добывающая        1  NaN
#
#                                              Тип Объект разработки до ГТМ  \
# 0                                ВНС из др. фонд                       Ю3
# 1                                            ГРП                       Ю3
# 2                                  Перевод в ППД                       Ю3
# 3  Выравнивание профиля притока или приёмистости                       Ю3
# 4                                Проведение ГДИС                       Ю3
# 5  Выравнивание профиля притока или приёмистости                       Ю3
# 6                             Запуск без ремонта                       Ю3
# 7                             Запуск без ремонта                       Ю3
# 8                             Запуск без ремонта                       Ю3
# 9                         Промывка гибкой трубой                       Ю3
#
#    Объект разработки после ГТМ Страница  Dэк  \
# 0                          NaN      -1_  NaN
# 1                          NaN      -1_  NaN
# 2                          NaN      -1_  NaN
# 3                          NaN      -1_  NaN
# 4                          NaN      -1_  NaN
# 5                          NaN      -1_  NaN
# 6                          NaN      -1_  NaN
# 7                          NaN      -1_  NaN
# 8                          NaN      -1_  NaN
# 9                          NaN      -1_  NaN
#
#                         Краткое описание мероприятий  ...  Напор.1  \
# 0                 КР9-5 Перевод скважин в добывающие  ...      NaN
# 1                               КР7-2 Проведение ГРП  ...      NaN
# 2  КР9-6 Перевод под нагнетание из других категор...  ...      NaN
# 3                                     Проведение ВПП  ...      NaN
# 4                     Гидродинамические исследования  ...      NaN
# 5                                     Проведение ВПП  ...      NaN
# 6                        Запуск в работу без ремонта  ...      NaN
# 7                        Запуск в работу без ремонта  ...      NaN
# 8                        Запуск в работу без ремонта  ...      NaN
# 9                             Промывка гибкой трубой  ...      NaN
#
#    Производительность.1  Комментарий  План  Факт  Пл-ть нефти  Коб  \
# 0                   NaN          NaN   NaN   NaN          NaN  NaN
# 1                   NaN          NaN   NaN   NaN          NaN  NaN
# 2                   NaN          NaN   NaN   NaN          NaN  NaN
# 3                   NaN          NaN   NaN   NaN          NaN  NaN
# 4                   NaN          NaN   NaN   NaN          NaN  NaN
# 5                   NaN          NaN   NaN   NaN          NaN  NaN
# 6                   NaN          NaN   NaN   NaN          NaN  NaN
# 7                   NaN          NaN   NaN   NaN          NaN  NaN
# 8                   NaN          NaN   NaN   NaN          NaN  NaN
# 9                   NaN          NaN   NaN   NaN          NaN  NaN
#
#    В-ть жидк.  P нас  Unnamed: 65
# 0         NaN    NaN          NaN
# 1         NaN    NaN          NaN
# 2         NaN    NaN          NaN
# 3         NaN    NaN          NaN
# 4         NaN    NaN          NaN
# 5         NaN    NaN          NaN
# 6         NaN    NaN          NaN
# 7         NaN    NaN          NaN
# 8         NaN    NaN          NaN
# 9         NaN    NaN          NaN
#
# [10 rows x 66 columns]

# %%
grp['Номер скважины'] = grp.apply(
            lambda x:
            str(x['Номер скважины']), axis=1)
        # координаты скважин для нашего объекта
my_wells = grp['Номер скважины'].tolist()
my_wells_no_repeat = []
for x in my_wells:
    if x not in my_wells_no_repeat:
        my_wells_no_repeat.append(x)
my_wells_no_repeat
# Out:
# ['99',
#  '96',
#  '949',
#  '924',
#  '923',
#  '911',
#  '909',
#  '906Л',
#  '905',
#  '9',
#  '898',
#  '897',
#  '890',
#  '883',
#  '882',
#  '881',
#  '880',
#  '878',
#  '876',
#  '874',
#  '870',
#  '87',
#  '85Л1',
#  '84',
#  '820',
#  '806',
#  '80',
#  '8',
#  '773',
#  '771',
#  '770Л',
#  '770',
#  '77',
#  '768',
#  '767',
#  '766',
#  '764',
#  '763Л',
#  '763',
#  '762',
#  '761',
#  '760',
#  '76',
#  '757',
#  '755',
#  '74',
#  '739',
#  '738Л2',
#  '738',
#  '737',
#  '732',
#  '731',
#  '729',
#  '728',
#  '727',
#  '726',
#  '725',
#  '724',
#  '723',
#  '722',
#  '721',
#  '720',
#  '72',
#  '714',
#  '713',
#  '711',
#  '71',
#  '708',
#  '70',
#  '7',
#  '68Л',
#  '686',
#  '681',
#  '680',
#  '68',
#  '679',
#  '678',
#  '675',
#  '673',
#  '665',
#  '663',
#  '662',
#  '66',
#  '655',
#  '650',
#  '649',
#  '648',
#  '647',
#  '640',
#  '637',
#  '636',
#  '635',
#  '63',
#  '629',
#  '628',
#  '627',
#  '626',
#  '622',
#  '621',
#  '620',
#  '619Л2',
#  '619',
#  '617',
#  '616',
#  '613',
#  '612',
#  '61',
#  '606',
#  '604',
#  '603',
#  '602',
#  '601',
#  '60',
#  '6',
#  '5Л',
#  '591',
#  '585',
#  '584',
#  '582Л2',
#  '582',
#  '581',
#  '577',
#  '574',
#  '573',
#  '572',
#  '571',
#  '570',
#  '57',
#  '569',
#  '567Л',
#  '5676',
#  '567',
#  '56',
#  '550',
#  '549',
#  '542',
#  '541',
#  '539',
#  '537',
#  '534',
#  '53',
#  '529',
#  '527Л',
#  '526',
#  '515',
#  '509',
#  '507',
#  '505',
#  '503',
#  '500',
#  '498',
#  '497',
#  '496',
#  '494',
#  '492',
#  '491',
#  '489Л2',
#  '489',
#  '488',
#  '487',
#  '486',
#  '485',
#  '484',
#  '483',
#  '480',
#  '48',
#  '479',
#  '478',
#  '472',
#  '471',
#  '470',
#  '469',
#  '465',
#  '464',
#  '4630',
#  '4627',
#  '4625',
#  '459',
#  '458',
#  '457',
#  '455',
#  '454',
#  '451',
#  '449',
#  '441',
#  '437',
#  '436',
#  '434',
#  '433Л',
#  '433',
#  '431',
#  '4306',
#  '4305',
#  '4302',
#  '4301',
#  '429',
#  '428',
#  '425',
#  '424',
#  '421',
#  '415Л',
#  '415',
#  '412',
#  '410',
#  '40',
#  '4',
#  '39',
#  '385',
#  '383',
#  '3825',
#  '3821',
#  '3781',
#  '3780',
#  '3742',
#  '3702',
#  '3701',
#  '37',
#  '3635',
#  '3630',
#  '36',
#  '3552',
#  '35',
#  '33ПЛ',
#  '31',
#  '306',
#  '300ПЛ',
#  '30',
#  '3',
#  '2818Л',
#  '28',
#  '276',
#  '27',
#  '2640',
#  '26',
#  '258',
#  '25',
#  '24',
#  '23Л',
#  '2310',
#  '2306',
#  '2305',
#  '2304',
#  '2303',
#  '2302',
#  '2301',
#  '2300',
#  '23',
#  '22',
#  '21',
#  '207',
#  '202',
#  '20',
#  '1980',
#  '1977',
#  '1972',
#  '197',
#  '195',
#  '194',
#  '1910',
#  '1909',
#  '1908',
#  '1906',
#  '1903',
#  '1902',
#  '1901Л',
#  '1901',
#  '1900',
#  '186',
#  '18',
#  '17Л',
#  '1758',
#  '1756',
#  '173РЛ',
#  '17',
#  '1641',
#  '1640',
#  '1639',
#  '1638',
#  '1637Л',
#  '1637',
#  '1636',
#  '1635Л',
#  '1635',
#  '1634',
#  '1633',
#  '1632',
#  '1628',
#  '1626',
#  '1625',
#  '1623',
#  '1622Л',
#  '1622',
#  '1621',
#  '1620',
#  '162',
#  '1610',
#  '1608',
#  '1607',
#  '1606',
#  '1605',
#  '1603Л',
#  '1602',
#  '16',
#  '158',
#  '1562',
#  '1561',
#  '1560',
#  '1559',
#  '1557',
#  '1556',
#  '1551',
#  '1549Л',
#  '1549',
#  '154',
#  '153',
#  '1523',
#  '151Л',
#  '1513',
#  '1511',
#  '151',
#  '1507',
#  '1503',
#  '1502',
#  '1501',
#  '1500',
#  '150',
#  '15',
#  '149',
#  '148',
#  '1468',
#  '146',
#  '144',
#  '1433',
#  '143',
#  '142Л',
#  '142',
#  '141',
#  '140',
#  '14',
#  '139',
#  '1385',
#  '1383',
#  '1367',
#  '1366',
#  '1349',
#  '1345',
#  '1344',
#  '1341',
#  '133',
#  '1320',
#  '1311',
#  '131',
#  '1304',
#  '1300',
#  '130',
#  '13',
#  '128',
#  '1259',
#  '123Л',
#  '123',
#  '1223',
#  '1220',
#  '12',
#  '119',
#  '1160',
#  '1129',
#  '1128',
#  '1126',
#  '1124',
#  '1123',
#  '1122',
#  '1114',
#  '1113',
#  '1112',
#  '1111',
#  '11',
#  '1082',
#  '1006',
#  '1004',
#  '10',
#  '1']

# %%
my_wells_gtm = grp_now_we_go['Скважина'].tolist()
my_wells_no_repeat_gtm = []
for x in my_wells_gtm:
    if x not in my_wells_no_repeat_gtm:
        my_wells_no_repeat_gtm.append(x)

my_wells_no_repeat_gtm
# Out:
# ['1',
#  '10',
#  '1004',
#  '1005',
#  '1006',
#  '1007',
#  '1018',
#  '105',
#  '1081',
#  '1082',
#  '1092',
#  '11',
#  '110',
#  '1111',
#  '1112',
#  '1113',
#  '1114',
#  '1122',
#  '1123',
#  '1124',
#  '1125',
#  '1126',
#  '1128',
#  '1129',
#  '1176',
#  '119',
#  '12',
#  '122',
#  '1220',
#  '1221',
#  '1223',
#  '1224',
#  '123',
#  '1230',
#  '1232',
#  '124',
#  '1259',
#  '126',
#  '1260',
#  '1270',
#  '1272',
#  '1279',
#  '128',
#  '1289',
#  '1290',
#  '1291',
#  '13',
#  '130',
#  '1300',
#  '1302',
#  '1303',
#  '1304',
#  '131',
#  '1311',
#  '1312',
#  '1320',
#  '133',
#  '1334',
#  '1341',
#  '1344',
#  '1345',
#  '1349',
#  '1366',
#  '1367',
#  '137',
#  '1381',
#  '1383',
#  '1384',
#  '1385',
#  '1386',
#  '139',
#  '14',
#  '140',
#  '141',
#  '142',
#  '143',
#  '1433',
#  '144',
#  '145',
#  '146',
#  '1468',
#  '147',
#  '148',
#  '149',
#  '15',
#  '150',
#  '1500',
#  '1501',
#  '1502',
#  '1503',
#  '1504',
#  '1505',
#  '1506',
#  '1507',
#  '1508',
#  '151',
#  '1511',
#  '1513',
#  '1521',
#  '1522',
#  '1523',
#  '153',
#  '154',
#  '1544',
#  '1549',
#  '155',
#  '1550',
#  '1551',
#  '1555',
#  '1556',
#  '1556Л',
#  '1557',
#  '1559',
#  '1560',
#  '1561',
#  '1562',
#  '1576',
#  '158',
#  '1595',
#  '16',
#  '1602',
#  '1603',
#  '1605',
#  '1606',
#  '1607',
#  '1608',
#  '1609',
#  '1610',
#  '1611',
#  '162',
#  '1620',
#  '1621',
#  '1622',
#  '1623',
#  '1625',
#  '1626',
#  '1628',
#  '1630',
#  '1631',
#  '1632',
#  '1633',
#  '1634',
#  '1635',
#  '1636',
#  '1637',
#  '1638',
#  '1639',
#  '1640',
#  '1641',
#  '17',
#  '173Р',
#  '1756',
#  '1758',
#  '18',
#  '181',
#  '183',
#  '186',
#  '19',
#  '190',
#  '1900',
#  '1901',
#  '1902',
#  '1903',
#  '1906',
#  '1908',
#  '1909',
#  '1910',
#  '194',
#  '195',
#  '196',
#  '197',
#  '1970',
#  '1972',
#  '1973',
#  '1974',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '198',
#  '1980',
#  '199',
#  '20',
#  '201',
#  '202',
#  '204',
#  '2056',
#  '206',
#  '207',
#  '209',
#  '21',
#  '211Р',
#  '215Р',
#  '22',
#  '23',
#  '2300',
#  '2301',
#  '2302',
#  '2303',
#  '2304',
#  '2305',
#  '2306',
#  '2309',
#  '2310',
#  '24',
#  '25',
#  '256Р',
#  '258',
#  '26',
#  '2600',
#  '2640',
#  '2686',
#  '2688',
#  '27',
#  '276',
#  '28',
#  '2818',
#  '29',
#  '2969',
#  '3',
#  '30',
#  '300',
#  '304',
#  '306',
#  '3093',
#  '31',
#  '32',
#  '33',
#  '34',
#  '35',
#  '3551',
#  '3552',
#  '36',
#  '3630',
#  '3632',
#  '3633',
#  '3635',
#  '37',
#  '3700',
#  '3701',
#  '3702',
#  '3703',
#  '3742',
#  '3780',
#  '3781',
#  '38',
#  '3817',
#  '382',
#  '3820',
#  '3821',
#  '3822',
#  '3825',
#  '3827',
#  '3828',
#  '3829',
#  '383',
#  '385',
#  '3864',
#  '39',
#  '395',
#  '4',
#  '40',
#  '405',
#  '406',
#  '410',
#  '4100',
#  '4101',
#  '412',
#  '413',
#  '415',
#  '417',
#  '419',
#  '42',
#  '420',
#  '421',
#  '4221',
#  '423',
#  '424',
#  '425',
#  '426',
#  '427',
#  '428',
#  '429',
#  '430',
#  '4300',
#  '4301',
#  '4302',
#  '4305',
#  '4306',
#  '431',
#  '432',
#  '433',
#  '434',
#  '435',
#  '436',
#  '437',
#  '438',
#  '439',
#  '440',
#  '441',
#  '444',
#  '445',
#  '446',
#  '447',
#  '449',
#  '45',
#  '450',
#  '451',
#  '453',
#  '454',
#  '455',
#  '456',
#  '457',
#  '458',
#  '459',
#  '460',
#  '462',
#  '4625',
#  '4627',
#  '463',
#  '4630',
#  '464',
#  '465',
#  '466',
#  '467',
#  '468',
#  '469',
#  '47',
#  '470',
#  '471',
#  '472',
#  '473',
#  '474',
#  '475',
#  '476',
#  '477',
#  '478',
#  '479',
#  '48',
#  '480',
#  '481',
#  '482',
#  '483',
#  '484',
#  '485',
#  '486',
#  '487',
#  '488',
#  '489',
#  '490',
#  '491',
#  '492',
#  '493',
#  '494',
#  '495',
#  '496',
#  '497',
#  '498',
#  '499',
#  '5',
#  '500',
#  '501',
#  '502',
#  '503',
#  '504',
#  '505',
#  '506',
#  '507',
#  '509',
#  '515',
#  '526',
#  '527Л',
#  '529',
#  '53',
#  '534',
#  '537',
#  '539',
#  '540',
#  '541',
#  '542',
#  '544',
#  '549',
#  '55',
#  '550',
#  '552',
#  '554',
#  '557',
#  '56',
#  '563',
#  '567',
#  '5676',
#  '569',
#  '57',
#  '570',
#  '571',
#  '572',
#  '573',
#  '574',
#  '575',
#  '577',
#  '578',
#  '579',
#  '580',
#  '581',
#  '582',
#  '583',
#  '584',
#  '585',
#  '588',
#  '591',
#  '596',
#  '598',
#  '599',
#  '6',
#  '60',
#  '601',
#  '602',
#  '603',
#  '604',
#  '606',
#  '608',
#  '609',
#  '61',
#  '610',
#  '611',
#  '612',
#  '613',
#  '614',
#  '615',
#  '616',
#  '617',
#  '618',
#  '619',
#  '62',
#  '620',
#  '621',
#  '622',
#  '626',
#  '627',
#  '628',
#  '629',
#  '63',
#  '632',
#  '635',
#  '636',
#  '637',
#  '638',
#  '640',
#  '641',
#  '644',
#  '647',
#  '648',
#  '649',
#  '65',
#  '650',
#  '651',
#  '655',
#  '656',
#  '66',
#  '662',
#  '663',
#  '665',
#  '667',
#  '673',
#  '675',
#  '678',
#  '679',
#  '68',
#  '680',
#  '681',
#  '682',
#  '683',
#  '686',
#  '69',
#  '7',
#  '70',
#  '705',
#  '707',
#  '708',
#  '71',
#  '710',
#  '711',
#  '712',
#  '713',
#  '714',
#  '715',
#  '72',
#  '720',
#  '721',
#  '722',
#  '723',
#  '724',
#  '725',
#  '726',
#  '727',
#  '728',
#  '729',
#  '73',
#  '730',
#  '731',
#  '732',
#  '733',
#  '734',
#  '735',
#  '737',
#  '738',
#  '739',
#  '74',
#  '741',
#  '743',
#  '748',
#  '752',
#  '754',
#  '755',
#  '756',
#  '757',
#  '758',
#  '76',
#  '760',
#  '761',
#  '762',
#  '763',
#  '764',
#  '766',
#  '767',
#  '768',
#  '769',
#  '77',
#  '770',
#  '771',
#  '773',
#  '781',
#  '79',
#  '8',
#  '80',
#  '806',
#  '820',
#  '83',
#  '84',
#  '85',
#  '86',
#  '87',
#  '870',
#  '874',
#  '876',
#  '878',
#  '880',
#  '881',
#  '882',
#  '883',
#  '890',
#  '896',
#  '897',
#  '898',
#  '9',
#  '901',
#  '904',
#  '905',
#  '906',
#  '907',
#  '908',
#  '909',
#  '910',
#  '911',
#  '916',
#  '918',
#  '919',
#  '922',
#  '923',
#  '924',
#  '926',
#  '927',
#  '936',
#  '942',
#  '949',
#  '96',
#  '971',
#  '99']

# %%
my_wells_only_frak = []
for i in my_wells_no_repeat:
    if i not in my_wells_no_repeat_gtm:
            my_wells_only_frak.append(i)
my_wells_only_frak
# Out:
# ['906Л',
#  '85Л1',
#  '770Л',
#  '763Л',
#  '738Л2',
#  '68Л',
#  '619Л2',
#  '5Л',
#  '582Л2',
#  '567Л',
#  '489Л2',
#  '433Л',
#  '415Л',
#  '33ПЛ',
#  '300ПЛ',
#  '2818Л',
#  '23Л',
#  '1901Л',
#  '17Л',
#  '173РЛ',
#  '1637Л',
#  '1635Л',
#  '1622Л',
#  '1603Л',
#  '1549Л',
#  '151Л',
#  '142Л',
#  '123Л',
#  '1160']

# %%
wells_GTM = pd.DataFrame({"Номер скважины": my_wells_no_repeat_gtm
                                  })
coordinates_f = coordinates[
            coordinates['№ скважины'].isin(my_wells_no_repeat_gtm)].reset_index(drop=True)
coordinates_f = coordinates_f.drop(['Координата X', 'Координата Y', 'Координата забоя Х (по траектории)',
                                            'Координата забоя Y (по траектории)'], axis=1)
new = coordinates_f['№ скважины'].tolist()
coordinates_f['Скважина'] = new
coordinates_f = coordinates_f.drop(['№ скважины'], axis=1)
final = grp_now_we_go.merge(coordinates_f, on='Скважина')
final
# Out:
#      Месторождение      Unnamed: 0 Скважина     Куст  \
# 0     Тайлаковское      Добывающая        1      NaN
# 1     Тайлаковское      Добывающая        1      NaN
# 2     Тайлаковское  Нагнетательная        1      NaN
# 3     Тайлаковское      Добывающая        1      NaN
# 4     Тайлаковское      Добывающая        1      NaN
# ...            ...             ...      ...      ...
# 4923  Тайлаковское      Добывающая       99  КУСТ-96
# 4924  Тайлаковское      Добывающая       99  КУСТ-96
# 4925  Тайлаковское      Добывающая       99  КУСТ-96
# 4926  Тайлаковское      Добывающая       99  КУСТ-96
# 4927  Тайлаковское      Добывающая       99  КУСТ-96
#
#                                                 Тип Объект разработки до ГТМ  \
# 0                                   ВНС из др. фонд                       Ю3
# 1                                               ГРП                       Ю3
# 2                                     Перевод в ППД                       Ю3
# 3     Выравнивание профиля притока или приёмистости                       Ю3
# 4                                   Проведение ГДИС                       Ю3
# ...                                             ...                      ...
# 4923                             Запуск без ремонта                       Ю3
# 4924                             Запуск без ремонта                       Ю3
# 4925                             Запуск без ремонта                       Ю3
# 4926                             Запуск без ремонта                       Ю3
# 4927                             Запуск без ремонта                       Ю3
#
#       Объект разработки после ГТМ Страница  Dэк  \
# 0                             NaN      -1_  NaN
# 1                             NaN      -1_  NaN
# 2                             NaN      -1_  NaN
# 3                             NaN      -1_  NaN
# 4                             NaN      -1_  NaN
# ...                           ...      ...  ...
# 4923                          NaN      -1_  NaN
# 4924                          NaN      -1_  NaN
# 4925                          NaN      -1_  NaN
# 4926                          NaN      -1_  NaN
# 4927                          NaN      -1_  NaN
#
#                            Краткое описание мероприятий  ...  \
# 0                    КР9-5 Перевод скважин в добывающие  ...
# 1                                  КР7-2 Проведение ГРП  ...
# 2     КР9-6 Перевод под нагнетание из других категор...  ...
# 3                                        Проведение ВПП  ...
# 4                        Гидродинамические исследования  ...
# ...                                                 ...  ...
# 4923                        Запуск в работу без ремонта  ...
# 4924                        Запуск в работу без ремонта  ...
# 4925                        Запуск в работу без ремонта  ...
# 4926                        Запуск в работу без ремонта  ...
# 4927                        Запуск в работу без ремонта  ...
#
#       Производительность.1  Комментарий  План  Факт  Пл-ть нефти  Коб  \
# 0                      NaN          NaN   NaN   NaN          NaN  NaN
# 1                      NaN          NaN   NaN   NaN          NaN  NaN
# 2                      NaN          NaN   NaN   NaN          NaN  NaN
# 3                      NaN          NaN   NaN   NaN          NaN  NaN
# 4                      NaN          NaN   NaN   NaN          NaN  NaN
# ...                    ...          ...   ...   ...          ...  ...
# 4923                   NaN          NaN   NaN   NaN          NaN  NaN
# 4924                   NaN          NaN   NaN   NaN          NaN  NaN
# 4925                   NaN          NaN   NaN   NaN          NaN  NaN
# 4926                   NaN          NaN   NaN   NaN          NaN  NaN
# 4927                   NaN          NaN   NaN   NaN          NaN  NaN
#
#       В-ть жидк.  P нас  Unnamed: 65     Length
# 0            NaN    NaN          NaN   4.123106
# 1            NaN    NaN          NaN   4.123106
# 2            NaN    NaN          NaN   4.123106
# 3            NaN    NaN          NaN   4.123106
# 4            NaN    NaN          NaN   4.123106
# ...          ...    ...          ...        ...
# 4923         NaN    NaN          NaN  34.365681
# 4924         NaN    NaN          NaN  34.365681
# 4925         NaN    NaN          NaN  34.365681
# 4926         NaN    NaN          NaN  34.365681
# 4927         NaN    NaN          NaN  34.365681
#
# [4928 rows x 67 columns]

# %%
final['Длина ГС, м'] = final.apply(
        lambda x:
        x['Length'] if x['Length'] >= 110
        else 0, axis=1)
final = final.drop(['Length'], axis=1)
final
# Out:
#      Месторождение      Unnamed: 0 Скважина     Куст  \
# 0     Тайлаковское      Добывающая        1      NaN
# 1     Тайлаковское      Добывающая        1      NaN
# 2     Тайлаковское  Нагнетательная        1      NaN
# 3     Тайлаковское      Добывающая        1      NaN
# 4     Тайлаковское      Добывающая        1      NaN
# ...            ...             ...      ...      ...
# 4923  Тайлаковское      Добывающая       99  КУСТ-96
# 4924  Тайлаковское      Добывающая       99  КУСТ-96
# 4925  Тайлаковское      Добывающая       99  КУСТ-96
# 4926  Тайлаковское      Добывающая       99  КУСТ-96
# 4927  Тайлаковское      Добывающая       99  КУСТ-96
#
#                                                 Тип Объект разработки до ГТМ  \
# 0                                   ВНС из др. фонд                       Ю3
# 1                                               ГРП                       Ю3
# 2                                     Перевод в ППД                       Ю3
# 3     Выравнивание профиля притока или приёмистости                       Ю3
# 4                                   Проведение ГДИС                       Ю3
# ...                                             ...                      ...
# 4923                             Запуск без ремонта                       Ю3
# 4924                             Запуск без ремонта                       Ю3
# 4925                             Запуск без ремонта                       Ю3
# 4926                             Запуск без ремонта                       Ю3
# 4927                             Запуск без ремонта                       Ю3
#
#       Объект разработки после ГТМ Страница  Dэк  \
# 0                             NaN      -1_  NaN
# 1                             NaN      -1_  NaN
# 2                             NaN      -1_  NaN
# 3                             NaN      -1_  NaN
# 4                             NaN      -1_  NaN
# ...                           ...      ...  ...
# 4923                          NaN      -1_  NaN
# 4924                          NaN      -1_  NaN
# 4925                          NaN      -1_  NaN
# 4926                          NaN      -1_  NaN
# 4927                          NaN      -1_  NaN
#
#                            Краткое описание мероприятий  ...  \
# 0                    КР9-5 Перевод скважин в добывающие  ...
# 1                                  КР7-2 Проведение ГРП  ...
# 2     КР9-6 Перевод под нагнетание из других категор...  ...
# 3                                        Проведение ВПП  ...
# 4                        Гидродинамические исследования  ...
# ...                                                 ...  ...
# 4923                        Запуск в работу без ремонта  ...
# 4924                        Запуск в работу без ремонта  ...
# 4925                        Запуск в работу без ремонта  ...
# 4926                        Запуск в работу без ремонта  ...
# 4927                        Запуск в работу без ремонта  ...
#
#       Производительность.1  Комментарий  План  Факт  Пл-ть нефти  Коб  \
# 0                      NaN          NaN   NaN   NaN          NaN  NaN
# 1                      NaN          NaN   NaN   NaN          NaN  NaN
# 2                      NaN          NaN   NaN   NaN          NaN  NaN
# 3                      NaN          NaN   NaN   NaN          NaN  NaN
# 4                      NaN          NaN   NaN   NaN          NaN  NaN
# ...                    ...          ...   ...   ...          ...  ...
# 4923                   NaN          NaN   NaN   NaN          NaN  NaN
# 4924                   NaN          NaN   NaN   NaN          NaN  NaN
# 4925                   NaN          NaN   NaN   NaN          NaN  NaN
# 4926                   NaN          NaN   NaN   NaN          NaN  NaN
# 4927                   NaN          NaN   NaN   NaN          NaN  NaN
#
#       В-ть жидк.  P нас  Unnamed: 65  Длина ГС, м
# 0            NaN    NaN          NaN          0.0
# 1            NaN    NaN          NaN          0.0
# 2            NaN    NaN          NaN          0.0
# 3            NaN    NaN          NaN          0.0
# 4            NaN    NaN          NaN          0.0
# ...          ...    ...          ...          ...
# 4923         NaN    NaN          NaN          0.0
# 4924         NaN    NaN          NaN          0.0
# 4925         NaN    NaN          NaN          0.0
# 4926         NaN    NaN          NaN          0.0
# 4927         NaN    NaN          NaN          0.0
#
# [4928 rows x 67 columns]

# %%
final_number = final.groupby(by=['Скважина', 'ВНР.1','Тип','Объект разработки до ГТМ']).agg(
            {'Длина ГС, м': lambda x:
            x.tolist()[:2]}
        )
final_number
# Out:
#                                                                                            Длина ГС, м
# Скважина ВНР.1      Тип                                           Объект разработки до ГТМ
# 1        2016-03-12 ВНС из др. фонд                               Ю3                             [0.0]
#                     ГРП                                           Ю3                             [0.0]
#          2017-03-16 Перевод в ППД                                 Ю3                             [0.0]
#          2018-12-03 Выравнивание профиля притока или приёмистости Ю3                             [0.0]
#          2019-06-14 Проведение ГДИС                               Ю3                             [0.0]
# ...                                                                                                ...
# 99       2020-09-02 Запуск без ремонта                            Ю3                             [0.0]
#          2021-08-31 Запуск без ремонта                            Ю3                             [0.0]
#          2021-09-02 Запуск без ремонта                            Ю3                             [0.0]
#          2021-09-05 Запуск без ремонта                            Ю3                             [0.0]
#          2021-11-27 Запуск без ремонта                            Ю3                             [0.0]
#
# [4787 rows x 1 columns]

# %%
final_number.reset_index(inplace=True)

# %%
final_number
# Out:
#      Скважина      ВНР.1                                            Тип  \
# 0           1 2016-03-12                                ВНС из др. фонд
# 1           1 2016-03-12                                            ГРП
# 2           1 2017-03-16                                  Перевод в ППД
# 3           1 2018-12-03  Выравнивание профиля притока или приёмистости
# 4           1 2019-06-14                                Проведение ГДИС
# ...       ...        ...                                            ...
# 4782       99 2020-09-02                             Запуск без ремонта
# 4783       99 2021-08-31                             Запуск без ремонта
# 4784       99 2021-09-02                             Запуск без ремонта
# 4785       99 2021-09-05                             Запуск без ремонта
# 4786       99 2021-11-27                             Запуск без ремонта
#
#      Объект разработки до ГТМ Длина ГС, м
# 0                          Ю3       [0.0]
# 1                          Ю3       [0.0]
# 2                          Ю3       [0.0]
# 3                          Ю3       [0.0]
# 4                          Ю3       [0.0]
# ...                       ...         ...
# 4782                       Ю3       [0.0]
# 4783                       Ю3       [0.0]
# 4784                       Ю3       [0.0]
# 4785                       Ю3       [0.0]
# 4786                       Ю3       [0.0]
#
# [4787 rows x 5 columns]

# %%
final_number.loc[final_number['Скважина'] == '1304']
# Out:
#     Скважина      ВНР.1  Тип Объект разработки до ГТМ         Длина ГС, м
# 414     1304 2010-10-19  ОПЗ                       Ю3  [261.283371074395]
# 415     1304 2014-07-20  3БС                       Ю3  [261.283371074395]
# 416     1304 2014-07-20  ГРП                       Ю3  [261.283371074395]
# 417     1304 2014-10-01  ОПЗ                       Ю3  [261.283371074395]

# %%
final_number['Дата ВНР после'] = final_number.apply(
            lambda x:
            x['ВНР.1'] if 'ГРП' in str(x['Тип'])
            else x['ВНР.1'] if 'ВНС' in str(x['Тип'])
            else x['ВНР.1'] if '3Б' in str(x['Тип'])
            else 'нет', axis=1)
final_number = final_number.drop(final_number[final_number['Дата ВНР после'] == 'нет'].index)
final_number
# Out:
#      Скважина      ВНР.1              Тип Объект разработки до ГТМ  \
# 0           1 2016-03-12  ВНС из др. фонд                       Ю3
# 1           1 2016-03-12              ГРП                       Ю3
# 14         10 2008-10-12              ВНС                       Ю3
# 15         10 2013-03-03              ГРП                       Ю3
# 24       1004 2011-02-04              ВНС                       Ю3
# ...       ...        ...              ...                      ...
# 4773       96 2019-07-31              ГРП                       Ю3
# 4776      971 2012-04-19              ВНС                       Ю3
# 4777      971 2013-01-23              ГРП                       Ю3
# 4778       99 2019-11-01              ВНС                       Ю3
# 4779       99 2019-11-01              ГРП                       Ю3
#
#               Длина ГС, м       Дата ВНР после
# 0                   [0.0]  2016-03-12 00:00:00
# 1                   [0.0]  2016-03-12 00:00:00
# 14                  [0.0]  2008-10-12 00:00:00
# 15                  [0.0]  2013-03-03 00:00:00
# 24                  [0.0]  2011-02-04 00:00:00
# ...                   ...                  ...
# 4773                [0.0]  2019-07-31 00:00:00
# 4776  [762.3778590698972]  2012-04-19 00:00:00
# 4777  [762.3778590698972]  2013-01-23 00:00:00
# 4778                [0.0]  2019-11-01 00:00:00
# 4779                [0.0]  2019-11-01 00:00:00
#
# [1222 rows x 6 columns]

# %%
final_number.loc[final_number['Скважина'] == '1304']
# Out:
#     Скважина      ВНР.1  Тип Объект разработки до ГТМ         Длина ГС, м  \
# 415     1304 2014-07-20  3БС                       Ю3  [261.283371074395]
# 416     1304 2014-07-20  ГРП                       Ю3  [261.283371074395]
#
#           Дата ВНР после
# 415  2014-07-20 00:00:00
# 416  2014-07-20 00:00:00

# %%
final_number['Длина ГС, м'] = final_number.apply(
            lambda x:
            x['Длина ГС, м'][0], axis=1)
final_number
# Out:
#      Скважина      ВНР.1              Тип Объект разработки до ГТМ  \
# 0           1 2016-03-12  ВНС из др. фонд                       Ю3
# 1           1 2016-03-12              ГРП                       Ю3
# 14         10 2008-10-12              ВНС                       Ю3
# 15         10 2013-03-03              ГРП                       Ю3
# 24       1004 2011-02-04              ВНС                       Ю3
# ...       ...        ...              ...                      ...
# 4773       96 2019-07-31              ГРП                       Ю3
# 4776      971 2012-04-19              ВНС                       Ю3
# 4777      971 2013-01-23              ГРП                       Ю3
# 4778       99 2019-11-01              ВНС                       Ю3
# 4779       99 2019-11-01              ГРП                       Ю3
#
#       Длина ГС, м       Дата ВНР после
# 0        0.000000  2016-03-12 00:00:00
# 1        0.000000  2016-03-12 00:00:00
# 14       0.000000  2008-10-12 00:00:00
# 15       0.000000  2013-03-03 00:00:00
# 24       0.000000  2011-02-04 00:00:00
# ...           ...                  ...
# 4773     0.000000  2019-07-31 00:00:00
# 4776   762.377859  2012-04-19 00:00:00
# 4777   762.377859  2013-01-23 00:00:00
# 4778     0.000000  2019-11-01 00:00:00
# 4779     0.000000  2019-11-01 00:00:00
#
# [1222 rows x 6 columns]

# %%
final_number.reset_index(inplace=True)
final_number
# Out:
#       index Скважина      ВНР.1              Тип Объект разработки до ГТМ  \
# 0         0        1 2016-03-12  ВНС из др. фонд                       Ю3
# 1         1        1 2016-03-12              ГРП                       Ю3
# 2        14       10 2008-10-12              ВНС                       Ю3
# 3        15       10 2013-03-03              ГРП                       Ю3
# 4        24     1004 2011-02-04              ВНС                       Ю3
# ...     ...      ...        ...              ...                      ...
# 1217   4773       96 2019-07-31              ГРП                       Ю3
# 1218   4776      971 2012-04-19              ВНС                       Ю3
# 1219   4777      971 2013-01-23              ГРП                       Ю3
# 1220   4778       99 2019-11-01              ВНС                       Ю3
# 1221   4779       99 2019-11-01              ГРП                       Ю3
#
#       Длина ГС, м       Дата ВНР после
# 0        0.000000  2016-03-12 00:00:00
# 1        0.000000  2016-03-12 00:00:00
# 2        0.000000  2008-10-12 00:00:00
# 3        0.000000  2013-03-03 00:00:00
# 4        0.000000  2011-02-04 00:00:00
# ...           ...                  ...
# 1217     0.000000  2019-07-31 00:00:00
# 1218   762.377859  2012-04-19 00:00:00
# 1219   762.377859  2013-01-23 00:00:00
# 1220     0.000000  2019-11-01 00:00:00
# 1221     0.000000  2019-11-01 00:00:00
#
# [1222 rows x 7 columns]

# %%
final_number['Тип'] = final_number.apply(
            lambda x:
            'ВНС' if 'ВН' in str(x['Тип'])
            else x['Тип'], axis=1)
final_number
# Out:
#       index Скважина      ВНР.1  Тип Объект разработки до ГТМ  Длина ГС, м  \
# 0         0        1 2016-03-12  ВНС                       Ю3     0.000000
# 1         1        1 2016-03-12  ГРП                       Ю3     0.000000
# 2        14       10 2008-10-12  ВНС                       Ю3     0.000000
# 3        15       10 2013-03-03  ГРП                       Ю3     0.000000
# 4        24     1004 2011-02-04  ВНС                       Ю3     0.000000
# ...     ...      ...        ...  ...                      ...          ...
# 1217   4773       96 2019-07-31  ГРП                       Ю3     0.000000
# 1218   4776      971 2012-04-19  ВНС                       Ю3   762.377859
# 1219   4777      971 2013-01-23  ГРП                       Ю3   762.377859
# 1220   4778       99 2019-11-01  ВНС                       Ю3     0.000000
# 1221   4779       99 2019-11-01  ГРП                       Ю3     0.000000
#
#            Дата ВНР после
# 0     2016-03-12 00:00:00
# 1     2016-03-12 00:00:00
# 2     2008-10-12 00:00:00
# 3     2013-03-03 00:00:00
# 4     2011-02-04 00:00:00
# ...                   ...
# 1217  2019-07-31 00:00:00
# 1218  2012-04-19 00:00:00
# 1219  2013-01-23 00:00:00
# 1220  2019-11-01 00:00:00
# 1221  2019-11-01 00:00:00
#
# [1222 rows x 7 columns]

# %%
final_number['index'] = final_number.index
grp_vnski_double = final_number.drop(final_number[final_number['Тип'] != 'ВНС'].index)
grp_vnski_double['index'] = grp_vnski_double.index
grp_vnski_double
# Out:
#       index Скважина      ВНР.1  Тип Объект разработки до ГТМ  Длина ГС, м  \
# 0         0        1 2016-03-12  ВНС                       Ю3     0.000000
# 2         2       10 2008-10-12  ВНС                       Ю3     0.000000
# 4         4     1004 2011-02-04  ВНС                       Ю3     0.000000
# 8         8     1005 2011-08-31  ВНС                       Ю3     0.000000
# 11       11     1007 2010-10-28  ВНС                       Ю3     0.000000
# ...     ...      ...        ...  ...                      ...          ...
# 1209   1209      927 2011-11-14  ВНС                       Ю3     0.000000
# 1212   1212      936 2008-09-27  ВНС                       Ю3     0.000000
# 1216   1216       96 2019-07-31  ВНС                       Ю3     0.000000
# 1218   1218      971 2012-04-19  ВНС                       Ю3   762.377859
# 1220   1220       99 2019-11-01  ВНС                       Ю3     0.000000
#
#            Дата ВНР после
# 0     2016-03-12 00:00:00
# 2     2008-10-12 00:00:00
# 4     2011-02-04 00:00:00
# 8     2011-08-31 00:00:00
# 11    2010-10-28 00:00:00
# ...                   ...
# 1209  2011-11-14 00:00:00
# 1212  2008-09-27 00:00:00
# 1216  2019-07-31 00:00:00
# 1218  2012-04-19 00:00:00
# 1220  2019-11-01 00:00:00
#
# [501 rows x 7 columns]

# %%
grp_vnski_double = grp_vnski_double.groupby('Скважина').agg(
            {'index': lambda x:
            x.tolist()[1:]}
        )
sveta = []
for i in grp_vnski_double['index']:
    sveta += i
final_number = final_number[~final_number['index'].isin(sveta)].reset_index(drop=True)
final_number = final_number.drop(['index'], axis=1)
final_number
# Out:
#      Скважина      ВНР.1  Тип Объект разработки до ГТМ  Длина ГС, м  \
# 0           1 2016-03-12  ВНС                       Ю3     0.000000
# 1           1 2016-03-12  ГРП                       Ю3     0.000000
# 2          10 2008-10-12  ВНС                       Ю3     0.000000
# 3          10 2013-03-03  ГРП                       Ю3     0.000000
# 4        1004 2011-02-04  ВНС                       Ю3     0.000000
# ...       ...        ...  ...                      ...          ...
# 1207       96 2019-07-31  ГРП                       Ю3     0.000000
# 1208      971 2012-04-19  ВНС                       Ю3   762.377859
# 1209      971 2013-01-23  ГРП                       Ю3   762.377859
# 1210       99 2019-11-01  ВНС                       Ю3     0.000000
# 1211       99 2019-11-01  ГРП                       Ю3     0.000000
#
#            Дата ВНР после
# 0     2016-03-12 00:00:00
# 1     2016-03-12 00:00:00
# 2     2008-10-12 00:00:00
# 3     2013-03-03 00:00:00
# 4     2011-02-04 00:00:00
# ...                   ...
# 1207  2019-07-31 00:00:00
# 1208  2012-04-19 00:00:00
# 1209  2013-01-23 00:00:00
# 1210  2019-11-01 00:00:00
# 1211  2019-11-01 00:00:00
#
# [1212 rows x 6 columns]

# %%
final_number = final_number.drop(['ВНР.1'], axis=1)
final_number.head()
# Out:
#   Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после
# 0        1  ВНС                       Ю3          0.0  2016-03-12 00:00:00
# 1        1  ГРП                       Ю3          0.0  2016-03-12 00:00:00
# 2       10  ВНС                       Ю3          0.0  2008-10-12 00:00:00
# 3       10  ГРП                       Ю3          0.0  2013-03-03 00:00:00
# 4     1004  ВНС                       Ю3          0.0  2011-02-04 00:00:00

# %%
final_number['Полудлина трещины, м'] = final_number.apply(
            lambda x:
            100, axis=1)
final_number['Ширина трещины, мм'] = final_number.apply(
            lambda x:
            4, axis=1)
final_number['Проницаемость проппанта, Д'] = final_number.apply(
            lambda x:
            100, axis=1)
final_number['Полудлина трещины, м'] = final_number.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип'])
            else x['Полудлина трещины, м']
            , axis=1)
final_number['Ширина трещины, мм'] = final_number.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип'])
            else x['Ширина трещины, мм']
            , axis=1)
final_number['Проницаемость проппанта, Д'] = final_number.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип'])
            else x['Проницаемость проппанта, Д']
            , axis=1)
        # ДОБАВИТЬ В ВНС
final_number['Число стадий ГРП'] = final_number.apply(
            lambda x:
            1, axis=1)
final_number['Число стадий ГРП'] = final_number.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип'])
            else x['Число стадий ГРП']
            , axis=1)
final_number
# Out:
#      Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0           1  ВНС                       Ю3     0.000000  2016-03-12 00:00:00
# 1           1  ГРП                       Ю3     0.000000  2016-03-12 00:00:00
# 2          10  ВНС                       Ю3     0.000000  2008-10-12 00:00:00
# 3          10  ГРП                       Ю3     0.000000  2013-03-03 00:00:00
# 4        1004  ВНС                       Ю3     0.000000  2011-02-04 00:00:00
# ...       ...  ...                      ...          ...                  ...
# 1207       96  ГРП                       Ю3     0.000000  2019-07-31 00:00:00
# 1208      971  ВНС                       Ю3   762.377859  2012-04-19 00:00:00
# 1209      971  ГРП                       Ю3   762.377859  2013-01-23 00:00:00
# 1210       99  ВНС                       Ю3     0.000000  2019-11-01 00:00:00
# 1211       99  ГРП                       Ю3     0.000000  2019-11-01 00:00:00
#
#       Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                        0                   0                           0
# 1                      100                   4                         100
# 2                        0                   0                           0
# 3                      100                   4                         100
# 4                        0                   0                           0
# ...                    ...                 ...                         ...
# 1207                   100                   4                         100
# 1208                     0                   0                           0
# 1209                   100                   4                         100
# 1210                     0                   0                           0
# 1211                   100                   4                         100
#
#       Число стадий ГРП
# 0                    0
# 1                    1
# 2                    0
# 3                    1
# 4                    0
# ...                ...
# 1207                 1
# 1208                 0
# 1209                 1
# 1210                 0
# 1211                 1
#
# [1212 rows x 9 columns]

# %%
final_number.loc[final_number['Тип'] == '3БС']
# Out:
#      Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 60        123  3БС                       Ю3   313.336879  2019-06-16 00:00:00
# 61        123  3БС                       Ю3   313.336879  2019-08-18 00:00:00
# 63        123  3БС                       Ю3   313.336879  2019-09-03 00:00:00
# 65       1230  3БС                       Ю3   381.848137  2014-07-12 00:00:00
# 88       1304  3БС                       Ю3   261.283371  2014-07-20 00:00:00
# ...       ...  ...                      ...          ...                  ...
# 1166      897  3БС                       Ю3     0.000000  2012-06-29 00:00:00
# 1180      906  3БС                       Ю3     0.000000  2021-08-15 00:00:00
# 1181      906  3БС                       Ю3     0.000000  2021-09-30 00:00:00
# 1186      909  3БС                       Ю3   294.803324  2014-07-03 00:00:00
# 1205      949  3БС                       Ю3   343.052474  2021-09-24 00:00:00
#
#       Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 60                     100                   4                         100
# 61                     100                   4                         100
# 63                     100                   4                         100
# 65                     100                   4                         100
# 88                     100                   4                         100
# ...                    ...                 ...                         ...
# 1166                   100                   4                         100
# 1180                   100                   4                         100
# 1181                   100                   4                         100
# 1186                   100                   4                         100
# 1205                   100                   4                         100
#
#       Число стадий ГРП
# 60                   1
# 61                   1
# 63                   1
# 65                   1
# 88                   1
# ...                ...
# 1166                 1
# 1180                 1
# 1181                 1
# 1186                 1
# 1205                 1
#
# [125 rows x 9 columns]

# %%
final_number['ГС/ННС'] = final_number.apply(
            lambda x:
            'ННС' if x['Длина ГС, м'] == 0
            else 'ГС', axis=1)
final_number
# Out:
#      Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0           1  ВНС                       Ю3     0.000000  2016-03-12 00:00:00
# 1           1  ГРП                       Ю3     0.000000  2016-03-12 00:00:00
# 2          10  ВНС                       Ю3     0.000000  2008-10-12 00:00:00
# 3          10  ГРП                       Ю3     0.000000  2013-03-03 00:00:00
# 4        1004  ВНС                       Ю3     0.000000  2011-02-04 00:00:00
# ...       ...  ...                      ...          ...                  ...
# 1207       96  ГРП                       Ю3     0.000000  2019-07-31 00:00:00
# 1208      971  ВНС                       Ю3   762.377859  2012-04-19 00:00:00
# 1209      971  ГРП                       Ю3   762.377859  2013-01-23 00:00:00
# 1210       99  ВНС                       Ю3     0.000000  2019-11-01 00:00:00
# 1211       99  ГРП                       Ю3     0.000000  2019-11-01 00:00:00
#
#       Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                        0                   0                           0
# 1                      100                   4                         100
# 2                        0                   0                           0
# 3                      100                   4                         100
# 4                        0                   0                           0
# ...                    ...                 ...                         ...
# 1207                   100                   4                         100
# 1208                     0                   0                           0
# 1209                   100                   4                         100
# 1210                     0                   0                           0
# 1211                   100                   4                         100
#
#       Число стадий ГРП ГС/ННС
# 0                    0    ННС
# 1                    1    ННС
# 2                    0    ННС
# 3                    1    ННС
# 4                    0    ННС
# ...                ...    ...
# 1207                 1    ННС
# 1208                 0     ГС
# 1209                 1     ГС
# 1210                 0    ННС
# 1211                 1    ННС
#
# [1212 rows x 10 columns]

# %%
final_number['index'] = final_number.index
final_number['index'] = final_number.apply(
            lambda x:
            str(x['index'])
            + ('_да' if x['Тип'] == 'ГРП' else ''),
            axis=1
        )

# %%
final_number['index'] = final_number.apply(
            lambda x:
            str(x['index'])
            + ('_збс' if 'Б' in str(x['Тип']) else ''),
            axis=1
        )
final_number
# Out:
#      Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0           1  ВНС                       Ю3     0.000000  2016-03-12 00:00:00
# 1           1  ГРП                       Ю3     0.000000  2016-03-12 00:00:00
# 2          10  ВНС                       Ю3     0.000000  2008-10-12 00:00:00
# 3          10  ГРП                       Ю3     0.000000  2013-03-03 00:00:00
# 4        1004  ВНС                       Ю3     0.000000  2011-02-04 00:00:00
# ...       ...  ...                      ...          ...                  ...
# 1207       96  ГРП                       Ю3     0.000000  2019-07-31 00:00:00
# 1208      971  ВНС                       Ю3   762.377859  2012-04-19 00:00:00
# 1209      971  ГРП                       Ю3   762.377859  2013-01-23 00:00:00
# 1210       99  ВНС                       Ю3     0.000000  2019-11-01 00:00:00
# 1211       99  ГРП                       Ю3     0.000000  2019-11-01 00:00:00
#
#       Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                        0                   0                           0
# 1                      100                   4                         100
# 2                        0                   0                           0
# 3                      100                   4                         100
# 4                        0                   0                           0
# ...                    ...                 ...                         ...
# 1207                   100                   4                         100
# 1208                     0                   0                           0
# 1209                   100                   4                         100
# 1210                     0                   0                           0
# 1211                   100                   4                         100
#
#       Число стадий ГРП ГС/ННС    index
# 0                    0    ННС        0
# 1                    1    ННС     1_да
# 2                    0    ННС        2
# 3                    1    ННС     3_да
# 4                    0    ННС        4
# ...                ...    ...      ...
# 1207                 1    ННС  1207_да
# 1208                 0     ГС     1208
# 1209                 1     ГС  1209_да
# 1210                 0    ННС     1210
# 1211                 1    ННС  1211_да
#
# [1212 rows x 11 columns]

# %%
final_number.loc[final_number['Скважина'] == '1304']
# Out:
#    Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 88     1304  3БС                       Ю3   261.283371  2014-07-20 00:00:00
# 89     1304  ГРП                       Ю3   261.283371  2014-07-20 00:00:00
#
#     Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 88                   100                   4                         100
# 89                   100                   4                         100
#
#     Число стадий ГРП ГС/ННС   index
# 88                 1     ГС  88_збс
# 89                 1     ГС   89_да

# %%
final_double = final_number.groupby(by=['Скважина', 'Дата ВНР после']).agg(
            {'index': lambda x:
            x.tolist()}
        )
final_double
# Out:
#                                    index
# Скважина Дата ВНР после
# 1        2016-03-12            [0, 1_да]
# 10       2008-10-12                  [2]
#          2013-03-03               [3_да]
# 1004     2011-02-04            [4, 5_да]
#          2013-01-31               [6_да]
# ...                                  ...
# 949      2021-09-24           [1205_збс]
# 96       2019-07-31      [1206, 1207_да]
# 971      2012-04-19               [1208]
#          2013-01-23            [1209_да]
# 99       2019-11-01      [1210, 1211_да]
#
# [964 rows x 1 columns]

# %%
final_double.reset_index(inplace=True)
final_double['длина'] = final_double.apply(
            lambda x:
            len(x['index']), axis=1)
final_double = final_double.drop(final_double[final_double['длина'] == 1].index)
final_double
# Out:
#     Скважина Дата ВНР после            index  длина
# 0          1     2016-03-12        [0, 1_да]      2
# 3       1004     2011-02-04        [4, 5_да]      2
# 6       1005     2011-08-31        [8, 9_да]      2
# 12      1092     2010-07-21      [15, 16_да]      2
# 13        11     2009-04-01      [17, 18_да]      2
# ..       ...            ...              ...    ...
# 948      922     2011-12-14  [1191, 1192_да]      2
# 953      926     2011-03-28  [1197, 1198_да]      2
# 957      936     2008-09-27  [1202, 1203_да]      2
# 960       96     2019-07-31  [1206, 1207_да]      2
# 963       99     2019-11-01  [1210, 1211_да]      2
#
# [248 rows x 4 columns]

# %%
final_double.tail(60)
# Out:
#     Скважина Дата ВНР после                index  длина
# 728      637     2009-07-24        [916, 917_да]      2
# 732      641     2009-06-29        [921, 922_да]      2
# 734      644     2009-09-23        [924, 925_да]      2
# 735      647     2010-03-26        [926, 927_да]      2
# 736      648     2016-03-05        [928, 929_да]      2
# 737      649     2016-04-13        [930, 931_да]      2
# 744      651     2010-12-07        [938, 939_да]      2
# 745      655     2016-09-20        [940, 941_да]      2
# 748      662     2015-10-28        [944, 945_да]      2
# 749      663     2015-11-23        [946, 947_да]      2
# 750      665     2015-11-30        [948, 949_да]      2
# 751      673     2010-01-03        [950, 951_да]      2
# 752      675     2009-09-19        [952, 953_да]      2
# 754      675     2014-08-21    [955_збс, 956_да]      2
# 756      678     2009-09-03        [958, 959_да]      2
# 758      679     2009-12-29        [961, 962_да]      2
# 764      680     2015-05-21        [968, 969_да]      2
# 766      686     2015-10-05        [971, 972_да]      2
# 782      711     2014-01-03        [988, 989_да]      2
# 783      713     2009-12-16        [990, 991_да]      2
# 784      714     2009-06-26        [992, 993_да]      2
# 791      720     2013-08-24      [1000, 1001_да]      2
# 792      720     2014-12-23  [1002_збс, 1003_да]      2
# 796      722     2009-08-12      [1007, 1008_да]      2
# 799      724     2009-12-11      [1011, 1012_да]      2
# 801      725     2009-10-09      [1014, 1015_да]      2
# 803      726     2010-01-03      [1017, 1018_да]      2
# 811      729     2017-07-11  [1026_збс, 1027_да]      2
# 813      731     2009-07-21      [1029, 1030_да]      2
# 815      732     2009-08-18      [1032, 1033_да]      2
# 821      737     2013-09-29      [1039, 1040_да]      2
# 823      738     2013-09-15      [1042, 1043_да]      2
# 827      739     2013-10-19      [1047, 1048_да]      2
# 829      739     2015-04-30  [1050_збс, 1051_да]      2
# 834      752     2010-06-17      [1056, 1057_да]      2
# 840      757     2009-10-08      [1063, 1064_да]      2
# 853      762     2014-02-27  [1077_збс, 1078_да]      2
# 861      766     2009-07-13      [1086, 1087_да]      2
# 865      767     2009-10-02      [1091, 1092_да]      2
# 872      770     2010-02-26      [1099, 1100_да]      2
# 879      773     2009-09-12      [1107, 1108_да]      2
# 886        8     2014-09-21  [1115_збс, 1116_да]      2
# 891      806     2008-03-19      [1121, 1122_да]      2
# 892      806     2015-06-26  [1123_збс, 1124_да]      2
# 896       84     2006-02-27      [1128, 1129_да]      2
# 897       84     2014-08-01  [1130_збс, 1131_да]      2
# 908       87     2011-05-24      [1142, 1143_да]      2
# 912      874     2019-10-18      [1147, 1148_да]      2
# 920      881     2019-06-24      [1156, 1157_да]      2
# 927      897     2011-01-17      [1164, 1165_да]      2
# 930      898     2011-09-22      [1168, 1169_да]      2
# 937      905     2010-10-28      [1176, 1177_да]      2
# 938      906     2010-11-26      [1178, 1179_да]      2
# 943      909     2011-01-10      [1184, 1185_да]      2
# 944      909     2014-07-03  [1186_збс, 1187_да]      2
# 948      922     2011-12-14      [1191, 1192_да]      2
# 953      926     2011-03-28      [1197, 1198_да]      2
# 957      936     2008-09-27      [1202, 1203_да]      2
# 960       96     2019-07-31      [1206, 1207_да]      2
# 963       99     2019-11-01      [1210, 1211_да]      2

# %%
final_double['збс'] = final_double.apply(
            lambda x:
            'да' if 'збс' in str(x['index'])
            else 'нет', axis=1)
final_double
# Out:
#     Скважина Дата ВНР после            index  длина  збс
# 0          1     2016-03-12        [0, 1_да]      2  нет
# 3       1004     2011-02-04        [4, 5_да]      2  нет
# 6       1005     2011-08-31        [8, 9_да]      2  нет
# 12      1092     2010-07-21      [15, 16_да]      2  нет
# 13        11     2009-04-01      [17, 18_да]      2  нет
# ..       ...            ...              ...    ...  ...
# 948      922     2011-12-14  [1191, 1192_да]      2  нет
# 953      926     2011-03-28  [1197, 1198_да]      2  нет
# 957      936     2008-09-27  [1202, 1203_да]      2  нет
# 960       96     2019-07-31  [1206, 1207_да]      2  нет
# 963       99     2019-11-01  [1210, 1211_да]      2  нет
#
# [248 rows x 5 columns]

# %%
final_double.tail(40)
# Out:
#     Скважина Дата ВНР после                index  длина  збс
# 784      714     2009-06-26        [992, 993_да]      2  нет
# 791      720     2013-08-24      [1000, 1001_да]      2  нет
# 792      720     2014-12-23  [1002_збс, 1003_да]      2   да
# 796      722     2009-08-12      [1007, 1008_да]      2  нет
# 799      724     2009-12-11      [1011, 1012_да]      2  нет
# 801      725     2009-10-09      [1014, 1015_да]      2  нет
# 803      726     2010-01-03      [1017, 1018_да]      2  нет
# 811      729     2017-07-11  [1026_збс, 1027_да]      2   да
# 813      731     2009-07-21      [1029, 1030_да]      2  нет
# 815      732     2009-08-18      [1032, 1033_да]      2  нет
# 821      737     2013-09-29      [1039, 1040_да]      2  нет
# 823      738     2013-09-15      [1042, 1043_да]      2  нет
# 827      739     2013-10-19      [1047, 1048_да]      2  нет
# 829      739     2015-04-30  [1050_збс, 1051_да]      2   да
# 834      752     2010-06-17      [1056, 1057_да]      2  нет
# 840      757     2009-10-08      [1063, 1064_да]      2  нет
# 853      762     2014-02-27  [1077_збс, 1078_да]      2   да
# 861      766     2009-07-13      [1086, 1087_да]      2  нет
# 865      767     2009-10-02      [1091, 1092_да]      2  нет
# 872      770     2010-02-26      [1099, 1100_да]      2  нет
# 879      773     2009-09-12      [1107, 1108_да]      2  нет
# 886        8     2014-09-21  [1115_збс, 1116_да]      2   да
# 891      806     2008-03-19      [1121, 1122_да]      2  нет
# 892      806     2015-06-26  [1123_збс, 1124_да]      2   да
# 896       84     2006-02-27      [1128, 1129_да]      2  нет
# 897       84     2014-08-01  [1130_збс, 1131_да]      2   да
# 908       87     2011-05-24      [1142, 1143_да]      2  нет
# 912      874     2019-10-18      [1147, 1148_да]      2  нет
# 920      881     2019-06-24      [1156, 1157_да]      2  нет
# 927      897     2011-01-17      [1164, 1165_да]      2  нет
# 930      898     2011-09-22      [1168, 1169_да]      2  нет
# 937      905     2010-10-28      [1176, 1177_да]      2  нет
# 938      906     2010-11-26      [1178, 1179_да]      2  нет
# 943      909     2011-01-10      [1184, 1185_да]      2  нет
# 944      909     2014-07-03  [1186_збс, 1187_да]      2   да
# 948      922     2011-12-14      [1191, 1192_да]      2  нет
# 953      926     2011-03-28      [1197, 1198_да]      2  нет
# 957      936     2008-09-27      [1202, 1203_да]      2  нет
# 960       96     2019-07-31      [1206, 1207_да]      2  нет
# 963       99     2019-11-01      [1210, 1211_да]      2  нет

# %%
final_double.tail(60)
# Out:
#     Скважина Дата ВНР после                index  длина  збс
# 728      637     2009-07-24        [916, 917_да]      2  нет
# 732      641     2009-06-29        [921, 922_да]      2  нет
# 734      644     2009-09-23        [924, 925_да]      2  нет
# 735      647     2010-03-26        [926, 927_да]      2  нет
# 736      648     2016-03-05        [928, 929_да]      2  нет
# 737      649     2016-04-13        [930, 931_да]      2  нет
# 744      651     2010-12-07        [938, 939_да]      2  нет
# 745      655     2016-09-20        [940, 941_да]      2  нет
# 748      662     2015-10-28        [944, 945_да]      2  нет
# 749      663     2015-11-23        [946, 947_да]      2  нет
# 750      665     2015-11-30        [948, 949_да]      2  нет
# 751      673     2010-01-03        [950, 951_да]      2  нет
# 752      675     2009-09-19        [952, 953_да]      2  нет
# 754      675     2014-08-21    [955_збс, 956_да]      2   да
# 756      678     2009-09-03        [958, 959_да]      2  нет
# 758      679     2009-12-29        [961, 962_да]      2  нет
# 764      680     2015-05-21        [968, 969_да]      2  нет
# 766      686     2015-10-05        [971, 972_да]      2  нет
# 782      711     2014-01-03        [988, 989_да]      2  нет
# 783      713     2009-12-16        [990, 991_да]      2  нет
# 784      714     2009-06-26        [992, 993_да]      2  нет
# 791      720     2013-08-24      [1000, 1001_да]      2  нет
# 792      720     2014-12-23  [1002_збс, 1003_да]      2   да
# 796      722     2009-08-12      [1007, 1008_да]      2  нет
# 799      724     2009-12-11      [1011, 1012_да]      2  нет
# 801      725     2009-10-09      [1014, 1015_да]      2  нет
# 803      726     2010-01-03      [1017, 1018_да]      2  нет
# 811      729     2017-07-11  [1026_збс, 1027_да]      2   да
# 813      731     2009-07-21      [1029, 1030_да]      2  нет
# 815      732     2009-08-18      [1032, 1033_да]      2  нет
# 821      737     2013-09-29      [1039, 1040_да]      2  нет
# 823      738     2013-09-15      [1042, 1043_да]      2  нет
# 827      739     2013-10-19      [1047, 1048_да]      2  нет
# 829      739     2015-04-30  [1050_збс, 1051_да]      2   да
# 834      752     2010-06-17      [1056, 1057_да]      2  нет
# 840      757     2009-10-08      [1063, 1064_да]      2  нет
# 853      762     2014-02-27  [1077_збс, 1078_да]      2   да
# 861      766     2009-07-13      [1086, 1087_да]      2  нет
# 865      767     2009-10-02      [1091, 1092_да]      2  нет
# 872      770     2010-02-26      [1099, 1100_да]      2  нет
# 879      773     2009-09-12      [1107, 1108_да]      2  нет
# 886        8     2014-09-21  [1115_збс, 1116_да]      2   да
# 891      806     2008-03-19      [1121, 1122_да]      2  нет
# 892      806     2015-06-26  [1123_збс, 1124_да]      2   да
# 896       84     2006-02-27      [1128, 1129_да]      2  нет
# 897       84     2014-08-01  [1130_збс, 1131_да]      2   да
# 908       87     2011-05-24      [1142, 1143_да]      2  нет
# 912      874     2019-10-18      [1147, 1148_да]      2  нет
# 920      881     2019-06-24      [1156, 1157_да]      2  нет
# 927      897     2011-01-17      [1164, 1165_да]      2  нет
# 930      898     2011-09-22      [1168, 1169_да]      2  нет
# 937      905     2010-10-28      [1176, 1177_да]      2  нет
# 938      906     2010-11-26      [1178, 1179_да]      2  нет
# 943      909     2011-01-10      [1184, 1185_да]      2  нет
# 944      909     2014-07-03  [1186_збс, 1187_да]      2   да
# 948      922     2011-12-14      [1191, 1192_да]      2  нет
# 953      926     2011-03-28      [1197, 1198_да]      2  нет
# 957      936     2008-09-27      [1202, 1203_да]      2  нет
# 960       96     2019-07-31      [1206, 1207_да]      2  нет
# 963       99     2019-11-01      [1210, 1211_да]      2  нет

# %%
final_double.head(60)
# Out:
#     Скважина Дата ВНР после              index  длина  збс
# 0          1     2016-03-12          [0, 1_да]      2  нет
# 3       1004     2011-02-04          [4, 5_да]      2  нет
# 6       1005     2011-08-31          [8, 9_да]      2  нет
# 12      1092     2010-07-21        [15, 16_да]      2  нет
# 13        11     2009-04-01        [17, 18_да]      2  нет
# 15      1111     2015-03-27        [20, 21_да]      2  нет
# 16      1112     2015-05-07        [22, 23_да]      2  нет
# 17      1113     2015-06-16        [24, 25_да]      2  нет
# 18      1122     2020-03-03        [26, 27_да]      2  нет
# 19      1123     2020-03-31        [28, 29_да]      2  нет
# 20      1124     2020-03-17        [30, 31_да]      2  нет
# 22      1126     2019-10-05        [33, 34_да]      2  нет
# 23      1128     2019-11-08        [35, 36_да]      2  нет
# 24      1129     2020-01-02        [37, 38_да]      2  нет
# 31       122     2008-10-25        [45, 46_да]      2  нет
# 32      1220     2010-08-31        [47, 48_да]      2  нет
# 34      1221     2011-04-30        [50, 51_да]      2  нет
# 38      1224     2010-11-14        [55, 56_да]      2  нет
# 51      1259     2009-03-29        [69, 70_да]      2  нет
# 57       128     2014-03-13        [76, 77_да]      2  нет
# 66      1302     2010-07-22        [86, 87_да]      2  нет
# 67      1304     2014-07-20    [88_збс, 89_да]      2   да
# 68       131     2009-04-02        [90, 91_да]      2  нет
# 73      1311     2012-02-24    [96_збс, 97_да]      2   да
# 78       133     2013-10-11      [102, 103_да]      2  нет
# 79       133     2014-06-16  [104_збс, 105_да]      2   да
# 85      1341     2017-03-27      [111, 112_да]      2  нет
# 101     1384     2009-06-27      [128, 129_да]      2  нет
# 102     1385     2009-07-31      [130, 131_да]      2  нет
# 105     1386     2009-07-15      [134, 135_да]      2  нет
# 107      139     2012-03-23      [137, 138_да]      2  нет
# 111       14     2014-10-21  [142_збс, 143_да]      2   да
# 122      144     2016-03-17      [154, 155_да]      2  нет
# 130      148     2012-09-09      [163, 164_да]      2  нет
# 134       15     2007-12-11      [168, 169_да]      2  нет
# 142     1502     2013-01-24      [177, 178_да]      2  нет
# 144     1503     2014-08-07  [180_збс, 181_да]      2   да
# 146     1504     2012-10-07      [183, 184_да]      2  нет
# 147     1505     2012-11-30      [185, 186_да]      2  нет
# 158     1511     2014-10-10      [197, 198_да]      2  нет
# 161     1513     2014-11-26      [201, 202_да]      2  нет
# 162     1521     2009-06-30      [203, 204_да]      2  нет
# 166      153     2009-03-26      [208, 209_да]      2  нет
# 174     1549     2010-06-22      [217, 218_да]      2  нет
# 177     1549     2021-11-02  [221_збс, 222_да]      2   да
# 183     1555     2018-05-24      [228, 229_да]      2  нет
# 187    1556Л     2018-10-05      [233, 234_да]      2  нет
# 188     1557     2018-07-29      [235, 236_да]      2  нет
# 189     1559     2018-08-22      [237, 238_да]      2  нет
# 190     1560     2018-08-22      [239, 240_да]      2  нет
# 191     1561     2018-10-05      [241, 242_да]      2  нет
# 192     1562     2010-07-23      [243, 244_да]      2  нет
# 200       16     2007-02-28      [252, 253_да]      2  нет
# 201     1602     2016-05-06      [254, 255_да]      2  нет
# 203     1605     2016-09-05      [257, 258_да]      2  нет
# 204     1606     2016-08-22      [259, 260_да]      2  нет
# 205     1607     2016-10-22      [261, 262_да]      2  нет
# 206     1608     2016-07-06      [263, 264_да]      2  нет
# 207     1609     2016-12-27      [265, 266_да]      2  нет
# 208     1610     2016-09-12      [267, 268_да]      2  нет

# %%
final_double_zbs= final_double.drop(final_double[final_double['збс'] == 'нет'].index).reset_index(drop=True)
final_double_zbs
# Out:
#    Скважина Дата ВНР после                index  длина збс
# 0      1304     2014-07-20      [88_збс, 89_да]      2  да
# 1      1311     2012-02-24      [96_збс, 97_да]      2  да
# 2       133     2014-06-16    [104_збс, 105_да]      2  да
# 3        14     2014-10-21    [142_збс, 143_да]      2  да
# 4      1503     2014-08-07    [180_збс, 181_да]      2  да
# 5      1549     2021-11-02    [221_збс, 222_да]      2  да
# 6      173Р     2014-07-16    [327_збс, 328_да]      2  да
# 7      1901     2018-08-02    [347_збс, 348_да]      2  да
# 8        35     2014-08-25    [475_збс, 476_да]      2  да
# 9      3552     2014-08-23    [479_збс, 480_да]      2  да
# 10     3825     2014-09-30    [519_збс, 520_да]      2  да
# 11      415     2018-12-26    [554_збс, 555_да]      2  да
# 12      454     2014-06-19    [624_збс, 625_да]      2  да
# 13      459     2014-06-28    [637_збс, 638_да]      2  да
# 14      463     2014-11-17    [645_збс, 646_да]      2  да
# 15      491     2014-11-05    [700_збс, 701_да]      2  да
# 16      494     2015-06-21    [708_збс, 709_да]      2  да
# 17        5     2018-05-05    [726_збс, 727_да]      2  да
# 18      515     2015-07-19    [752_збс, 753_да]      2  да
# 19      541     2014-03-27    [775_збс, 776_да]      2  да
# 20      603     2011-04-01    [861_збс, 862_да]      2  да
# 21      626     2014-09-22    [900_збс, 901_да]      2  да
# 22      675     2014-08-21    [955_збс, 956_да]      2  да
# 23      720     2014-12-23  [1002_збс, 1003_да]      2  да
# 24      729     2017-07-11  [1026_збс, 1027_да]      2  да
# 25      739     2015-04-30  [1050_збс, 1051_да]      2  да
# 26      762     2014-02-27  [1077_збс, 1078_да]      2  да
# 27        8     2014-09-21  [1115_збс, 1116_да]      2  да
# 28      806     2015-06-26  [1123_збс, 1124_да]      2  да
# 29       84     2014-08-01  [1130_збс, 1131_да]      2  да
# 30      909     2014-07-03  [1186_збс, 1187_да]      2  да

# %%
welles_zbs=[]
for i in final_double_zbs['index']:
    welles_zbs+=i
welles_zbs
# Out:
# ['88_збс',
#  '89_да',
#  '96_збс',
#  '97_да',
#  '104_збс',
#  '105_да',
#  '142_збс',
#  '143_да',
#  '180_збс',
#  '181_да',
#  '221_збс',
#  '222_да',
#  '327_збс',
#  '328_да',
#  '347_збс',
#  '348_да',
#  '475_збс',
#  '476_да',
#  '479_збс',
#  '480_да',
#  '519_збс',
#  '520_да',
#  '554_збс',
#  '555_да',
#  '624_збс',
#  '625_да',
#  '637_збс',
#  '638_да',
#  '645_збс',
#  '646_да',
#  '700_збс',
#  '701_да',
#  '708_збс',
#  '709_да',
#  '726_збс',
#  '727_да',
#  '752_збс',
#  '753_да',
#  '775_збс',
#  '776_да',
#  '861_збс',
#  '862_да',
#  '900_збс',
#  '901_да',
#  '955_збс',
#  '956_да',
#  '1002_збс',
#  '1003_да',
#  '1026_збс',
#  '1027_да',
#  '1050_збс',
#  '1051_да',
#  '1077_збс',
#  '1078_да',
#  '1115_збс',
#  '1116_да',
#  '1123_збс',
#  '1124_да',
#  '1130_збс',
#  '1131_да',
#  '1186_збс',
#  '1187_да']

# %%
welles_zbs_corr=[]
for i in welles_zbs:
    if 'да' in i:
        welles_zbs_corr.append(i)
welles_zbs_corr
# Out:
# ['89_да',
#  '97_да',
#  '105_да',
#  '143_да',
#  '181_да',
#  '222_да',
#  '328_да',
#  '348_да',
#  '476_да',
#  '480_да',
#  '520_да',
#  '555_да',
#  '625_да',
#  '638_да',
#  '646_да',
#  '701_да',
#  '709_да',
#  '727_да',
#  '753_да',
#  '776_да',
#  '862_да',
#  '901_да',
#  '956_да',
#  '1003_да',
#  '1027_да',
#  '1051_да',
#  '1078_да',
#  '1116_да',
#  '1124_да',
#  '1131_да',
#  '1187_да']

# %%
welles_zbs_incorr=[]
for i in welles_zbs:
    if 'да' not in i:
        welles_zbs_incorr.append(i)
welles_zbs_incorr
# Out:
# ['88_збс',
#  '96_збс',
#  '104_збс',
#  '142_збс',
#  '180_збс',
#  '221_збс',
#  '327_збс',
#  '347_збс',
#  '475_збс',
#  '479_збс',
#  '519_збс',
#  '554_збс',
#  '624_збс',
#  '637_збс',
#  '645_збс',
#  '700_збс',
#  '708_збс',
#  '726_збс',
#  '752_збс',
#  '775_збс',
#  '861_збс',
#  '900_збс',
#  '955_збс',
#  '1002_збс',
#  '1026_збс',
#  '1050_збс',
#  '1077_збс',
#  '1115_збс',
#  '1123_збс',
#  '1130_збс',
#  '1186_збс']

# %%
final_number = final_number[~final_number['index'].isin(welles_zbs_corr)].reset_index(drop=True)
final_number
# Out:
#      Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0           1  ВНС                       Ю3     0.000000  2016-03-12 00:00:00
# 1           1  ГРП                       Ю3     0.000000  2016-03-12 00:00:00
# 2          10  ВНС                       Ю3     0.000000  2008-10-12 00:00:00
# 3          10  ГРП                       Ю3     0.000000  2013-03-03 00:00:00
# 4        1004  ВНС                       Ю3     0.000000  2011-02-04 00:00:00
# ...       ...  ...                      ...          ...                  ...
# 1176       96  ГРП                       Ю3     0.000000  2019-07-31 00:00:00
# 1177      971  ВНС                       Ю3   762.377859  2012-04-19 00:00:00
# 1178      971  ГРП                       Ю3   762.377859  2013-01-23 00:00:00
# 1179       99  ВНС                       Ю3     0.000000  2019-11-01 00:00:00
# 1180       99  ГРП                       Ю3     0.000000  2019-11-01 00:00:00
#
#       Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                        0                   0                           0
# 1                      100                   4                         100
# 2                        0                   0                           0
# 3                      100                   4                         100
# 4                        0                   0                           0
# ...                    ...                 ...                         ...
# 1176                   100                   4                         100
# 1177                     0                   0                           0
# 1178                   100                   4                         100
# 1179                     0                   0                           0
# 1180                   100                   4                         100
#
#       Число стадий ГРП ГС/ННС    index
# 0                    0    ННС        0
# 1                    1    ННС     1_да
# 2                    0    ННС        2
# 3                    1    ННС     3_да
# 4                    0    ННС        4
# ...                ...    ...      ...
# 1176                 1    ННС  1207_да
# 1177                 0     ГС     1208
# 1178                 1     ГС  1209_да
# 1179                 0    ННС     1210
# 1180                 1    ННС  1211_да
#
# [1181 rows x 11 columns]

# %%
final_number['Тип'] = final_number.apply(
            lambda x:
            str(x['Тип'])
            + ('+ГРП' if x['index'] in welles_zbs_incorr else ''),
            axis=1
        )
final_number['ГС/ННС'] = final_number.apply(
            lambda x:
            str(x['ГС/ННС'])
            + ('+ГРП' if x['index'] in welles_zbs_incorr else ''),
            axis=1
        )
final_number
# Out:
#      Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0           1  ВНС                       Ю3     0.000000  2016-03-12 00:00:00
# 1           1  ГРП                       Ю3     0.000000  2016-03-12 00:00:00
# 2          10  ВНС                       Ю3     0.000000  2008-10-12 00:00:00
# 3          10  ГРП                       Ю3     0.000000  2013-03-03 00:00:00
# 4        1004  ВНС                       Ю3     0.000000  2011-02-04 00:00:00
# ...       ...  ...                      ...          ...                  ...
# 1176       96  ГРП                       Ю3     0.000000  2019-07-31 00:00:00
# 1177      971  ВНС                       Ю3   762.377859  2012-04-19 00:00:00
# 1178      971  ГРП                       Ю3   762.377859  2013-01-23 00:00:00
# 1179       99  ВНС                       Ю3     0.000000  2019-11-01 00:00:00
# 1180       99  ГРП                       Ю3     0.000000  2019-11-01 00:00:00
#
#       Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                        0                   0                           0
# 1                      100                   4                         100
# 2                        0                   0                           0
# 3                      100                   4                         100
# 4                        0                   0                           0
# ...                    ...                 ...                         ...
# 1176                   100                   4                         100
# 1177                     0                   0                           0
# 1178                   100                   4                         100
# 1179                     0                   0                           0
# 1180                   100                   4                         100
#
#       Число стадий ГРП ГС/ННС    index
# 0                    0    ННС        0
# 1                    1    ННС     1_да
# 2                    0    ННС        2
# 3                    1    ННС     3_да
# 4                    0    ННС        4
# ...                ...    ...      ...
# 1176                 1    ННС  1207_да
# 1177                 0     ГС     1208
# 1178                 1     ГС  1209_да
# 1179                 0    ННС     1210
# 1180                 1    ННС  1211_да
#
# [1181 rows x 11 columns]

# %%
final_number.loc[final_number['Тип'] == '3БС+ГРП']
# Out:
#      Скважина      Тип Объект разработки до ГТМ  Длина ГС, м  \
# 88       1304  3БС+ГРП                       Ю3   261.283371
# 95       1311  3БС+ГРП                       Ю3     0.000000
# 102       133  3БС+ГРП                       Ю3   331.593124
# 139        14  3БС+ГРП                       Ю3   253.822773
# 176      1503  3БС+ГРП                       Ю3   252.873486
# 216      1549  3БС+ГРП                       Ю3   352.434391
# 321      173Р  3БС+ГРП                       Ю3   235.053185
# 340      1901  3БС+ГРП                       Ю3   178.370401
# 467        35  3БС+ГРП                       Ю3   177.552809
# 470      3552  3БС+ГРП                       Ю3   209.973808
# 509      3825  3БС+ГРП                       Ю3   314.760226
# 543       415  3БС+ГРП                       Ю3   349.676994
# 612       454  3БС+ГРП                       Ю3   250.241883
# 624       459  3БС+ГРП                       Ю3   290.759351
# 631       463  3БС+ГРП                       Ю3   249.647752
# 685       491  3БС+ГРП                       Ю3   275.116339
# 692       494  3БС+ГРП                       Ю3     0.000000
# 709         5  3БС+ГРП                       Ю3   346.101141
# 734       515  3БС+ГРП                       Ю3   266.270539
# 756       541  3БС+ГРП                       Ю3   132.230859
# 841       603  3БС+ГРП                       Ю3     0.000000
# 879       626  3БС+ГРП                       Ю3   350.864646
# 933       675  3БС+ГРП                       Ю3   242.985596
# 979       720  3БС+ГРП                       Ю3   239.708156
# 1002      729  3БС+ГРП                       Ю3   346.978385
# 1025      739  3БС+ГРП                       Ю3   314.039806
# 1051      762  3БС+ГРП                       Ю3   289.458114
# 1088        8  3БС+ГРП                       Ю3   255.219513
# 1095      806  3БС+ГРП                       Ю3     0.000000
# 1101       84  3БС+ГРП                       Ю3   238.298133
# 1156      909  3БС+ГРП                       Ю3   294.803324
#
#            Дата ВНР после  Полудлина трещины, м  Ширина трещины, мм  \
# 88    2014-07-20 00:00:00                   100                   4
# 95    2012-02-24 00:00:00                   100                   4
# 102   2014-06-16 00:00:00                   100                   4
# 139   2014-10-21 00:00:00                   100                   4
# 176   2014-08-07 00:00:00                   100                   4
# 216   2021-11-02 00:00:00                   100                   4
# 321   2014-07-16 00:00:00                   100                   4
# 340   2018-08-02 00:00:00                   100                   4
# 467   2014-08-25 00:00:00                   100                   4
# 470   2014-08-23 00:00:00                   100                   4
# 509   2014-09-30 00:00:00                   100                   4
# 543   2018-12-26 00:00:00                   100                   4
# 612   2014-06-19 00:00:00                   100                   4
# 624   2014-06-28 00:00:00                   100                   4
# 631   2014-11-17 00:00:00                   100                   4
# 685   2014-11-05 00:00:00                   100                   4
# 692   2015-06-21 00:00:00                   100                   4
# 709   2018-05-05 00:00:00                   100                   4
# 734   2015-07-19 00:00:00                   100                   4
# 756   2014-03-27 00:00:00                   100                   4
# 841   2011-04-01 00:00:00                   100                   4
# 879   2014-09-22 00:00:00                   100                   4
# 933   2014-08-21 00:00:00                   100                   4
# 979   2014-12-23 00:00:00                   100                   4
# 1002  2017-07-11 00:00:00                   100                   4
# 1025  2015-04-30 00:00:00                   100                   4
# 1051  2014-02-27 00:00:00                   100                   4
# 1088  2014-09-21 00:00:00                   100                   4
# 1095  2015-06-26 00:00:00                   100                   4
# 1101  2014-08-01 00:00:00                   100                   4
# 1156  2014-07-03 00:00:00                   100                   4
#
#       Проницаемость проппанта, Д  Число стадий ГРП   ГС/ННС     index
# 88                           100                 1   ГС+ГРП    88_збс
# 95                           100                 1  ННС+ГРП    96_збс
# 102                          100                 1   ГС+ГРП   104_збс
# 139                          100                 1   ГС+ГРП   142_збс
# 176                          100                 1   ГС+ГРП   180_збс
# 216                          100                 1   ГС+ГРП   221_збс
# 321                          100                 1   ГС+ГРП   327_збс
# 340                          100                 1   ГС+ГРП   347_збс
# 467                          100                 1   ГС+ГРП   475_збс
# 470                          100                 1   ГС+ГРП   479_збс
# 509                          100                 1   ГС+ГРП   519_збс
# 543                          100                 1   ГС+ГРП   554_збс
# 612                          100                 1   ГС+ГРП   624_збс
# 624                          100                 1   ГС+ГРП   637_збс
# 631                          100                 1   ГС+ГРП   645_збс
# 685                          100                 1   ГС+ГРП   700_збс
# 692                          100                 1  ННС+ГРП   708_збс
# 709                          100                 1   ГС+ГРП   726_збс
# 734                          100                 1   ГС+ГРП   752_збс
# 756                          100                 1   ГС+ГРП   775_збс
# 841                          100                 1  ННС+ГРП   861_збс
# 879                          100                 1   ГС+ГРП   900_збс
# 933                          100                 1   ГС+ГРП   955_збс
# 979                          100                 1   ГС+ГРП  1002_збс
# 1002                         100                 1   ГС+ГРП  1026_збс
# 1025                         100                 1   ГС+ГРП  1050_збс
# 1051                         100                 1   ГС+ГРП  1077_збс
# 1088                         100                 1   ГС+ГРП  1115_збс
# 1095                         100                 1  ННС+ГРП  1123_збс
# 1101                         100                 1   ГС+ГРП  1130_збс
# 1156                         100                 1   ГС+ГРП  1186_збс

# %%
final_double_nns= final_double.drop(final_double[final_double['збс'] == 'да'].index).reset_index(drop=True)
final_double_nns
# Out:
#     Скважина Дата ВНР после            index  длина  збс
# 0          1     2016-03-12        [0, 1_да]      2  нет
# 1       1004     2011-02-04        [4, 5_да]      2  нет
# 2       1005     2011-08-31        [8, 9_да]      2  нет
# 3       1092     2010-07-21      [15, 16_да]      2  нет
# 4         11     2009-04-01      [17, 18_да]      2  нет
# ..       ...            ...              ...    ...  ...
# 212      922     2011-12-14  [1191, 1192_да]      2  нет
# 213      926     2011-03-28  [1197, 1198_да]      2  нет
# 214      936     2008-09-27  [1202, 1203_да]      2  нет
# 215       96     2019-07-31  [1206, 1207_да]      2  нет
# 216       99     2019-11-01  [1210, 1211_да]      2  нет
#
# [217 rows x 5 columns]

# %%
final_double_nns.head(60)
# Out:
#    Скважина Дата ВНР после          index  длина  збс
# 0         1     2016-03-12      [0, 1_да]      2  нет
# 1      1004     2011-02-04      [4, 5_да]      2  нет
# 2      1005     2011-08-31      [8, 9_да]      2  нет
# 3      1092     2010-07-21    [15, 16_да]      2  нет
# 4        11     2009-04-01    [17, 18_да]      2  нет
# 5      1111     2015-03-27    [20, 21_да]      2  нет
# 6      1112     2015-05-07    [22, 23_да]      2  нет
# 7      1113     2015-06-16    [24, 25_да]      2  нет
# 8      1122     2020-03-03    [26, 27_да]      2  нет
# 9      1123     2020-03-31    [28, 29_да]      2  нет
# 10     1124     2020-03-17    [30, 31_да]      2  нет
# 11     1126     2019-10-05    [33, 34_да]      2  нет
# 12     1128     2019-11-08    [35, 36_да]      2  нет
# 13     1129     2020-01-02    [37, 38_да]      2  нет
# 14      122     2008-10-25    [45, 46_да]      2  нет
# 15     1220     2010-08-31    [47, 48_да]      2  нет
# 16     1221     2011-04-30    [50, 51_да]      2  нет
# 17     1224     2010-11-14    [55, 56_да]      2  нет
# 18     1259     2009-03-29    [69, 70_да]      2  нет
# 19      128     2014-03-13    [76, 77_да]      2  нет
# 20     1302     2010-07-22    [86, 87_да]      2  нет
# 21      131     2009-04-02    [90, 91_да]      2  нет
# 22      133     2013-10-11  [102, 103_да]      2  нет
# 23     1341     2017-03-27  [111, 112_да]      2  нет
# 24     1384     2009-06-27  [128, 129_да]      2  нет
# 25     1385     2009-07-31  [130, 131_да]      2  нет
# 26     1386     2009-07-15  [134, 135_да]      2  нет
# 27      139     2012-03-23  [137, 138_да]      2  нет
# 28      144     2016-03-17  [154, 155_да]      2  нет
# 29      148     2012-09-09  [163, 164_да]      2  нет
# 30       15     2007-12-11  [168, 169_да]      2  нет
# 31     1502     2013-01-24  [177, 178_да]      2  нет
# 32     1504     2012-10-07  [183, 184_да]      2  нет
# 33     1505     2012-11-30  [185, 186_да]      2  нет
# 34     1511     2014-10-10  [197, 198_да]      2  нет
# 35     1513     2014-11-26  [201, 202_да]      2  нет
# 36     1521     2009-06-30  [203, 204_да]      2  нет
# 37      153     2009-03-26  [208, 209_да]      2  нет
# 38     1549     2010-06-22  [217, 218_да]      2  нет
# 39     1555     2018-05-24  [228, 229_да]      2  нет
# 40    1556Л     2018-10-05  [233, 234_да]      2  нет
# 41     1557     2018-07-29  [235, 236_да]      2  нет
# 42     1559     2018-08-22  [237, 238_да]      2  нет
# 43     1560     2018-08-22  [239, 240_да]      2  нет
# 44     1561     2018-10-05  [241, 242_да]      2  нет
# 45     1562     2010-07-23  [243, 244_да]      2  нет
# 46       16     2007-02-28  [252, 253_да]      2  нет
# 47     1602     2016-05-06  [254, 255_да]      2  нет
# 48     1605     2016-09-05  [257, 258_да]      2  нет
# 49     1606     2016-08-22  [259, 260_да]      2  нет
# 50     1607     2016-10-22  [261, 262_да]      2  нет
# 51     1608     2016-07-06  [263, 264_да]      2  нет
# 52     1609     2016-12-27  [265, 266_да]      2  нет
# 53     1610     2016-09-12  [267, 268_да]      2  нет
# 54     1611     2017-01-11  [269, 270_да]      2  нет
# 55     1620     2016-04-20  [273, 274_да]      2  нет
# 56     1621     2016-04-18  [275, 276_да]      2  нет
# 57     1622     2016-07-31  [277, 278_да]      2  нет
# 58     1623     2016-06-13  [281, 282_да]      2  нет
# 59     1625     2016-08-06  [283, 284_да]      2  нет

# %%
welles=[]
for i in final_double_nns['index']:
    welles+=i
welles
# Out:
# ['0',
#  '1_да',
#  '4',
#  '5_да',
#  '8',
#  '9_да',
#  '15',
#  '16_да',
#  '17',
#  '18_да',
#  '20',
#  '21_да',
#  '22',
#  '23_да',
#  '24',
#  '25_да',
#  '26',
#  '27_да',
#  '28',
#  '29_да',
#  '30',
#  '31_да',
#  '33',
#  '34_да',
#  '35',
#  '36_да',
#  '37',
#  '38_да',
#  '45',
#  '46_да',
#  '47',
#  '48_да',
#  '50',
#  '51_да',
#  '55',
#  '56_да',
#  '69',
#  '70_да',
#  '76',
#  '77_да',
#  '86',
#  '87_да',
#  '90',
#  '91_да',
#  '102',
#  '103_да',
#  '111',
#  '112_да',
#  '128',
#  '129_да',
#  '130',
#  '131_да',
#  '134',
#  '135_да',
#  '137',
#  '138_да',
#  '154',
#  '155_да',
#  '163',
#  '164_да',
#  '168',
#  '169_да',
#  '177',
#  '178_да',
#  '183',
#  '184_да',
#  '185',
#  '186_да',
#  '197',
#  '198_да',
#  '201',
#  '202_да',
#  '203',
#  '204_да',
#  '208',
#  '209_да',
#  '217',
#  '218_да',
#  '228',
#  '229_да',
#  '233',
#  '234_да',
#  '235',
#  '236_да',
#  '237',
#  '238_да',
#  '239',
#  '240_да',
#  '241',
#  '242_да',
#  '243',
#  '244_да',
#  '252',
#  '253_да',
#  '254',
#  '255_да',
#  '257',
#  '258_да',
#  '259',
#  '260_да',
#  '261',
#  '262_да',
#  '263',
#  '264_да',
#  '265',
#  '266_да',
#  '267',
#  '268_да',
#  '269',
#  '270_да',
#  '273',
#  '274_да',
#  '275',
#  '276_да',
#  '277',
#  '278_да',
#  '281',
#  '282_да',
#  '283',
#  '284_да',
#  '285',
#  '286_да',
#  '287',
#  '288_да',
#  '289',
#  '290_да',
#  '291',
#  '292_да',
#  '293',
#  '294_да',
#  '295',
#  '296_да',
#  '297',
#  '298_да',
#  '299',
#  '300_да',
#  '304',
#  '305_да',
#  '306',
#  '307_да',
#  '313',
#  '314_да',
#  '316',
#  '317_да',
#  '318',
#  '319_да',
#  '320',
#  '321_да',
#  '322',
#  '323_да',
#  '329',
#  '330_да',
#  '331',
#  '332_да',
#  '333',
#  '334_да',
#  '342',
#  '343_да',
#  '345',
#  '346_да',
#  '350',
#  '351_да',
#  '352',
#  '353_да',
#  '355',
#  '356_да',
#  '357',
#  '358_да',
#  '359',
#  '360_да',
#  '362',
#  '363_да',
#  '365',
#  '366_да',
#  '368',
#  '369_да',
#  '370',
#  '371_да',
#  '374',
#  '375_да',
#  '385',
#  '386_да',
#  '395',
#  '396_да',
#  '414',
#  '415_да',
#  '429',
#  '430_да',
#  '431',
#  '432_да',
#  '440',
#  '441_да',
#  '442',
#  '443_да',
#  '450',
#  '451_да',
#  '452',
#  '453_да',
#  '459',
#  '460_да',
#  '463',
#  '464_да',
#  '465',
#  '466_да',
#  '467',
#  '468_да',
#  '472',
#  '473_да',
#  '481',
#  '482_да',
#  '489',
#  '490_да',
#  '492',
#  '493_да',
#  '494',
#  '495_да',
#  '498',
#  '499_да',
#  '500',
#  '501_да',
#  '502',
#  '503_да',
#  '504',
#  '505_да',
#  '508',
#  '509_да',
#  '514',
#  '515_да',
#  '521',
#  '522_да',
#  '524',
#  '525_да',
#  '528',
#  '529_да',
#  '530',
#  '531_да',
#  '538',
#  '539_да',
#  '540',
#  '541_да',
#  '563',
#  '564_да',
#  '567',
#  '568_да',
#  '572',
#  '573_да',
#  '576',
#  '577_да',
#  '578',
#  '579_да',
#  '580',
#  '581_да',
#  '585',
#  '586_да',
#  '609',
#  '610_да',
#  '612',
#  '613_да',
#  '641',
#  '642_да',
#  '643',
#  '644_да',
#  '647',
#  '648_да',
#  '649',
#  '650_да',
#  '660',
#  '661_да',
#  '662',
#  '663_да',
#  '664',
#  '665_да',
#  '668',
#  '669_да',
#  '697',
#  '698_да',
#  '706',
#  '707_да',
#  '711',
#  '712_да',
#  '714',
#  '715_да',
#  '723',
#  '724_да',
#  '734',
#  '735_да',
#  '744',
#  '745_да',
#  '755',
#  '756_да',
#  '757',
#  '758_да',
#  '759',
#  '760_да',
#  '763',
#  '764_да',
#  '777',
#  '778_да',
#  '783',
#  '784_да',
#  '790',
#  '791_да',
#  '795',
#  '796_да',
#  '797',
#  '798_да',
#  '801',
#  '802_да',
#  '805',
#  '806_да',
#  '807',
#  '808_да',
#  '812',
#  '813_да',
#  '815',
#  '816_да',
#  '827',
#  '828_да',
#  '838',
#  '839_да',
#  '846',
#  '847_да',
#  '857',
#  '858_да',
#  '863',
#  '864_да',
#  '898',
#  '899_да',
#  '902',
#  '903_да',
#  '905',
#  '906_да',
#  '916',
#  '917_да',
#  '921',
#  '922_да',
#  '924',
#  '925_да',
#  '926',
#  '927_да',
#  '928',
#  '929_да',
#  '930',
#  '931_да',
#  '938',
#  '939_да',
#  '940',
#  '941_да',
#  '944',
#  '945_да',
#  '946',
#  '947_да',
#  '948',
#  '949_да',
#  '950',
#  '951_да',
#  '952',
#  '953_да',
#  '958',
#  '959_да',
#  '961',
#  '962_да',
#  '968',
#  '969_да',
#  '971',
#  '972_да',
#  '988',
#  '989_да',
#  '990',
#  '991_да',
#  '992',
#  '993_да',
#  '1000',
#  '1001_да',
#  '1007',
#  '1008_да',
#  '1011',
#  '1012_да',
#  '1014',
#  '1015_да',
#  '1017',
#  '1018_да',
#  '1029',
#  '1030_да',
#  '1032',
#  '1033_да',
#  '1039',
#  '1040_да',
#  '1042',
#  '1043_да',
#  '1047',
#  '1048_да',
#  '1056',
#  '1057_да',
#  '1063',
#  '1064_да',
#  '1086',
#  '1087_да',
#  '1091',
#  '1092_да',
#  '1099',
#  '1100_да',
#  '1107',
#  '1108_да',
#  '1121',
#  '1122_да',
#  '1128',
#  '1129_да',
#  '1142',
#  '1143_да',
#  '1147',
#  '1148_да',
#  '1156',
#  '1157_да',
#  '1164',
#  '1165_да',
#  '1168',
#  '1169_да',
#  '1176',
#  '1177_да',
#  '1178',
#  '1179_да',
#  '1184',
#  '1185_да',
#  '1191',
#  '1192_да',
#  '1197',
#  '1198_да',
#  '1202',
#  '1203_да',
#  '1206',
#  '1207_да',
#  '1210',
#  '1211_да']

# %%
welles_corr=[]
for i in welles:
    if 'да' in i:
        welles_corr.append(i)
welles_corr
# Out:
# ['1_да',
#  '5_да',
#  '9_да',
#  '16_да',
#  '18_да',
#  '21_да',
#  '23_да',
#  '25_да',
#  '27_да',
#  '29_да',
#  '31_да',
#  '34_да',
#  '36_да',
#  '38_да',
#  '46_да',
#  '48_да',
#  '51_да',
#  '56_да',
#  '70_да',
#  '77_да',
#  '87_да',
#  '91_да',
#  '103_да',
#  '112_да',
#  '129_да',
#  '131_да',
#  '135_да',
#  '138_да',
#  '155_да',
#  '164_да',
#  '169_да',
#  '178_да',
#  '184_да',
#  '186_да',
#  '198_да',
#  '202_да',
#  '204_да',
#  '209_да',
#  '218_да',
#  '229_да',
#  '234_да',
#  '236_да',
#  '238_да',
#  '240_да',
#  '242_да',
#  '244_да',
#  '253_да',
#  '255_да',
#  '258_да',
#  '260_да',
#  '262_да',
#  '264_да',
#  '266_да',
#  '268_да',
#  '270_да',
#  '274_да',
#  '276_да',
#  '278_да',
#  '282_да',
#  '284_да',
#  '286_да',
#  '288_да',
#  '290_да',
#  '292_да',
#  '294_да',
#  '296_да',
#  '298_да',
#  '300_да',
#  '305_да',
#  '307_да',
#  '314_да',
#  '317_да',
#  '319_да',
#  '321_да',
#  '323_да',
#  '330_да',
#  '332_да',
#  '334_да',
#  '343_да',
#  '346_да',
#  '351_да',
#  '353_да',
#  '356_да',
#  '358_да',
#  '360_да',
#  '363_да',
#  '366_да',
#  '369_да',
#  '371_да',
#  '375_да',
#  '386_да',
#  '396_да',
#  '415_да',
#  '430_да',
#  '432_да',
#  '441_да',
#  '443_да',
#  '451_да',
#  '453_да',
#  '460_да',
#  '464_да',
#  '466_да',
#  '468_да',
#  '473_да',
#  '482_да',
#  '490_да',
#  '493_да',
#  '495_да',
#  '499_да',
#  '501_да',
#  '503_да',
#  '505_да',
#  '509_да',
#  '515_да',
#  '522_да',
#  '525_да',
#  '529_да',
#  '531_да',
#  '539_да',
#  '541_да',
#  '564_да',
#  '568_да',
#  '573_да',
#  '577_да',
#  '579_да',
#  '581_да',
#  '586_да',
#  '610_да',
#  '613_да',
#  '642_да',
#  '644_да',
#  '648_да',
#  '650_да',
#  '661_да',
#  '663_да',
#  '665_да',
#  '669_да',
#  '698_да',
#  '707_да',
#  '712_да',
#  '715_да',
#  '724_да',
#  '735_да',
#  '745_да',
#  '756_да',
#  '758_да',
#  '760_да',
#  '764_да',
#  '778_да',
#  '784_да',
#  '791_да',
#  '796_да',
#  '798_да',
#  '802_да',
#  '806_да',
#  '808_да',
#  '813_да',
#  '816_да',
#  '828_да',
#  '839_да',
#  '847_да',
#  '858_да',
#  '864_да',
#  '899_да',
#  '903_да',
#  '906_да',
#  '917_да',
#  '922_да',
#  '925_да',
#  '927_да',
#  '929_да',
#  '931_да',
#  '939_да',
#  '941_да',
#  '945_да',
#  '947_да',
#  '949_да',
#  '951_да',
#  '953_да',
#  '959_да',
#  '962_да',
#  '969_да',
#  '972_да',
#  '989_да',
#  '991_да',
#  '993_да',
#  '1001_да',
#  '1008_да',
#  '1012_да',
#  '1015_да',
#  '1018_да',
#  '1030_да',
#  '1033_да',
#  '1040_да',
#  '1043_да',
#  '1048_да',
#  '1057_да',
#  '1064_да',
#  '1087_да',
#  '1092_да',
#  '1100_да',
#  '1108_да',
#  '1122_да',
#  '1129_да',
#  '1143_да',
#  '1148_да',
#  '1157_да',
#  '1165_да',
#  '1169_да',
#  '1177_да',
#  '1179_да',
#  '1185_да',
#  '1192_да',
#  '1198_да',
#  '1203_да',
#  '1207_да',
#  '1211_да']

# %%
welles_incorr=[]
for i in welles:
    if 'да' not in i:
        welles_incorr.append(i)
welles_incorr
# Out:
# ['0',
#  '4',
#  '8',
#  '15',
#  '17',
#  '20',
#  '22',
#  '24',
#  '26',
#  '28',
#  '30',
#  '33',
#  '35',
#  '37',
#  '45',
#  '47',
#  '50',
#  '55',
#  '69',
#  '76',
#  '86',
#  '90',
#  '102',
#  '111',
#  '128',
#  '130',
#  '134',
#  '137',
#  '154',
#  '163',
#  '168',
#  '177',
#  '183',
#  '185',
#  '197',
#  '201',
#  '203',
#  '208',
#  '217',
#  '228',
#  '233',
#  '235',
#  '237',
#  '239',
#  '241',
#  '243',
#  '252',
#  '254',
#  '257',
#  '259',
#  '261',
#  '263',
#  '265',
#  '267',
#  '269',
#  '273',
#  '275',
#  '277',
#  '281',
#  '283',
#  '285',
#  '287',
#  '289',
#  '291',
#  '293',
#  '295',
#  '297',
#  '299',
#  '304',
#  '306',
#  '313',
#  '316',
#  '318',
#  '320',
#  '322',
#  '329',
#  '331',
#  '333',
#  '342',
#  '345',
#  '350',
#  '352',
#  '355',
#  '357',
#  '359',
#  '362',
#  '365',
#  '368',
#  '370',
#  '374',
#  '385',
#  '395',
#  '414',
#  '429',
#  '431',
#  '440',
#  '442',
#  '450',
#  '452',
#  '459',
#  '463',
#  '465',
#  '467',
#  '472',
#  '481',
#  '489',
#  '492',
#  '494',
#  '498',
#  '500',
#  '502',
#  '504',
#  '508',
#  '514',
#  '521',
#  '524',
#  '528',
#  '530',
#  '538',
#  '540',
#  '563',
#  '567',
#  '572',
#  '576',
#  '578',
#  '580',
#  '585',
#  '609',
#  '612',
#  '641',
#  '643',
#  '647',
#  '649',
#  '660',
#  '662',
#  '664',
#  '668',
#  '697',
#  '706',
#  '711',
#  '714',
#  '723',
#  '734',
#  '744',
#  '755',
#  '757',
#  '759',
#  '763',
#  '777',
#  '783',
#  '790',
#  '795',
#  '797',
#  '801',
#  '805',
#  '807',
#  '812',
#  '815',
#  '827',
#  '838',
#  '846',
#  '857',
#  '863',
#  '898',
#  '902',
#  '905',
#  '916',
#  '921',
#  '924',
#  '926',
#  '928',
#  '930',
#  '938',
#  '940',
#  '944',
#  '946',
#  '948',
#  '950',
#  '952',
#  '958',
#  '961',
#  '968',
#  '971',
#  '988',
#  '990',
#  '992',
#  '1000',
#  '1007',
#  '1011',
#  '1014',
#  '1017',
#  '1029',
#  '1032',
#  '1039',
#  '1042',
#  '1047',
#  '1056',
#  '1063',
#  '1086',
#  '1091',
#  '1099',
#  '1107',
#  '1121',
#  '1128',
#  '1142',
#  '1147',
#  '1156',
#  '1164',
#  '1168',
#  '1176',
#  '1178',
#  '1184',
#  '1191',
#  '1197',
#  '1202',
#  '1206',
#  '1210']

# %%
final_number = final_number[~final_number['index'].isin(welles_corr)].reset_index(drop=True)
final_number
# Out:
#     Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0          1  ВНС                       Ю3     0.000000  2016-03-12 00:00:00
# 1         10  ВНС                       Ю3     0.000000  2008-10-12 00:00:00
# 2         10  ГРП                       Ю3     0.000000  2013-03-03 00:00:00
# 3       1004  ВНС                       Ю3     0.000000  2011-02-04 00:00:00
# 4       1004  ГРП                       Ю3     0.000000  2013-01-31 00:00:00
# ..       ...  ...                      ...          ...                  ...
# 959      949  3БС                       Ю3   343.052474  2021-09-24 00:00:00
# 960       96  ВНС                       Ю3     0.000000  2019-07-31 00:00:00
# 961      971  ВНС                       Ю3   762.377859  2012-04-19 00:00:00
# 962      971  ГРП                       Ю3   762.377859  2013-01-23 00:00:00
# 963       99  ВНС                       Ю3     0.000000  2019-11-01 00:00:00
#
#      Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                       0                   0                           0
# 1                       0                   0                           0
# 2                     100                   4                         100
# 3                       0                   0                           0
# 4                     100                   4                         100
# ..                    ...                 ...                         ...
# 959                   100                   4                         100
# 960                     0                   0                           0
# 961                     0                   0                           0
# 962                   100                   4                         100
# 963                     0                   0                           0
#
#      Число стадий ГРП ГС/ННС     index
# 0                   0    ННС         0
# 1                   0    ННС         2
# 2                   1    ННС      3_да
# 3                   0    ННС         4
# 4                   1    ННС      6_да
# ..                ...    ...       ...
# 959                 1     ГС  1205_збс
# 960                 0    ННС      1206
# 961                 0     ГС      1208
# 962                 1     ГС   1209_да
# 963                 0    ННС      1210
#
# [964 rows x 11 columns]

# %%
final_number['ГС/ННС'] = final_number.apply(
            lambda x:
            str(x['ГС/ННС'])
            + ('+ГРП' if x['index'] in welles_incorr else ''),
            axis=1
        )
final_number
# Out:
#     Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0          1  ВНС                       Ю3     0.000000  2016-03-12 00:00:00
# 1         10  ВНС                       Ю3     0.000000  2008-10-12 00:00:00
# 2         10  ГРП                       Ю3     0.000000  2013-03-03 00:00:00
# 3       1004  ВНС                       Ю3     0.000000  2011-02-04 00:00:00
# 4       1004  ГРП                       Ю3     0.000000  2013-01-31 00:00:00
# ..       ...  ...                      ...          ...                  ...
# 959      949  3БС                       Ю3   343.052474  2021-09-24 00:00:00
# 960       96  ВНС                       Ю3     0.000000  2019-07-31 00:00:00
# 961      971  ВНС                       Ю3   762.377859  2012-04-19 00:00:00
# 962      971  ГРП                       Ю3   762.377859  2013-01-23 00:00:00
# 963       99  ВНС                       Ю3     0.000000  2019-11-01 00:00:00
#
#      Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                       0                   0                           0
# 1                       0                   0                           0
# 2                     100                   4                         100
# 3                       0                   0                           0
# 4                     100                   4                         100
# ..                    ...                 ...                         ...
# 959                   100                   4                         100
# 960                     0                   0                           0
# 961                     0                   0                           0
# 962                   100                   4                         100
# 963                     0                   0                           0
#
#      Число стадий ГРП   ГС/ННС     index
# 0                   0  ННС+ГРП         0
# 1                   0      ННС         2
# 2                   1      ННС      3_да
# 3                   0  ННС+ГРП         4
# 4                   1      ННС      6_да
# ..                ...      ...       ...
# 959                 1       ГС  1205_збс
# 960                 0  ННС+ГРП      1206
# 961                 0       ГС      1208
# 962                 1       ГС   1209_да
# 963                 0  ННС+ГРП      1210
#
# [964 rows x 11 columns]

# %%
final_number['Полудлина трещины, м'] = final_number.apply(
            lambda x:
            100 if 'ГРП' in str(x['ГС/ННС'])
            else x['Полудлина трещины, м']
            , axis=1)
final_number['Ширина трещины, мм'] = final_number.apply(
            lambda x:
            4 if 'ГРП' in str(x['ГС/ННС'])
            else x['Ширина трещины, мм']
            , axis=1)
final_number['Проницаемость проппанта, Д'] = final_number.apply(
            lambda x:
            100 if 'ГРП' in str(x['ГС/ННС'])
            else x['Проницаемость проппанта, Д']
            , axis=1)
final_number['Число стадий ГРП'] = final_number.apply(
            lambda x:
            1 if 'ГРП' in str(x['ГС/ННС'])
            else x['Число стадий ГРП']
            , axis=1)
final_number
# Out:
#     Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0          1  ВНС                       Ю3     0.000000  2016-03-12 00:00:00
# 1         10  ВНС                       Ю3     0.000000  2008-10-12 00:00:00
# 2         10  ГРП                       Ю3     0.000000  2013-03-03 00:00:00
# 3       1004  ВНС                       Ю3     0.000000  2011-02-04 00:00:00
# 4       1004  ГРП                       Ю3     0.000000  2013-01-31 00:00:00
# ..       ...  ...                      ...          ...                  ...
# 959      949  3БС                       Ю3   343.052474  2021-09-24 00:00:00
# 960       96  ВНС                       Ю3     0.000000  2019-07-31 00:00:00
# 961      971  ВНС                       Ю3   762.377859  2012-04-19 00:00:00
# 962      971  ГРП                       Ю3   762.377859  2013-01-23 00:00:00
# 963       99  ВНС                       Ю3     0.000000  2019-11-01 00:00:00
#
#      Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     100                   4                         100
# 1                       0                   0                           0
# 2                     100                   4                         100
# 3                     100                   4                         100
# 4                     100                   4                         100
# ..                    ...                 ...                         ...
# 959                   100                   4                         100
# 960                   100                   4                         100
# 961                     0                   0                           0
# 962                   100                   4                         100
# 963                   100                   4                         100
#
#      Число стадий ГРП   ГС/ННС     index
# 0                   1  ННС+ГРП         0
# 1                   0      ННС         2
# 2                   1      ННС      3_да
# 3                   1  ННС+ГРП         4
# 4                   1      ННС      6_да
# ..                ...      ...       ...
# 959                 1       ГС  1205_збс
# 960                 1  ННС+ГРП      1206
# 961                 0       ГС      1208
# 962                 1       ГС   1209_да
# 963                 1  ННС+ГРП      1210
#
# [964 rows x 11 columns]

# %%
final_number['Тип'] = final_number.apply(
            lambda x:
            'ГРП' if 'ГРП' in str(x['ГС/ННС']) and str(x['Тип'])!='3БС+ГРП'
            else x['Тип']
            , axis=1)
final_number
# Out:
#     Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0          1  ГРП                       Ю3     0.000000  2016-03-12 00:00:00
# 1         10  ВНС                       Ю3     0.000000  2008-10-12 00:00:00
# 2         10  ГРП                       Ю3     0.000000  2013-03-03 00:00:00
# 3       1004  ГРП                       Ю3     0.000000  2011-02-04 00:00:00
# 4       1004  ГРП                       Ю3     0.000000  2013-01-31 00:00:00
# ..       ...  ...                      ...          ...                  ...
# 959      949  3БС                       Ю3   343.052474  2021-09-24 00:00:00
# 960       96  ГРП                       Ю3     0.000000  2019-07-31 00:00:00
# 961      971  ВНС                       Ю3   762.377859  2012-04-19 00:00:00
# 962      971  ГРП                       Ю3   762.377859  2013-01-23 00:00:00
# 963       99  ГРП                       Ю3     0.000000  2019-11-01 00:00:00
#
#      Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                     100                   4                         100
# 1                       0                   0                           0
# 2                     100                   4                         100
# 3                     100                   4                         100
# 4                     100                   4                         100
# ..                    ...                 ...                         ...
# 959                   100                   4                         100
# 960                   100                   4                         100
# 961                     0                   0                           0
# 962                   100                   4                         100
# 963                   100                   4                         100
#
#      Число стадий ГРП   ГС/ННС     index
# 0                   1  ННС+ГРП         0
# 1                   0      ННС         2
# 2                   1      ННС      3_да
# 3                   1  ННС+ГРП         4
# 4                   1      ННС      6_да
# ..                ...      ...       ...
# 959                 1       ГС  1205_збс
# 960                 1  ННС+ГРП      1206
# 961                 0       ГС      1208
# 962                 1       ГС   1209_да
# 963                 1  ННС+ГРП      1210
#
# [964 rows x 11 columns]

# %%
final_number.loc[final_number['Тип'] == '3БС+ГРП']
# Out:
#     Скважина      Тип Объект разработки до ГТМ  Длина ГС, м  \
# 67      1304  3БС+ГРП                       Ю3   261.283371
# 73      1311  3БС+ГРП                       Ю3     0.000000
# 79       133  3БС+ГРП                       Ю3   331.593124
# 111       14  3БС+ГРП                       Ю3   253.822773
# 144     1503  3БС+ГРП                       Ю3   252.873486
# 177     1549  3БС+ГРП                       Ю3   352.434391
# 246     173Р  3БС+ГРП                       Ю3   235.053185
# 260     1901  3БС+ГРП                       Ю3   178.370401
# 363       35  3БС+ГРП                       Ю3   177.552809
# 366     3552  3БС+ГРП                       Ю3   209.973808
# 395     3825  3БС+ГРП                       Ю3   314.760226
# 423      415  3БС+ГРП                       Ю3   349.676994
# 483      454  3БС+ГРП                       Ю3   250.241883
# 495      459  3БС+ГРП                       Ю3   290.759351
# 500      463  3БС+ГРП                       Ю3   249.647752
# 547      491  3БС+ГРП                       Ю3   275.116339
# 553      494  3БС+ГРП                       Ю3     0.000000
# 567        5  3БС+ГРП                       Ю3   346.101141
# 590      515  3БС+ГРП                       Ю3   266.270539
# 608      541  3БС+ГРП                       Ю3   132.230859
# 679      603  3БС+ГРП                       Ю3     0.000000
# 715      626  3БС+ГРП                       Ю3   350.864646
# 754      675  3БС+ГРП                       Ю3   242.985596
# 792      720  3БС+ГРП                       Ю3   239.708156
# 811      729  3БС+ГРП                       Ю3   346.978385
# 829      739  3БС+ГРП                       Ю3   314.039806
# 853      762  3БС+ГРП                       Ю3   289.458114
# 886        8  3БС+ГРП                       Ю3   255.219513
# 892      806  3БС+ГРП                       Ю3     0.000000
# 897       84  3БС+ГРП                       Ю3   238.298133
# 944      909  3БС+ГРП                       Ю3   294.803324
#
#           Дата ВНР после  Полудлина трещины, м  Ширина трещины, мм  \
# 67   2014-07-20 00:00:00                   100                   4
# 73   2012-02-24 00:00:00                   100                   4
# 79   2014-06-16 00:00:00                   100                   4
# 111  2014-10-21 00:00:00                   100                   4
# 144  2014-08-07 00:00:00                   100                   4
# 177  2021-11-02 00:00:00                   100                   4
# 246  2014-07-16 00:00:00                   100                   4
# 260  2018-08-02 00:00:00                   100                   4
# 363  2014-08-25 00:00:00                   100                   4
# 366  2014-08-23 00:00:00                   100                   4
# 395  2014-09-30 00:00:00                   100                   4
# 423  2018-12-26 00:00:00                   100                   4
# 483  2014-06-19 00:00:00                   100                   4
# 495  2014-06-28 00:00:00                   100                   4
# 500  2014-11-17 00:00:00                   100                   4
# 547  2014-11-05 00:00:00                   100                   4
# 553  2015-06-21 00:00:00                   100                   4
# 567  2018-05-05 00:00:00                   100                   4
# 590  2015-07-19 00:00:00                   100                   4
# 608  2014-03-27 00:00:00                   100                   4
# 679  2011-04-01 00:00:00                   100                   4
# 715  2014-09-22 00:00:00                   100                   4
# 754  2014-08-21 00:00:00                   100                   4
# 792  2014-12-23 00:00:00                   100                   4
# 811  2017-07-11 00:00:00                   100                   4
# 829  2015-04-30 00:00:00                   100                   4
# 853  2014-02-27 00:00:00                   100                   4
# 886  2014-09-21 00:00:00                   100                   4
# 892  2015-06-26 00:00:00                   100                   4
# 897  2014-08-01 00:00:00                   100                   4
# 944  2014-07-03 00:00:00                   100                   4
#
#      Проницаемость проппанта, Д  Число стадий ГРП   ГС/ННС     index
# 67                          100                 1   ГС+ГРП    88_збс
# 73                          100                 1  ННС+ГРП    96_збс
# 79                          100                 1   ГС+ГРП   104_збс
# 111                         100                 1   ГС+ГРП   142_збс
# 144                         100                 1   ГС+ГРП   180_збс
# 177                         100                 1   ГС+ГРП   221_збс
# 246                         100                 1   ГС+ГРП   327_збс
# 260                         100                 1   ГС+ГРП   347_збс
# 363                         100                 1   ГС+ГРП   475_збс
# 366                         100                 1   ГС+ГРП   479_збс
# 395                         100                 1   ГС+ГРП   519_збс
# 423                         100                 1   ГС+ГРП   554_збс
# 483                         100                 1   ГС+ГРП   624_збс
# 495                         100                 1   ГС+ГРП   637_збс
# 500                         100                 1   ГС+ГРП   645_збс
# 547                         100                 1   ГС+ГРП   700_збс
# 553                         100                 1  ННС+ГРП   708_збс
# 567                         100                 1   ГС+ГРП   726_збс
# 590                         100                 1   ГС+ГРП   752_збс
# 608                         100                 1   ГС+ГРП   775_збс
# 679                         100                 1  ННС+ГРП   861_збс
# 715                         100                 1   ГС+ГРП   900_збс
# 754                         100                 1   ГС+ГРП   955_збс
# 792                         100                 1   ГС+ГРП  1002_збс
# 811                         100                 1   ГС+ГРП  1026_збс
# 829                         100                 1   ГС+ГРП  1050_збс
# 853                         100                 1   ГС+ГРП  1077_збс
# 886                         100                 1   ГС+ГРП  1115_збс
# 892                         100                 1  ННС+ГРП  1123_збс
# 897                         100                 1   ГС+ГРП  1130_збс
# 944                         100                 1   ГС+ГРП  1186_збс

# %%
new_400 = final_number['Скважина'].tolist()
final_number['Скважина №'] = new_400
final_number = final_number.drop(['Скважина'], axis=1)
final_number = final_number.drop(['index'], axis=1)
new_300 = final_number['Тип'].tolist()
final_number['Тип ГТМ'] = new_300
final_number = final_number.drop(['Тип'], axis=1)
new_200 = final_number['Объект разработки до ГТМ'].tolist()
final_number['Пласт'] = new_200
final_number = final_number.drop(['Объект разработки до ГТМ'], axis=1)
final_number = final_number.reindex(
            columns=['Скважина №', 'Длина ГС, м', 'Число стадий ГРП', 'Полудлина трещины, м', 'Ширина трещины, мм',
                     'Проницаемость проппанта, Д', 'Дата ВНР после','ГС/ННС','Тип ГТМ', 'Пласт'])
final_number
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0            1     0.000000                 1                   100
# 1           10     0.000000                 0                     0
# 2           10     0.000000                 1                   100
# 3         1004     0.000000                 1                   100
# 4         1004     0.000000                 1                   100
# ..         ...          ...               ...                   ...
# 959        949   343.052474                 1                   100
# 960         96     0.000000                 1                   100
# 961        971   762.377859                 0                     0
# 962        971   762.377859                 1                   100
# 963         99     0.000000                 1                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д       Дата ВНР после  \
# 0                     4                         100  2016-03-12 00:00:00
# 1                     0                           0  2008-10-12 00:00:00
# 2                     4                         100  2013-03-03 00:00:00
# 3                     4                         100  2011-02-04 00:00:00
# 4                     4                         100  2013-01-31 00:00:00
# ..                  ...                         ...                  ...
# 959                   4                         100  2021-09-24 00:00:00
# 960                   4                         100  2019-07-31 00:00:00
# 961                   0                           0  2012-04-19 00:00:00
# 962                   4                         100  2013-01-23 00:00:00
# 963                   4                         100  2019-11-01 00:00:00
#
#       ГС/ННС Тип ГТМ Пласт
# 0    ННС+ГРП     ГРП    Ю3
# 1        ННС     ВНС    Ю3
# 2        ННС     ГРП    Ю3
# 3    ННС+ГРП     ГРП    Ю3
# 4        ННС     ГРП    Ю3
# ..       ...     ...   ...
# 959       ГС     3БС    Ю3
# 960  ННС+ГРП     ГРП    Ю3
# 961       ГС     ВНС    Ю3
# 962       ГС     ГРП    Ю3
# 963  ННС+ГРП     ГРП    Ю3
#
# [964 rows x 10 columns]

# %%
final_number.head(30)
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0           1     0.000000                 1                   100
# 1          10     0.000000                 0                     0
# 2          10     0.000000                 1                   100
# 3        1004     0.000000                 1                   100
# 4        1004     0.000000                 1                   100
# 5        1004     0.000000                 1                   100
# 6        1005     0.000000                 1                   100
# 7        1006     0.000000                 1                   100
# 8        1007     0.000000                 0                     0
# 9         105     0.000000                 0                     0
# 10        105     0.000000                 1                   100
# 11        105     0.000000                 1                   100
# 12       1092     0.000000                 1                   100
# 13         11     0.000000                 1                   100
# 14        110   817.866126                 0                     0
# 15       1111   626.258732                 1                   100
# 16       1112   530.136775                 1                   100
# 17       1113   649.148673                 1                   100
# 18       1122   782.218000                 1                   100
# 19       1123   760.906039                 1                   100
# 20       1124   505.466122                 1                   100
# 21       1125     0.000000                 0                     0
# 22       1126   847.651461                 1                   100
# 23       1128   636.704013                 1                   100
# 24       1129   616.370019                 1                   100
# 25       1176     0.000000                 0                     0
# 26        119     0.000000                 0                     0
# 27        119     0.000000                 1                   100
# 28         12     0.000000                 0                     0
# 29         12     0.000000                 1                   100
#
#     Ширина трещины, мм  Проницаемость проппанта, Д       Дата ВНР после  \
# 0                    4                         100  2016-03-12 00:00:00
# 1                    0                           0  2008-10-12 00:00:00
# 2                    4                         100  2013-03-03 00:00:00
# 3                    4                         100  2011-02-04 00:00:00
# 4                    4                         100  2013-01-31 00:00:00
# 5                    4                         100  2013-03-03 00:00:00
# 6                    4                         100  2011-08-31 00:00:00
# 7                    4                         100  2019-08-16 00:00:00
# 8                    0                           0  2010-10-28 00:00:00
# 9                    0                           0  2008-08-27 00:00:00
# 10                   4                         100  2010-10-23 00:00:00
# 11                   4                         100  2013-02-03 00:00:00
# 12                   4                         100  2010-07-21 00:00:00
# 13                   4                         100  2009-04-01 00:00:00
# 14                   0                           0  2020-02-17 00:00:00
# 15                   4                         100  2015-03-27 00:00:00
# 16                   4                         100  2015-05-07 00:00:00
# 17                   4                         100  2015-06-16 00:00:00
# 18                   4                         100  2020-03-03 00:00:00
# 19                   4                         100  2020-03-31 00:00:00
# 20                   4                         100  2020-03-17 00:00:00
# 21                   0                           0  2020-01-30 00:00:00
# 22                   4                         100  2019-10-05 00:00:00
# 23                   4                         100  2019-11-08 00:00:00
# 24                   4                         100  2020-01-02 00:00:00
# 25                   0                           0  2021-07-16 00:00:00
# 26                   0                           0  2009-11-03 00:00:00
# 27                   4                         100  2010-03-31 00:00:00
# 28                   0                           0  2007-10-09 00:00:00
# 29                   4                         100  2008-01-09 00:00:00
#
#      ГС/ННС Тип ГТМ Пласт
# 0   ННС+ГРП     ГРП    Ю3
# 1       ННС     ВНС    Ю3
# 2       ННС     ГРП    Ю3
# 3   ННС+ГРП     ГРП    Ю3
# 4       ННС     ГРП    Ю3
# 5       ННС     ГРП    Ю3
# 6   ННС+ГРП     ГРП    Ю3
# 7       ННС     ГРП    Ю3
# 8       ННС     ВНС    Ю3
# 9       ННС     ВНС    Ю3
# 10      ННС     ГРП    Ю3
# 11      ННС     ГРП    Ю3
# 12  ННС+ГРП     ГРП    Ю3
# 13  ННС+ГРП     ГРП    Ю3
# 14       ГС     ВНС    Ю3
# 15   ГС+ГРП     ГРП    Ю3
# 16   ГС+ГРП     ГРП    Ю3
# 17   ГС+ГРП     ГРП    Ю3
# 18   ГС+ГРП     ГРП    Ю3
# 19   ГС+ГРП     ГРП    Ю3
# 20   ГС+ГРП     ГРП    Ю3
# 21      ННС     ВНС    Ю3
# 22   ГС+ГРП     ГРП    Ю3
# 23   ГС+ГРП     ГРП    Ю3
# 24   ГС+ГРП     ГРП    Ю3
# 25      ННС     ВНС    Ю3
# 26      ННС     ВНС    Ю3
# 27      ННС     ГРП    Ю3
# 28      ННС     ВНС    Ю3
# 29      ННС     ГРП    Ю3

# %%
final_number.tail(60)
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 904         85   439.829512                 1                   100
# 905         85   439.829512                 1                   100
# 906         85   439.829512                 1                   100
# 907         86     0.000000                 0                     0
# 908         87   343.011662                 1                   100
# 909         87   343.011662                 1                   100
# 910         87   343.011662                 1                   100
# 911        870     0.000000                 1                   100
# 912        874   923.703957                 1                   100
# 913        874   923.703957                 1                   100
# 914        876   801.034956                 0                     0
# 915        876   801.034956                 1                   100
# 916        878   980.939346                 0                     0
# 917        878   980.939346                 1                   100
# 918        880     0.000000                 1                   100
# 919        880     0.000000                 1                   100
# 920        881   962.422984                 1                   100
# 921        882   598.820507                 0                     0
# 922        882   598.820507                 1                   100
# 923        883     0.000000                 0                     0
# 924        883     0.000000                 1                   100
# 925        883     0.000000                 1                   100
# 926        890   261.604664                 1                   100
# 927        897     0.000000                 1                   100
# 928        897     0.000000                 1                   100
# 929        897     0.000000                 1                   100
# 930        898   444.542461                 1                   100
# 931          9     0.000000                 0                     0
# 932          9     0.000000                 1                   100
# 933          9     0.000000                 1                   100
# 934        901     0.000000                 0                     0
# 935        901     0.000000                 1                   100
# 936        904     0.000000                 0                     0
# 937        905     0.000000                 1                   100
# 938        906     0.000000                 1                   100
# 939        906     0.000000                 1                   100
# 940        906     0.000000                 1                   100
# 941        907   417.579932                 0                     0
# 942        908   621.097416                 0                     0
# 943        909   294.803324                 1                   100
# 944        909   294.803324                 1                   100
# 945        911   686.385460                 0                     0
# 946        911   686.385460                 1                   100
# 947        919   624.759954                 0                     0
# 948        922     0.000000                 1                   100
# 949        923     0.000000                 0                     0
# 950        923     0.000000                 1                   100
# 951        924     0.000000                 0                     0
# 952        924     0.000000                 1                   100
# 953        926     0.000000                 1                   100
# 954        927     0.000000                 0                     0
# 955        927     0.000000                 1                   100
# 956        927     0.000000                 1                   100
# 957        936     0.000000                 1                   100
# 958        942     0.000000                 1                   100
# 959        949   343.052474                 1                   100
# 960         96     0.000000                 1                   100
# 961        971   762.377859                 0                     0
# 962        971   762.377859                 1                   100
# 963         99     0.000000                 1                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д       Дата ВНР после  \
# 904                   4                         100  2020-05-25 00:00:00
# 905                   4                         100  2020-05-26 00:00:00
# 906                   4                         100  2020-06-11 00:00:00
# 907                   0                           0  2011-02-19 00:00:00
# 908                   4                         100  2011-05-24 00:00:00
# 909                   4                         100  2017-08-11 00:00:00
# 910                   4                         100  2017-08-16 00:00:00
# 911                   4                         100  2019-05-02 00:00:00
# 912                   4                         100  2019-10-18 00:00:00
# 913                   4                         100  2022-01-25 00:00:00
# 914                   0                           0  2019-09-02 00:00:00
# 915                   4                         100  2019-09-03 00:00:00
# 916                   0                           0  2019-11-01 00:00:00
# 917                   4                         100  2019-11-27 00:00:00
# 918                   4                         100  2019-05-01 00:00:00
# 919                   4                         100  2019-05-19 00:00:00
# 920                   4                         100  2019-06-24 00:00:00
# 921                   0                           0  2019-07-14 00:00:00
# 922                   4                         100  2019-07-22 00:00:00
# 923                   0                           0  2019-08-01 00:00:00
# 924                   4                         100  2019-08-08 00:00:00
# 925                   4                         100  2020-03-05 00:00:00
# 926                   4                         100  2022-01-28 00:00:00
# 927                   4                         100  2011-01-17 00:00:00
# 928                   4                         100  2012-06-29 00:00:00
# 929                   4                         100  2019-05-11 00:00:00
# 930                   4                         100  2011-09-22 00:00:00
# 931                   0                           0  2007-06-21 00:00:00
# 932                   4                         100  2007-08-19 00:00:00
# 933                   4                         100  2008-02-20 00:00:00
# 934                   0                           0  2010-09-24 00:00:00
# 935                   4                         100  2010-11-10 00:00:00
# 936                   0                           0  2010-11-11 00:00:00
# 937                   4                         100  2010-10-28 00:00:00
# 938                   4                         100  2010-11-26 00:00:00
# 939                   4                         100  2021-08-15 00:00:00
# 940                   4                         100  2021-09-30 00:00:00
# 941                   0                           0  2011-05-22 00:00:00
# 942                   0                           0  2011-03-21 00:00:00
# 943                   4                         100  2011-01-10 00:00:00
# 944                   4                         100  2014-07-03 00:00:00
# 945                   0                           0  2011-01-27 00:00:00
# 946                   4                         100  2015-03-18 00:00:00
# 947                   0                           0  2011-06-17 00:00:00
# 948                   4                         100  2011-12-14 00:00:00
# 949                   0                           0  2010-12-10 00:00:00
# 950                   4                         100  2011-01-22 00:00:00
# 951                   0                           0  2010-11-28 00:00:00
# 952                   4                         100  2012-09-19 00:00:00
# 953                   4                         100  2011-03-28 00:00:00
# 954                   0                           0  2011-11-14 00:00:00
# 955                   4                         100  2012-03-08 00:00:00
# 956                   4                         100  2014-10-26 00:00:00
# 957                   4                         100  2008-09-27 00:00:00
# 958                   4                         100  2013-06-19 00:00:00
# 959                   4                         100  2021-09-24 00:00:00
# 960                   4                         100  2019-07-31 00:00:00
# 961                   0                           0  2012-04-19 00:00:00
# 962                   4                         100  2013-01-23 00:00:00
# 963                   4                         100  2019-11-01 00:00:00
#
#       ГС/ННС  Тип ГТМ Пласт
# 904       ГС      3БС    Ю3
# 905       ГС      3БС    Ю3
# 906       ГС      3БС    Ю3
# 907      ННС      ВНС    Ю3
# 908   ГС+ГРП      ГРП    Ю3
# 909       ГС      ГРП    Ю3
# 910       ГС      3БС    Ю3
# 911      ННС      ГРП    Ю3
# 912   ГС+ГРП      ГРП    Ю3
# 913       ГС      ГРП    Ю3
# 914       ГС      ВНС    Ю3
# 915       ГС      ГРП    Ю3
# 916       ГС      ВНС    Ю3
# 917       ГС      ГРП    Ю3
# 918      ННС      ГРП    Ю3
# 919      ННС      ГРП    Ю3
# 920   ГС+ГРП      ГРП    Ю3
# 921       ГС      ВНС    Ю3
# 922       ГС      ГРП    Ю3
# 923      ННС      ВНС    Ю3
# 924      ННС      ГРП    Ю3
# 925      ННС      ГРП    Ю3
# 926       ГС      3БС    Ю3
# 927  ННС+ГРП      ГРП    Ю3
# 928      ННС      3БС    Ю3
# 929      ННС      ГРП    Ю3
# 930   ГС+ГРП      ГРП    Ю3
# 931      ННС      ВНС    Ю3
# 932      ННС      ГРП    Ю3
# 933      ННС      ГРП    Ю3
# 934      ННС      ВНС    Ю3
# 935      ННС      ГРП    Ю3
# 936      ННС      ВНС    Ю3
# 937  ННС+ГРП      ГРП    Ю3
# 938  ННС+ГРП      ГРП    Ю3
# 939      ННС      3БС    Ю3
# 940      ННС      3БС    Ю3
# 941       ГС      ВНС    Ю3
# 942       ГС      ВНС    Ю3
# 943   ГС+ГРП      ГРП    Ю3
# 944   ГС+ГРП  3БС+ГРП    Ю3
# 945       ГС      ВНС    Ю3
# 946       ГС      ГРП    Ю3
# 947       ГС      ВНС    Ю3
# 948  ННС+ГРП      ГРП    Ю3
# 949      ННС      ВНС    Ю3
# 950      ННС      ГРП    Ю3
# 951      ННС      ВНС    Ю3
# 952      ННС      ГРП    Ю3
# 953  ННС+ГРП      ГРП    Ю3
# 954      ННС      ВНС    Ю3
# 955      ННС      ГРП    Ю3
# 956      ННС      ГРП    Ю3
# 957  ННС+ГРП      ГРП    Ю3
# 958      ННС      ГРП    Ю3
# 959       ГС      3БС    Ю3
# 960  ННС+ГРП      ГРП    Ю3
# 961       ГС      ВНС    Ю3
# 962       ГС      ГРП    Ю3
# 963  ННС+ГРП      ГРП    Ю3

# %%
final_number.loc[final_number['Тип ГТМ'] == '3БС+ГРП']
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 67        1304   261.283371                 1                   100
# 73        1311     0.000000                 1                   100
# 79         133   331.593124                 1                   100
# 111         14   253.822773                 1                   100
# 144       1503   252.873486                 1                   100
# 177       1549   352.434391                 1                   100
# 246       173Р   235.053185                 1                   100
# 260       1901   178.370401                 1                   100
# 363         35   177.552809                 1                   100
# 366       3552   209.973808                 1                   100
# 395       3825   314.760226                 1                   100
# 423        415   349.676994                 1                   100
# 483        454   250.241883                 1                   100
# 495        459   290.759351                 1                   100
# 500        463   249.647752                 1                   100
# 547        491   275.116339                 1                   100
# 553        494     0.000000                 1                   100
# 567          5   346.101141                 1                   100
# 590        515   266.270539                 1                   100
# 608        541   132.230859                 1                   100
# 679        603     0.000000                 1                   100
# 715        626   350.864646                 1                   100
# 754        675   242.985596                 1                   100
# 792        720   239.708156                 1                   100
# 811        729   346.978385                 1                   100
# 829        739   314.039806                 1                   100
# 853        762   289.458114                 1                   100
# 886          8   255.219513                 1                   100
# 892        806     0.000000                 1                   100
# 897         84   238.298133                 1                   100
# 944        909   294.803324                 1                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д       Дата ВНР после  \
# 67                    4                         100  2014-07-20 00:00:00
# 73                    4                         100  2012-02-24 00:00:00
# 79                    4                         100  2014-06-16 00:00:00
# 111                   4                         100  2014-10-21 00:00:00
# 144                   4                         100  2014-08-07 00:00:00
# 177                   4                         100  2021-11-02 00:00:00
# 246                   4                         100  2014-07-16 00:00:00
# 260                   4                         100  2018-08-02 00:00:00
# 363                   4                         100  2014-08-25 00:00:00
# 366                   4                         100  2014-08-23 00:00:00
# 395                   4                         100  2014-09-30 00:00:00
# 423                   4                         100  2018-12-26 00:00:00
# 483                   4                         100  2014-06-19 00:00:00
# 495                   4                         100  2014-06-28 00:00:00
# 500                   4                         100  2014-11-17 00:00:00
# 547                   4                         100  2014-11-05 00:00:00
# 553                   4                         100  2015-06-21 00:00:00
# 567                   4                         100  2018-05-05 00:00:00
# 590                   4                         100  2015-07-19 00:00:00
# 608                   4                         100  2014-03-27 00:00:00
# 679                   4                         100  2011-04-01 00:00:00
# 715                   4                         100  2014-09-22 00:00:00
# 754                   4                         100  2014-08-21 00:00:00
# 792                   4                         100  2014-12-23 00:00:00
# 811                   4                         100  2017-07-11 00:00:00
# 829                   4                         100  2015-04-30 00:00:00
# 853                   4                         100  2014-02-27 00:00:00
# 886                   4                         100  2014-09-21 00:00:00
# 892                   4                         100  2015-06-26 00:00:00
# 897                   4                         100  2014-08-01 00:00:00
# 944                   4                         100  2014-07-03 00:00:00
#
#       ГС/ННС  Тип ГТМ Пласт
# 67    ГС+ГРП  3БС+ГРП    Ю3
# 73   ННС+ГРП  3БС+ГРП    Ю3
# 79    ГС+ГРП  3БС+ГРП    Ю3
# 111   ГС+ГРП  3БС+ГРП    Ю3
# 144   ГС+ГРП  3БС+ГРП    Ю3
# 177   ГС+ГРП  3БС+ГРП    Ю3
# 246   ГС+ГРП  3БС+ГРП    Ю3
# 260   ГС+ГРП  3БС+ГРП    Ю3
# 363   ГС+ГРП  3БС+ГРП    Ю3
# 366   ГС+ГРП  3БС+ГРП    Ю3
# 395   ГС+ГРП  3БС+ГРП    Ю3
# 423   ГС+ГРП  3БС+ГРП    Ю3
# 483   ГС+ГРП  3БС+ГРП    Ю3
# 495   ГС+ГРП  3БС+ГРП    Ю3
# 500   ГС+ГРП  3БС+ГРП    Ю3
# 547   ГС+ГРП  3БС+ГРП    Ю3
# 553  ННС+ГРП  3БС+ГРП    Ю3
# 567   ГС+ГРП  3БС+ГРП    Ю3
# 590   ГС+ГРП  3БС+ГРП    Ю3
# 608   ГС+ГРП  3БС+ГРП    Ю3
# 679  ННС+ГРП  3БС+ГРП    Ю3
# 715   ГС+ГРП  3БС+ГРП    Ю3
# 754   ГС+ГРП  3БС+ГРП    Ю3
# 792   ГС+ГРП  3БС+ГРП    Ю3
# 811   ГС+ГРП  3БС+ГРП    Ю3
# 829   ГС+ГРП  3БС+ГРП    Ю3
# 853   ГС+ГРП  3БС+ГРП    Ю3
# 886   ГС+ГРП  3БС+ГРП    Ю3
# 892  ННС+ГРП  3БС+ГРП    Ю3
# 897   ГС+ГРП  3БС+ГРП    Ю3
# 944   ГС+ГРП  3БС+ГРП    Ю3

# %%
final_number['Дата ВНР после'] = final_number.apply(
            lambda x:
            str(x['Дата ВНР после']), axis=1)
final_number['месяц с грп'] = final_number.apply(
            lambda x:
            x['Дата ВНР после'][:4],
            axis=1
        )
final_number
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0            1     0.000000                 1                   100
# 1           10     0.000000                 0                     0
# 2           10     0.000000                 1                   100
# 3         1004     0.000000                 1                   100
# 4         1004     0.000000                 1                   100
# ..         ...          ...               ...                   ...
# 959        949   343.052474                 1                   100
# 960         96     0.000000                 1                   100
# 961        971   762.377859                 0                     0
# 962        971   762.377859                 1                   100
# 963         99     0.000000                 1                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д       Дата ВНР после  \
# 0                     4                         100  2016-03-12 00:00:00
# 1                     0                           0  2008-10-12 00:00:00
# 2                     4                         100  2013-03-03 00:00:00
# 3                     4                         100  2011-02-04 00:00:00
# 4                     4                         100  2013-01-31 00:00:00
# ..                  ...                         ...                  ...
# 959                   4                         100  2021-09-24 00:00:00
# 960                   4                         100  2019-07-31 00:00:00
# 961                   0                           0  2012-04-19 00:00:00
# 962                   4                         100  2013-01-23 00:00:00
# 963                   4                         100  2019-11-01 00:00:00
#
#       ГС/ННС Тип ГТМ Пласт месяц с грп
# 0    ННС+ГРП     ГРП    Ю3        2016
# 1        ННС     ВНС    Ю3        2008
# 2        ННС     ГРП    Ю3        2013
# 3    ННС+ГРП     ГРП    Ю3        2011
# 4        ННС     ГРП    Ю3        2013
# ..       ...     ...   ...         ...
# 959       ГС     3БС    Ю3        2021
# 960  ННС+ГРП     ГРП    Ю3        2019
# 961       ГС     ВНС    Ю3        2012
# 962       ГС     ГРП    Ю3        2013
# 963  ННС+ГРП     ГРП    Ю3        2019
#
# [964 rows x 11 columns]

# %%
grp = copy.deepcopy(grp_dad)
grp['Дата'] = grp.apply(
            lambda x:
            str(x['Дата']), axis=1)
grp['месяц с грп'] = grp.apply(
            lambda x:
            x['Дата'][:4],
            axis=1
        )
grp
# Out:
#      Номер скважины                   Unnamed: 0                 Дата  \
# 0                99  Проблемы при построении ГРП  2019-10-20 00:00:00
# 1                96  Проблемы при построении ГРП  2019-06-20 00:00:00
# 2               949  Проблемы при построении ГРП  2021-09-15 00:00:00
# 3               949  Проблемы при построении ГРП  2021-09-15 00:00:00
# 4               949  Проблемы при построении ГРП  2021-09-15 00:00:00
# ...             ...                          ...                  ...
# 1043           1082  Проблемы при построении ГРП  2020-02-07 00:00:00
# 1044           1006  Проблемы при построении ГРП  2019-07-26 00:00:00
# 1045           1004  Проблемы при построении ГРП  2013-01-03 00:00:00
# 1046             10                          NaN  2013-02-16 00:00:00
# 1047              1  Проблемы при построении ГРП  2016-02-23 00:00:00
#
#      Подрядчик                                        Комментарии Страница  \
# 0           КН  Оборудование:  НКТ, ПРО, АМТ-  ООО "КАТКонефть...      -1_
# 1          SLB  По согласованию с представителями Заказчика пр...      -1_
# 2           КН  Оборудование:  НКТ, АМТ- ООО "КАТКонефть"  Сти...      -1_
# 3           КН  Оборудование:  НКТ, АМТ- ООО "КАТКонефть"  Сти...      -1_
# 4           КН  Оборудование:  НКТ, АМТ- ООО "КАТКонефть"  Сти...      -1_
# ...        ...                                                ...      ...
# 1043       МКМ  ГРП по плану (+), 42 т.  Выполнена стадия Запо...      -1_
# 1044       SLB  По согласованию с представителями Заказчика пр...      -1_
# 1045       ШЛБ  По результатам МиниГРП масса пропанта по перво...      -1_
# 1046       ШЛБ  При проведении работ по ГРП 16/02/2013 закачка...      -1_
# 1047        КН  Мини ГРП проводился 23.02.2016 г. По результат...      -1_
#
#       Unnamed: 6 Пласт  Наклон  Азимут  ...  Рпл Хорнер   Эфф  Расход    Конц  \
# 0            NaN    Ю3    17.0   245.0  ...        48.0  71.0     3.2   900.0
# 1            NaN    Ю3     7.0   152.0  ...        45.0  63.0     3.6   800.0
# 2            NaN    Ю3    93.7   305.1  ...        60.0  37.0     3.6  1000.0
# 3            NaN    Ю3    93.7   305.1  ...        62.0  31.5     3.6  1000.0
# 4            NaN    Ю3    93.7   305.1  ...        58.0  36.0     3.6  1000.0
# ...          ...   ...     ...     ...  ...         ...   ...     ...     ...
# 1043         NaN    Ю3    20.0   305.0  ...        49.0  74.8     3.6   800.0
# 1044         NaN    Ю3    22.0    40.0  ...        61.0  43.0     3.4   800.0
# 1045         NaN    Ю3    40.0    34.0  ...       200.0  32.0     3.8   890.0
# 1046         NaN    Ю3     2.0     NaN  ...       235.0  73.0     2.6  1056.0
# 1047         NaN    Ю3     1.0     NaN  ...         NaN  43.0     3.4  1200.0
#
#       Гель       М бр  V под  V без под  V гель  месяц с грп
# 0      NaN   41.10000    9.0        NaN    53.0         2019
# 1      NaN  241.37000   32.0        NaN   165.0         2019
# 2      NaN   45.95220    NaN        NaN    71.5         2021
# 3      NaN   40.47128    NaN        NaN    54.8         2021
# 4      NaN   41.01312    NaN        NaN    53.8         2021
# ...    ...        ...    ...        ...     ...          ...
# 1043   NaN   50.00000   35.0        NaN   145.0         2020
# 1044   NaN  133.24063    NaN        5.0    73.0         2019
# 1045   NaN        NaN  110.0      367.3     NaN         2013
# 1046   NaN        NaN   14.0      100.0     NaN         2013
# 1047   NaN   85.00000   30.0      154.4     NaN         2016
#
# [1048 rows x 37 columns]

# %%
grp = grp.groupby(by=['Номер скважины', 'месяц с грп']).agg(
            {'Пласт': lambda x:
            x.tolist()}
        )
grp
# Out:
#                                            Пласт
# Номер скважины месяц с грп
# 1              2016                         [Ю3]
# 10             2013                         [Ю3]
# 1004           2013                         [Ю3]
# 1006           2019                         [Ю3]
# 1082           2020                         [Ю3]
# ...                                          ...
# 923            2011                         [Ю3]
# 924            2012                         [Ю3]
# 949            2021         [Ю3, Ю3, Ю3, Ю3, Ю3]
# 96             2019                         [Ю3]
# 99             2019                         [Ю3]
#
# [449 rows x 1 columns]

# %%
grp['Количество'] = grp.apply(
            lambda x:
            len(x['Пласт'])
            , axis=1)
grp
# Out:
#                                            Пласт  Количество
# Номер скважины месяц с грп
# 1              2016                         [Ю3]           1
# 10             2013                         [Ю3]           1
# 1004           2013                         [Ю3]           1
# 1006           2019                         [Ю3]           1
# 1082           2020                         [Ю3]           1
# ...                                          ...         ...
# 923            2011                         [Ю3]           1
# 924            2012                         [Ю3]           1
# 949            2021         [Ю3, Ю3, Ю3, Ю3, Ю3]           5
# 96             2019                         [Ю3]           1
# 99             2019                         [Ю3]           1
#
# [449 rows x 2 columns]

# %%
grp.reset_index(inplace=True)
grp
# Out:
#     Номер скважины месяц с грп                 Пласт  Количество
# 0                1        2016                  [Ю3]           1
# 1               10        2013                  [Ю3]           1
# 2             1004        2013                  [Ю3]           1
# 3             1006        2019                  [Ю3]           1
# 4             1082        2020                  [Ю3]           1
# ..             ...         ...                   ...         ...
# 444            923        2011                  [Ю3]           1
# 445            924        2012                  [Ю3]           1
# 446            949        2021  [Ю3, Ю3, Ю3, Ю3, Ю3]           5
# 447             96        2019                  [Ю3]           1
# 448             99        2019                  [Ю3]           1
#
# [449 rows x 4 columns]

# %%
new_100 = grp['Номер скважины'].tolist()
grp['Скважина №'] = new_100
grp = grp.drop(['Номер скважины'], axis=1)
grp
# Out:
#     месяц с грп                 Пласт  Количество Скважина №
# 0          2016                  [Ю3]           1          1
# 1          2013                  [Ю3]           1         10
# 2          2013                  [Ю3]           1       1004
# 3          2019                  [Ю3]           1       1006
# 4          2020                  [Ю3]           1       1082
# ..          ...                   ...         ...        ...
# 444        2011                  [Ю3]           1        923
# 445        2012                  [Ю3]           1        924
# 446        2021  [Ю3, Ю3, Ю3, Ю3, Ю3]           5        949
# 447        2019                  [Ю3]           1         96
# 448        2019                  [Ю3]           1         99
#
# [449 rows x 4 columns]

# %%
grp = grp.drop(['Пласт'], axis=1)
grp
# Out:
#     месяц с грп  Количество Скважина №
# 0          2016           1          1
# 1          2013           1         10
# 2          2013           1       1004
# 3          2019           1       1006
# 4          2020           1       1082
# ..          ...         ...        ...
# 444        2011           1        923
# 445        2012           1        924
# 446        2021           5        949
# 447        2019           1         96
# 448        2019           1         99
#
# [449 rows x 3 columns]

# %%
sotired = final_number.merge(grp, on=['месяц с грп', 'Скважина №'],how='left')
sotired
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0            1     0.000000                 1                   100
# 1           10     0.000000                 0                     0
# 2           10     0.000000                 1                   100
# 3         1004     0.000000                 1                   100
# 4         1004     0.000000                 1                   100
# ..         ...          ...               ...                   ...
# 959        949   343.052474                 1                   100
# 960         96     0.000000                 1                   100
# 961        971   762.377859                 0                     0
# 962        971   762.377859                 1                   100
# 963         99     0.000000                 1                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д       Дата ВНР после  \
# 0                     4                         100  2016-03-12 00:00:00
# 1                     0                           0  2008-10-12 00:00:00
# 2                     4                         100  2013-03-03 00:00:00
# 3                     4                         100  2011-02-04 00:00:00
# 4                     4                         100  2013-01-31 00:00:00
# ..                  ...                         ...                  ...
# 959                   4                         100  2021-09-24 00:00:00
# 960                   4                         100  2019-07-31 00:00:00
# 961                   0                           0  2012-04-19 00:00:00
# 962                   4                         100  2013-01-23 00:00:00
# 963                   4                         100  2019-11-01 00:00:00
#
#       ГС/ННС Тип ГТМ Пласт месяц с грп  Количество
# 0    ННС+ГРП     ГРП    Ю3        2016         1.0
# 1        ННС     ВНС    Ю3        2008         NaN
# 2        ННС     ГРП    Ю3        2013         1.0
# 3    ННС+ГРП     ГРП    Ю3        2011         NaN
# 4        ННС     ГРП    Ю3        2013         1.0
# ..       ...     ...   ...         ...         ...
# 959       ГС     3БС    Ю3        2021         5.0
# 960  ННС+ГРП     ГРП    Ю3        2019         1.0
# 961       ГС     ВНС    Ю3        2012         NaN
# 962       ГС     ГРП    Ю3        2013         NaN
# 963  ННС+ГРП     ГРП    Ю3        2019         1.0
#
# [964 rows x 12 columns]

# %%
sotired = sotired.drop(['Число стадий ГРП'], axis=1)
sotired
# Out:
#     Скважина №  Длина ГС, м  Полудлина трещины, м  Ширина трещины, мм  \
# 0            1     0.000000                   100                   4
# 1           10     0.000000                     0                   0
# 2           10     0.000000                   100                   4
# 3         1004     0.000000                   100                   4
# 4         1004     0.000000                   100                   4
# ..         ...          ...                   ...                 ...
# 959        949   343.052474                   100                   4
# 960         96     0.000000                   100                   4
# 961        971   762.377859                     0                   0
# 962        971   762.377859                   100                   4
# 963         99     0.000000                   100                   4
#
#      Проницаемость проппанта, Д       Дата ВНР после   ГС/ННС Тип ГТМ Пласт  \
# 0                           100  2016-03-12 00:00:00  ННС+ГРП     ГРП    Ю3
# 1                             0  2008-10-12 00:00:00      ННС     ВНС    Ю3
# 2                           100  2013-03-03 00:00:00      ННС     ГРП    Ю3
# 3                           100  2011-02-04 00:00:00  ННС+ГРП     ГРП    Ю3
# 4                           100  2013-01-31 00:00:00      ННС     ГРП    Ю3
# ..                          ...                  ...      ...     ...   ...
# 959                         100  2021-09-24 00:00:00       ГС     3БС    Ю3
# 960                         100  2019-07-31 00:00:00  ННС+ГРП     ГРП    Ю3
# 961                           0  2012-04-19 00:00:00       ГС     ВНС    Ю3
# 962                         100  2013-01-23 00:00:00       ГС     ГРП    Ю3
# 963                         100  2019-11-01 00:00:00  ННС+ГРП     ГРП    Ю3
#
#     месяц с грп  Количество
# 0          2016         1.0
# 1          2008         NaN
# 2          2013         1.0
# 3          2011         NaN
# 4          2013         1.0
# ..          ...         ...
# 959        2021         5.0
# 960        2019         1.0
# 961        2012         NaN
# 962        2013         NaN
# 963        2019         1.0
#
# [964 rows x 11 columns]

# %%
new_50 = sotired['Количество'].tolist()
sotired['Число стадий ГРП'] = new_50
sotired = sotired.drop(['Количество'], axis=1)
sotired['Число стадий ГРП'] = sotired.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Число стадий ГРП']
            , axis=1)
sotired
# Out:
#     Скважина №  Длина ГС, м  Полудлина трещины, м  Ширина трещины, мм  \
# 0            1     0.000000                   100                   4
# 1           10     0.000000                     0                   0
# 2           10     0.000000                   100                   4
# 3         1004     0.000000                   100                   4
# 4         1004     0.000000                   100                   4
# ..         ...          ...                   ...                 ...
# 959        949   343.052474                   100                   4
# 960         96     0.000000                   100                   4
# 961        971   762.377859                     0                   0
# 962        971   762.377859                   100                   4
# 963         99     0.000000                   100                   4
#
#      Проницаемость проппанта, Д       Дата ВНР после   ГС/ННС Тип ГТМ Пласт  \
# 0                           100  2016-03-12 00:00:00  ННС+ГРП     ГРП    Ю3
# 1                             0  2008-10-12 00:00:00      ННС     ВНС    Ю3
# 2                           100  2013-03-03 00:00:00      ННС     ГРП    Ю3
# 3                           100  2011-02-04 00:00:00  ННС+ГРП     ГРП    Ю3
# 4                           100  2013-01-31 00:00:00      ННС     ГРП    Ю3
# ..                          ...                  ...      ...     ...   ...
# 959                         100  2021-09-24 00:00:00       ГС     3БС    Ю3
# 960                         100  2019-07-31 00:00:00  ННС+ГРП     ГРП    Ю3
# 961                           0  2012-04-19 00:00:00       ГС     ВНС    Ю3
# 962                         100  2013-01-23 00:00:00       ГС     ГРП    Ю3
# 963                         100  2019-11-01 00:00:00  ННС+ГРП     ГРП    Ю3
#
#     месяц с грп  Число стадий ГРП
# 0          2016               1.0
# 1          2008               0.0
# 2          2013               1.0
# 3          2011               NaN
# 4          2013               1.0
# ..          ...               ...
# 959        2021               5.0
# 960        2019               1.0
# 961        2012               0.0
# 962        2013               NaN
# 963        2019               1.0
#
# [964 rows x 11 columns]

# %%
sotired.tail(30)
# Out:
#     Скважина №  Длина ГС, м  Полудлина трещины, м  Ширина трещины, мм  \
# 934        901     0.000000                     0                   0
# 935        901     0.000000                   100                   4
# 936        904     0.000000                     0                   0
# 937        905     0.000000                   100                   4
# 938        906     0.000000                   100                   4
# 939        906     0.000000                   100                   4
# 940        906     0.000000                   100                   4
# 941        907   417.579932                     0                   0
# 942        908   621.097416                     0                   0
# 943        909   294.803324                   100                   4
# 944        909   294.803324                   100                   4
# 945        911   686.385460                     0                   0
# 946        911   686.385460                   100                   4
# 947        919   624.759954                     0                   0
# 948        922     0.000000                   100                   4
# 949        923     0.000000                     0                   0
# 950        923     0.000000                   100                   4
# 951        924     0.000000                     0                   0
# 952        924     0.000000                   100                   4
# 953        926     0.000000                   100                   4
# 954        927     0.000000                     0                   0
# 955        927     0.000000                   100                   4
# 956        927     0.000000                   100                   4
# 957        936     0.000000                   100                   4
# 958        942     0.000000                   100                   4
# 959        949   343.052474                   100                   4
# 960         96     0.000000                   100                   4
# 961        971   762.377859                     0                   0
# 962        971   762.377859                   100                   4
# 963         99     0.000000                   100                   4
#
#      Проницаемость проппанта, Д       Дата ВНР после   ГС/ННС  Тип ГТМ Пласт  \
# 934                           0  2010-09-24 00:00:00      ННС      ВНС    Ю3
# 935                         100  2010-11-10 00:00:00      ННС      ГРП    Ю3
# 936                           0  2010-11-11 00:00:00      ННС      ВНС    Ю3
# 937                         100  2010-10-28 00:00:00  ННС+ГРП      ГРП    Ю3
# 938                         100  2010-11-26 00:00:00  ННС+ГРП      ГРП    Ю3
# 939                         100  2021-08-15 00:00:00      ННС      3БС    Ю3
# 940                         100  2021-09-30 00:00:00      ННС      3БС    Ю3
# 941                           0  2011-05-22 00:00:00       ГС      ВНС    Ю3
# 942                           0  2011-03-21 00:00:00       ГС      ВНС    Ю3
# 943                         100  2011-01-10 00:00:00   ГС+ГРП      ГРП    Ю3
# 944                         100  2014-07-03 00:00:00   ГС+ГРП  3БС+ГРП    Ю3
# 945                           0  2011-01-27 00:00:00       ГС      ВНС    Ю3
# 946                         100  2015-03-18 00:00:00       ГС      ГРП    Ю3
# 947                           0  2011-06-17 00:00:00       ГС      ВНС    Ю3
# 948                         100  2011-12-14 00:00:00  ННС+ГРП      ГРП    Ю3
# 949                           0  2010-12-10 00:00:00      ННС      ВНС    Ю3
# 950                         100  2011-01-22 00:00:00      ННС      ГРП    Ю3
# 951                           0  2010-11-28 00:00:00      ННС      ВНС    Ю3
# 952                         100  2012-09-19 00:00:00      ННС      ГРП    Ю3
# 953                         100  2011-03-28 00:00:00  ННС+ГРП      ГРП    Ю3
# 954                           0  2011-11-14 00:00:00      ННС      ВНС    Ю3
# 955                         100  2012-03-08 00:00:00      ННС      ГРП    Ю3
# 956                         100  2014-10-26 00:00:00      ННС      ГРП    Ю3
# 957                         100  2008-09-27 00:00:00  ННС+ГРП      ГРП    Ю3
# 958                         100  2013-06-19 00:00:00      ННС      ГРП    Ю3
# 959                         100  2021-09-24 00:00:00       ГС      3БС    Ю3
# 960                         100  2019-07-31 00:00:00  ННС+ГРП      ГРП    Ю3
# 961                           0  2012-04-19 00:00:00       ГС      ВНС    Ю3
# 962                         100  2013-01-23 00:00:00       ГС      ГРП    Ю3
# 963                         100  2019-11-01 00:00:00  ННС+ГРП      ГРП    Ю3
#
#     месяц с грп  Число стадий ГРП
# 934        2010               0.0
# 935        2010               NaN
# 936        2010               0.0
# 937        2010               1.0
# 938        2010               NaN
# 939        2021               NaN
# 940        2021               NaN
# 941        2011               0.0
# 942        2011               0.0
# 943        2011               NaN
# 944        2014               4.0
# 945        2011               0.0
# 946        2015               1.0
# 947        2011               0.0
# 948        2011               NaN
# 949        2010               0.0
# 950        2011               1.0
# 951        2010               0.0
# 952        2012               1.0
# 953        2011               NaN
# 954        2011               0.0
# 955        2012               NaN
# 956        2014               NaN
# 957        2008               NaN
# 958        2013               NaN
# 959        2021               5.0
# 960        2019               1.0
# 961        2012               0.0
# 962        2013               NaN
# 963        2019               1.0

# %%
sotired['Дата ВНР после'] = pd.to_datetime(sotired['Дата ВНР после'])

sotired
# Out:
#     Скважина №  Длина ГС, м  Полудлина трещины, м  Ширина трещины, мм  \
# 0            1     0.000000                   100                   4
# 1           10     0.000000                     0                   0
# 2           10     0.000000                   100                   4
# 3         1004     0.000000                   100                   4
# 4         1004     0.000000                   100                   4
# ..         ...          ...                   ...                 ...
# 959        949   343.052474                   100                   4
# 960         96     0.000000                   100                   4
# 961        971   762.377859                     0                   0
# 962        971   762.377859                   100                   4
# 963         99     0.000000                   100                   4
#
#      Проницаемость проппанта, Д Дата ВНР после   ГС/ННС Тип ГТМ Пласт  \
# 0                           100     2016-03-12  ННС+ГРП     ГРП    Ю3
# 1                             0     2008-10-12      ННС     ВНС    Ю3
# 2                           100     2013-03-03      ННС     ГРП    Ю3
# 3                           100     2011-02-04  ННС+ГРП     ГРП    Ю3
# 4                           100     2013-01-31      ННС     ГРП    Ю3
# ..                          ...            ...      ...     ...   ...
# 959                         100     2021-09-24       ГС     3БС    Ю3
# 960                         100     2019-07-31  ННС+ГРП     ГРП    Ю3
# 961                           0     2012-04-19       ГС     ВНС    Ю3
# 962                         100     2013-01-23       ГС     ГРП    Ю3
# 963                         100     2019-11-01  ННС+ГРП     ГРП    Ю3
#
#     месяц с грп  Число стадий ГРП
# 0          2016               1.0
# 1          2008               0.0
# 2          2013               1.0
# 3          2011               NaN
# 4          2013               1.0
# ..          ...               ...
# 959        2021               5.0
# 960        2019               1.0
# 961        2012               0.0
# 962        2013               NaN
# 963        2019               1.0
#
# [964 rows x 11 columns]

# %%
sotired['ГС/ННС'] = sotired.apply(
            lambda x:
            str(x['ГС/ННС']) + '+ГРП' if str(x['Тип ГТМ']) == 'ГРП' and 'ГРП' not in str(x['ГС/ННС'])
            else x['ГС/ННС'], axis=1)
sotired
# Out:
#     Скважина №  Длина ГС, м  Полудлина трещины, м  Ширина трещины, мм  \
# 0            1     0.000000                   100                   4
# 1           10     0.000000                     0                   0
# 2           10     0.000000                   100                   4
# 3         1004     0.000000                   100                   4
# 4         1004     0.000000                   100                   4
# ..         ...          ...                   ...                 ...
# 959        949   343.052474                   100                   4
# 960         96     0.000000                   100                   4
# 961        971   762.377859                     0                   0
# 962        971   762.377859                   100                   4
# 963         99     0.000000                   100                   4
#
#      Проницаемость проппанта, Д Дата ВНР после   ГС/ННС Тип ГТМ Пласт  \
# 0                           100     2016-03-12  ННС+ГРП     ГРП    Ю3
# 1                             0     2008-10-12      ННС     ВНС    Ю3
# 2                           100     2013-03-03  ННС+ГРП     ГРП    Ю3
# 3                           100     2011-02-04  ННС+ГРП     ГРП    Ю3
# 4                           100     2013-01-31  ННС+ГРП     ГРП    Ю3
# ..                          ...            ...      ...     ...   ...
# 959                         100     2021-09-24       ГС     3БС    Ю3
# 960                         100     2019-07-31  ННС+ГРП     ГРП    Ю3
# 961                           0     2012-04-19       ГС     ВНС    Ю3
# 962                         100     2013-01-23   ГС+ГРП     ГРП    Ю3
# 963                         100     2019-11-01  ННС+ГРП     ГРП    Ю3
#
#     месяц с грп  Число стадий ГРП
# 0          2016               1.0
# 1          2008               0.0
# 2          2013               1.0
# 3          2011               NaN
# 4          2013               1.0
# ..          ...               ...
# 959        2021               5.0
# 960        2019               1.0
# 961        2012               0.0
# 962        2013               NaN
# 963        2019               1.0
#
# [964 rows x 11 columns]

# %%
sotired['ГС/ННС'] = sotired.apply(
            lambda x:
            str(x['ГС/ННС']) + '+ГРП' if str(x['Тип ГТМ']) == '3БС+ГРП' and 'ГРП' not in str(x['ГС/ННС'])
            else x['ГС/ННС'], axis=1)
sotired
# Out:
#     Скважина №  Длина ГС, м  Полудлина трещины, м  Ширина трещины, мм  \
# 0            1     0.000000                   100                   4
# 1           10     0.000000                     0                   0
# 2           10     0.000000                   100                   4
# 3         1004     0.000000                   100                   4
# 4         1004     0.000000                   100                   4
# ..         ...          ...                   ...                 ...
# 959        949   343.052474                   100                   4
# 960         96     0.000000                   100                   4
# 961        971   762.377859                     0                   0
# 962        971   762.377859                   100                   4
# 963         99     0.000000                   100                   4
#
#      Проницаемость проппанта, Д Дата ВНР после   ГС/ННС Тип ГТМ Пласт  \
# 0                           100     2016-03-12  ННС+ГРП     ГРП    Ю3
# 1                             0     2008-10-12      ННС     ВНС    Ю3
# 2                           100     2013-03-03  ННС+ГРП     ГРП    Ю3
# 3                           100     2011-02-04  ННС+ГРП     ГРП    Ю3
# 4                           100     2013-01-31  ННС+ГРП     ГРП    Ю3
# ..                          ...            ...      ...     ...   ...
# 959                         100     2021-09-24       ГС     3БС    Ю3
# 960                         100     2019-07-31  ННС+ГРП     ГРП    Ю3
# 961                           0     2012-04-19       ГС     ВНС    Ю3
# 962                         100     2013-01-23   ГС+ГРП     ГРП    Ю3
# 963                         100     2019-11-01  ННС+ГРП     ГРП    Ю3
#
#     месяц с грп  Число стадий ГРП
# 0          2016               1.0
# 1          2008               0.0
# 2          2013               1.0
# 3          2011               NaN
# 4          2013               1.0
# ..          ...               ...
# 959        2021               5.0
# 960        2019               1.0
# 961        2012               0.0
# 962        2013               NaN
# 963        2019               1.0
#
# [964 rows x 11 columns]

# %%
sotired = sotired.reindex(
            columns=['Скважина №', 'Длина ГС, м', 'Число стадий ГРП', 'Полудлина трещины, м', 'Ширина трещины, мм',
                     'Проницаемость проппанта, Д', 'Дата ВНР после', 'ГС/ННС', 'Тип ГТМ', 'Пласт'])
sotired['Число стадий ГРП'] = sotired.apply(
            lambda x:
            0 if str(x['Тип ГТМ']) == 'ВНС'
            else x['Число стадий ГРП'], axis=1)
sotired
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0            1     0.000000               1.0                   100
# 1           10     0.000000               0.0                     0
# 2           10     0.000000               1.0                   100
# 3         1004     0.000000               NaN                   100
# 4         1004     0.000000               1.0                   100
# ..         ...          ...               ...                   ...
# 959        949   343.052474               5.0                   100
# 960         96     0.000000               1.0                   100
# 961        971   762.377859               0.0                     0
# 962        971   762.377859               NaN                   100
# 963         99     0.000000               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после   ГС/ННС  \
# 0                     4                         100     2016-03-12  ННС+ГРП
# 1                     0                           0     2008-10-12      ННС
# 2                     4                         100     2013-03-03  ННС+ГРП
# 3                     4                         100     2011-02-04  ННС+ГРП
# 4                     4                         100     2013-01-31  ННС+ГРП
# ..                  ...                         ...            ...      ...
# 959                   4                         100     2021-09-24       ГС
# 960                   4                         100     2019-07-31  ННС+ГРП
# 961                   0                           0     2012-04-19       ГС
# 962                   4                         100     2013-01-23   ГС+ГРП
# 963                   4                         100     2019-11-01  ННС+ГРП
#
#     Тип ГТМ Пласт
# 0       ГРП    Ю3
# 1       ВНС    Ю3
# 2       ГРП    Ю3
# 3       ГРП    Ю3
# 4       ГРП    Ю3
# ..      ...   ...
# 959     3БС    Ю3
# 960     ГРП    Ю3
# 961     ВНС    Ю3
# 962     ГРП    Ю3
# 963     ГРП    Ю3
#
# [964 rows x 10 columns]

# %%
sotired['Число стадий ГРП'] = sotired.apply(
            lambda x:
            0 if str(x['Тип ГТМ']) == '3БС'
            else x['Число стадий ГРП'], axis=1)
sotired
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0            1     0.000000               1.0                   100
# 1           10     0.000000               0.0                     0
# 2           10     0.000000               1.0                   100
# 3         1004     0.000000               NaN                   100
# 4         1004     0.000000               1.0                   100
# ..         ...          ...               ...                   ...
# 959        949   343.052474               0.0                   100
# 960         96     0.000000               1.0                   100
# 961        971   762.377859               0.0                     0
# 962        971   762.377859               NaN                   100
# 963         99     0.000000               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после   ГС/ННС  \
# 0                     4                         100     2016-03-12  ННС+ГРП
# 1                     0                           0     2008-10-12      ННС
# 2                     4                         100     2013-03-03  ННС+ГРП
# 3                     4                         100     2011-02-04  ННС+ГРП
# 4                     4                         100     2013-01-31  ННС+ГРП
# ..                  ...                         ...            ...      ...
# 959                   4                         100     2021-09-24       ГС
# 960                   4                         100     2019-07-31  ННС+ГРП
# 961                   0                           0     2012-04-19       ГС
# 962                   4                         100     2013-01-23   ГС+ГРП
# 963                   4                         100     2019-11-01  ННС+ГРП
#
#     Тип ГТМ Пласт
# 0       ГРП    Ю3
# 1       ВНС    Ю3
# 2       ГРП    Ю3
# 3       ГРП    Ю3
# 4       ГРП    Ю3
# ..      ...   ...
# 959     3БС    Ю3
# 960     ГРП    Ю3
# 961     ВНС    Ю3
# 962     ГРП    Ю3
# 963     ГРП    Ю3
#
# [964 rows x 10 columns]

# %%
sotired['Полудлина трещины, м'] = sotired.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Полудлина трещины, м']
            , axis=1)
sotired['Ширина трещины, мм'] = sotired.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Ширина трещины, мм']
            , axis=1)
sotired['Проницаемость проппанта, Д'] = sotired.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Проницаемость проппанта, Д']
            , axis=1)
        # ДОБАВИТЬ В ВНС
sotired['Число стадий ГРП'] = sotired.apply(
            lambda x:
            0 if str(x['Тип ГТМ']) == '3БС'
            else x['Число стадий ГРП']
            , axis=1)
sotired['Полудлина трещины, м'] = sotired.apply(
            lambda x:
            0 if str(x['Тип ГТМ']) == '3БС'
            else x['Полудлина трещины, м']
            , axis=1)
sotired['Ширина трещины, мм'] = sotired.apply(
            lambda x:
            0 if str(x['Тип ГТМ']) == '3БС'
            else x['Ширина трещины, мм']
            , axis=1)
sotired['Проницаемость проппанта, Д'] = sotired.apply(
            lambda x:
            0 if str(x['Тип ГТМ']) == '3БС'
            else x['Проницаемость проппанта, Д']
            , axis=1)
        # ДОБАВИТЬ В ВНС
sotired['Число стадий ГРП'] = sotired.apply(
            lambda x:
            0 if str(x['Тип ГТМ']) == '3БС'
            else x['Число стадий ГРП']
            , axis=1)

sotired
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0            1     0.000000               1.0                   100
# 1           10     0.000000               0.0                     0
# 2           10     0.000000               1.0                   100
# 3         1004     0.000000               NaN                   100
# 4         1004     0.000000               1.0                   100
# ..         ...          ...               ...                   ...
# 959        949   343.052474               0.0                     0
# 960         96     0.000000               1.0                   100
# 961        971   762.377859               0.0                     0
# 962        971   762.377859               NaN                   100
# 963         99     0.000000               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после   ГС/ННС  \
# 0                     4                         100     2016-03-12  ННС+ГРП
# 1                     0                           0     2008-10-12      ННС
# 2                     4                         100     2013-03-03  ННС+ГРП
# 3                     4                         100     2011-02-04  ННС+ГРП
# 4                     4                         100     2013-01-31  ННС+ГРП
# ..                  ...                         ...            ...      ...
# 959                   0                           0     2021-09-24       ГС
# 960                   4                         100     2019-07-31  ННС+ГРП
# 961                   0                           0     2012-04-19       ГС
# 962                   4                         100     2013-01-23   ГС+ГРП
# 963                   4                         100     2019-11-01  ННС+ГРП
#
#     Тип ГТМ Пласт
# 0       ГРП    Ю3
# 1       ВНС    Ю3
# 2       ГРП    Ю3
# 3       ГРП    Ю3
# 4       ГРП    Ю3
# ..      ...   ...
# 959     3БС    Ю3
# 960     ГРП    Ю3
# 961     ВНС    Ю3
# 962     ГРП    Ю3
# 963     ГРП    Ю3
#
# [964 rows x 10 columns]

# %%
        # удаляем если в одном месяце

    
    
    
    
    
    
    
    
    #думаю тут может что-то потеряться (уверен)

# %%
        # проверяем ЗБС
grp_4 = copy.deepcopy(grp_gtm)

grp_4['Скважина'] = grp_4.apply(
            lambda x:
            str(x['Скважина']), axis=1)

grp_4
# Out:
#      Месторождение      Unnamed: 0 Скважина     Куст  \
# 0     Тайлаковское      Добывающая        1      NaN
# 1     Тайлаковское      Добывающая        1      NaN
# 2     Тайлаковское  Нагнетательная        1      NaN
# 3     Тайлаковское      Добывающая        1      NaN
# 4     Тайлаковское      Добывающая        1      NaN
# ...            ...             ...      ...      ...
# 4923  Тайлаковское      Добывающая       99  КУСТ-96
# 4924  Тайлаковское      Добывающая       99  КУСТ-96
# 4925  Тайлаковское      Добывающая       99  КУСТ-96
# 4926  Тайлаковское      Добывающая       99  КУСТ-96
# 4927  Тайлаковское      Добывающая       99  КУСТ-96
#
#                                                 Тип Объект разработки до ГТМ  \
# 0                                   ВНС из др. фонд                       Ю3
# 1                                               ГРП                       Ю3
# 2                                     Перевод в ППД                       Ю3
# 3     Выравнивание профиля притока или приёмистости                       Ю3
# 4                                   Проведение ГДИС                       Ю3
# ...                                             ...                      ...
# 4923                             Запуск без ремонта                       Ю3
# 4924                             Запуск без ремонта                       Ю3
# 4925                             Запуск без ремонта                       Ю3
# 4926                             Запуск без ремонта                       Ю3
# 4927                             Запуск без ремонта                       Ю3
#
#       Объект разработки после ГТМ Страница  Dэк  \
# 0                             NaN      -1_  NaN
# 1                             NaN      -1_  NaN
# 2                             NaN      -1_  NaN
# 3                             NaN      -1_  NaN
# 4                             NaN      -1_  NaN
# ...                           ...      ...  ...
# 4923                          NaN      -1_  NaN
# 4924                          NaN      -1_  NaN
# 4925                          NaN      -1_  NaN
# 4926                          NaN      -1_  NaN
# 4927                          NaN      -1_  NaN
#
#                            Краткое описание мероприятий  ...  Напор.1  \
# 0                    КР9-5 Перевод скважин в добывающие  ...      NaN
# 1                                  КР7-2 Проведение ГРП  ...      NaN
# 2     КР9-6 Перевод под нагнетание из других категор...  ...      NaN
# 3                                        Проведение ВПП  ...      NaN
# 4                        Гидродинамические исследования  ...      NaN
# ...                                                 ...  ...      ...
# 4923                        Запуск в работу без ремонта  ...      NaN
# 4924                        Запуск в работу без ремонта  ...      NaN
# 4925                        Запуск в работу без ремонта  ...      NaN
# 4926                        Запуск в работу без ремонта  ...      NaN
# 4927                        Запуск в работу без ремонта  ...      NaN
#
#       Производительность.1  Комментарий  План  Факт  Пл-ть нефти  Коб  \
# 0                      NaN          NaN   NaN   NaN          NaN  NaN
# 1                      NaN          NaN   NaN   NaN          NaN  NaN
# 2                      NaN          NaN   NaN   NaN          NaN  NaN
# 3                      NaN          NaN   NaN   NaN          NaN  NaN
# 4                      NaN          NaN   NaN   NaN          NaN  NaN
# ...                    ...          ...   ...   ...          ...  ...
# 4923                   NaN          NaN   NaN   NaN          NaN  NaN
# 4924                   NaN          NaN   NaN   NaN          NaN  NaN
# 4925                   NaN          NaN   NaN   NaN          NaN  NaN
# 4926                   NaN          NaN   NaN   NaN          NaN  NaN
# 4927                   NaN          NaN   NaN   NaN          NaN  NaN
#
#       В-ть жидк.  P нас  Unnamed: 65
# 0            NaN    NaN          NaN
# 1            NaN    NaN          NaN
# 2            NaN    NaN          NaN
# 3            NaN    NaN          NaN
# 4            NaN    NaN          NaN
# ...          ...    ...          ...
# 4923         NaN    NaN          NaN
# 4924         NaN    NaN          NaN
# 4925         NaN    NaN          NaN
# 4926         NaN    NaN          NaN
# 4927         NaN    NaN          NaN
#
# [4928 rows x 66 columns]

# %%
grp_zbs = grp_4.drop(grp_4[grp_4['Тип'] != '3БС'].index).reset_index(drop=True)
        # grp_zbs = grp_4.loc[grp_4['Тип'] == 'ЗБС']
grp_zbs = grp_zbs.groupby('Скважина').agg(
            {'Начало.1': lambda x:
            x.tolist()[1] if len(x.tolist()) > 1
            else x.tolist()[0]}
        )
grp_zbs
# Out:
#            Начало.1
# Скважина
# 123      2019-07-13
# 1230     2014-07-12
# 1304     2014-07-09
# 1311     2011-12-05
# 133      2014-03-28
# ...             ...
# 890      2021-11-16
# 897      2012-04-26
# 906      2021-09-30
# 909      2014-07-03
# 949      2021-09-11
#
# [79 rows x 1 columns]

# %%
grp_zbs.reset_index(drop=True)
grp_zbs.reset_index(inplace=True)
        # grp_zbs

vv = grp_zbs['Скважина'].tolist()

grp_zbs['Скважина №'] = vv
grp_zbs = grp_zbs.drop(['Скважина'], axis=1)
grp_zbs
# Out:
#      Начало.1 Скважина №
# 0  2019-07-13        123
# 1  2014-07-12       1230
# 2  2014-07-09       1304
# 3  2011-12-05       1311
# 4  2014-03-28        133
# ..        ...        ...
# 74 2021-11-16        890
# 75 2012-04-26        897
# 76 2021-09-30        906
# 77 2014-07-03        909
# 78 2021-09-11        949
#
# [79 rows x 2 columns]

# %%
grp_zbs.loc[grp_zbs['Скважина №'] == '507']
# Out:
#      Начало.1 Скважина №
# 43 2011-06-15        507

# %%
sotired_final_zbs = sotired.merge(grp_zbs, on='Скважина №')
sotired_final_zbs
# Out:
#     Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0          123   313.336879               0.0                     0
# 1          123   313.336879               NaN                   100
# 2          123   313.336879               NaN                   100
# 3          123   313.336879               0.0                     0
# 4          123   313.336879               0.0                     0
# ..         ...          ...               ...                   ...
# 274        906     0.000000               0.0                     0
# 275        906     0.000000               0.0                     0
# 276        909   294.803324               NaN                   100
# 277        909   294.803324               4.0                   100
# 278        949   343.052474               0.0                     0
#
#      Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после  ГС/ННС  \
# 0                     0                           0     2009-01-20      ГС
# 1                     4                         100     2009-03-16  ГС+ГРП
# 2                     4                         100     2012-07-15  ГС+ГРП
# 3                     0                           0     2019-06-16      ГС
# 4                     0                           0     2019-08-18      ГС
# ..                  ...                         ...            ...     ...
# 274                   0                           0     2021-08-15     ННС
# 275                   0                           0     2021-09-30     ННС
# 276                   4                         100     2011-01-10  ГС+ГРП
# 277                   4                         100     2014-07-03  ГС+ГРП
# 278                   0                           0     2021-09-24      ГС
#
#      Тип ГТМ Пласт   Начало.1
# 0        ВНС    Ю3 2019-07-13
# 1        ГРП    Ю3 2019-07-13
# 2        ГРП    Ю3 2019-07-13
# 3        3БС    Ю3 2019-07-13
# 4        3БС    Ю3 2019-07-13
# ..       ...   ...        ...
# 274      3БС    Ю3 2021-09-30
# 275      3БС    Ю3 2021-09-30
# 276      ГРП    Ю3 2014-07-03
# 277  3БС+ГРП    Ю3 2014-07-03
# 278      3БС    Ю3 2021-09-11
#
# [279 rows x 11 columns]

# %%
abba = sotired_final_zbs['Скважина №'].tolist()

arura=[]
for i in abba:
    if i not in arura:
        arura.append(i)
arura
# Out:
# ['123',
#  '1230',
#  '1304',
#  '1311',
#  '133',
#  '14',
#  '142',
#  '1468',
#  '1501',
#  '1503',
#  '151',
#  '1549',
#  '1556',
#  '1562',
#  '1603',
#  '1622',
#  '1635',
#  '1637',
#  '17',
#  '173Р',
#  '1901',
#  '1977',
#  '21',
#  '23',
#  '256Р',
#  '2818',
#  '35',
#  '3552',
#  '3821',
#  '3825',
#  '4100',
#  '415',
#  '433',
#  '449',
#  '454',
#  '459',
#  '463',
#  '485',
#  '489',
#  '491',
#  '494',
#  '5',
#  '500',
#  '507',
#  '515',
#  '541',
#  '567',
#  '569',
#  '582',
#  '6',
#  '603',
#  '619',
#  '626',
#  '636',
#  '65',
#  '675',
#  '68',
#  '71',
#  '720',
#  '724',
#  '726',
#  '729',
#  '738',
#  '739',
#  '762',
#  '763',
#  '766',
#  '770',
#  '79',
#  '8',
#  '806',
#  '84',
#  '85',
#  '87',
#  '890',
#  '897',
#  '906',
#  '909',
#  '949']

# %%
if sotired_final_zbs.shape[0] != 0:
    
    sotired_final_zbs['Число стадий ГРП'] = sotired_final_zbs.apply(
            lambda x:
            1 if x['Дата ВНР после'] < x['Начало.1'] else x['Число стадий ГРП'],
            axis=1
            )
    sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            str(x['Скважина №'])
            + ('_Л' if x['Дата ВНР после'] < x['Начало.1'] else ''),
            axis=1
            )
    sotired_final_zbs = sotired_final_zbs.drop(['Начало.1'], axis=1)
    sotired_final = sotired[~sotired['Скважина №'].isin(arura)].reset_index(drop=True)
sotired_final1 = pd.concat([sotired_final, sotired_final_zbs])
sotired_final1.reset_index(drop=True)
sotired_final1.reset_index(inplace=True)
sotired_final1
# Out:
#      index Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        0          1     0.000000               1.0                   100
# 1        1         10     0.000000               0.0                     0
# 2        2         10     0.000000               1.0                   100
# 3        3       1004     0.000000               NaN                   100
# 4        4       1004     0.000000               1.0                   100
# ..     ...        ...          ...               ...                   ...
# 959    274      906_Л     0.000000               1.0                     0
# 960    275        906     0.000000               0.0                     0
# 961    276      909_Л   294.803324               1.0                   100
# 962    277        909   294.803324               4.0                   100
# 963    278        949   343.052474               0.0                     0
#
#      Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после   ГС/ННС  \
# 0                     4                         100     2016-03-12  ННС+ГРП
# 1                     0                           0     2008-10-12      ННС
# 2                     4                         100     2013-03-03  ННС+ГРП
# 3                     4                         100     2011-02-04  ННС+ГРП
# 4                     4                         100     2013-01-31  ННС+ГРП
# ..                  ...                         ...            ...      ...
# 959                   0                           0     2021-08-15      ННС
# 960                   0                           0     2021-09-30      ННС
# 961                   4                         100     2011-01-10   ГС+ГРП
# 962                   4                         100     2014-07-03   ГС+ГРП
# 963                   0                           0     2021-09-24       ГС
#
#      Тип ГТМ Пласт
# 0        ГРП    Ю3
# 1        ВНС    Ю3
# 2        ГРП    Ю3
# 3        ГРП    Ю3
# 4        ГРП    Ю3
# ..       ...   ...
# 959      3БС    Ю3
# 960      3БС    Ю3
# 961      ГРП    Ю3
# 962  3БС+ГРП    Ю3
# 963      3БС    Ю3
#
# [964 rows x 11 columns]

# %%
        # приставка ФРАК там где надо
sotired_final.reset_index(drop=True)
sotired_final.reset_index(inplace=True)
sotired_final['index']=sotired_final.index
step = sotired_final.drop(
            sotired_final[(sotired_final['ГС/ННС'] == 'ГС') | (sotired_final['ГС/ННС'] == 'ННС')].index)
step['для_фрак'] = step.apply(
            lambda x:
            x['Скважина №'].partition('_')[0] if '_' in str(x['Скважина №'])
            else x['Скважина №'], axis=1)
step = step.groupby(by=['для_фрак']).agg(
            {'index': lambda x:
            x.tolist()}
        )
step
# Out:
#               index
# для_фрак
# 1               [0]
# 10              [2]
# 1004      [3, 4, 5]
# 1005            [6]
# 1006            [7]
# ...             ...
# 936           [679]
# 942           [680]
# 96            [681]
# 971           [683]
# 99            [684]
#
# [338 rows x 1 columns]

# %%
step.reset_index(inplace=True)
step.rename(columns={'для_фрак': 'список'}, inplace=True)

step['Length'] = step.apply(
            lambda x: len(x['index'])
            , axis=1)
step = step.drop(step[step['Length'] < 1].index)
gang1 = []
gang2 = []
gang3 = []
gang4 = []
gang5 = []
gang6 = []
gang7 = []
gang8 = []
gang9 = []
gang10 = []
gang1
# Out:
# []

# %%
for i in step['index']:
    if len(i) >= 1:
        gang1.append(i[0])
    if len(i) >= 2:
        gang2.append(i[1])
    if len(i) >= 3:
        gang3.append(i[2])
    if len(i) >= 4:
        gang4.append(i[3])
    if len(i) >= 5:
        gang5.append(i[4])
    if len(i) >= 6:
        gang6.append(i[5])
    if len(i) >= 7:
        gang7.append(i[6])
    if len(i) >= 8:
        gang8.append(i[7])
    if len(i) >= 9:
        gang9.append(i[8])
    if len(i) >= 10:
        gang10.append(i[9])
    else:
        pass
gang1
# Out:
# [0,
#  2,
#  3,
#  6,
#  7,
#  10,
#  12,
#  13,
#  15,
#  16,
#  17,
#  18,
#  19,
#  20,
#  22,
#  23,
#  24,
#  27,
#  29,
#  31,
#  32,
#  34,
#  36,
#  38,
#  41,
#  42,
#  47,
#  48,
#  50,
#  52,
#  54,
#  57,
#  58,
#  63,
#  66,
#  67,
#  69,
#  70,
#  72,
#  75,
#  77,
#  80,
#  83,
#  84,
#  87,
#  89,
#  92,
#  95,
#  96,
#  99,
#  103,
#  106,
#  107,
#  109,
#  111,
#  112,
#  113,
#  114,
#  117,
#  119,
#  122,
#  123,
#  126,
#  127,
#  130,
#  133,
#  136,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  144,
#  147,
#  149,
#  150,
#  151,
#  152,
#  153,
#  154,
#  155,
#  156,
#  157,
#  159,
#  160,
#  161,
#  162,
#  163,
#  164,
#  165,
#  166,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  174,
#  175,
#  176,
#  177,
#  178,
#  179,
#  182,
#  184,
#  187,
#  189,
#  190,
#  192,
#  193,
#  194,
#  196,
#  198,
#  200,
#  201,
#  204,
#  211,
#  213,
#  216,
#  220,
#  224,
#  227,
#  230,
#  232,
#  233,
#  243,
#  244,
#  248,
#  249,
#  250,
#  251,
#  253,
#  256,
#  257,
#  259,
#  260,
#  262,
#  263,
#  264,
#  265,
#  270,
#  272,
#  275,
#  277,
#  279,
#  280,
#  283,
#  284,
#  285,
#  286,
#  289,
#  291,
#  294,
#  296,
#  299,
#  300,
#  302,
#  304,
#  306,
#  307,
#  308,
#  309,
#  310,
#  311,
#  315,
#  318,
#  319,
#  321,
#  323,
#  325,
#  328,
#  329,
#  330,
#  333,
#  334,
#  339,
#  344,
#  346,
#  349,
#  351,
#  352,
#  353,
#  354,
#  358,
#  361,
#  363,
#  366,
#  368,
#  371,
#  372,
#  373,
#  375,
#  377,
#  381,
#  383,
#  384,
#  385,
#  387,
#  388,
#  391,
#  393,
#  396,
#  398,
#  400,
#  404,
#  407,
#  409,
#  412,
#  414,
#  417,
#  420,
#  423,
#  425,
#  427,
#  431,
#  435,
#  436,
#  437,
#  438,
#  440,
#  441,
#  444,
#  448,
#  451,
#  453,
#  457,
#  459,
#  461,
#  463,
#  464,
#  465,
#  469,
#  471,
#  474,
#  483,
#  485,
#  486,
#  488,
#  490,
#  492,
#  494,
#  496,
#  498,
#  500,
#  503,
#  505,
#  509,
#  513,
#  518,
#  520,
#  523,
#  525,
#  526,
#  528,
#  530,
#  532,
#  534,
#  535,
#  538,
#  539,
#  541,
#  542,
#  543,
#  544,
#  546,
#  548,
#  549,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  558,
#  559,
#  561,
#  564,
#  566,
#  568,
#  570,
#  572,
#  574,
#  575,
#  576,
#  582,
#  583,
#  585,
#  586,
#  588,
#  591,
#  593,
#  595,
#  598,
#  600,
#  601,
#  604,
#  606,
#  607,
#  609,
#  611,
#  613,
#  615,
#  617,
#  619,
#  621,
#  624,
#  625,
#  628,
#  629,
#  631,
#  632,
#  633,
#  635,
#  639,
#  642,
#  643,
#  646,
#  648,
#  649,
#  651,
#  653,
#  655,
#  657,
#  659,
#  662,
#  664,
#  668,
#  670,
#  672,
#  674,
#  675,
#  677,
#  679,
#  680,
#  681,
#  683,
#  684]

# %%
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ГРП' if x['index'] in gang1
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_1' if x['index'] in gang2
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_2' if x['index'] in gang3
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_3' if x['index'] in gang4
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_4' if x['index'] in gang5
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_5' if x['index'] in gang6
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_6' if x['index'] in gang7
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_7' if x['index'] in gang8
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_8' if x['index'] in gang9
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_9' if x['index'] in gang10
            else x['Скважина №'], axis=1)
sotired_final = sotired_final.drop(['index'], axis=1)
sotired_final
# Out:
#       Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0          1_ГРП     0.000000               1.0                   100
# 1             10     0.000000               0.0                     0
# 2         10_ГРП     0.000000               1.0                   100
# 3       1004_ГРП     0.000000               NaN                   100
# 4    1004_ФРАК_1     0.000000               1.0                   100
# ..           ...          ...               ...                   ...
# 680      942_ГРП     0.000000               NaN                   100
# 681       96_ГРП     0.000000               1.0                   100
# 682          971   762.377859               0.0                     0
# 683      971_ГРП   762.377859               NaN                   100
# 684       99_ГРП     0.000000               1.0                   100
#
#      Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после   ГС/ННС  \
# 0                     4                         100     2016-03-12  ННС+ГРП
# 1                     0                           0     2008-10-12      ННС
# 2                     4                         100     2013-03-03  ННС+ГРП
# 3                     4                         100     2011-02-04  ННС+ГРП
# 4                     4                         100     2013-01-31  ННС+ГРП
# ..                  ...                         ...            ...      ...
# 680                   4                         100     2013-06-19  ННС+ГРП
# 681                   4                         100     2019-07-31  ННС+ГРП
# 682                   0                           0     2012-04-19       ГС
# 683                   4                         100     2013-01-23   ГС+ГРП
# 684                   4                         100     2019-11-01  ННС+ГРП
#
#     Тип ГТМ Пласт
# 0       ГРП    Ю3
# 1       ВНС    Ю3
# 2       ГРП    Ю3
# 3       ГРП    Ю3
# 4       ГРП    Ю3
# ..      ...   ...
# 680     ГРП    Ю3
# 681     ГРП    Ю3
# 682     ВНС    Ю3
# 683     ГРП    Ю3
# 684     ГРП    Ю3
#
# [685 rows x 10 columns]

# %%
        # sotired_final = sotired_final.drop(['месяц с грп'], axis=1)


sotired_final.reset_index(drop=True)
sotired_final.reset_index(inplace=True)
sotired_final = sotired_final.drop(['index'], axis=1)
sotired_final['Число стадий ГРП'] = sotired_final.apply(
            lambda x:
            1 if x['Длина ГС, м'] == 0 and 'ГРП' in x['ГС/ННС']
            else x['Число стадий ГРП'], axis=1)
sotired_final_zbs['index']=sotired_final_zbs.index
sotired_final_zbs.reset_index(drop=True)
sotired_final_zbs.reset_index(inplace=True)
step1 = sotired_final_zbs.drop(
            sotired_final_zbs[(sotired_final_zbs['ГС/ННС'] == 'ГС') | (sotired_final_zbs['ГС/ННС'] == 'ННС')].index)
step1 = step1.groupby(by=['Скважина №']).agg(
            {'index': lambda x:
            x.tolist()}
        )
step1.reset_index(inplace=True)
step1['Length'] = step1.apply(
            lambda x: len(x['index'])
            , axis=1)
step1 = step1.drop(step1[step1['Length'] < 1].index)
gang11 = []
gang21 = []
gang31 = []
gang41 = []
gang51 = []
gang61 = []
gang71 = []
gang81 = []
gang91 = []
gang101 = []
gang11
# Out:
# []

# %%
for i in step1['index']:
    if len(i) >= 1:
        gang11.append(i[0])
    if len(i) >= 2:
        gang21.append(i[1])
    if len(i) >= 3:
        gang31.append(i[2])
    if len(i) >= 4:
        gang41.append(i[3])
    if len(i) >= 5:
        gang51.append(i[4])
    if len(i) >= 6:
        gang61.append(i[5])
    if len(i) >= 7:
        gang71.append(i[6])
    if len(i) >= 8:
        gang81.append(i[7])
    if len(i) >= 9:
        gang91.append(i[8])
    if len(i) >= 10:
        gang101.append(i[9])
    else:
        pass
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ГРП' if x['index'] in gang11
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_1' if x['index'] in gang21
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_2' if x['index'] in gang31
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_3' if x['index'] in gang41
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_4' if x['index'] in gang51
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_5' if x['index'] in gang61
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_6' if x['index'] in gang71
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_7' if x['index'] in gang81
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_8' if x['index'] in gang91
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_9' if x['index'] in gang101
            else x['Скважина №'], axis=1)
sotired_final_zbs = sotired_final_zbs.drop(['index'], axis=1)

        
sotired_final_zbs.reset_index(drop=True)
sotired_final_zbs.reset_index(inplace=True)
sotired_final_zbs = sotired_final_zbs.drop(['index'], axis=1)
sotired_final_zbs['Число стадий ГРП'] = sotired_final_zbs.apply(
            lambda x:
            1 if x['Длина ГС, м'] == 0 and 'ГРП' in x['ГС/ННС']
            else x['Число стадий ГРП'], axis=1)
we_here = pd.concat([sotired_final, sotired_final_zbs])
we_here['Число стадий ГРП'] = we_here.apply(
            lambda x:
            1 if 'ФРАК' in str(x['Скважина №'])
            else x['Число стадий ГРП'], axis=1)
we_here['Число стадий ГРП'] = we_here.apply(
            lambda x:
            0 if 'ГС' == str(x['ГС/ННС'])
            else x['Число стадий ГРП'], axis=1)
we_here['Число стадий ГРП'] = we_here.apply(
            lambda x:
            0 if 'ННС' == str(x['ГС/ННС'])
            else x['Число стадий ГРП'], axis=1)
we_here['Скважина №'] = we_here.apply(
            lambda x:
            str(x['Скважина №']).replace('_Л', 'Л') if '_Л' in str(x['Скважина №']) else str(x['Скважина №']),
            axis=1
        )
we_here
# Out:
#       Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0          1_ГРП     0.000000               1.0                   100
# 1             10     0.000000               0.0                     0
# 2         10_ГРП     0.000000               1.0                   100
# 3       1004_ГРП     0.000000               1.0                   100
# 4    1004_ФРАК_1     0.000000               1.0                   100
# ..           ...          ...               ...                   ...
# 274         906Л     0.000000               0.0                     0
# 275          906     0.000000               0.0                     0
# 276     909Л_ГРП   294.803324               1.0                   100
# 277      909_ГРП   294.803324               4.0                   100
# 278          949   343.052474               0.0                     0
#
#      Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после   ГС/ННС  \
# 0                     4                         100     2016-03-12  ННС+ГРП
# 1                     0                           0     2008-10-12      ННС
# 2                     4                         100     2013-03-03  ННС+ГРП
# 3                     4                         100     2011-02-04  ННС+ГРП
# 4                     4                         100     2013-01-31  ННС+ГРП
# ..                  ...                         ...            ...      ...
# 274                   0                           0     2021-08-15      ННС
# 275                   0                           0     2021-09-30      ННС
# 276                   4                         100     2011-01-10   ГС+ГРП
# 277                   4                         100     2014-07-03   ГС+ГРП
# 278                   0                           0     2021-09-24       ГС
#
#      Тип ГТМ Пласт  level_0
# 0        ГРП    Ю3      NaN
# 1        ВНС    Ю3      NaN
# 2        ГРП    Ю3      NaN
# 3        ГРП    Ю3      NaN
# 4        ГРП    Ю3      NaN
# ..       ...   ...      ...
# 274      3БС    Ю3    274.0
# 275      3БС    Ю3    275.0
# 276      ГРП    Ю3    276.0
# 277  3БС+ГРП    Ю3    277.0
# 278      3БС    Ю3    278.0
#
# [964 rows x 11 columns]

# %%
we_here.to_excel('10_03_22.xlsx')
