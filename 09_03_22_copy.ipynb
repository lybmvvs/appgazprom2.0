# %%
import sys
import copy
import pandas as pd
import statistics
import datetime

# %%
grp_dad = pd.read_excel('3.xlsx',header=[1], index_col=[1])
print(grp_dad.head(20),grp_dad.shape)
# Out:
# C:\Users\USER\miniconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                  Unnamed: 0       Дата Подрядчик  \
# Номер скважины
# 99Б             Проблемы при построении ГРП 2014-05-29       ТВС
# 99              Проблемы при построении ГРП 2015-12-04        КН
# 99              Проблемы при построении ГРП 2011-03-27       ТВС
# 97              Проблемы при построении ГРП 2014-06-03       ТВС
# 969             Проблемы при построении ГРП 2014-12-19       ТВС
# 969             Проблемы при построении ГРП 2014-12-11       ТВС
# 965             Проблемы при построении ГРП 2014-10-27       МКН
# 965             Проблемы при построении ГРП 2014-10-26       ТВС
# 965             Проблемы при построении ГРП 2014-10-26       ТВС
# 944             Проблемы при построении ГРП 2008-04-08       МКН
# 94              Проблемы при построении ГРП 2014-05-31       МКН
# 93Л             Проблемы при построении ГРП 2018-11-16        КН
# 93Л             Проблемы при построении ГРП 2018-11-15        КН
# 93Л             Проблемы при построении ГРП 2018-11-15        КН
# 93Л             Проблемы при построении ГРП 2018-11-15        КН
# 93Л             Проблемы при построении ГРП 2018-11-14        КН
# 939             Проблемы при построении ГРП 2016-08-29        КН
# 939             Проблемы при построении ГРП 2008-04-15       МКН
# 924             Проблемы при построении ГРП 2020-01-14       МКМ
# 924             Проблемы при построении ГРП 2020-01-14       МКМ
#
#                                                       Комментарии Страница  \
# Номер скважины
# 99Б             ГРП по плану (+), 10т. По результатам заполнен...      -1_
# 99                                                            336      -1_
# 99                                        ГРП по плану  (+), 17т.      -1_
# 97              ГРП (-), ОТКЛОНЕНИЕ от плана, 14-11-10.7т. По ...      -1_
# 969                                                           336      -1_
# 969                                                           336      -1_
# 965                                                           336      -1_
# 965                                                           336      -1_
# 965                                                           336      -1_
# 944             Увеличили стадию подушка до 18м3 (план 16м3). ...      -1_
# 94              После анализа данных, полученных после  провед...      -1_
# 93Л             Оборудование:  НКТ, АМТ-  ЗАО СП "МеКаМинефть"...      -1_
# 93Л             Оборудование:  НКТ, АМТ-  ЗАО СП "МеКаМинефть"...      -1_
# 93Л             Оборудование:  НКТ, АМТ-  ЗАО СП "МеКаМинефть"...      -1_
# 93Л             Оборудование:  НКТ, АМТ-  ЗАО СП "МеКаМинефть"...      -1_
# 93Л             Оборудование:  НКТ, АМТ-  ЗАО СП "МеКаМинефть"...      -1_
# 939                                                           336      -1_
# 939             По результату Мини-ГРП принято решение оставит...      -1_
# 924             ГРП по плану (+), 10 т.  Выполнена стадия Запо...      -1_
# 924             ГРП по плану (+), 7 т.  Выполнена стадия Запол...      -1_
#
#                 Unnamed: 6   Пласт  Наклон  Азимут     k  ...  \
# Номер скважины                                            ...
# 99Б                    NaN   А1(3)    6.00   358.0   9.3  ...
# 99                     NaN      А3    0.85   354.0   9.7  ...
# 99                     NaN      Б9   24.00   103.0  20.0  ...
# 97                     NaN      Б9    1.00     NaN   9.2  ...
# 969                    NaN      А3   24.00    51.0   6.3  ...
# 969                    NaN      А3   24.00    51.0   6.3  ...
# 965                    NaN  Б17-21   85.30   331.0   5.1  ...
# 965                    NaN  Б17-21   88.00   337.0   5.1  ...
# 965                    NaN  Б17-21   88.00   337.0   5.1  ...
# 944                    NaN      А4    9.00   222.0   9.2  ...
# 94                     NaN      Б9   11.75   223.0  10.0  ...
# 93Л                    NaN  Б17-21   85.91   238.6   6.2  ...
# 93Л                    NaN  Б17-21   85.91   238.6   6.2  ...
# 93Л                    NaN  Б17-21   85.91   238.6   6.2  ...
# 93Л                    NaN  Б17-21   85.91   238.6   6.2  ...
# 93Л                    NaN  Б17-21   85.91   238.6   6.2  ...
# 939                    NaN      А3   17.00   163.0  14.0  ...
# 939                    NaN   А1(3)    5.80   282.0  36.0  ...
# 924                    NaN  Б17-21   91.00   270.0   1.3  ...
# 924                    NaN  Б17-21   86.00   271.0   1.3  ...
#
#                                               Проппант  Рпл Хорнер   Эфф  \
# Номер скважины
# 99Б                                                NaN       115.0   NaN
# 99                       Welltech 20/40+Welltech 16/20         NaN  58.0
# 99                                                 NaN       157.0  30.0
# 97                                                 NaN       165.0  64.0
# 969             QuartzSand+20/40BoroProp+16/20BoroProp         NaN  46.0
# 969                        20/40BoroProp+16/20BoroProp         NaN  76.0
# 965                      20/40 БКО +16/20 БКО+12/18БКО         NaN  60.0
# 965                      20/40 БКО +16/20 БКО+12/18БКО         NaN  60.0
# 965                               20/40 БКО +16/20 БКО         NaN  50.0
# 944                                                NaN       157.0  38.0
# 94                                                 NaN       179.0  35.0
# 93Л                  NIKA (Ptprop)+NIKA (Ptprop)+Fores        21.0  61.0
# 93Л                  NIKA (Ptprop)+NIKA (Ptprop)+Fores        23.0  76.0
# 93Л                  NIKA (Ptprop)+NIKA (Ptprop)+Fores        51.0  35.0
# 93Л                        NIKA (Ptprop)+NIKA (Ptprop)        35.0  45.0
# 93Л                        NIKA (Ptprop)+NIKA (Ptprop)        48.0  44.0
# 939                     WellTech 20/40+WellTech 16/20+         NaN  60.0
# 939                                                NaN       147.0  40.0
# 924                              20/40 Nika+16/30 Nika         8.5  53.2
# 924                              20/40 Nika+16/30 Nika        15.0  70.5
#
#                 Расход    Конц  Гель   М бр  V под  V без под  V гель
# Номер скважины
# 99Б                2.0  1000.0   NaN   26.9    8.0   40.10000     NaN
# 99                 2.0   800.0   NaN   64.8   16.0   95.18816     NaN
# 99                 2.2  1100.0   NaN    NaN   12.0   82.50000     NaN
# 97                 2.0   810.0   NaN   46.3    7.0  101.80000     NaN
# 969                2.0   800.0   NaN   59.0    7.0   64.90000     NaN
# 969                1.8  1200.0   NaN   15.7    8.0   34.40000     NaN
# 965                3.5   800.0   NaN  132.0  122.0  379.10000     NaN
# 965                3.5   800.0   NaN  136.0  115.0  372.30000     NaN
# 965                3.2   800.0   NaN  121.0   61.0  238.50000     NaN
# 944                NaN   800.0   NaN    NaN   18.0   90.50000     NaN
# 94                 2.8  1000.0   NaN   46.9   14.0   46.90000     NaN
# 93Л                3.2   900.0   NaN   33.5   27.0   91.00000     NaN
# 93Л                3.2   900.0   NaN   52.0   27.0   91.00000     NaN
# 93Л                3.2   800.0   NaN   45.0   37.0  118.00000     NaN
# 93Л                3.2   800.0   NaN   45.0   27.0   67.00000     NaN
# 93Л                3.2   800.0   NaN   68.0   35.0  109.00000     NaN
# 939                2.2  1100.0   NaN   33.0    9.0   51.00000     NaN
# 939                NaN   900.0   NaN    NaN   16.0   93.20000     NaN
# 924                3.4   800.0   NaN   18.5    8.0    8.00000    54.4
# 924                3.4   800.0   NaN   12.5    6.0        NaN    27.4
#
# [20 rows x 35 columns] (2261, 35)

# %%
grp_gtm = pd.read_excel('1.xlsx',header=[1], index_col=[1])
print(grp_gtm.head(10),grp_gtm.shape)
# Out:
# C:\Users\USER\miniconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                Unnamed: 0 Скважина     Куст       Тип  \
# Месторождение
# Аганское       Добывающая        1  КУСТ-67  Доп.перф
# Аганское       Добывающая        1  КУСТ-67       РИР
# Аганское       Добывающая        1  КУСТ-67       РИР
# Аганское       Добывающая       10  КУСТ-50       РИР
# Аганское       Добывающая       10  КУСТ-50       РИР
# Аганское       Добывающая       10  КУСТ-50  Доп.перф
# Аганское       Добывающая      100  КУСТ-12       РИР
# Аганское       Добывающая      100  КУСТ-12       РИР
# Аганское       Добывающая      100  КУСТ-12       РИР
# Аганское       Добывающая      100  КУСТ-12       РИР
#
#               Краткое описание мероприятий Объект разработки до ГТМ  \
# Месторождение
# Аганское                               NaN                      NaN
# Аганское                               NaN                      NaN
# Аганское                               NaN                      NaN
# Аганское                               NaN                      NaN
# Аганское                               NaN                      NaN
# Аганское                               NaN                      NaN
# Аганское                               NaN                      NaN
# Аганское                               NaN                      NaN
# Аганское                               NaN                      NaN
# Аганское                               NaN                      NaN
#
#                Объект разработки после ГТМ  Dэк Страница  Unnamed: 10  ...  \
# Месторождение                                                          ...
# Аганское                               NaN  NaN      -1_          NaN  ...
# Аганское                               NaN  NaN      -1_          NaN  ...
# Аганское                               NaN  NaN      -1_          NaN  ...
# Аганское                               NaN  NaN      -1_          NaN  ...
# Аганское                               NaN  NaN      -1_          NaN  ...
# Аганское                               NaN  NaN      -1_          NaN  ...
# Аганское                               NaN  NaN      -1_          NaN  ...
# Аганское                               NaN  NaN      -1_          NaN  ...
# Аганское                               NaN  NaN      -1_          NaN  ...
# Аганское                               NaN  NaN      -1_          NaN  ...
#
#                Состояние.1  Кпр  Скин-фактор.1  Комментарий  План  Факт  \
# Месторождение
# Аганское               NaN  NaN            NaN          NaN   NaN   NaN
# Аганское               NaN  NaN            NaN          NaN   NaN   NaN
# Аганское               NaN  NaN            NaN          NaN   NaN   NaN
# Аганское               NaN  NaN            NaN          NaN   NaN   NaN
# Аганское               NaN  NaN            NaN          NaN   NaN   NaN
# Аганское               NaN  NaN            NaN          NaN   NaN   NaN
# Аганское               NaN  NaN            NaN          NaN   NaN   NaN
# Аганское               NaN  NaN            NaN          NaN   NaN   NaN
# Аганское               NaN  NaN            NaN          NaN   NaN   NaN
# Аганское               NaN  NaN            NaN          NaN   NaN   NaN
#
#                Пл-ть нефти  Коб  В-ть жидк.  P нас
# Месторождение
# Аганское               NaN  NaN         NaN    NaN
# Аганское               NaN  NaN         NaN    NaN
# Аганское               NaN  NaN         NaN    NaN
# Аганское               NaN  NaN         NaN    NaN
# Аганское               NaN  NaN         NaN    NaN
# Аганское               NaN  NaN         NaN    NaN
# Аганское               NaN  NaN         NaN    NaN
# Аганское               NaN  NaN         NaN    NaN
# Аганское               NaN  NaN         NaN    NaN
# Аганское               NaN  NaN         NaN    NaN
#
# [10 rows x 64 columns] (27544, 64)

# %%
coordinates = pd.read_excel('2.xlsx')
print(coordinates.head(10),coordinates.shape)
# Out:
#   № скважины  Координата X  Координата Y  Координата забоя Х (по траектории)  \
# 0          1        561371       6814685                              561365
# 1         10        565617       6812237                              565622
# 2        100        563312       6814342                              563435
# 3       1000        550406       6814136                              550366
# 4       1001        558031       6820598                              558008
# 5       1002        557998       6820121                              557998
# 6      10027        557702       6820448                              557550
# 7      10028        557664       6820016                              557599
# 8       1003        558540       6820749                              558576
# 9       1004        558039       6819398                              557909
#
#    Координата забоя Y (по траектории)
# 0                             6814684
# 1                             6812254
# 2                             6814435
# 3                             6814104
# 4                             6820606
# 5                             6820098
# 6                             6820362
# 7                             6819882
# 8                             6820843
# 9                             6819020   (2030, 5)

# %%
grp_dad.reset_index(drop=True)
grp_dad.reset_index(inplace=True)

# %%
#вставка 22.02.22
grp_dad['Номер скважины'] = grp_dad.apply(
            lambda x:
            str(x['Номер скважины']), axis=1)
grp_gtm['Скважина'] = grp_gtm.apply(
            lambda x:
            str(x['Скважина']), axis=1)

        #вставка 22.02.22

# %%
plasttt = 'Б6'
grp_dad['удалю'] = grp_dad.apply(
            lambda x:
            'нет' if plasttt in str(x['Пласт'])
            else 'да', axis=1)
grp_dad = grp_dad.drop(grp_dad[grp_dad['удалю'] == 'да'].index).reset_index(drop=True)
grp_dad = grp_dad.drop(['удалю'], axis=1)
grp_gtm.reset_index(drop=True)
grp_gtm.reset_index(inplace=True)
grp_gtm = grp_gtm[grp_gtm['Объект разработки до ГТМ'].notna()]
grp_dad.head(10)
# Out:
#   Номер скважины                   Unnamed: 0       Дата Подрядчик  \
# 0            805  Проблемы при построении ГРП 2009-07-02       МКН
# 1            804  Проблемы при построении ГРП 2007-06-27       МКН
# 2            801                          NaN 2012-09-06       МКН
# 3            688                          NaN 2006-08-12       ШЛБ
# 4             66  Проблемы при построении ГРП 2008-07-31       МКН
# 5            634                          NaN 2006-08-13       ХЛБ
# 6            632  Проблемы при построении ГРП 2013-03-05       ТВС
# 7            577  Проблемы при построении ГРП 2009-10-05       ТВС
# 8            577                          NaN 2004-03-15       МКН
# 9            560  Проблемы при построении ГРП 2004-01-12       МКН
#
#                                          Комментарии Страница  Unnamed: 6  \
# 0  После анализа данных, полученных при проведени...      -1_         NaN
# 1  По результату Мини-ГРП принято решение уменьши...      -1_         NaN
# 2  После анализа данных, полученных при проведени...      -1_         NaN
# 3                                                NaN      -1_         NaN
# 4  Уменьшили подушку до 11м3 (план 20м3), увеличи...      -1_         NaN
# 5                                                NaN      -1_         NaN
# 6  ГРП по плану (+), 3т. уменьшена подушка с 3 м3...      -1_         NaN
# 7                                       По программе      -1_         NaN
# 8                                                NaN      -1_         NaN
# 9                        Без миниГРП. Без остановки.      -1_         NaN
#
#   Пласт  Наклон  Азимут  ...  Проппант  Рпл Хорнер   Эфф  Расход    Конц  \
# 0    Б6   14.70   197.0  ...       NaN       199.0  33.0     2.0   900.0
# 1    Б6   33.70   220.0  ...       NaN       147.0  42.0     NaN   700.0
# 2    Б6   19.10   255.0  ...       NaN       167.0  65.0     2.4   900.0
# 3    Б6    2.00   312.0  ...       NaN         NaN   NaN     NaN     NaN
# 4    Б6   11.16   164.0  ...       NaN       166.0  54.0     NaN   800.0
# 5    Б6    8.00     NaN  ...       NaN       175.0   NaN     NaN     NaN
# 6    Б6   10.00    51.0  ...       NaN       164.0  55.0     2.0   600.0
# 7    Б6    8.00   219.0  ...       NaN       161.0  58.0     2.2  1230.0
# 8    Б6     NaN     NaN  ...       NaN         NaN   NaN     NaN     NaN
# 9    Б6     NaN     NaN  ...       NaN         NaN   NaN     NaN   670.0
#
#    Гель  М бр  V под  V без под  V гель
# 0   NaN   NaN    5.0       59.4     NaN
# 1   NaN   NaN    8.5       95.3     NaN
# 2   NaN   NaN    5.0       61.8     NaN
# 3   NaN   NaN    NaN        NaN     NaN
# 4   NaN   NaN   11.0       87.7     NaN
# 5   NaN   NaN   15.0        NaN     NaN
# 6   NaN   NaN    2.0       36.2     NaN
# 7   NaN   NaN   14.0      108.9     NaN
# 8   NaN   NaN    5.0        NaN     NaN
# 9   NaN   NaN    5.0       37.4     NaN
#
# [10 rows x 36 columns]

# %%
grp_gtm = grp_gtm.drop(grp_gtm[grp_gtm['Объект разработки до ГТМ'] != plasttt].index).reset_index(drop=True)
grp_gtm.head(10)
# Out:
#   Месторождение  Unnamed: 0 Скважина       Куст                 Тип  \
# 0      Аганское  Добывающая     1000  КУСТ-110Б                 ВНС
# 1      Аганское  Добывающая     1000  КУСТ-110Б                 ОПТ
# 2      Аганское  Добывающая     1000  КУСТ-110Б                 ОПТ
# 3      Аганское  Добывающая    10187    КУСТ-5Б                 ГРП
# 4      Аганское  Добывающая    10187    КУСТ-5Б                 ВНС
# 5      Аганское  Добывающая    10244   КУСТ-139                 ВНС
# 6      Аганское  Добывающая    10244   КУСТ-139               См_ПО
# 7      Аганское  Добывающая    10244   КУСТ-139               См_ПО
# 8      Аганское  Добывающая    10244   КУСТ-139  Запуск без ремонта
# 9      Аганское  Добывающая    10244   КУСТ-139               См_ПО
#
#           Краткое описание мероприятий Объект разработки до ГТМ  \
# 0   Ввод добывающих скважин из бурения                       Б6
# 1  ТР3 Оптимизация режима эксплуатации                       Б6
# 2  ТР3 Оптимизация режима эксплуатации                       Б6
# 3                 КР7-2 Проведение ГРП                       Б6
# 4   Ввод добывающих скважин из бурения                       Б6
# 5   Ввод добывающих скважин из бурения                       Б6
# 6                      ТР5-1 Смена ЭЦН                       Б6
# 7                      ТР5-1 Смена ЭЦН                       Б6
# 8          Запуск в работу без ремонта                       Б6
# 9      ТР5-7 Подъем воронки спуск УЭЦН                       Б6
#
#    Объект разработки после ГТМ  Dэк Страница  ...  Состояние.1  Кпр  \
# 0                          NaN  NaN      -1_  ...          NaN  NaN
# 1                          NaN  NaN      -1_  ...          NaN  NaN
# 2                          NaN  NaN      -1_  ...          NaN  NaN
# 3                          NaN  NaN      -1_  ...          NaN  NaN
# 4                          NaN  NaN      -1_  ...          NaN  NaN
# 5                          NaN  NaN      -1_  ...          NaN  NaN
# 6                          NaN  NaN      -1_  ...          NaN  NaN
# 7                          NaN  NaN      -1_  ...          NaN  NaN
# 8                          NaN  NaN      -1_  ...          NaN  NaN
# 9                          NaN  NaN      -1_  ...          NaN  NaN
#
#    Скин-фактор.1  Комментарий  План  Факт  Пл-ть нефти  Коб  В-ть жидк.  P нас
# 0            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 1            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 2            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 4            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 5            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 6            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 7            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 8            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 9            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
#
# [10 rows x 65 columns]

# %%
coordinates['Length'] = coordinates.apply(
            lambda x: ((x['Координата забоя Х (по траектории)'] - x['Координата X']) ** (2) +
                       (x['Координата забоя Y (по траектории)'] - x['Координата Y']) ** (2)) ** (0.5)
            , axis=1)
coordinates['№ скважины'] = coordinates.apply(
            lambda x:
            str(x['№ скважины']), axis=1)
grp = copy.deepcopy(grp_dad)
coordinates.head(10)
# Out:
#   № скважины  Координата X  Координата Y  Координата забоя Х (по траектории)  \
# 0          1        561371       6814685                              561365
# 1         10        565617       6812237                              565622
# 2        100        563312       6814342                              563435
# 3       1000        550406       6814136                              550366
# 4       1001        558031       6820598                              558008
# 5       1002        557998       6820121                              557998
# 6      10027        557702       6820448                              557550
# 7      10028        557664       6820016                              557599
# 8       1003        558540       6820749                              558576
# 9       1004        558039       6819398                              557909
#
#    Координата забоя Y (по траектории)      Length
# 0                             6814684    6.082763
# 1                             6812254   17.720045
# 2                             6814435  154.201167
# 3                             6814104   51.224994
# 4                             6820606   24.351591
# 5                             6820098   23.000000
# 6                             6820362  174.642492
# 7                             6819882  148.932871
# 8                             6820843  100.657836
# 9                             6819020  399.729909

# %%
grp_now_we_go = copy.deepcopy(grp_gtm)
#grp_now_we_go['Скважина'] = grp_now_we_go.apply(
#            lambda x:
#            str(x['Скважина']), axis=1)
grp_now_we_go.head(10)
# Out:
#   Месторождение  Unnamed: 0 Скважина       Куст                 Тип  \
# 0      Аганское  Добывающая     1000  КУСТ-110Б                 ВНС
# 1      Аганское  Добывающая     1000  КУСТ-110Б                 ОПТ
# 2      Аганское  Добывающая     1000  КУСТ-110Б                 ОПТ
# 3      Аганское  Добывающая    10187    КУСТ-5Б                 ГРП
# 4      Аганское  Добывающая    10187    КУСТ-5Б                 ВНС
# 5      Аганское  Добывающая    10244   КУСТ-139                 ВНС
# 6      Аганское  Добывающая    10244   КУСТ-139               См_ПО
# 7      Аганское  Добывающая    10244   КУСТ-139               См_ПО
# 8      Аганское  Добывающая    10244   КУСТ-139  Запуск без ремонта
# 9      Аганское  Добывающая    10244   КУСТ-139               См_ПО
#
#           Краткое описание мероприятий Объект разработки до ГТМ  \
# 0   Ввод добывающих скважин из бурения                       Б6
# 1  ТР3 Оптимизация режима эксплуатации                       Б6
# 2  ТР3 Оптимизация режима эксплуатации                       Б6
# 3                 КР7-2 Проведение ГРП                       Б6
# 4   Ввод добывающих скважин из бурения                       Б6
# 5   Ввод добывающих скважин из бурения                       Б6
# 6                      ТР5-1 Смена ЭЦН                       Б6
# 7                      ТР5-1 Смена ЭЦН                       Б6
# 8          Запуск в работу без ремонта                       Б6
# 9      ТР5-7 Подъем воронки спуск УЭЦН                       Б6
#
#    Объект разработки после ГТМ  Dэк Страница  ...  Состояние.1  Кпр  \
# 0                          NaN  NaN      -1_  ...          NaN  NaN
# 1                          NaN  NaN      -1_  ...          NaN  NaN
# 2                          NaN  NaN      -1_  ...          NaN  NaN
# 3                          NaN  NaN      -1_  ...          NaN  NaN
# 4                          NaN  NaN      -1_  ...          NaN  NaN
# 5                          NaN  NaN      -1_  ...          NaN  NaN
# 6                          NaN  NaN      -1_  ...          NaN  NaN
# 7                          NaN  NaN      -1_  ...          NaN  NaN
# 8                          NaN  NaN      -1_  ...          NaN  NaN
# 9                          NaN  NaN      -1_  ...          NaN  NaN
#
#    Скин-фактор.1  Комментарий  План  Факт  Пл-ть нефти  Коб  В-ть жидк.  P нас
# 0            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 1            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 2            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 3            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 4            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 5            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 6            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 7            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 8            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
# 9            NaN          NaN   NaN   NaN          NaN  NaN         NaN    NaN
#
# [10 rows x 65 columns]

# %%
#grp['Номер скважины'] = grp.apply(
#            lambda x:
#            str(x['Номер скважины']), axis=1)
        # координаты скважин для нашего объекта
my_wells = grp['Номер скважины'].tolist()
my_wells_no_repeat = []
for x in my_wells:
    if x not in my_wells_no_repeat:
        my_wells_no_repeat.append(x)
my_wells_no_repeat
# Out:
# ['805',
#  '804',
#  '801',
#  '688',
#  '66',
#  '634',
#  '632',
#  '577',
#  '560',
#  '545',
#  '529',
#  '49',
#  '466',
#  '411',
#  '224',
#  '1812',
#  '1811Л',
#  '1809Л',
#  '147',
#  '11011',
#  '10187']

# %%
my_wells_gtm = grp_now_we_go['Скважина'].tolist()
my_wells_no_repeat_gtm = []
for x in my_wells_gtm:
    if x not in my_wells_no_repeat_gtm:
        my_wells_no_repeat_gtm.append(x)

my_wells_no_repeat_gtm
# Out:
# ['1000',
#  '10187',
#  '10244',
#  '10274',
#  '105',
#  '10527',
#  '10530',
#  '10535',
#  '1059',
#  '106',
#  '1060',
#  '1061',
#  '1062',
#  '1066',
#  '1073',
#  '1080',
#  '109',
#  '1096',
#  '1098',
#  '110',
#  '11011',
#  '11024',
#  '1121',
#  '1123',
#  '1137',
#  '114',
#  '115',
#  '1152',
#  '116',
#  '1160',
#  '1161',
#  '1164',
#  '1170',
#  '1186',
#  '1198',
#  '1253',
#  '1254',
#  '1304',
#  '1316',
#  '1319',
#  '1321',
#  '1324',
#  '1325',
#  '1330',
#  '1336',
#  '1337',
#  '1338',
#  '1345',
#  '1346',
#  '1347',
#  '1353',
#  '1356',
#  '1370',
#  '1376',
#  '1383',
#  '1389',
#  '139',
#  '1392',
#  '1393',
#  '1405',
#  '1407',
#  '147',
#  '148',
#  '1517',
#  '1518',
#  '1542',
#  '1547',
#  '1548',
#  '1549',
#  '1556',
#  '1613',
#  '1626',
#  '163',
#  '164',
#  '165',
#  '1695',
#  '1714',
#  '1715Б',
#  '1802',
#  '1803',
#  '1809',
#  '1810',
#  '1811',
#  '1812',
#  '1813',
#  '1814',
#  '1831',
#  '1837',
#  '1842',
#  '1846',
#  '1848',
#  '1849',
#  '1853',
#  '1857',
#  '1858',
#  '1860',
#  '1861',
#  '1870',
#  '190',
#  '192',
#  '1К',
#  '2002',
#  '2004',
#  '2018',
#  '204',
#  '205Б',
#  '205К',
#  '206',
#  '208',
#  '209',
#  '219',
#  '220',
#  '223Б',
#  '224',
#  '226',
#  '239',
#  '252',
#  '2К',
#  '323',
#  '330',
#  '331',
#  '335',
#  '336',
#  '337',
#  '338',
#  '340',
#  '343',
#  '345',
#  '361',
#  '365',
#  '368',
#  '369',
#  '371',
#  '391',
#  '4',
#  '401',
#  '402',
#  '418',
#  '428',
#  '43',
#  '430',
#  '431',
#  '435',
#  '437',
#  '454',
#  '461',
#  '466',
#  '47',
#  '476',
#  '49',
#  '490К',
#  '492',
#  '498',
#  '4П',
#  '505',
#  '506',
#  '524',
#  '527',
#  '528',
#  '529',
#  '534',
#  '537',
#  '539',
#  '540',
#  '542',
#  '545',
#  '546',
#  '548',
#  '550',
#  '555',
#  '559',
#  '560',
#  '567',
#  '568',
#  '569',
#  '570',
#  '571',
#  '572',
#  '576БК',
#  '577',
#  '578',
#  '581',
#  '583',
#  '584',
#  '586',
#  '587',
#  '588Б',
#  '589К',
#  '591',
#  '595',
#  '598',
#  '603',
#  '604',
#  '606',
#  '614',
#  '62',
#  '625',
#  '628',
#  '63',
#  '631',
#  '632',
#  '636',
#  '638',
#  '639',
#  '64',
#  '641',
#  '642',
#  '645',
#  '65',
#  '655',
#  '658',
#  '66',
#  '661',
#  '665Б',
#  '677',
#  '678',
#  '68',
#  '681',
#  '685',
#  '688',
#  '69',
#  '690',
#  '691',
#  '694',
#  '697',
#  '699',
#  '700',
#  '706',
#  '708',
#  '710Б',
#  '712',
#  '742',
#  '745',
#  '752',
#  '758',
#  '761',
#  '762',
#  '766',
#  '769',
#  '771',
#  '793',
#  '794',
#  '801',
#  '803',
#  '804',
#  '805',
#  '813',
#  '814',
#  '816',
#  '817',
#  '818',
#  '827',
#  '84',
#  '85',
#  '854',
#  '86',
#  '87',
#  '88',
#  '881',
#  '882',
#  '89',
#  '896',
#  '898',
#  '90',
#  '924',
#  '928',
#  '929',
#  '934',
#  '936',
#  '938',
#  '94',
#  '944',
#  '95Б',
#  '96',
#  '964',
#  '965',
#  '98',
#  '999',
#  '99Б']

# %%
my_wells_only_frak = []
for i in my_wells_no_repeat:
    if i not in my_wells_no_repeat_gtm:
            my_wells_only_frak.append(i)
my_wells_only_frak
# Out:
# ['634', '411', '1811Л', '1809Л']

# %%
wells_GTM = pd.DataFrame({"Номер скважины": my_wells_no_repeat_gtm
                                  })
coordinates_f = coordinates[
            coordinates['№ скважины'].isin(my_wells_no_repeat_gtm)].reset_index(drop=True)
coordinates_f = coordinates_f.drop(['Координата X', 'Координата Y', 'Координата забоя Х (по траектории)',
                                            'Координата забоя Y (по траектории)'], axis=1)
new = coordinates_f['№ скважины'].tolist()
coordinates_f['Скважина'] = new
coordinates_f = coordinates_f.drop(['№ скважины'], axis=1)
grp_now_we_go['Скважина'] = grp_now_we_go.apply(
                    lambda x:
                    str(x['Скважина']), axis=1)
coordinates_f['Скважина'] = coordinates_f.apply(
            lambda x:
            str(x['Скважина']), axis=1)
final = grp_now_we_go.merge(coordinates_f, on='Скважина')
final
# Out:
#      Месторождение      Unnamed: 0 Скважина       Куст  \
# 0         Аганское      Добывающая     1000  КУСТ-110Б
# 1         Аганское      Добывающая     1000  КУСТ-110Б
# 2         Аганское      Добывающая     1000  КУСТ-110Б
# 3         Аганское      Добывающая    10187    КУСТ-5Б
# 4         Аганское      Добывающая    10187    КУСТ-5Б
# ...            ...             ...      ...        ...
# 1104      Аганское      Добывающая       98    КУСТ-11
# 1105      Аганское      Добывающая      999  КУСТ-110Б
# 1106      Аганское      Добывающая      999  КУСТ-110Б
# 1107      Аганское  Нагнетательная      99Б    КУСТ-12
# 1108      Аганское      Добывающая      99Б    КУСТ-12
#
#                                                 Тип  \
# 0                                               ВНС
# 1                                               ОПТ
# 2                                               ОПТ
# 3                                               ГРП
# 4                                               ВНС
# ...                                             ...
# 1104                         Переход или приобщение
# 1105                                            ВНС
# 1106                  РИР негерметичности э/колонны
# 1107                                  Перевод в ППД
# 1108  Выравнивание профиля притока или приёмистости
#
#                            Краткое описание мероприятий  \
# 0                    Ввод добывающих скважин из бурения
# 1                   ТР3 Оптимизация режима эксплуатации
# 2                   ТР3 Оптимизация режима эксплуатации
# 3                                  КР7-2 Проведение ГРП
# 4                    Ввод добывающих скважин из бурения
# ...                                                 ...
# 1104  КР4-1 Переход  на другие вышележащие и нижележ...
# 1105                 Ввод добывающих скважин из бурения
# 1106  КР2-4 Устранение негерметичности частичной сме...
# 1107  КР9-6 Перевод под нагнетание из других категор...
# 1108                                     Проведение ВПП
#
#      Объект разработки до ГТМ  Объект разработки после ГТМ  Dэк Страница  ...  \
# 0                          Б6                          NaN  NaN      -1_  ...
# 1                          Б6                          NaN  NaN      -1_  ...
# 2                          Б6                          NaN  NaN      -1_  ...
# 3                          Б6                          NaN  NaN      -1_  ...
# 4                          Б6                          NaN  NaN      -1_  ...
# ...                       ...                          ...  ...      ...  ...
# 1104                       Б6                          NaN  NaN      -1_  ...
# 1105                       Б6                          NaN  NaN      -1_  ...
# 1106                       Б6                          NaN  NaN      -1_  ...
# 1107                       Б6                          NaN  NaN      -1_  ...
# 1108                       Б6                          NaN  NaN      -1_  ...
#
#       Кпр  Скин-фактор.1  Комментарий  План  Факт  Пл-ть нефти  Коб  \
# 0     NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 1     NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 2     NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 3     NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 4     NaN            NaN          NaN   NaN   NaN          NaN  NaN
# ...   ...            ...          ...   ...   ...          ...  ...
# 1104  NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 1105  NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 1106  NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 1107  NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 1108  NaN            NaN          NaN   NaN   NaN          NaN  NaN
#
#       В-ть жидк.  P нас      Length
# 0            NaN    NaN   51.224994
# 1            NaN    NaN   51.224994
# 2            NaN    NaN   51.224994
# 3            NaN    NaN  187.275199
# 4            NaN    NaN  187.275199
# ...          ...    ...         ...
# 1104         NaN    NaN   36.891733
# 1105         NaN    NaN    5.099020
# 1106         NaN    NaN    5.099020
# 1107         NaN    NaN   13.341664
# 1108         NaN    NaN   13.341664
#
# [1109 rows x 66 columns]

# %%
final['Длина ГС, м'] = final.apply(
        lambda x:
        x['Length'] if x['Length'] >= 110
        else 0, axis=1)
final = final.drop(['Length'], axis=1)
final
# Out:
#      Месторождение      Unnamed: 0 Скважина       Куст  \
# 0         Аганское      Добывающая     1000  КУСТ-110Б
# 1         Аганское      Добывающая     1000  КУСТ-110Б
# 2         Аганское      Добывающая     1000  КУСТ-110Б
# 3         Аганское      Добывающая    10187    КУСТ-5Б
# 4         Аганское      Добывающая    10187    КУСТ-5Б
# ...            ...             ...      ...        ...
# 1104      Аганское      Добывающая       98    КУСТ-11
# 1105      Аганское      Добывающая      999  КУСТ-110Б
# 1106      Аганское      Добывающая      999  КУСТ-110Б
# 1107      Аганское  Нагнетательная      99Б    КУСТ-12
# 1108      Аганское      Добывающая      99Б    КУСТ-12
#
#                                                 Тип  \
# 0                                               ВНС
# 1                                               ОПТ
# 2                                               ОПТ
# 3                                               ГРП
# 4                                               ВНС
# ...                                             ...
# 1104                         Переход или приобщение
# 1105                                            ВНС
# 1106                  РИР негерметичности э/колонны
# 1107                                  Перевод в ППД
# 1108  Выравнивание профиля притока или приёмистости
#
#                            Краткое описание мероприятий  \
# 0                    Ввод добывающих скважин из бурения
# 1                   ТР3 Оптимизация режима эксплуатации
# 2                   ТР3 Оптимизация режима эксплуатации
# 3                                  КР7-2 Проведение ГРП
# 4                    Ввод добывающих скважин из бурения
# ...                                                 ...
# 1104  КР4-1 Переход  на другие вышележащие и нижележ...
# 1105                 Ввод добывающих скважин из бурения
# 1106  КР2-4 Устранение негерметичности частичной сме...
# 1107  КР9-6 Перевод под нагнетание из других категор...
# 1108                                     Проведение ВПП
#
#      Объект разработки до ГТМ  Объект разработки после ГТМ  Dэк Страница  ...  \
# 0                          Б6                          NaN  NaN      -1_  ...
# 1                          Б6                          NaN  NaN      -1_  ...
# 2                          Б6                          NaN  NaN      -1_  ...
# 3                          Б6                          NaN  NaN      -1_  ...
# 4                          Б6                          NaN  NaN      -1_  ...
# ...                       ...                          ...  ...      ...  ...
# 1104                       Б6                          NaN  NaN      -1_  ...
# 1105                       Б6                          NaN  NaN      -1_  ...
# 1106                       Б6                          NaN  NaN      -1_  ...
# 1107                       Б6                          NaN  NaN      -1_  ...
# 1108                       Б6                          NaN  NaN      -1_  ...
#
#       Кпр  Скин-фактор.1  Комментарий  План  Факт  Пл-ть нефти  Коб  \
# 0     NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 1     NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 2     NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 3     NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 4     NaN            NaN          NaN   NaN   NaN          NaN  NaN
# ...   ...            ...          ...   ...   ...          ...  ...
# 1104  NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 1105  NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 1106  NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 1107  NaN            NaN          NaN   NaN   NaN          NaN  NaN
# 1108  NaN            NaN          NaN   NaN   NaN          NaN  NaN
#
#       В-ть жидк.  P нас  Длина ГС, м
# 0            NaN    NaN     0.000000
# 1            NaN    NaN     0.000000
# 2            NaN    NaN     0.000000
# 3            NaN    NaN   187.275199
# 4            NaN    NaN   187.275199
# ...          ...    ...          ...
# 1104         NaN    NaN     0.000000
# 1105         NaN    NaN     0.000000
# 1106         NaN    NaN     0.000000
# 1107         NaN    NaN     0.000000
# 1108         NaN    NaN     0.000000
#
# [1109 rows x 66 columns]

# %%
final_number = final.groupby(by=['Скважина', 'ВНР.1','Тип','Объект разработки до ГТМ']).agg(
            {'Длина ГС, м': lambda x:
            x.tolist()[0]}
        )
final_number
# Out:
#                                                                                             Длина ГС, м
# Скважина ВНР.1      Тип                                           Объект разработки до ГТМ
# 1000     2000-07-24 ВНС                                           Б6                           0.000000
#          2004-04-09 ОПТ                                           Б6                           0.000000
#          2005-11-24 ОПТ                                           Б6                           0.000000
# 10187    2012-12-24 ВНС                                           Б6                         187.275199
#                     ГРП                                           Б6                         187.275199
# ...                                                                                                 ...
# 98       2012-05-23 Переход или приобщение                        Б6                           0.000000
# 999      2000-05-17 ВНС                                           Б6                           0.000000
#          2001-06-20 РИР негерметичности э/колонны                 Б6                           0.000000
# 99Б      2009-06-13 Перевод в ППД                                 Б6                           0.000000
#          2013-08-05 Выравнивание профиля притока или приёмистости Б6                           0.000000
#
# [1088 rows x 1 columns]

# %%
final_number.reset_index(inplace=True)

# %%
final_number
# Out:
#      Скважина      ВНР.1                                            Тип  \
# 0        1000 2000-07-24                                            ВНС
# 1        1000 2004-04-09                                            ОПТ
# 2        1000 2005-11-24                                            ОПТ
# 3       10187 2012-12-24                                            ВНС
# 4       10187 2012-12-24                                            ГРП
# ...       ...        ...                                            ...
# 1083       98 2012-05-23                         Переход или приобщение
# 1084      999 2000-05-17                                            ВНС
# 1085      999 2001-06-20                  РИР негерметичности э/колонны
# 1086      99Б 2009-06-13                                  Перевод в ППД
# 1087      99Б 2013-08-05  Выравнивание профиля притока или приёмистости
#
#      Объект разработки до ГТМ  Длина ГС, м
# 0                          Б6     0.000000
# 1                          Б6     0.000000
# 2                          Б6     0.000000
# 3                          Б6   187.275199
# 4                          Б6   187.275199
# ...                       ...          ...
# 1083                       Б6     0.000000
# 1084                       Б6     0.000000
# 1085                       Б6     0.000000
# 1086                       Б6     0.000000
# 1087                       Б6     0.000000
#
# [1088 rows x 5 columns]

# %%
final_number['Дата ВНР после'] = final_number.apply(
            lambda x:
            x['ВНР.1'] if 'ГРП' in str(x['Тип'])
            else x['ВНР.1'] if 'ВНС' in str(x['Тип'])
            
            else 'нет', axis=1)
final_number = final_number.drop(final_number[final_number['Дата ВНР после'] == 'нет'].index)
final_number
# Out:
#      Скважина      ВНР.1  Тип Объект разработки до ГТМ  Длина ГС, м  \
# 0        1000 2000-07-24  ВНС                       Б6     0.000000
# 3       10187 2012-12-24  ВНС                       Б6   187.275199
# 4       10187 2012-12-24  ГРП                       Б6   187.275199
# 5       10244 2010-12-28  ВНС                       Б6   216.831732
# 11      10244 2022-01-29  ГРП                       Б6   216.831732
# ...       ...        ...  ...                      ...          ...
# 952       805 2009-07-02  ГРП                       Б6     0.000000
# 969       827 2003-04-26  ВНС                       Б6   195.941318
# 980       854 2010-11-23  ВНС                       Б6   500.433812
# 1066      95Б 2021-02-01  ГРП                       Б6     0.000000
# 1084      999 2000-05-17  ВНС                       Б6     0.000000
#
#            Дата ВНР после
# 0     2000-07-24 00:00:00
# 3     2012-12-24 00:00:00
# 4     2012-12-24 00:00:00
# 5     2010-12-28 00:00:00
# 11    2022-01-29 00:00:00
# ...                   ...
# 952   2009-07-02 00:00:00
# 969   2003-04-26 00:00:00
# 980   2010-11-23 00:00:00
# 1066  2021-02-01 00:00:00
# 1084  2000-05-17 00:00:00
#
# [76 rows x 6 columns]

# %%
final_number.reset_index(inplace=True)
final_number
# Out:
#     index Скважина      ВНР.1  Тип Объект разработки до ГТМ  Длина ГС, м  \
# 0       0     1000 2000-07-24  ВНС                       Б6     0.000000
# 1       3    10187 2012-12-24  ВНС                       Б6   187.275199
# 2       4    10187 2012-12-24  ГРП                       Б6   187.275199
# 3       5    10244 2010-12-28  ВНС                       Б6   216.831732
# 4      11    10244 2022-01-29  ГРП                       Б6   216.831732
# ..    ...      ...        ...  ...                      ...          ...
# 71    952      805 2009-07-02  ГРП                       Б6     0.000000
# 72    969      827 2003-04-26  ВНС                       Б6   195.941318
# 73    980      854 2010-11-23  ВНС                       Б6   500.433812
# 74   1066      95Б 2021-02-01  ГРП                       Б6     0.000000
# 75   1084      999 2000-05-17  ВНС                       Б6     0.000000
#
#          Дата ВНР после
# 0   2000-07-24 00:00:00
# 1   2012-12-24 00:00:00
# 2   2012-12-24 00:00:00
# 3   2010-12-28 00:00:00
# 4   2022-01-29 00:00:00
# ..                  ...
# 71  2009-07-02 00:00:00
# 72  2003-04-26 00:00:00
# 73  2010-11-23 00:00:00
# 74  2021-02-01 00:00:00
# 75  2000-05-17 00:00:00
#
# [76 rows x 7 columns]

# %%
final_number['Тип'] = final_number.apply(
            lambda x:
            'ВНС' if 'ВН' in str(x['Тип'])
            else x['Тип'], axis=1)
final_number
# Out:
#     index Скважина      ВНР.1  Тип Объект разработки до ГТМ  Длина ГС, м  \
# 0       0     1000 2000-07-24  ВНС                       Б6     0.000000
# 1       3    10187 2012-12-24  ВНС                       Б6   187.275199
# 2       4    10187 2012-12-24  ГРП                       Б6   187.275199
# 3       5    10244 2010-12-28  ВНС                       Б6   216.831732
# 4      11    10244 2022-01-29  ГРП                       Б6   216.831732
# ..    ...      ...        ...  ...                      ...          ...
# 71    952      805 2009-07-02  ГРП                       Б6     0.000000
# 72    969      827 2003-04-26  ВНС                       Б6   195.941318
# 73    980      854 2010-11-23  ВНС                       Б6   500.433812
# 74   1066      95Б 2021-02-01  ГРП                       Б6     0.000000
# 75   1084      999 2000-05-17  ВНС                       Б6     0.000000
#
#          Дата ВНР после
# 0   2000-07-24 00:00:00
# 1   2012-12-24 00:00:00
# 2   2012-12-24 00:00:00
# 3   2010-12-28 00:00:00
# 4   2022-01-29 00:00:00
# ..                  ...
# 71  2009-07-02 00:00:00
# 72  2003-04-26 00:00:00
# 73  2010-11-23 00:00:00
# 74  2021-02-01 00:00:00
# 75  2000-05-17 00:00:00
#
# [76 rows x 7 columns]

# %%
final_number['index'] = final_number.index
grp_vnski_double = final_number.drop(final_number[final_number['Тип'] != 'ВНС'].index)
grp_vnski_double['index'] = grp_vnski_double.index
grp_vnski_double = grp_vnski_double.groupby('Скважина').agg(
            {'index': lambda x:
            x.tolist()[1:]}
        )
sveta = []
for i in grp_vnski_double['index']:
    sveta += i
final_number = final_number[~final_number['index'].isin(sveta)].reset_index(drop=True)
final_number = final_number.drop(['index'], axis=1)
final_number
# Out:
#    Скважина      ВНР.1  Тип Объект разработки до ГТМ  Длина ГС, м  \
# 0      1000 2000-07-24  ВНС                       Б6     0.000000
# 1     10187 2012-12-24  ВНС                       Б6   187.275199
# 2     10187 2012-12-24  ГРП                       Б6   187.275199
# 3     10244 2010-12-28  ВНС                       Б6   216.831732
# 4     10244 2022-01-29  ГРП                       Б6   216.831732
# ..      ...        ...  ...                      ...          ...
# 71      805 2009-07-02  ГРП                       Б6     0.000000
# 72      827 2003-04-26  ВНС                       Б6   195.941318
# 73      854 2010-11-23  ВНС                       Б6   500.433812
# 74      95Б 2021-02-01  ГРП                       Б6     0.000000
# 75      999 2000-05-17  ВНС                       Б6     0.000000
#
#          Дата ВНР после
# 0   2000-07-24 00:00:00
# 1   2012-12-24 00:00:00
# 2   2012-12-24 00:00:00
# 3   2010-12-28 00:00:00
# 4   2022-01-29 00:00:00
# ..                  ...
# 71  2009-07-02 00:00:00
# 72  2003-04-26 00:00:00
# 73  2010-11-23 00:00:00
# 74  2021-02-01 00:00:00
# 75  2000-05-17 00:00:00
#
# [76 rows x 6 columns]

# %%
final_number = final_number.drop(['ВНР.1'], axis=1)
final_number.head()
# Out:
#   Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после
# 0     1000  ВНС                       Б6     0.000000  2000-07-24 00:00:00
# 1    10187  ВНС                       Б6   187.275199  2012-12-24 00:00:00
# 2    10187  ГРП                       Б6   187.275199  2012-12-24 00:00:00
# 3    10244  ВНС                       Б6   216.831732  2010-12-28 00:00:00
# 4    10244  ГРП                       Б6   216.831732  2022-01-29 00:00:00

# %%
final_number['Полудлина трещины, м'] = final_number.apply(
            lambda x:
            100, axis=1)
final_number['Ширина трещины, мм'] = final_number.apply(
            lambda x:
            4, axis=1)
final_number['Проницаемость проппанта, Д'] = final_number.apply(
            lambda x:
            100, axis=1)
final_number['Полудлина трещины, м'] = final_number.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип'])
            else x['Полудлина трещины, м']
            , axis=1)
final_number['Ширина трещины, мм'] = final_number.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип'])
            else x['Ширина трещины, мм']
            , axis=1)
final_number['Проницаемость проппанта, Д'] = final_number.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип'])
            else x['Проницаемость проппанта, Д']
            , axis=1)
        # ДОБАВИТЬ В ВНС
final_number['Число стадий ГРП'] = final_number.apply(
            lambda x:
            1, axis=1)
final_number['Число стадий ГРП'] = final_number.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип'])
            else x['Число стадий ГРП']
            , axis=1)
final_number
# Out:
#    Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0      1000  ВНС                       Б6     0.000000  2000-07-24 00:00:00
# 1     10187  ВНС                       Б6   187.275199  2012-12-24 00:00:00
# 2     10187  ГРП                       Б6   187.275199  2012-12-24 00:00:00
# 3     10244  ВНС                       Б6   216.831732  2010-12-28 00:00:00
# 4     10244  ГРП                       Б6   216.831732  2022-01-29 00:00:00
# ..      ...  ...                      ...          ...                  ...
# 71      805  ГРП                       Б6     0.000000  2009-07-02 00:00:00
# 72      827  ВНС                       Б6   195.941318  2003-04-26 00:00:00
# 73      854  ВНС                       Б6   500.433812  2010-11-23 00:00:00
# 74      95Б  ГРП                       Б6     0.000000  2021-02-01 00:00:00
# 75      999  ВНС                       Б6     0.000000  2000-05-17 00:00:00
#
#     Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                      0                   0                           0
# 1                      0                   0                           0
# 2                    100                   4                         100
# 3                      0                   0                           0
# 4                    100                   4                         100
# ..                   ...                 ...                         ...
# 71                   100                   4                         100
# 72                     0                   0                           0
# 73                     0                   0                           0
# 74                   100                   4                         100
# 75                     0                   0                           0
#
#     Число стадий ГРП
# 0                  0
# 1                  0
# 2                  1
# 3                  0
# 4                  1
# ..               ...
# 71                 1
# 72                 0
# 73                 0
# 74                 1
# 75                 0
#
# [76 rows x 9 columns]

# %%
final_number['ГС/ННС'] = final_number.apply(
            lambda x:
            'ННС' if x['Длина ГС, м'] == 0
            else 'ГС', axis=1)
final_number
# Out:
#    Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0      1000  ВНС                       Б6     0.000000  2000-07-24 00:00:00
# 1     10187  ВНС                       Б6   187.275199  2012-12-24 00:00:00
# 2     10187  ГРП                       Б6   187.275199  2012-12-24 00:00:00
# 3     10244  ВНС                       Б6   216.831732  2010-12-28 00:00:00
# 4     10244  ГРП                       Б6   216.831732  2022-01-29 00:00:00
# ..      ...  ...                      ...          ...                  ...
# 71      805  ГРП                       Б6     0.000000  2009-07-02 00:00:00
# 72      827  ВНС                       Б6   195.941318  2003-04-26 00:00:00
# 73      854  ВНС                       Б6   500.433812  2010-11-23 00:00:00
# 74      95Б  ГРП                       Б6     0.000000  2021-02-01 00:00:00
# 75      999  ВНС                       Б6     0.000000  2000-05-17 00:00:00
#
#     Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                      0                   0                           0
# 1                      0                   0                           0
# 2                    100                   4                         100
# 3                      0                   0                           0
# 4                    100                   4                         100
# ..                   ...                 ...                         ...
# 71                   100                   4                         100
# 72                     0                   0                           0
# 73                     0                   0                           0
# 74                   100                   4                         100
# 75                     0                   0                           0
#
#     Число стадий ГРП ГС/ННС
# 0                  0    ННС
# 1                  0     ГС
# 2                  1     ГС
# 3                  0     ГС
# 4                  1     ГС
# ..               ...    ...
# 71                 1    ННС
# 72                 0     ГС
# 73                 0     ГС
# 74                 1    ННС
# 75                 0    ННС
#
# [76 rows x 10 columns]

# %%
final_number['index'] = final_number.index
final_number['index'] = final_number.apply(
            lambda x:
            str(x['index'])
            + ('_да' if x['Тип'] == 'ГРП' else ''),
            axis=1
        )

# %%
final_double = final_number.groupby(by=['Скважина', 'Дата ВНР после']).agg(
            {'index': lambda x:
            x.tolist()}
        )
final_double
# Out:
#                              index
# Скважина Дата ВНР после
# 1000     2000-07-24            [0]
# 10187    2012-12-24      [1, 2_да]
# 10244    2010-12-28            [3]
#          2022-01-29         [4_да]
# 10530    2012-09-22            [5]
# ...                            ...
# 805      2009-07-02        [71_да]
# 827      2003-04-26           [72]
# 854      2010-11-23           [73]
# 95Б      2021-02-01        [74_да]
# 999      2000-05-17           [75]
#
# [75 rows x 1 columns]

# %%
final_double.reset_index(inplace=True)
final_double['длина'] = final_double.apply(
            lambda x:
            len(x['index']), axis=1)
final_double = final_double.drop(final_double[final_double['длина'] == 1].index)
final_double
# Out:
#   Скважина Дата ВНР после      index  длина
# 1    10187     2012-12-24  [1, 2_да]      2

# %%
welles=[]
for i in final_double['index']:
    welles+=i
welles
# Out:
# ['1', '2_да']

# %%
welles_corr=[]
for i in welles:
    if 'да' in i:
        welles_corr.append(i)
welles_corr
# Out:
# ['2_да']

# %%
welles_incorr=[]
for i in welles:
    if 'да' not in i:
        welles_incorr.append(i)
welles_incorr
# Out:
# ['1']

# %%
final_number = final_number[~final_number['index'].isin(welles_corr)].reset_index(drop=True)
final_number
# Out:
#    Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0      1000  ВНС                       Б6     0.000000  2000-07-24 00:00:00
# 1     10187  ВНС                       Б6   187.275199  2012-12-24 00:00:00
# 2     10244  ВНС                       Б6   216.831732  2010-12-28 00:00:00
# 3     10244  ГРП                       Б6   216.831732  2022-01-29 00:00:00
# 4     10530  ВНС                       Б6   446.010090  2012-09-22 00:00:00
# ..      ...  ...                      ...          ...                  ...
# 70      805  ГРП                       Б6     0.000000  2009-07-02 00:00:00
# 71      827  ВНС                       Б6   195.941318  2003-04-26 00:00:00
# 72      854  ВНС                       Б6   500.433812  2010-11-23 00:00:00
# 73      95Б  ГРП                       Б6     0.000000  2021-02-01 00:00:00
# 74      999  ВНС                       Б6     0.000000  2000-05-17 00:00:00
#
#     Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                      0                   0                           0
# 1                      0                   0                           0
# 2                      0                   0                           0
# 3                    100                   4                         100
# 4                      0                   0                           0
# ..                   ...                 ...                         ...
# 70                   100                   4                         100
# 71                     0                   0                           0
# 72                     0                   0                           0
# 73                   100                   4                         100
# 74                     0                   0                           0
#
#     Число стадий ГРП ГС/ННС  index
# 0                  0    ННС      0
# 1                  0     ГС      1
# 2                  0     ГС      3
# 3                  1     ГС   4_да
# 4                  0     ГС      5
# ..               ...    ...    ...
# 70                 1    ННС  71_да
# 71                 0     ГС     72
# 72                 0     ГС     73
# 73                 1    ННС  74_да
# 74                 0    ННС     75
#
# [75 rows x 11 columns]

# %%
final_number['ГС/ННС'] = final_number.apply(
            lambda x:
            str(x['ГС/ННС'])
            + ('+ГРП' if x['index'] in welles_incorr else ''),
            axis=1
        )
final_number
# Out:
#    Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0      1000  ВНС                       Б6     0.000000  2000-07-24 00:00:00
# 1     10187  ВНС                       Б6   187.275199  2012-12-24 00:00:00
# 2     10244  ВНС                       Б6   216.831732  2010-12-28 00:00:00
# 3     10244  ГРП                       Б6   216.831732  2022-01-29 00:00:00
# 4     10530  ВНС                       Б6   446.010090  2012-09-22 00:00:00
# ..      ...  ...                      ...          ...                  ...
# 70      805  ГРП                       Б6     0.000000  2009-07-02 00:00:00
# 71      827  ВНС                       Б6   195.941318  2003-04-26 00:00:00
# 72      854  ВНС                       Б6   500.433812  2010-11-23 00:00:00
# 73      95Б  ГРП                       Б6     0.000000  2021-02-01 00:00:00
# 74      999  ВНС                       Б6     0.000000  2000-05-17 00:00:00
#
#     Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                      0                   0                           0
# 1                      0                   0                           0
# 2                      0                   0                           0
# 3                    100                   4                         100
# 4                      0                   0                           0
# ..                   ...                 ...                         ...
# 70                   100                   4                         100
# 71                     0                   0                           0
# 72                     0                   0                           0
# 73                   100                   4                         100
# 74                     0                   0                           0
#
#     Число стадий ГРП  ГС/ННС  index
# 0                  0     ННС      0
# 1                  0  ГС+ГРП      1
# 2                  0      ГС      3
# 3                  1      ГС   4_да
# 4                  0      ГС      5
# ..               ...     ...    ...
# 70                 1     ННС  71_да
# 71                 0      ГС     72
# 72                 0      ГС     73
# 73                 1     ННС  74_да
# 74                 0     ННС     75
#
# [75 rows x 11 columns]

# %%
final_number['Полудлина трещины, м'] = final_number.apply(
            lambda x:
            100 if 'ГРП' in str(x['ГС/ННС'])
            else x['Полудлина трещины, м']
            , axis=1)
final_number['Ширина трещины, мм'] = final_number.apply(
            lambda x:
            4 if 'ГРП' in str(x['ГС/ННС'])
            else x['Ширина трещины, мм']
            , axis=1)
final_number['Проницаемость проппанта, Д'] = final_number.apply(
            lambda x:
            100 if 'ГРП' in str(x['ГС/ННС'])
            else x['Проницаемость проппанта, Д']
            , axis=1)
final_number['Число стадий ГРП'] = final_number.apply(
            lambda x:
            1 if 'ГРП' in str(x['ГС/ННС'])
            else x['Число стадий ГРП']
            , axis=1)
final_number
# Out:
#    Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0      1000  ВНС                       Б6     0.000000  2000-07-24 00:00:00
# 1     10187  ВНС                       Б6   187.275199  2012-12-24 00:00:00
# 2     10244  ВНС                       Б6   216.831732  2010-12-28 00:00:00
# 3     10244  ГРП                       Б6   216.831732  2022-01-29 00:00:00
# 4     10530  ВНС                       Б6   446.010090  2012-09-22 00:00:00
# ..      ...  ...                      ...          ...                  ...
# 70      805  ГРП                       Б6     0.000000  2009-07-02 00:00:00
# 71      827  ВНС                       Б6   195.941318  2003-04-26 00:00:00
# 72      854  ВНС                       Б6   500.433812  2010-11-23 00:00:00
# 73      95Б  ГРП                       Б6     0.000000  2021-02-01 00:00:00
# 74      999  ВНС                       Б6     0.000000  2000-05-17 00:00:00
#
#     Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                      0                   0                           0
# 1                    100                   4                         100
# 2                      0                   0                           0
# 3                    100                   4                         100
# 4                      0                   0                           0
# ..                   ...                 ...                         ...
# 70                   100                   4                         100
# 71                     0                   0                           0
# 72                     0                   0                           0
# 73                   100                   4                         100
# 74                     0                   0                           0
#
#     Число стадий ГРП  ГС/ННС  index
# 0                  0     ННС      0
# 1                  1  ГС+ГРП      1
# 2                  0      ГС      3
# 3                  1      ГС   4_да
# 4                  0      ГС      5
# ..               ...     ...    ...
# 70                 1     ННС  71_да
# 71                 0      ГС     72
# 72                 0      ГС     73
# 73                 1     ННС  74_да
# 74                 0     ННС     75
#
# [75 rows x 11 columns]

# %%
final_number['Тип'] = final_number.apply(
            lambda x:
            'ГРП' if 'ГРП' in str(x['ГС/ННС'])
            else x['Тип']
            , axis=1)
final_number
# Out:
#    Скважина  Тип Объект разработки до ГТМ  Длина ГС, м       Дата ВНР после  \
# 0      1000  ВНС                       Б6     0.000000  2000-07-24 00:00:00
# 1     10187  ГРП                       Б6   187.275199  2012-12-24 00:00:00
# 2     10244  ВНС                       Б6   216.831732  2010-12-28 00:00:00
# 3     10244  ГРП                       Б6   216.831732  2022-01-29 00:00:00
# 4     10530  ВНС                       Б6   446.010090  2012-09-22 00:00:00
# ..      ...  ...                      ...          ...                  ...
# 70      805  ГРП                       Б6     0.000000  2009-07-02 00:00:00
# 71      827  ВНС                       Б6   195.941318  2003-04-26 00:00:00
# 72      854  ВНС                       Б6   500.433812  2010-11-23 00:00:00
# 73      95Б  ГРП                       Б6     0.000000  2021-02-01 00:00:00
# 74      999  ВНС                       Б6     0.000000  2000-05-17 00:00:00
#
#     Полудлина трещины, м  Ширина трещины, мм  Проницаемость проппанта, Д  \
# 0                      0                   0                           0
# 1                    100                   4                         100
# 2                      0                   0                           0
# 3                    100                   4                         100
# 4                      0                   0                           0
# ..                   ...                 ...                         ...
# 70                   100                   4                         100
# 71                     0                   0                           0
# 72                     0                   0                           0
# 73                   100                   4                         100
# 74                     0                   0                           0
#
#     Число стадий ГРП  ГС/ННС  index
# 0                  0     ННС      0
# 1                  1  ГС+ГРП      1
# 2                  0      ГС      3
# 3                  1      ГС   4_да
# 4                  0      ГС      5
# ..               ...     ...    ...
# 70                 1     ННС  71_да
# 71                 0      ГС     72
# 72                 0      ГС     73
# 73                 1     ННС  74_да
# 74                 0     ННС     75
#
# [75 rows x 11 columns]

# %%
new_400 = final_number['Скважина'].tolist()
final_number['Скважина №'] = new_400
final_number = final_number.drop(['Скважина'], axis=1)
final_number = final_number.drop(['index'], axis=1)
new_300 = final_number['Тип'].tolist()
final_number['Тип ГТМ'] = new_300
final_number = final_number.drop(['Тип'], axis=1)
new_200 = final_number['Объект разработки до ГТМ'].tolist()
final_number['Пласт'] = new_200
final_number = final_number.drop(['Объект разработки до ГТМ'], axis=1)
final_number = final_number.reindex(
            columns=['Скважина №', 'Длина ГС, м', 'Число стадий ГРП', 'Полудлина трещины, м', 'Ширина трещины, мм',
                     'Проницаемость проппанта, Д', 'Дата ВНР после','ГС/ННС','Тип ГТМ', 'Пласт'])
final_number
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1000     0.000000                 0                     0
# 1       10187   187.275199                 1                   100
# 2       10244   216.831732                 0                     0
# 3       10244   216.831732                 1                   100
# 4       10530   446.010090                 0                     0
# ..        ...          ...               ...                   ...
# 70        805     0.000000                 1                   100
# 71        827   195.941318                 0                     0
# 72        854   500.433812                 0                     0
# 73        95Б     0.000000                 1                   100
# 74        999     0.000000                 0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д       Дата ВНР после  \
# 0                    0                           0  2000-07-24 00:00:00
# 1                    4                         100  2012-12-24 00:00:00
# 2                    0                           0  2010-12-28 00:00:00
# 3                    4                         100  2022-01-29 00:00:00
# 4                    0                           0  2012-09-22 00:00:00
# ..                 ...                         ...                  ...
# 70                   4                         100  2009-07-02 00:00:00
# 71                   0                           0  2003-04-26 00:00:00
# 72                   0                           0  2010-11-23 00:00:00
# 73                   4                         100  2021-02-01 00:00:00
# 74                   0                           0  2000-05-17 00:00:00
#
#     ГС/ННС Тип ГТМ Пласт
# 0      ННС     ВНС    Б6
# 1   ГС+ГРП     ГРП    Б6
# 2       ГС     ВНС    Б6
# 3       ГС     ГРП    Б6
# 4       ГС     ВНС    Б6
# ..     ...     ...   ...
# 70     ННС     ГРП    Б6
# 71      ГС     ВНС    Б6
# 72      ГС     ВНС    Б6
# 73     ННС     ГРП    Б6
# 74     ННС     ВНС    Б6
#
# [75 rows x 10 columns]

# %%
final_number.head(30)
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1000     0.000000                 0                     0
# 1       10187   187.275199                 1                   100
# 2       10244   216.831732                 0                     0
# 3       10244   216.831732                 1                   100
# 4       10530   446.010090                 0                     0
# 5        1137     0.000000                 1                   100
# 6        1137     0.000000                 1                   100
# 7        1253     0.000000                 1                   100
# 8        1254     0.000000                 0                     0
# 9        1356   575.633564                 1                   100
# 10        147     0.000000                 1                   100
# 11       1517   700.805965                 0                     0
# 12       1518   371.183243                 0                     0
# 13       1802     0.000000                 0                     0
# 14       1809   564.088646                 0                     0
# 15       1809   564.088646                 1                   100
# 16       1810     0.000000                 0                     0
# 17       1810     0.000000                 1                   100
# 18       1811   642.012461                 0                     0
# 19       1811   642.012461                 1                   100
# 20       1812     0.000000                 0                     0
# 21       1812     0.000000                 1                   100
# 22       1813   512.609988                 0                     0
# 23       1814   448.742688                 0                     0
# 24       1831   545.517186                 0                     0
# 25       1837     0.000000                 0                     0
# 26       1842   627.391425                 0                     0
# 27       1846     0.000000                 0                     0
# 28       1848   296.735573                 0                     0
# 29       1853   223.432316                 0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д       Дата ВНР после  \
# 0                    0                           0  2000-07-24 00:00:00
# 1                    4                         100  2012-12-24 00:00:00
# 2                    0                           0  2010-12-28 00:00:00
# 3                    4                         100  2022-01-29 00:00:00
# 4                    0                           0  2012-09-22 00:00:00
# 5                    4                         100  2017-11-21 00:00:00
# 6                    4                         100  2019-05-22 00:00:00
# 7                    4                         100  2020-02-03 00:00:00
# 8                    0                           0  2001-02-26 00:00:00
# 9                    4                         100  2019-05-18 00:00:00
# 10                   4                         100  2012-12-22 00:00:00
# 11                   0                           0  2014-01-22 00:00:00
# 12                   0                           0  2014-03-18 00:00:00
# 13                   0                           0  2000-03-18 00:00:00
# 14                   0                           0  2001-06-25 00:00:00
# 15                   4                         100  2004-02-14 00:00:00
# 16                   0                           0  2001-07-30 00:00:00
# 17                   4                         100  2002-10-17 00:00:00
# 18                   0                           0  2001-09-05 00:00:00
# 19                   4                         100  2004-03-30 00:00:00
# 20                   0                           0  2001-09-26 00:00:00
# 21                   4                         100  2003-12-24 00:00:00
# 22                   0                           0  2001-02-14 00:00:00
# 23                   0                           0  2001-02-05 00:00:00
# 24                   0                           0  2000-12-29 00:00:00
# 25                   0                           0  2001-07-16 00:00:00
# 26                   0                           0  2003-05-03 00:00:00
# 27                   0                           0  2003-01-01 00:00:00
# 28                   0                           0  2003-01-28 00:00:00
# 29                   0                           0  2003-04-22 00:00:00
#
#     ГС/ННС Тип ГТМ Пласт
# 0      ННС     ВНС    Б6
# 1   ГС+ГРП     ГРП    Б6
# 2       ГС     ВНС    Б6
# 3       ГС     ГРП    Б6
# 4       ГС     ВНС    Б6
# 5      ННС     ГРП    Б6
# 6      ННС     ГРП    Б6
# 7      ННС     ГРП    Б6
# 8      ННС     ВНС    Б6
# 9       ГС     ГРП    Б6
# 10     ННС     ГРП    Б6
# 11      ГС     ВНС    Б6
# 12      ГС     ВНС    Б6
# 13     ННС     ВНС    Б6
# 14      ГС     ВНС    Б6
# 15      ГС     ГРП    Б6
# 16     ННС     ВНС    Б6
# 17     ННС     ГРП    Б6
# 18      ГС     ВНС    Б6
# 19      ГС     ГРП    Б6
# 20     ННС     ВНС    Б6
# 21     ННС     ГРП    Б6
# 22      ГС     ВНС    Б6
# 23      ГС     ВНС    Б6
# 24      ГС     ВНС    Б6
# 25     ННС     ВНС    Б6
# 26      ГС     ВНС    Б6
# 27     ННС     ВНС    Б6
# 28      ГС     ВНС    Б6
# 29      ГС     ВНС    Б6

# %%
#final_number.loc[final_number['Тип'] == 'ЗБС']

# %%
final_number
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1000     0.000000                 0                     0
# 1       10187   187.275199                 1                   100
# 2       10244   216.831732                 0                     0
# 3       10244   216.831732                 1                   100
# 4       10530   446.010090                 0                     0
# ..        ...          ...               ...                   ...
# 70        805     0.000000                 1                   100
# 71        827   195.941318                 0                     0
# 72        854   500.433812                 0                     0
# 73        95Б     0.000000                 1                   100
# 74        999     0.000000                 0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д       Дата ВНР после  \
# 0                    0                           0  2000-07-24 00:00:00
# 1                    4                         100  2012-12-24 00:00:00
# 2                    0                           0  2010-12-28 00:00:00
# 3                    4                         100  2022-01-29 00:00:00
# 4                    0                           0  2012-09-22 00:00:00
# ..                 ...                         ...                  ...
# 70                   4                         100  2009-07-02 00:00:00
# 71                   0                           0  2003-04-26 00:00:00
# 72                   0                           0  2010-11-23 00:00:00
# 73                   4                         100  2021-02-01 00:00:00
# 74                   0                           0  2000-05-17 00:00:00
#
#     ГС/ННС Тип ГТМ Пласт
# 0      ННС     ВНС    Б6
# 1   ГС+ГРП     ГРП    Б6
# 2       ГС     ВНС    Б6
# 3       ГС     ГРП    Б6
# 4       ГС     ВНС    Б6
# ..     ...     ...   ...
# 70     ННС     ГРП    Б6
# 71      ГС     ВНС    Б6
# 72      ГС     ВНС    Б6
# 73     ННС     ГРП    Б6
# 74     ННС     ВНС    Б6
#
# [75 rows x 10 columns]

# %%
final_number['Дата ВНР после'] = final_number.apply(
            lambda x:
            str(x['Дата ВНР после']), axis=1)
final_number['месяц с грп'] = final_number.apply(
            lambda x:
            x['Дата ВНР после'][:4],
            axis=1
        )
final_number
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1000     0.000000                 0                     0
# 1       10187   187.275199                 1                   100
# 2       10244   216.831732                 0                     0
# 3       10244   216.831732                 1                   100
# 4       10530   446.010090                 0                     0
# ..        ...          ...               ...                   ...
# 70        805     0.000000                 1                   100
# 71        827   195.941318                 0                     0
# 72        854   500.433812                 0                     0
# 73        95Б     0.000000                 1                   100
# 74        999     0.000000                 0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д       Дата ВНР после  \
# 0                    0                           0  2000-07-24 00:00:00
# 1                    4                         100  2012-12-24 00:00:00
# 2                    0                           0  2010-12-28 00:00:00
# 3                    4                         100  2022-01-29 00:00:00
# 4                    0                           0  2012-09-22 00:00:00
# ..                 ...                         ...                  ...
# 70                   4                         100  2009-07-02 00:00:00
# 71                   0                           0  2003-04-26 00:00:00
# 72                   0                           0  2010-11-23 00:00:00
# 73                   4                         100  2021-02-01 00:00:00
# 74                   0                           0  2000-05-17 00:00:00
#
#     ГС/ННС Тип ГТМ Пласт месяц с грп
# 0      ННС     ВНС    Б6        2000
# 1   ГС+ГРП     ГРП    Б6        2012
# 2       ГС     ВНС    Б6        2010
# 3       ГС     ГРП    Б6        2022
# 4       ГС     ВНС    Б6        2012
# ..     ...     ...   ...         ...
# 70     ННС     ГРП    Б6        2009
# 71      ГС     ВНС    Б6        2003
# 72      ГС     ВНС    Б6        2010
# 73     ННС     ГРП    Б6        2021
# 74     ННС     ВНС    Б6        2000
#
# [75 rows x 11 columns]

# %%
grp = copy.deepcopy(grp_dad)
grp['Дата'] = grp.apply(
            lambda x:
            str(x['Дата']), axis=1)
grp['месяц с грп'] = grp.apply(
            lambda x:
            x['Дата'][:4],
            axis=1
        )
grp
# Out:
#    Номер скважины                   Unnamed: 0                 Дата Подрядчик  \
# 0             805  Проблемы при построении ГРП  2009-07-02 00:00:00       МКН
# 1             804  Проблемы при построении ГРП  2007-06-27 00:00:00       МКН
# 2             801                          NaN  2012-09-06 00:00:00       МКН
# 3             688                          NaN  2006-08-12 00:00:00       ШЛБ
# 4              66  Проблемы при построении ГРП  2008-07-31 00:00:00       МКН
# 5             634                          NaN  2006-08-13 00:00:00       ХЛБ
# 6             632  Проблемы при построении ГРП  2013-03-05 00:00:00       ТВС
# 7             577  Проблемы при построении ГРП  2009-10-05 00:00:00       ТВС
# 8             577                          NaN  2004-03-15 00:00:00       МКН
# 9             560  Проблемы при построении ГРП  2004-01-12 00:00:00       МКН
# 10            545                          NaN  2006-09-21 00:00:00       ШЛБ
# 11            529                          NaN  2006-10-02 00:00:00       ШЛБ
# 12             49  Проблемы при построении ГРП  2012-10-09 00:00:00       ТВС
# 13            466  Проблемы при построении ГРП  2020-04-22 00:00:00       МКМ
# 14            411  Проблемы при построении ГРП  2019-08-10 00:00:00        КН
# 15            224  Проблемы при построении ГРП  2012-01-15 00:00:00       ТВС
# 16           1812  Проблемы при построении ГРП  2003-12-24 00:00:00       МКН
# 17          1811Л  Проблемы при построении ГРП  2004-03-30 00:00:00       МКН
# 18          1809Л  Проблемы при построении ГРП  2004-02-14 00:00:00       МКН
# 19            147  Проблемы при построении ГРП  2012-11-14 00:00:00       ТВС
# 20          11011  Проблемы при построении ГРП  2010-11-10 00:00:00       ТВС
# 21          10187  Проблемы при построении ГРП  2012-12-07 00:00:00       ТВС
#
#                                           Комментарии Страница  Unnamed: 6  \
# 0   После анализа данных, полученных при проведени...      -1_         NaN
# 1   По результату Мини-ГРП принято решение уменьши...      -1_         NaN
# 2   После анализа данных, полученных при проведени...      -1_         NaN
# 3                                                 NaN      -1_         NaN
# 4   Уменьшили подушку до 11м3 (план 20м3), увеличи...      -1_         NaN
# 5                                                 NaN      -1_         NaN
# 6   ГРП по плану (+), 3т. уменьшена подушка с 3 м3...      -1_         NaN
# 7                                        По программе      -1_         NaN
# 8                                                 NaN      -1_         NaN
# 9                         Без миниГРП. Без остановки.      -1_         NaN
# 10                                                NaN      -1_         NaN
# 11                                                NaN      -1_         NaN
# 12  ГРП по плану (+), 5т. В связи с высокой вероят...      -1_         NaN
# 13  ГРП (+) План. 8т. / Пласт 7.9т. / В скважине 0...      -1_         NaN
# 14  Оборудование: ПАКЕР, НКТ, АМТ-  ООО "КАТКонефт...      -1_         NaN
# 15                              ГРП по плану (+), 2т.      -1_         NaN
# 16                                       Без миниГРП.      -1_         NaN
# 17                                        без миниГРП      -1_         NaN
# 18                                      без остановки      -1_         NaN
# 19                               ГРП по плану (+), т.      -1_         NaN
# 20                             ГРП по плану (+), 40т.      -1_         NaN
# 21                              ГРП по плану (+), 6т.      -1_         NaN
#
#    Пласт  Наклон  Азимут  ...  Рпл Хорнер   Эфф  Расход    Конц  Гель    М бр  \
# 0     Б6   14.70   197.0  ...       199.0  33.0     2.0   900.0   NaN     NaN
# 1     Б6   33.70   220.0  ...       147.0  42.0     NaN   700.0   NaN     NaN
# 2     Б6   19.10   255.0  ...       167.0  65.0     2.4   900.0   NaN     NaN
# 3     Б6    2.00   312.0  ...         NaN   NaN     NaN     NaN   NaN     NaN
# 4     Б6   11.16   164.0  ...       166.0  54.0     NaN   800.0   NaN     NaN
# 5     Б6    8.00     NaN  ...       175.0   NaN     NaN     NaN   NaN     NaN
# 6     Б6   10.00    51.0  ...       164.0  55.0     2.0   600.0   NaN     NaN
# 7     Б6    8.00   219.0  ...       161.0  58.0     2.2  1230.0   NaN     NaN
# 8     Б6     NaN     NaN  ...         NaN   NaN     NaN     NaN   NaN     NaN
# 9     Б6     NaN     NaN  ...         NaN   NaN     NaN   670.0   NaN     NaN
# 10    Б6   14.00   319.0  ...         NaN   NaN     NaN     NaN   NaN     NaN
# 11    Б6   30.00   180.0  ...         NaN   NaN     NaN     NaN   NaN     NaN
# 12    Б6   15.00   354.0  ...         NaN   NaN     2.2   900.0   NaN     NaN
# 13    Б6    6.00    18.0  ...        34.0  46.0     2.2  1000.0   NaN  11.315
# 14    Б6    5.73   175.0  ...        30.0  38.0     3.0  1000.0   NaN  52.000
# 15    Б6   14.00    97.0  ...         NaN   NaN     NaN     NaN   NaN     NaN
# 16    Б6     NaN     NaN  ...         NaN   NaN     NaN     NaN   NaN     NaN
# 17    Б6     NaN     NaN  ...         NaN   NaN     NaN     NaN   NaN     NaN
# 18    Б6     NaN     NaN  ...         NaN   NaN     NaN     NaN   NaN     NaN
# 19    Б6     NaN     NaN  ...         NaN   NaN     NaN     NaN   NaN     NaN
# 20    Б6   15.70   171.1  ...       256.0  79.0     2.5  1200.0   NaN     NaN
# 21    Б6   87.00     3.0  ...       110.0  45.0     2.6   800.0   NaN     NaN
#
#     V под  V без под  V гель  месяц с грп
# 0     5.0       59.4     NaN         2009
# 1     8.5       95.3     NaN         2007
# 2     5.0       61.8     NaN         2012
# 3     NaN        NaN     NaN         2006
# 4    11.0       87.7     NaN         2008
# 5    15.0        NaN     NaN         2006
# 6     2.0       36.2     NaN         2013
# 7    14.0      108.9     NaN         2009
# 8     5.0        NaN     NaN         2004
# 9     5.0       37.4     NaN         2004
# 10    8.0        NaN     NaN         2006
# 11    6.0        NaN     NaN         2006
# 12    3.0       25.0     NaN         2012
# 13    7.0        NaN    24.8         2020
# 14    NaN       10.0    18.0         2019
# 15    NaN       21.9     NaN         2012
# 16   22.0        NaN     NaN         2003
# 17    5.0        NaN     NaN         2004
# 18    4.0        NaN     NaN         2004
# 19    NaN        NaN     NaN         2012
# 20   13.0      127.6     NaN         2010
# 21    6.0        NaN     NaN         2012
#
# [22 rows x 37 columns]

# %%
grp = grp.groupby(by=['Номер скважины', 'месяц с грп']).agg(
            {'Пласт': lambda x:
            x.tolist()}
        )
grp
# Out:
#                            Пласт
# Номер скважины месяц с грп
# 10187          2012         [Б6]
# 11011          2010         [Б6]
# 147            2012         [Б6]
# 1809Л          2004         [Б6]
# 1811Л          2004         [Б6]
# 1812           2003         [Б6]
# 224            2012         [Б6]
# 411            2019         [Б6]
# 466            2020         [Б6]
# 49             2012         [Б6]
# 529            2006         [Б6]
# 545            2006         [Б6]
# 560            2004         [Б6]
# 577            2004         [Б6]
#                2009         [Б6]
# 632            2013         [Б6]
# 634            2006         [Б6]
# 66             2008         [Б6]
# 688            2006         [Б6]
# 801            2012         [Б6]
# 804            2007         [Б6]
# 805            2009         [Б6]

# %%
grp['Количество'] = grp.apply(
            lambda x:
            len(x['Пласт'])
            , axis=1)
grp
# Out:
#                            Пласт  Количество
# Номер скважины месяц с грп
# 10187          2012         [Б6]           1
# 11011          2010         [Б6]           1
# 147            2012         [Б6]           1
# 1809Л          2004         [Б6]           1
# 1811Л          2004         [Б6]           1
# 1812           2003         [Б6]           1
# 224            2012         [Б6]           1
# 411            2019         [Б6]           1
# 466            2020         [Б6]           1
# 49             2012         [Б6]           1
# 529            2006         [Б6]           1
# 545            2006         [Б6]           1
# 560            2004         [Б6]           1
# 577            2004         [Б6]           1
#                2009         [Б6]           1
# 632            2013         [Б6]           1
# 634            2006         [Б6]           1
# 66             2008         [Б6]           1
# 688            2006         [Б6]           1
# 801            2012         [Б6]           1
# 804            2007         [Б6]           1
# 805            2009         [Б6]           1

# %%
grp.reset_index(inplace=True)
grp
# Out:
#    Номер скважины месяц с грп Пласт  Количество
# 0           10187        2012  [Б6]           1
# 1           11011        2010  [Б6]           1
# 2             147        2012  [Б6]           1
# 3           1809Л        2004  [Б6]           1
# 4           1811Л        2004  [Б6]           1
# 5            1812        2003  [Б6]           1
# 6             224        2012  [Б6]           1
# 7             411        2019  [Б6]           1
# 8             466        2020  [Б6]           1
# 9              49        2012  [Б6]           1
# 10            529        2006  [Б6]           1
# 11            545        2006  [Б6]           1
# 12            560        2004  [Б6]           1
# 13            577        2004  [Б6]           1
# 14            577        2009  [Б6]           1
# 15            632        2013  [Б6]           1
# 16            634        2006  [Б6]           1
# 17             66        2008  [Б6]           1
# 18            688        2006  [Б6]           1
# 19            801        2012  [Б6]           1
# 20            804        2007  [Б6]           1
# 21            805        2009  [Б6]           1

# %%
new_100 = grp['Номер скважины'].tolist()
grp['Скважина №'] = new_100
grp = grp.drop(['Номер скважины'], axis=1)
grp
# Out:
#    месяц с грп Пласт  Количество Скважина №
# 0         2012  [Б6]           1      10187
# 1         2010  [Б6]           1      11011
# 2         2012  [Б6]           1        147
# 3         2004  [Б6]           1      1809Л
# 4         2004  [Б6]           1      1811Л
# 5         2003  [Б6]           1       1812
# 6         2012  [Б6]           1        224
# 7         2019  [Б6]           1        411
# 8         2020  [Б6]           1        466
# 9         2012  [Б6]           1         49
# 10        2006  [Б6]           1        529
# 11        2006  [Б6]           1        545
# 12        2004  [Б6]           1        560
# 13        2004  [Б6]           1        577
# 14        2009  [Б6]           1        577
# 15        2013  [Б6]           1        632
# 16        2006  [Б6]           1        634
# 17        2008  [Б6]           1         66
# 18        2006  [Б6]           1        688
# 19        2012  [Б6]           1        801
# 20        2007  [Б6]           1        804
# 21        2009  [Б6]           1        805

# %%
grp = grp.drop(['Пласт'], axis=1)
grp
# Out:
#    месяц с грп  Количество Скважина №
# 0         2012           1      10187
# 1         2010           1      11011
# 2         2012           1        147
# 3         2004           1      1809Л
# 4         2004           1      1811Л
# 5         2003           1       1812
# 6         2012           1        224
# 7         2019           1        411
# 8         2020           1        466
# 9         2012           1         49
# 10        2006           1        529
# 11        2006           1        545
# 12        2004           1        560
# 13        2004           1        577
# 14        2009           1        577
# 15        2013           1        632
# 16        2006           1        634
# 17        2008           1         66
# 18        2006           1        688
# 19        2012           1        801
# 20        2007           1        804
# 21        2009           1        805

# %%
sotired = final_number.merge(grp, on=['месяц с грп', 'Скважина №'],how='left')
sotired
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1000     0.000000                 0                     0
# 1       10187   187.275199                 1                   100
# 2       10244   216.831732                 0                     0
# 3       10244   216.831732                 1                   100
# 4       10530   446.010090                 0                     0
# ..        ...          ...               ...                   ...
# 70        805     0.000000                 1                   100
# 71        827   195.941318                 0                     0
# 72        854   500.433812                 0                     0
# 73        95Б     0.000000                 1                   100
# 74        999     0.000000                 0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д       Дата ВНР после  \
# 0                    0                           0  2000-07-24 00:00:00
# 1                    4                         100  2012-12-24 00:00:00
# 2                    0                           0  2010-12-28 00:00:00
# 3                    4                         100  2022-01-29 00:00:00
# 4                    0                           0  2012-09-22 00:00:00
# ..                 ...                         ...                  ...
# 70                   4                         100  2009-07-02 00:00:00
# 71                   0                           0  2003-04-26 00:00:00
# 72                   0                           0  2010-11-23 00:00:00
# 73                   4                         100  2021-02-01 00:00:00
# 74                   0                           0  2000-05-17 00:00:00
#
#     ГС/ННС Тип ГТМ Пласт месяц с грп  Количество
# 0      ННС     ВНС    Б6        2000         NaN
# 1   ГС+ГРП     ГРП    Б6        2012         1.0
# 2       ГС     ВНС    Б6        2010         NaN
# 3       ГС     ГРП    Б6        2022         NaN
# 4       ГС     ВНС    Б6        2012         NaN
# ..     ...     ...   ...         ...         ...
# 70     ННС     ГРП    Б6        2009         1.0
# 71      ГС     ВНС    Б6        2003         NaN
# 72      ГС     ВНС    Б6        2010         NaN
# 73     ННС     ГРП    Б6        2021         NaN
# 74     ННС     ВНС    Б6        2000         NaN
#
# [75 rows x 12 columns]

# %%
sotired = sotired.drop(['Число стадий ГРП'], axis=1)
sotired
# Out:
#    Скважина №  Длина ГС, м  Полудлина трещины, м  Ширина трещины, мм  \
# 0        1000     0.000000                     0                   0
# 1       10187   187.275199                   100                   4
# 2       10244   216.831732                     0                   0
# 3       10244   216.831732                   100                   4
# 4       10530   446.010090                     0                   0
# ..        ...          ...                   ...                 ...
# 70        805     0.000000                   100                   4
# 71        827   195.941318                     0                   0
# 72        854   500.433812                     0                   0
# 73        95Б     0.000000                   100                   4
# 74        999     0.000000                     0                   0
#
#     Проницаемость проппанта, Д       Дата ВНР после  ГС/ННС Тип ГТМ Пласт  \
# 0                            0  2000-07-24 00:00:00     ННС     ВНС    Б6
# 1                          100  2012-12-24 00:00:00  ГС+ГРП     ГРП    Б6
# 2                            0  2010-12-28 00:00:00      ГС     ВНС    Б6
# 3                          100  2022-01-29 00:00:00      ГС     ГРП    Б6
# 4                            0  2012-09-22 00:00:00      ГС     ВНС    Б6
# ..                         ...                  ...     ...     ...   ...
# 70                         100  2009-07-02 00:00:00     ННС     ГРП    Б6
# 71                           0  2003-04-26 00:00:00      ГС     ВНС    Б6
# 72                           0  2010-11-23 00:00:00      ГС     ВНС    Б6
# 73                         100  2021-02-01 00:00:00     ННС     ГРП    Б6
# 74                           0  2000-05-17 00:00:00     ННС     ВНС    Б6
#
#    месяц с грп  Количество
# 0         2000         NaN
# 1         2012         1.0
# 2         2010         NaN
# 3         2022         NaN
# 4         2012         NaN
# ..         ...         ...
# 70        2009         1.0
# 71        2003         NaN
# 72        2010         NaN
# 73        2021         NaN
# 74        2000         NaN
#
# [75 rows x 11 columns]

# %%
new_50 = sotired['Количество'].tolist()
sotired['Число стадий ГРП'] = new_50
sotired = sotired.drop(['Количество'], axis=1)
sotired['Число стадий ГРП'] = sotired.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Число стадий ГРП']
            , axis=1)
sotired
# Out:
#    Скважина №  Длина ГС, м  Полудлина трещины, м  Ширина трещины, мм  \
# 0        1000     0.000000                     0                   0
# 1       10187   187.275199                   100                   4
# 2       10244   216.831732                     0                   0
# 3       10244   216.831732                   100                   4
# 4       10530   446.010090                     0                   0
# ..        ...          ...                   ...                 ...
# 70        805     0.000000                   100                   4
# 71        827   195.941318                     0                   0
# 72        854   500.433812                     0                   0
# 73        95Б     0.000000                   100                   4
# 74        999     0.000000                     0                   0
#
#     Проницаемость проппанта, Д       Дата ВНР после  ГС/ННС Тип ГТМ Пласт  \
# 0                            0  2000-07-24 00:00:00     ННС     ВНС    Б6
# 1                          100  2012-12-24 00:00:00  ГС+ГРП     ГРП    Б6
# 2                            0  2010-12-28 00:00:00      ГС     ВНС    Б6
# 3                          100  2022-01-29 00:00:00      ГС     ГРП    Б6
# 4                            0  2012-09-22 00:00:00      ГС     ВНС    Б6
# ..                         ...                  ...     ...     ...   ...
# 70                         100  2009-07-02 00:00:00     ННС     ГРП    Б6
# 71                           0  2003-04-26 00:00:00      ГС     ВНС    Б6
# 72                           0  2010-11-23 00:00:00      ГС     ВНС    Б6
# 73                         100  2021-02-01 00:00:00     ННС     ГРП    Б6
# 74                           0  2000-05-17 00:00:00     ННС     ВНС    Б6
#
#    месяц с грп  Число стадий ГРП
# 0         2000               0.0
# 1         2012               1.0
# 2         2010               0.0
# 3         2022               NaN
# 4         2012               0.0
# ..         ...               ...
# 70        2009               1.0
# 71        2003               0.0
# 72        2010               0.0
# 73        2021               NaN
# 74        2000               0.0
#
# [75 rows x 11 columns]

# %%
sotired.tail(30)
# Out:
#    Скважина №  Длина ГС, м  Полудлина трещины, м  Ширина трещины, мм  \
# 45        540   703.022048                   100                   4
# 46        545     0.000000                   100                   4
# 47        560     0.000000                   100                   4
# 48        560     0.000000                   100                   4
# 49        568     0.000000                   100                   4
# 50        577   315.125372                   100                   4
# 51        584     0.000000                   100                   4
# 52        595     0.000000                   100                   4
# 53        658     0.000000                   100                   4
# 54         66     0.000000                   100                   4
# 55         66     0.000000                   100                   4
# 56        688     0.000000                   100                   4
# 57        706   669.127790                   100                   4
# 58        708   563.695840                   100                   4
# 59       710Б   211.804155                   100                   4
# 60       710Б   211.804155                   100                   4
# 61        742   142.351677                   100                   4
# 62        762     0.000000                   100                   4
# 63        771     0.000000                   100                   4
# 64        793   209.697401                     0                   0
# 65        794   175.182762                     0                   0
# 66        801     0.000000                   100                   4
# 67        803     0.000000                   100                   4
# 68        804     0.000000                     0                   0
# 69        805     0.000000                     0                   0
# 70        805     0.000000                   100                   4
# 71        827   195.941318                     0                   0
# 72        854   500.433812                     0                   0
# 73        95Б     0.000000                   100                   4
# 74        999     0.000000                     0                   0
#
#     Проницаемость проппанта, Д       Дата ВНР после ГС/ННС Тип ГТМ Пласт  \
# 45                         100  2012-06-19 00:00:00     ГС     ГРП    Б6
# 46                         100  2006-09-25 00:00:00    ННС     ГРП    Б6
# 47                         100  2004-01-12 00:00:00    ННС     ГРП    Б6
# 48                         100  2007-03-07 00:00:00    ННС     ГРП    Б6
# 49                         100  2008-04-08 00:00:00    ННС     ГРП    Б6
# 50                         100  2004-03-15 00:00:00     ГС     ГРП    Б6
# 51                         100  2009-11-18 00:00:00    ННС     ГРП    Б6
# 52                         100  2009-01-21 00:00:00    ННС     ГРП    Б6
# 53                         100  2007-02-04 00:00:00    ННС     ГРП    Б6
# 54                         100  2008-07-31 00:00:00    ННС     ГРП    Б6
# 55                         100  2008-10-27 00:00:00    ННС     ГРП    Б6
# 56                         100  2006-08-21 00:00:00    ННС     ГРП    Б6
# 57                         100  2007-05-19 00:00:00     ГС     ГРП    Б6
# 58                         100  2008-07-20 00:00:00     ГС     ГРП    Б6
# 59                         100  2019-12-31 00:00:00     ГС     ГРП    Б6
# 60                         100  2020-01-22 00:00:00     ГС     ГРП    Б6
# 61                         100  2009-05-07 00:00:00     ГС     ГРП    Б6
# 62                         100  2008-02-23 00:00:00    ННС     ГРП    Б6
# 63                         100  2009-10-27 00:00:00    ННС     ГРП    Б6
# 64                           0  2003-07-08 00:00:00     ГС     ВНС    Б6
# 65                           0  2003-03-09 00:00:00     ГС     ВНС    Б6
# 66                         100  2012-09-15 00:00:00    ННС     ГРП    Б6
# 67                         100  2008-08-03 00:00:00    ННС     ГРП    Б6
# 68                           0  2001-08-21 00:00:00    ННС     ВНС    Б6
# 69                           0  2001-08-30 00:00:00    ННС     ВНС    Б6
# 70                         100  2009-07-02 00:00:00    ННС     ГРП    Б6
# 71                           0  2003-04-26 00:00:00     ГС     ВНС    Б6
# 72                           0  2010-11-23 00:00:00     ГС     ВНС    Б6
# 73                         100  2021-02-01 00:00:00    ННС     ГРП    Б6
# 74                           0  2000-05-17 00:00:00    ННС     ВНС    Б6
#
#    месяц с грп  Число стадий ГРП
# 45        2012               NaN
# 46        2006               1.0
# 47        2004               1.0
# 48        2007               NaN
# 49        2008               NaN
# 50        2004               1.0
# 51        2009               NaN
# 52        2009               NaN
# 53        2007               NaN
# 54        2008               1.0
# 55        2008               1.0
# 56        2006               1.0
# 57        2007               NaN
# 58        2008               NaN
# 59        2019               NaN
# 60        2020               NaN
# 61        2009               NaN
# 62        2008               NaN
# 63        2009               NaN
# 64        2003               0.0
# 65        2003               0.0
# 66        2012               1.0
# 67        2008               NaN
# 68        2001               0.0
# 69        2001               0.0
# 70        2009               1.0
# 71        2003               0.0
# 72        2010               0.0
# 73        2021               NaN
# 74        2000               0.0

# %%
sotired['Дата ВНР после'] = pd.to_datetime(sotired['Дата ВНР после'])

sotired
# Out:
#    Скважина №  Длина ГС, м  Полудлина трещины, м  Ширина трещины, мм  \
# 0        1000     0.000000                     0                   0
# 1       10187   187.275199                   100                   4
# 2       10244   216.831732                     0                   0
# 3       10244   216.831732                   100                   4
# 4       10530   446.010090                     0                   0
# ..        ...          ...                   ...                 ...
# 70        805     0.000000                   100                   4
# 71        827   195.941318                     0                   0
# 72        854   500.433812                     0                   0
# 73        95Б     0.000000                   100                   4
# 74        999     0.000000                     0                   0
#
#     Проницаемость проппанта, Д Дата ВНР после  ГС/ННС Тип ГТМ Пласт  \
# 0                            0     2000-07-24     ННС     ВНС    Б6
# 1                          100     2012-12-24  ГС+ГРП     ГРП    Б6
# 2                            0     2010-12-28      ГС     ВНС    Б6
# 3                          100     2022-01-29      ГС     ГРП    Б6
# 4                            0     2012-09-22      ГС     ВНС    Б6
# ..                         ...            ...     ...     ...   ...
# 70                         100     2009-07-02     ННС     ГРП    Б6
# 71                           0     2003-04-26      ГС     ВНС    Б6
# 72                           0     2010-11-23      ГС     ВНС    Б6
# 73                         100     2021-02-01     ННС     ГРП    Б6
# 74                           0     2000-05-17     ННС     ВНС    Б6
#
#    месяц с грп  Число стадий ГРП
# 0         2000               0.0
# 1         2012               1.0
# 2         2010               0.0
# 3         2022               NaN
# 4         2012               0.0
# ..         ...               ...
# 70        2009               1.0
# 71        2003               0.0
# 72        2010               0.0
# 73        2021               NaN
# 74        2000               0.0
#
# [75 rows x 11 columns]

# %%
sotired['ГС/ННС'] = sotired.apply(
            lambda x:
            str(x['ГС/ННС']) + '+ГРП' if str(x['Тип ГТМ']) == 'ГРП' and 'ГРП' not in str(x['ГС/ННС'])
            else x['ГС/ННС'], axis=1)
sotired
# Out:
#    Скважина №  Длина ГС, м  Полудлина трещины, м  Ширина трещины, мм  \
# 0        1000     0.000000                     0                   0
# 1       10187   187.275199                   100                   4
# 2       10244   216.831732                     0                   0
# 3       10244   216.831732                   100                   4
# 4       10530   446.010090                     0                   0
# ..        ...          ...                   ...                 ...
# 70        805     0.000000                   100                   4
# 71        827   195.941318                     0                   0
# 72        854   500.433812                     0                   0
# 73        95Б     0.000000                   100                   4
# 74        999     0.000000                     0                   0
#
#     Проницаемость проппанта, Д Дата ВНР после   ГС/ННС Тип ГТМ Пласт  \
# 0                            0     2000-07-24      ННС     ВНС    Б6
# 1                          100     2012-12-24   ГС+ГРП     ГРП    Б6
# 2                            0     2010-12-28       ГС     ВНС    Б6
# 3                          100     2022-01-29   ГС+ГРП     ГРП    Б6
# 4                            0     2012-09-22       ГС     ВНС    Б6
# ..                         ...            ...      ...     ...   ...
# 70                         100     2009-07-02  ННС+ГРП     ГРП    Б6
# 71                           0     2003-04-26       ГС     ВНС    Б6
# 72                           0     2010-11-23       ГС     ВНС    Б6
# 73                         100     2021-02-01  ННС+ГРП     ГРП    Б6
# 74                           0     2000-05-17      ННС     ВНС    Б6
#
#    месяц с грп  Число стадий ГРП
# 0         2000               0.0
# 1         2012               1.0
# 2         2010               0.0
# 3         2022               NaN
# 4         2012               0.0
# ..         ...               ...
# 70        2009               1.0
# 71        2003               0.0
# 72        2010               0.0
# 73        2021               NaN
# 74        2000               0.0
#
# [75 rows x 11 columns]

# %%
sotired = sotired.reindex(
            columns=['Скважина №', 'Длина ГС, м', 'Число стадий ГРП', 'Полудлина трещины, м', 'Ширина трещины, мм',
                     'Проницаемость проппанта, Д', 'Дата ВНР после', 'ГС/ННС', 'Тип ГТМ', 'Пласт'])
sotired['Число стадий ГРП'] = sotired.apply(
            lambda x:
            0 if str(x['Тип ГТМ']) == 'ВНС'
            else x['Число стадий ГРП'], axis=1)
sotired
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1000     0.000000               0.0                     0
# 1       10187   187.275199               1.0                   100
# 2       10244   216.831732               0.0                     0
# 3       10244   216.831732               NaN                   100
# 4       10530   446.010090               0.0                     0
# ..        ...          ...               ...                   ...
# 70        805     0.000000               1.0                   100
# 71        827   195.941318               0.0                     0
# 72        854   500.433812               0.0                     0
# 73        95Б     0.000000               NaN                   100
# 74        999     0.000000               0.0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после   ГС/ННС  \
# 0                    0                           0     2000-07-24      ННС
# 1                    4                         100     2012-12-24   ГС+ГРП
# 2                    0                           0     2010-12-28       ГС
# 3                    4                         100     2022-01-29   ГС+ГРП
# 4                    0                           0     2012-09-22       ГС
# ..                 ...                         ...            ...      ...
# 70                   4                         100     2009-07-02  ННС+ГРП
# 71                   0                           0     2003-04-26       ГС
# 72                   0                           0     2010-11-23       ГС
# 73                   4                         100     2021-02-01  ННС+ГРП
# 74                   0                           0     2000-05-17      ННС
#
#    Тип ГТМ Пласт
# 0      ВНС    Б6
# 1      ГРП    Б6
# 2      ВНС    Б6
# 3      ГРП    Б6
# 4      ВНС    Б6
# ..     ...   ...
# 70     ГРП    Б6
# 71     ВНС    Б6
# 72     ВНС    Б6
# 73     ГРП    Б6
# 74     ВНС    Б6
#
# [75 rows x 10 columns]

# %%
sotired['Полудлина трещины, м'] = sotired.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Полудлина трещины, м']
            , axis=1)
sotired['Ширина трещины, мм'] = sotired.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Ширина трещины, мм']
            , axis=1)
sotired['Проницаемость проппанта, Д'] = sotired.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Проницаемость проппанта, Д']
            , axis=1)
        # ДОБАВИТЬ В ВНС
sotired['Число стадий ГРП'] = sotired.apply(
            lambda x:
            0 if 'ВНС' in str(x['Тип ГТМ'])
            else x['Число стадий ГРП']
            , axis=1)
sotired
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1000     0.000000               0.0                     0
# 1       10187   187.275199               1.0                   100
# 2       10244   216.831732               0.0                     0
# 3       10244   216.831732               NaN                   100
# 4       10530   446.010090               0.0                     0
# ..        ...          ...               ...                   ...
# 70        805     0.000000               1.0                   100
# 71        827   195.941318               0.0                     0
# 72        854   500.433812               0.0                     0
# 73        95Б     0.000000               NaN                   100
# 74        999     0.000000               0.0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после   ГС/ННС  \
# 0                    0                           0     2000-07-24      ННС
# 1                    4                         100     2012-12-24   ГС+ГРП
# 2                    0                           0     2010-12-28       ГС
# 3                    4                         100     2022-01-29   ГС+ГРП
# 4                    0                           0     2012-09-22       ГС
# ..                 ...                         ...            ...      ...
# 70                   4                         100     2009-07-02  ННС+ГРП
# 71                   0                           0     2003-04-26       ГС
# 72                   0                           0     2010-11-23       ГС
# 73                   4                         100     2021-02-01  ННС+ГРП
# 74                   0                           0     2000-05-17      ННС
#
#    Тип ГТМ Пласт
# 0      ВНС    Б6
# 1      ГРП    Б6
# 2      ВНС    Б6
# 3      ГРП    Б6
# 4      ВНС    Б6
# ..     ...   ...
# 70     ГРП    Б6
# 71     ВНС    Б6
# 72     ВНС    Б6
# 73     ГРП    Б6
# 74     ВНС    Б6
#
# [75 rows x 10 columns]

# %%
        # удаляем если в одном месяце
sotired['index']=sotired.index
dele = copy.deepcopy(sotired)
dele['чек'] = dele.apply(
            lambda x:
            x['Скважина №'].partition('_')[0] if '_' in str(x['Скважина №'])
            else x['Скважина №'], axis=1)
dele['месяц'] = dele.apply(
            lambda x:
            str(x['Дата ВНР после'])[:7],
            axis=1
        )
dele = dele.groupby(by=['чек', 'месяц']).agg(
            {'index': lambda x:
            x.tolist()}
        )
dele['скока_их'] = dele.apply(
            lambda x: len(x['index'])
            , axis=1)
dele = dele.drop(dele[dele['скока_их'] < 2].index).reset_index(drop=True)
to_stay = []
all_wells = []
for i in dele['index']:
    all_wells += i
for i in dele['index']:
    to_stay.append(i[-1])
dele
# Out:
# Empty DataFrame
# Columns: [index, скока_их]
# Index: []

# %%
alli = copy.deepcopy(sotired)
alli = alli[alli['index'].isin(all_wells)].reset_index(drop=True)
alli = alli.drop(alli[alli['Тип ГТМ'] == 'ВНС'].index).reset_index(drop=True)
alli = alli.groupby('Скважина №').agg(
            {'index': lambda x:
            x.tolist()[0]}
        )
definetely_stay = alli['index'].tolist()
array_3 = list(all_wells)
for x in definetely_stay:
    try:
        array_3.remove(x)
    except ValueError:
        pass
        # вот досюда
alli
# Out:
# Empty DataFrame
# Columns: [index]
# Index: []

# %%
sotired = sotired[~sotired['index'].isin(array_3)].reset_index(drop=True)
sotired = sotired.drop(['index'], axis=1)
sotired
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1000     0.000000               0.0                     0
# 1       10187   187.275199               1.0                   100
# 2       10244   216.831732               0.0                     0
# 3       10244   216.831732               NaN                   100
# 4       10530   446.010090               0.0                     0
# ..        ...          ...               ...                   ...
# 70        805     0.000000               1.0                   100
# 71        827   195.941318               0.0                     0
# 72        854   500.433812               0.0                     0
# 73        95Б     0.000000               NaN                   100
# 74        999     0.000000               0.0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после   ГС/ННС  \
# 0                    0                           0     2000-07-24      ННС
# 1                    4                         100     2012-12-24   ГС+ГРП
# 2                    0                           0     2010-12-28       ГС
# 3                    4                         100     2022-01-29   ГС+ГРП
# 4                    0                           0     2012-09-22       ГС
# ..                 ...                         ...            ...      ...
# 70                   4                         100     2009-07-02  ННС+ГРП
# 71                   0                           0     2003-04-26       ГС
# 72                   0                           0     2010-11-23       ГС
# 73                   4                         100     2021-02-01  ННС+ГРП
# 74                   0                           0     2000-05-17      ННС
#
#    Тип ГТМ Пласт
# 0      ВНС    Б6
# 1      ГРП    Б6
# 2      ВНС    Б6
# 3      ГРП    Б6
# 4      ВНС    Б6
# ..     ...   ...
# 70     ГРП    Б6
# 71     ВНС    Б6
# 72     ВНС    Б6
# 73     ГРП    Б6
# 74     ВНС    Б6
#
# [75 rows x 10 columns]

# %%
        # проверяем ЗБС
grp_4 = copy.deepcopy(grp_gtm)

grp_4['Скважина'] = grp_4.apply(
            lambda x:
            str(x['Скважина']), axis=1)

grp_4
# Out:
#      Месторождение      Unnamed: 0 Скважина       Куст  \
# 0         Аганское      Добывающая     1000  КУСТ-110Б
# 1         Аганское      Добывающая     1000  КУСТ-110Б
# 2         Аганское      Добывающая     1000  КУСТ-110Б
# 3         Аганское      Добывающая    10187    КУСТ-5Б
# 4         Аганское      Добывающая    10187    КУСТ-5Б
# ...            ...             ...      ...        ...
# 1104      Аганское      Добывающая       98    КУСТ-11
# 1105      Аганское      Добывающая      999  КУСТ-110Б
# 1106      Аганское      Добывающая      999  КУСТ-110Б
# 1107      Аганское  Нагнетательная      99Б    КУСТ-12
# 1108      Аганское      Добывающая      99Б    КУСТ-12
#
#                                                 Тип  \
# 0                                               ВНС
# 1                                               ОПТ
# 2                                               ОПТ
# 3                                               ГРП
# 4                                               ВНС
# ...                                             ...
# 1104                         Переход или приобщение
# 1105                                            ВНС
# 1106                  РИР негерметичности э/колонны
# 1107                                  Перевод в ППД
# 1108  Выравнивание профиля притока или приёмистости
#
#                            Краткое описание мероприятий  \
# 0                    Ввод добывающих скважин из бурения
# 1                   ТР3 Оптимизация режима эксплуатации
# 2                   ТР3 Оптимизация режима эксплуатации
# 3                                  КР7-2 Проведение ГРП
# 4                    Ввод добывающих скважин из бурения
# ...                                                 ...
# 1104  КР4-1 Переход  на другие вышележащие и нижележ...
# 1105                 Ввод добывающих скважин из бурения
# 1106  КР2-4 Устранение негерметичности частичной сме...
# 1107  КР9-6 Перевод под нагнетание из других категор...
# 1108                                     Проведение ВПП
#
#      Объект разработки до ГТМ  Объект разработки после ГТМ  Dэк Страница  ...  \
# 0                          Б6                          NaN  NaN      -1_  ...
# 1                          Б6                          NaN  NaN      -1_  ...
# 2                          Б6                          NaN  NaN      -1_  ...
# 3                          Б6                          NaN  NaN      -1_  ...
# 4                          Б6                          NaN  NaN      -1_  ...
# ...                       ...                          ...  ...      ...  ...
# 1104                       Б6                          NaN  NaN      -1_  ...
# 1105                       Б6                          NaN  NaN      -1_  ...
# 1106                       Б6                          NaN  NaN      -1_  ...
# 1107                       Б6                          NaN  NaN      -1_  ...
# 1108                       Б6                          NaN  NaN      -1_  ...
#
#       Состояние.1  Кпр  Скин-фактор.1  Комментарий  План  Факт  Пл-ть нефти  \
# 0             NaN  NaN            NaN          NaN   NaN   NaN          NaN
# 1             NaN  NaN            NaN          NaN   NaN   NaN          NaN
# 2             NaN  NaN            NaN          NaN   NaN   NaN          NaN
# 3             NaN  NaN            NaN          NaN   NaN   NaN          NaN
# 4             NaN  NaN            NaN          NaN   NaN   NaN          NaN
# ...           ...  ...            ...          ...   ...   ...          ...
# 1104          NaN  NaN            NaN          NaN   NaN   NaN          NaN
# 1105          NaN  NaN            NaN          NaN   NaN   NaN          NaN
# 1106          NaN  NaN            NaN          NaN   NaN   NaN          NaN
# 1107          NaN  NaN            NaN          NaN   NaN   NaN          NaN
# 1108          NaN  NaN            NaN          NaN   NaN   NaN          NaN
#
#       Коб  В-ть жидк.  P нас
# 0     NaN         NaN    NaN
# 1     NaN         NaN    NaN
# 2     NaN         NaN    NaN
# 3     NaN         NaN    NaN
# 4     NaN         NaN    NaN
# ...   ...         ...    ...
# 1104  NaN         NaN    NaN
# 1105  NaN         NaN    NaN
# 1106  NaN         NaN    NaN
# 1107  NaN         NaN    NaN
# 1108  NaN         NaN    NaN
#
# [1109 rows x 65 columns]

# %%
grp_zbs = grp_4.drop(grp_4[grp_4['Тип'] != '3БС'].index).reset_index(drop=True)
        # grp_zbs = grp_4.loc[grp_4['Тип'] == 'ЗБС']
grp_zbs = grp_zbs.groupby('Скважина').agg(
            {'Начало.1': lambda x:
            x.tolist()[1] if len(x.tolist()) > 1
            else x.tolist()[0]}
        )
grp_zbs
# Out:
#            Начало.1
# Скважина
# 1073     2018-12-28
# 11011    2014-11-06
# 1356     2019-08-09
# 1393     2019-02-13
# 1405     2019-06-07
# 1809     2019-02-14
# 1813     2009-05-03
# 1842     2019-05-06
# 206      2019-12-07
# 239      2020-03-04
# 331      2019-10-15
# 435      2020-03-27
# 490К     2009-03-14
# 527      2019-02-15
# 537      2008-10-11
# 540      2016-02-06
# 555      2019-01-21
# 677      2019-03-25
# 818      2020-01-21
# 827      2019-10-13
# 88       2016-08-20
# 924      2020-01-01
# 929      2018-11-21

# %%
grp_zbs.reset_index(drop=True)
grp_zbs.reset_index(inplace=True)
        # grp_zbs

vv = grp_zbs['Скважина'].tolist()

grp_zbs['Скважина №'] = vv
grp_zbs = grp_zbs.drop(['Скважина'], axis=1)
grp_zbs
# Out:
#      Начало.1 Скважина №
# 0  2018-12-28       1073
# 1  2014-11-06      11011
# 2  2019-08-09       1356
# 3  2019-02-13       1393
# 4  2019-06-07       1405
# 5  2019-02-14       1809
# 6  2009-05-03       1813
# 7  2019-05-06       1842
# 8  2019-12-07        206
# 9  2020-03-04        239
# 10 2019-10-15        331
# 11 2020-03-27        435
# 12 2009-03-14       490К
# 13 2019-02-15        527
# 14 2008-10-11        537
# 15 2016-02-06        540
# 16 2019-01-21        555
# 17 2019-03-25        677
# 18 2020-01-21        818
# 19 2019-10-13        827
# 20 2016-08-20         88
# 21 2020-01-01        924
# 22 2018-11-21        929

# %%
grp_zbs.loc[grp_zbs['Скважина №'] == '507']
# Out:
# Empty DataFrame
# Columns: [Начало.1, Скважина №]
# Index: []

# %%
sotired_final_zbs = sotired.merge(grp_zbs, on='Скважина №')
sotired_final_zbs
# Out:
#   Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0       1356   575.633564               NaN                   100
# 1       1809   564.088646               0.0                     0
# 2       1809   564.088646               NaN                   100
# 3       1813   512.609988               0.0                     0
# 4       1842   627.391425               0.0                     0
# 5        540   703.022048               NaN                   100
# 6        827   195.941318               0.0                     0
#
#    Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после  ГС/ННС  \
# 0                   4                         100     2019-05-18  ГС+ГРП
# 1                   0                           0     2001-06-25      ГС
# 2                   4                         100     2004-02-14  ГС+ГРП
# 3                   0                           0     2001-02-14      ГС
# 4                   0                           0     2003-05-03      ГС
# 5                   4                         100     2012-06-19  ГС+ГРП
# 6                   0                           0     2003-04-26      ГС
#
#   Тип ГТМ Пласт   Начало.1
# 0     ГРП    Б6 2019-08-09
# 1     ВНС    Б6 2019-02-14
# 2     ГРП    Б6 2019-02-14
# 3     ВНС    Б6 2009-05-03
# 4     ВНС    Б6 2019-05-06
# 5     ГРП    Б6 2016-02-06
# 6     ВНС    Б6 2019-10-13

# %%
abba = sotired_final_zbs['Скважина №'].tolist()

arura=[]
for i in abba:
    if i not in arura:
        arura.append(i)
arura
# Out:
# ['1356', '1809', '1813', '1842', '540', '827']

# %%
a=sotired_final_zbs['Дата ВНР после'][0]
type(a)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
b=sotired_final_zbs['Начало.1'][0]
type(b)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
if sotired_final_zbs.shape[0] != 0:
    
    sotired_final_zbs['Число стадий ГРП'] = sotired_final_zbs.apply(
            lambda x:
            1 if x['Дата ВНР после'] < x['Начало.1'] else x['Число стадий ГРП'],
            axis=1
            )
    sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            str(x['Скважина №'])
            + ('_Л' if x['Дата ВНР после'] < x['Начало.1'] else ''),
            axis=1
            )
    #sotired_final_zbs['L'] = sotired_final_zbs.apply(
    #            lambda x:
    #            1 if 'Л' in str(x['Скважина №'])
    #            else 0, axis=1)
    #sotired_final_zbs['ГС/ННС'] = sotired_final_zbs.apply(
    #            lambda x:
    #            str(x['ГС/ННС']).replace('ГС', 'ННС') if x['L'] == 1 else str(x['ГС/ННС']),
    #            axis=1
    #        )
    #sotired_final_zbs = sotired_final_zbs.drop(['L'], axis=1)
    sotired_final_zbs = sotired_final_zbs.drop(['Начало.1'], axis=1)
    sotired_final = sotired[~sotired['Скважина №'].isin(arura)].reset_index(drop=True)
sotired_final1 = pd.concat([sotired_final, sotired_final_zbs])
sotired_final1.reset_index(drop=True)
sotired_final1.reset_index(inplace=True)
sotired_final1
# Out:
#     index Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0       0       1000     0.000000               0.0                     0
# 1       1      10187   187.275199               1.0                   100
# 2       2      10244   216.831732               0.0                     0
# 3       3      10244   216.831732               NaN                   100
# 4       4      10530   446.010090               0.0                     0
# ..    ...        ...          ...               ...                   ...
# 70      2     1809_Л   564.088646               1.0                   100
# 71      3     1813_Л   512.609988               1.0                     0
# 72      4     1842_Л   627.391425               1.0                     0
# 73      5      540_Л   703.022048               1.0                   100
# 74      6      827_Л   195.941318               1.0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после  ГС/ННС  \
# 0                    0                           0     2000-07-24     ННС
# 1                    4                         100     2012-12-24  ГС+ГРП
# 2                    0                           0     2010-12-28      ГС
# 3                    4                         100     2022-01-29  ГС+ГРП
# 4                    0                           0     2012-09-22      ГС
# ..                 ...                         ...            ...     ...
# 70                   4                         100     2004-02-14  ГС+ГРП
# 71                   0                           0     2001-02-14      ГС
# 72                   0                           0     2003-05-03      ГС
# 73                   4                         100     2012-06-19  ГС+ГРП
# 74                   0                           0     2003-04-26      ГС
#
#    Тип ГТМ Пласт
# 0      ВНС    Б6
# 1      ГРП    Б6
# 2      ВНС    Б6
# 3      ГРП    Б6
# 4      ВНС    Б6
# ..     ...   ...
# 70     ГРП    Б6
# 71     ВНС    Б6
# 72     ВНС    Б6
# 73     ГРП    Б6
# 74     ВНС    Б6
#
# [75 rows x 11 columns]

# %%
sotired_final_zbs
# Out:
#   Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0     1356_Л   575.633564                 1                   100
# 1     1809_Л   564.088646                 1                     0
# 2     1809_Л   564.088646                 1                   100
# 3     1813_Л   512.609988                 1                     0
# 4     1842_Л   627.391425                 1                     0
# 5      540_Л   703.022048                 1                   100
# 6      827_Л   195.941318                 1                     0
#
#    Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после  ГС/ННС  \
# 0                   4                         100     2019-05-18  ГС+ГРП
# 1                   0                           0     2001-06-25      ГС
# 2                   4                         100     2004-02-14  ГС+ГРП
# 3                   0                           0     2001-02-14      ГС
# 4                   0                           0     2003-05-03      ГС
# 5                   4                         100     2012-06-19  ГС+ГРП
# 6                   0                           0     2003-04-26      ГС
#
#   Тип ГТМ Пласт
# 0     ГРП    Б6
# 1     ВНС    Б6
# 2     ГРП    Б6
# 3     ВНС    Б6
# 4     ВНС    Б6
# 5     ГРП    Б6
# 6     ВНС    Б6

# %%
sotired_final
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1000     0.000000               0.0                     0
# 1       10187   187.275199               1.0                   100
# 2       10244   216.831732               0.0                     0
# 3       10244   216.831732               NaN                   100
# 4       10530   446.010090               0.0                     0
# ..        ...          ...               ...                   ...
# 63        805     0.000000               0.0                     0
# 64        805     0.000000               1.0                   100
# 65        854   500.433812               0.0                     0
# 66        95Б     0.000000               NaN                   100
# 67        999     0.000000               0.0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после   ГС/ННС  \
# 0                    0                           0     2000-07-24      ННС
# 1                    4                         100     2012-12-24   ГС+ГРП
# 2                    0                           0     2010-12-28       ГС
# 3                    4                         100     2022-01-29   ГС+ГРП
# 4                    0                           0     2012-09-22       ГС
# ..                 ...                         ...            ...      ...
# 63                   0                           0     2001-08-30      ННС
# 64                   4                         100     2009-07-02  ННС+ГРП
# 65                   0                           0     2010-11-23       ГС
# 66                   4                         100     2021-02-01  ННС+ГРП
# 67                   0                           0     2000-05-17      ННС
#
#    Тип ГТМ Пласт
# 0      ВНС    Б6
# 1      ГРП    Б6
# 2      ВНС    Б6
# 3      ГРП    Б6
# 4      ВНС    Б6
# ..     ...   ...
# 63     ВНС    Б6
# 64     ГРП    Б6
# 65     ВНС    Б6
# 66     ГРП    Б6
# 67     ВНС    Б6
#
# [68 rows x 10 columns]

# %%
        # приставка ФРАК там где надо
sotired_final.reset_index(drop=True)
sotired_final.reset_index(inplace=True)
sotired_final['index']=sotired_final.index
step = sotired_final.drop(
            sotired_final[(sotired_final['ГС/ННС'] == 'ГС') | (sotired_final['ГС/ННС'] == 'ННС')].index)
step['для_фрак'] = step.apply(
            lambda x:
            x['Скважина №'].partition('_')[0] if '_' in str(x['Скважина №'])
            else x['Скважина №'], axis=1)
step = step.groupby(by=['для_фрак']).agg(
            {'index': lambda x:
            x.tolist()}
        )
step
# Out:
#              index
# для_фрак
# 10187          [1]
# 10244          [3]
# 1137        [5, 6]
# 1253           [7]
# 147            [9]
# 1810          [14]
# 1811          [16]
# 1812          [18]
# 2002          [31]
# 418           [35]
# 466           [36]
# 49            [37]
# 4П            [39]
# 545           [40]
# 560       [41, 42]
# 568           [43]
# 577           [44]
# 584           [45]
# 595           [46]
# 658           [47]
# 66        [48, 49]
# 688           [50]
# 706           [51]
# 708           [52]
# 710Б      [53, 54]
# 742           [55]
# 762           [56]
# 771           [57]
# 801           [60]
# 803           [61]
# 805           [64]
# 95Б           [66]

# %%
step.reset_index(inplace=True)
step.rename(columns={'для_фрак': 'список'}, inplace=True)

step['Length'] = step.apply(
            lambda x: len(x['index'])
            , axis=1)
step = step.drop(step[step['Length'] < 1].index)
gang1 = []
gang2 = []
gang3 = []
gang4 = []
gang5 = []
gang6 = []
gang7 = []
gang8 = []
gang9 = []
gang10 = []
gang1
# Out:
# []

# %%
for i in step['index']:
    if len(i) >= 1:
        gang1.append(i[0])
    if len(i) >= 2:
        gang2.append(i[1])
    if len(i) >= 3:
        gang3.append(i[2])
    if len(i) >= 4:
        gang4.append(i[3])
    if len(i) >= 5:
        gang5.append(i[4])
    if len(i) >= 6:
        gang6.append(i[5])
    if len(i) >= 7:
        gang7.append(i[6])
    if len(i) >= 8:
        gang8.append(i[7])
    if len(i) >= 9:
        gang9.append(i[8])
    if len(i) >= 10:
        gang10.append(i[9])
    else:
        pass
gang1
# Out:
# [1,
#  3,
#  5,
#  7,
#  9,
#  14,
#  16,
#  18,
#  31,
#  35,
#  36,
#  37,
#  39,
#  40,
#  41,
#  43,
#  44,
#  45,
#  46,
#  47,
#  48,
#  50,
#  51,
#  52,
#  53,
#  55,
#  56,
#  57,
#  60,
#  61,
#  64,
#  66]

# %%
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ГРП' if x['index'] in gang1
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_1' if x['index'] in gang2
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_2' if x['index'] in gang3
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_3' if x['index'] in gang4
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_4' if x['index'] in gang5
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_5' if x['index'] in gang6
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_6' if x['index'] in gang7
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_7' if x['index'] in gang8
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_8' if x['index'] in gang9
            else x['Скважина №'], axis=1)
sotired_final['Скважина №'] = sotired_final.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_9' if x['index'] in gang10
            else x['Скважина №'], axis=1)
sotired_final = sotired_final.drop(['index'], axis=1)
sotired_final
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1000     0.000000               0.0                     0
# 1   10187_ГРП   187.275199               1.0                   100
# 2       10244   216.831732               0.0                     0
# 3   10244_ГРП   216.831732               NaN                   100
# 4       10530   446.010090               0.0                     0
# ..        ...          ...               ...                   ...
# 63        805     0.000000               0.0                     0
# 64    805_ГРП     0.000000               1.0                   100
# 65        854   500.433812               0.0                     0
# 66    95Б_ГРП     0.000000               NaN                   100
# 67        999     0.000000               0.0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после   ГС/ННС  \
# 0                    0                           0     2000-07-24      ННС
# 1                    4                         100     2012-12-24   ГС+ГРП
# 2                    0                           0     2010-12-28       ГС
# 3                    4                         100     2022-01-29   ГС+ГРП
# 4                    0                           0     2012-09-22       ГС
# ..                 ...                         ...            ...      ...
# 63                   0                           0     2001-08-30      ННС
# 64                   4                         100     2009-07-02  ННС+ГРП
# 65                   0                           0     2010-11-23       ГС
# 66                   4                         100     2021-02-01  ННС+ГРП
# 67                   0                           0     2000-05-17      ННС
#
#    Тип ГТМ Пласт
# 0      ВНС    Б6
# 1      ГРП    Б6
# 2      ВНС    Б6
# 3      ГРП    Б6
# 4      ВНС    Б6
# ..     ...   ...
# 63     ВНС    Б6
# 64     ГРП    Б6
# 65     ВНС    Б6
# 66     ГРП    Б6
# 67     ВНС    Б6
#
# [68 rows x 10 columns]

# %%
        # sotired_final = sotired_final.drop(['месяц с грп'], axis=1)


sotired_final.reset_index(drop=True)
sotired_final.reset_index(inplace=True)
sotired_final = sotired_final.drop(['index'], axis=1)
sotired_final['Число стадий ГРП'] = sotired_final.apply(
            lambda x:
            1 if x['Длина ГС, м'] == 0 and 'ГРП' in x['ГС/ННС']
            else x['Число стадий ГРП'], axis=1)
sotired_final_zbs['index']=sotired_final_zbs.index
sotired_final_zbs.reset_index(drop=True)
sotired_final_zbs.reset_index(inplace=True)
step1 = sotired_final_zbs.drop(
            sotired_final_zbs[(sotired_final_zbs['ГС/ННС'] == 'ГС') | (sotired_final_zbs['ГС/ННС'] == 'ННС')].index)
step1 = step1.groupby(by=['Скважина №']).agg(
            {'index': lambda x:
            x.tolist()}
        )
step1.reset_index(inplace=True)
step1['Length'] = step1.apply(
            lambda x: len(x['index'])
            , axis=1)
step1 = step1.drop(step1[step1['Length'] < 1].index)
gang11 = []
gang21 = []
gang31 = []
gang41 = []
gang51 = []
gang61 = []
gang71 = []
gang81 = []
gang91 = []
gang101 = []
gang11
# Out:
# []

# %%
for i in step1['index']:
    if len(i) >= 1:
        gang11.append(i[0])
    if len(i) >= 2:
        gang21.append(i[1])
    if len(i) >= 3:
        gang31.append(i[2])
    if len(i) >= 4:
        gang41.append(i[3])
    if len(i) >= 5:
        gang51.append(i[4])
    if len(i) >= 6:
        gang61.append(i[5])
    if len(i) >= 7:
        gang71.append(i[6])
    if len(i) >= 8:
        gang81.append(i[7])
    if len(i) >= 9:
        gang91.append(i[8])
    if len(i) >= 10:
        gang101.append(i[9])
    else:
        pass
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ГРП' if x['index'] in gang11
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_1' if x['index'] in gang21
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_2' if x['index'] in gang31
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_3' if x['index'] in gang41
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_4' if x['index'] in gang51
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_5' if x['index'] in gang61
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_6' if x['index'] in gang71
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_7' if x['index'] in gang81
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_8' if x['index'] in gang91
            else x['Скважина №'], axis=1)
sotired_final_zbs['Скважина №'] = sotired_final_zbs.apply(
            lambda x:
            x['Скважина №'] + '_ФРАК_9' if x['index'] in gang101
            else x['Скважина №'], axis=1)
sotired_final_zbs = sotired_final_zbs.drop(['index'], axis=1)

        
sotired_final_zbs.reset_index(drop=True)
sotired_final_zbs.reset_index(inplace=True)
sotired_final_zbs = sotired_final_zbs.drop(['index'], axis=1)
sotired_final_zbs['Число стадий ГРП'] = sotired_final_zbs.apply(
            lambda x:
            1 if x['Длина ГС, м'] == 0 and 'ГРП' in x['ГС/ННС']
            else x['Число стадий ГРП'], axis=1)
we_here = pd.concat([sotired_final, sotired_final_zbs])
we_here['Число стадий ГРП'] = we_here.apply(
            lambda x:
            1 if 'ФРАК' in str(x['Скважина №'])
            else x['Число стадий ГРП'], axis=1)
we_here['Число стадий ГРП'] = we_here.apply(
            lambda x:
            0 if 'ГС' == str(x['ГС/ННС'])
            else x['Число стадий ГРП'], axis=1)
we_here['Число стадий ГРП'] = we_here.apply(
            lambda x:
            0 if 'ННС' == str(x['ГС/ННС'])
            else x['Число стадий ГРП'], axis=1)
we_here['Скважина №'] = we_here.apply(
            lambda x:
            str(x['Скважина №']).replace('_Л', 'Л') if '_Л' in str(x['Скважина №']) else str(x['Скважина №']),
            axis=1
        )
we_here
# Out:
#    Скважина №  Длина ГС, м  Число стадий ГРП  Полудлина трещины, м  \
# 0        1000     0.000000               0.0                     0
# 1   10187_ГРП   187.275199               1.0                   100
# 2       10244   216.831732               0.0                     0
# 3   10244_ГРП   216.831732               NaN                   100
# 4       10530   446.010090               0.0                     0
# ..        ...          ...               ...                   ...
# 2   1809Л_ГРП   564.088646               1.0                   100
# 3       1813Л   512.609988               0.0                     0
# 4       1842Л   627.391425               0.0                     0
# 5    540Л_ГРП   703.022048               1.0                   100
# 6        827Л   195.941318               0.0                     0
#
#     Ширина трещины, мм  Проницаемость проппанта, Д Дата ВНР после  ГС/ННС  \
# 0                    0                           0     2000-07-24     ННС
# 1                    4                         100     2012-12-24  ГС+ГРП
# 2                    0                           0     2010-12-28      ГС
# 3                    4                         100     2022-01-29  ГС+ГРП
# 4                    0                           0     2012-09-22      ГС
# ..                 ...                         ...            ...     ...
# 2                    4                         100     2004-02-14  ГС+ГРП
# 3                    0                           0     2001-02-14      ГС
# 4                    0                           0     2003-05-03      ГС
# 5                    4                         100     2012-06-19  ГС+ГРП
# 6                    0                           0     2003-04-26      ГС
#
#    Тип ГТМ Пласт  level_0
# 0      ВНС    Б6      NaN
# 1      ГРП    Б6      NaN
# 2      ВНС    Б6      NaN
# 3      ГРП    Б6      NaN
# 4      ВНС    Б6      NaN
# ..     ...   ...      ...
# 2      ГРП    Б6      2.0
# 3      ВНС    Б6      3.0
# 4      ВНС    Б6      4.0
# 5      ГРП    Б6      5.0
# 6      ВНС    Б6      6.0
#
# [75 rows x 11 columns]

# %%
we_here.reset_index(drop=True)
we_here.reset_index(inplace=True)

# %%
we_here.to_excel('googles.xlsx')
